# %%
import scipy
print(scipy.__version__)
# Out:
# 1.15.3

# %%
import torch
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os
import numpy as np
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim
from scipy.stats import jensenshannon
import kagglehub

# Verify scipy version
import scipy
print(f"Using scipy version: {scipy.__version__}")
if int(scipy.__version__.split('.')[1]) < 7:
    raise ImportError("scipy version must be >= 1.7.0 to use jensenshannon. Please upgrade scipy using 'pip install --upgrade scipy'.")

# Define paths
generated_base_dir = r"C:\Users\hp\Desktop\fedavg\generated_samples-arch-A5"
good_images_dir = r"C:\Users\hp\Desktop\fedavg\good_images-arch-A5"
os.makedirs(good_images_dir, exist_ok=True)

# Hyperparameters
RESIZE = 128
num_classes = 5
original_dim = RESIZE * RESIZE * 3

# Custom Dataset for Kaggle Vehicle Type Image Dataset
class VehicleTypeDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = []
        self.class_to_idx = {}
        self.images = []
        self.labels = []

        print(f"Searching for images in {root_dir}")
        for root, dirs, files in os.walk(root_dir):
            image_files = [f for f in files if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
            if image_files:
                class_name = os.path.basename(root)
                if class_name not in self.class_to_idx:
                    self.classes.append(class_name)
                    self.class_to_idx[class_name] = len(self.classes) - 1
                for img_file in image_files:
                    img_path = os.path.join(root, img_file)
                    try:
                        Image.open(img_path).verify()
                        self.images.append(img_path)
                        self.labels.append(self.class_to_idx[class_name])
                    except:
                        print(f"Skipping corrupted image: {img_path}")

        if len(self.classes) != num_classes:
            raise ValueError(f"Expected {num_classes} classes, found {len(self.classes)}")
        print(f"Found {len(self.images)} images across {len(self.classes)} classes.")
        print(f"Classes: {self.classes}")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        image = Image.open(img_path).convert('RGB')
        label = self.labels[idx]
        sample = {'image': image, 'label': label}
        if self.transform:
            sample['image'] = self.transform(sample['image'])
        return sample

# Load a subset of real images as references (5 per class)
transform = transforms.Compose([
    transforms.Resize((RESIZE, RESIZE)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

path = kagglehub.dataset_download("sujaykapadnis/vehicle-type-image-dataset")
dataset = VehicleTypeDataset(root_dir=path, transform=transform)

# Collect reference images (5 per class)
reference_images = {i: [] for i in range(num_classes)}
for sample in dataset:
    label = sample['label']
    if len(reference_images[label]) < 5:
        reference_images[label].append(sample['image'])
    if all(len(refs) >= 5 for refs in reference_images.values()):
        break

# Function to compute PSNR, SSIM, and JS divergence
def compute_metrics_for_image(orig, gen):
    # Convert tensors to numpy arrays and rescale to [0, 1]
    orig_np = orig.cpu().numpy() * 0.5 + 0.5  # Denormalize
    gen_np = gen.cpu().numpy() * 0.5 + 0.5    # Denormalize
    orig_np = np.transpose(orig_np, (1, 2, 0))  # (C, H, W) -> (H, W, C)
    gen_np = np.transpose(gen_np, (1, 2, 0))    # (C, H, W) -> (H, W, C)
    orig_np = np.clip(orig_np, 0, 1)
    gen_np = np.clip(gen_np, 0, 1)

    # Compute PSNR
    psnr_score = psnr(orig_np, gen_np, data_range=1.0)

    # Compute SSIM (multichannel=True for RGB images)
    ssim_score = ssim(orig_np, gen_np, multichannel=True, data_range=1.0, channel_axis=2)

    # Compute JS divergence per channel
    js_scores = []
    for c in range(3):  # For each RGB channel
        orig_channel = orig_np[:, :, c].flatten()
        gen_channel = gen_np[:, :, c].flatten()
        # Normalize to probability distributions
        orig_channel = (orig_channel + 1e-10) / (np.sum(orig_channel) + 1e-10 * RESIZE * RESIZE)
        gen_channel = (gen_channel + 1e-10) / (np.sum(gen_channel) + 1e-10 * RESIZE * RESIZE)
        js_score = jensenshannon(orig_channel, gen_channel)
        if np.isnan(js_score):
            js_score = 1.0  # Worst case if computation fails
        js_scores.append(js_score)
    js_score = np.mean(js_scores)

    return psnr_score, ssim_score, js_score

# Process generated images and compute metrics
metrics_dict = {i: [] for i in range(num_classes)}  # Store metrics for each class
good_images = {i: [] for i in range(num_classes)}   # Store good images for each class

for class_label in range(num_classes):
    class_dir = os.path.join(generated_base_dir, str(class_label))
    good_class_dir = os.path.join(good_images_dir, str(class_label))
    os.makedirs(good_class_dir, exist_ok=True)

    if not os.path.exists(class_dir):
        print(f"Class directory {class_dir} not found, skipping class {class_label}.")
        continue

    # Reference images for this class
    ref_images = reference_images[class_label]  # List of 5 reference tensors

    # Process each generated image
    idx = 0
    while idx < 100:  # Attempt to process up to 100 samples per class
        img_path = os.path.join(class_dir, f"sample_{idx}.png")
        if not os.path.exists(img_path):
            print(f"Image {img_path} not found, stopping at index {idx} for class {class_label}.")
            break

        # Load and preprocess the generated image
        try:
            gen_image = Image.open(img_path).convert('RGB')
            gen_tensor = transform(gen_image)
        except Exception as e:
            print(f"Error loading image {img_path}: {str(e)}")
            idx += 1
            continue

        # Compute metrics against each reference image and average
        psnr_scores, ssim_scores, js_scores = [], [], []
        for ref_tensor in ref_images:
            try:
                psnr_score, ssim_score, js_score = compute_metrics_for_image(ref_tensor, gen_tensor)
                psnr_scores.append(psnr_score)
                ssim_scores.append(ssim_score)
                js_scores.append(js_score)
            except Exception as e:
                print(f"Error computing metrics for image {img_path}: {str(e)}")
                psnr_scores.append(0.0)  # Worst case
                ssim_scores.append(0.0)  # Worst case
                js_scores.append(1.0)    # Worst case

        avg_psnr = np.mean(psnr_scores)
        avg_ssim = np.mean(ssim_scores)
        avg_js = np.mean(js_scores)

        metrics_dict[class_label].append({
            'image': f"sample_{idx}.png",
            'psnr': avg_psnr,
            'ssim': avg_ssim,
            'js': avg_js
        })

        # Check if the image meets the "good" criteria
        if avg_psnr > 30 and avg_ssim > 0.7 and avg_js < 0.3:
            # Save the good image to the new folder
            good_img_path = os.path.join(good_class_dir, f"sample_{idx}.png")
            gen_image.save(good_img_path)
            good_images[class_label].append(f"sample_{idx}.png")

        idx += 1

    print(f"\nClass {class_label} Metrics:")
    for metric in metrics_dict[class_label]:
        print(f"Image: {metric['image']}, PSNR: {metric['psnr']:.2f}, SSIM: {metric['ssim']:.4f}, JS: {metric['js']:.4f}")
    print(f"Good images for class {class_label}: {len(good_images[class_label])} images saved to {good_class_dir}")

# Summary of good images
total_good = sum(len(good_images[cls]) for cls in good_images)
print(f"\nTotal good images across all classes: {total_good}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 10
#       8 from skimage.metrics import peak_signal_noise_ratio as psnr
#       9 from skimage.metrics import structural_similarity as ssim
# ---> 10 from scipy.stats import jensenshannon
#      11 import kagglehub
#      13 # Verify scipy version
#
# ImportError: cannot import name 'jensenshannon' from 'scipy.stats' (C:\Users\hp\Desktop\New folder\Lib\site-packages\scipy\stats\__init__.py)

# %%
pip install --upgrade scipy
# Out:
# Requirement already satisfied: scipy in c:\users\hp\desktop\new folder\lib\site-packages (1.15.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy<2.5,>=1.23.5 in c:\users\hp\desktop\new folder\lib\site-packages (from scipy) (1.26.4)

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.15.3

# %%
import torch
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os
import numpy as np
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim
# Correct the import path for jensenshannon
from scipy.spatial.distance import jensenshannon
import kagglehub

# Verify scipy version - keep this check for good practice, though importing from spatial.distance
# is more robust across versions where the function might be in both or just spatial.distance.
import scipy
print(f"Using scipy version: {scipy.__version__}")
# The check for > 1.7 is relevant if you strictly wanted it in scipy.stats.
# Since we import from spatial.distance, any version >= 1.6.0 should work.
# Let's adjust the check to reflect the actual requirement for scipy.spatial.distance.jensenshannon
from pkg_resources import parse_version
if parse_version(scipy.__version__) < parse_version("1.6.0"):
     raise ImportError(f"scipy version must be >= 1.6.0 to use jensenshannon from scipy.spatial.distance. Please upgrade scipy using 'pip install --upgrade scipy'. Current version: {scipy.__version__}")


# Define paths
generated_base_dir = r"C:\Users\hp\Desktop\fedavg\generated_samples-arch-A5"
good_images_dir = r"C:\Users\hp\Desktop\fedavg\good_images-arch-A5"
os.makedirs(good_images_dir, exist_ok=True)

# Hyperparameters
RESIZE = 128
num_classes = 5
original_dim = RESIZE * RESIZE * 3

# Custom Dataset for Kaggle Vehicle Type Image Dataset
class VehicleTypeDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = []
        self.class_to_idx = {}
        self.images = []
        self.labels = []

        print(f"Searching for images in {root_dir}")
        for root, dirs, files in os.walk(root_dir):
            image_files = [f for f in files if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
            if image_files:
                class_name = os.path.basename(root)
                if class_name not in self.class_to_idx:
                    self.classes.append(class_name)
                    self.class_to_idx[class_name] = len(self.classes) - 1
                for img_file in image_files:
                    img_path = os.path.join(root, img_file)
                    try:
                        Image.open(img_path).verify()
                        self.images.append(img_path)
                        self.labels.append(self.class_to_idx[class_name])
                    except:
                        print(f"Skipping corrupted image: {img_path}")

        if len(self.classes) != num_classes:
            raise ValueError(f"Expected {num_classes} classes, found {len(self.classes)}")
        print(f"Found {len(self.images)} images across {len(self.classes)} classes.")
        print(f"Classes: {self.classes}")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        image = Image.open(img_path).convert('RGB')
        label = self.labels[idx]
        sample = {'image': image, 'label': label}
        if self.transform:
            sample['image'] = self.transform(sample['image'])
        return sample

# Load a subset of real images as references (5 per class)
transform = transforms.Compose([
    transforms.Resize((RESIZE, RESIZE)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

path = kagglehub.dataset_download("sujaykapadnis/vehicle-type-image-dataset")
dataset = VehicleTypeDataset(root_dir=path, transform=transform)

# Collect reference images (5 per class)
reference_images = {i: [] for i in range(num_classes)}
for sample in dataset:
    label = sample['label']
    if len(reference_images[label]) < 5:
        reference_images[label].append(sample['image'])
    if all(len(refs) >= 5 for refs in reference_images.values()):
        break

# Function to compute PSNR, SSIM, and JS divergence
def compute_metrics_for_image(orig, gen):
    # Convert tensors to numpy arrays and rescale to [0, 1]
    orig_np = orig.cpu().numpy() * 0.5 + 0.5  # Denormalize
    gen_np = gen.cpu().numpy() * 0.5 + 0.5    # Denormalize
    orig_np = np.transpose(orig_np, (1, 2, 0))  # (C, H, W) -> (H, W, C)
    gen_np = np.transpose(gen_np, (1, 2, 0))    # (C, H, W) -> (H, W, C)
    orig_np = np.clip(orig_np, 0, 1)
    gen_np = np.clip(gen_np, 0, 1)

    # Compute PSNR
    psnr_score = psnr(orig_np, gen_np, data_range=1.0)

    # Compute SSIM (multichannel=True for RGB images)
    ssim_score = ssim(orig_np, gen_np, multichannel=True, data_range=1.0, channel_axis=2)

    # Compute JS divergence per channel
    js_scores = []
    for c in range(3):  # For each RGB channel
        orig_channel = orig_np[:, :, c].flatten()
        gen_channel = gen_np[:, :, c].flatten()
        # Normalize to probability distributions
        orig_channel = (orig_channel + 1e-10) / (np.sum(orig_channel) + 1e-10 * RESIZE * RESIZE)
        gen_channel = (gen_channel + 1e-10) / (np.sum(gen_channel) + 1e-10 * RESIZE * RESIZE)
        js_score = jensenshannon(orig_channel, gen_channel)
        if np.isnan(js_score):
            js_score = 1.0  # Worst case if computation fails
        js_scores.append(js_score)
    js_score = np.mean(js_scores)

    return psnr_score, ssim_score, js_score

# Process generated images and compute metrics
metrics_dict = {i: [] for i in range(num_classes)}  # Store metrics for each class
good_images = {i: [] for i in range(num_classes)}   # Store good images for each class

for class_label in range(num_classes):
    class_dir = os.path.join(generated_base_dir, str(class_label))
    good_class_dir = os.path.join(good_images_dir, str(class_label))
    os.makedirs(good_class_dir, exist_ok=True)

    if not os.path.exists(class_dir):
        print(f"Class directory {class_dir} not found, skipping class {class_label}.")
        continue

    # Reference images for this class
    ref_images = reference_images[class_label]  # List of 5 reference tensors

    # Process each generated image
    idx = 0
    while idx < 100:  # Attempt to process up to 100 samples per class
        img_path = os.path.join(class_dir, f"sample_{idx}.png")
        if not os.path.exists(img_path):
            print(f"Image {img_path} not found, stopping at index {idx} for class {class_label}.")
            break

        # Load and preprocess the generated image
        try:
            gen_image = Image.open(img_path).convert('RGB')
            gen_tensor = transform(gen_image)
        except Exception as e:
            print(f"Error loading image {img_path}: {str(e)}")
            idx += 1
            continue

        # Compute metrics against each reference image and average
        psnr_scores, ssim_scores, js_scores = [], [], []
        for ref_tensor in ref_images:
            try:
                psnr_score, ssim_score, js_score = compute_metrics_for_image(ref_tensor, gen_tensor)
                psnr_scores.append(psnr_score)
                ssim_scores.append(ssim_score)
                js_scores.append(js_score)
            except Exception as e:
                print(f"Error computing metrics for image {img_path}: {str(e)}")
                psnr_scores.append(0.0)  # Worst case
                ssim_scores.append(0.0)  # Worst case
                js_scores.append(1.0)    # Worst case

        avg_psnr = np.mean(psnr_scores)
        avg_ssim = np.mean(ssim_scores)
        avg_js = np.mean(js_scores)

        metrics_dict[class_label].append({
            'image': f"sample_{idx}.png",
            'psnr': avg_psnr,
            'ssim': avg_ssim,
            'js': avg_js
        })

        # Check if the image meets the "good" criteria
        if avg_psnr > 11.8 and avg_ssim > 0.19 and avg_js < 0.24:
            # Save the good image to the new folder
            good_img_path = os.path.join(good_class_dir, f"sample_{idx}.png")
            gen_image.save(good_img_path)
            good_images[class_label].append(f"sample_{idx}.png")

        idx += 1

    print(f"\nClass {class_label} Metrics:")
    for metric in metrics_dict[class_label]:
        print(f"Image: {metric['image']}, PSNR: {metric['psnr']:.2f}, SSIM: {metric['ssim']:.4f}, JS: {metric['js']:.4f}")
    print(f"Good images for class {class_label}: {len(good_images[class_label])} images saved to {good_class_dir}")

# Summary of good images
total_good = sum(len(good_images[cls]) for cls in good_images)
print(f"\nTotal good images across all classes: {total_good}")
# Out:
# Using scipy version: 1.15.3
# Searching for images in C:\Users\hp\.cache\kagglehub\datasets\sujaykapadnis\vehicle-type-image-dataset\versions\1
# Found 4793 images across 5 classes.
# Classes: ['Hatchback', 'Other', 'Pickup', 'Seden', 'SUV']
#
# Class 0 Metrics:
# Image: sample_0.png, PSNR: 11.93, SSIM: 0.1640, JS: 0.2541
# Image: sample_1.png, PSNR: 10.80, SSIM: 0.1612, JS: 0.2956
# Image: sample_2.png, PSNR: 10.92, SSIM: 0.1493, JS: 0.2460
# Image: sample_3.png, PSNR: 11.50, SSIM: 0.2208, JS: 0.2346
# Image: sample_4.png, PSNR: 12.32, SSIM: 0.1646, JS: 0.2506
# Image: sample_5.png, PSNR: 12.13, SSIM: 0.1911, JS: 0.2549
# Image: sample_6.png, PSNR: 11.24, SSIM: 0.1623, JS: 0.2438
# Image: sample_7.png, PSNR: 12.06, SSIM: 0.2141, JS: 0.2492
# Image: sample_8.png, PSNR: 10.21, SSIM: 0.1236, JS: 0.3296
# Image: sample_9.png, PSNR: 9.25, SSIM: 0.1064, JS: 0.2737
# Image: sample_10.png, PSNR: 10.65, SSIM: 0.1652, JS: 0.2691
# Image: sample_11.png, PSNR: 11.34, SSIM: 0.1956, JS: 0.2737
# Image: sample_12.png, PSNR: 10.19, SSIM: 0.1409, JS: 0.2436
# Image: sample_13.png, PSNR: 10.72, SSIM: 0.1169, JS: 0.2749
# Image: sample_14.png, PSNR: 11.92, SSIM: 0.1634, JS: 0.2613
# Image: sample_15.png, PSNR: 11.12, SSIM: 0.1277, JS: 0.2719
# Image: sample_16.png, PSNR: 9.67, SSIM: 0.1409, JS: 0.3042
# Image: sample_17.png, PSNR: 10.18, SSIM: 0.0857, JS: 0.2803
# Image: sample_18.png, PSNR: 8.94, SSIM: 0.1025, JS: 0.3059
# Image: sample_19.png, PSNR: 11.24, SSIM: 0.1283, JS: 0.2828
# Image: sample_20.png, PSNR: 10.28, SSIM: 0.1602, JS: 0.2546
# Image: sample_21.png, PSNR: 10.18, SSIM: 0.1462, JS: 0.3441
# Image: sample_22.png, PSNR: 12.03, SSIM: 0.1598, JS: 0.2591
# Image: sample_23.png, PSNR: 10.79, SSIM: 0.1579, JS: 0.2573
# Image: sample_24.png, PSNR: 12.06, SSIM: 0.2022, JS: 0.2456
# Image: sample_25.png, PSNR: 10.72, SSIM: 0.1179, JS: 0.2952
# Image: sample_26.png, PSNR: 7.20, SSIM: 0.0595, JS: 0.2921
# Image: sample_27.png, PSNR: 11.78, SSIM: 0.1804, JS: 0.2550
# Image: sample_28.png, PSNR: 9.83, SSIM: 0.1021, JS: 0.2569
# Image: sample_29.png, PSNR: 9.50, SSIM: 0.0956, JS: 0.2862
# Image: sample_30.png, PSNR: 9.31, SSIM: 0.1033, JS: 0.2609
# Image: sample_31.png, PSNR: 8.49, SSIM: 0.0861, JS: 0.2856
# Image: sample_32.png, PSNR: 10.01, SSIM: 0.1212, JS: 0.2885
# Image: sample_33.png, PSNR: 9.87, SSIM: 0.1303, JS: 0.2910
# Image: sample_34.png, PSNR: 9.47, SSIM: 0.0906, JS: 0.2525
# Image: sample_35.png, PSNR: 9.92, SSIM: 0.0804, JS: 0.2539
# Image: sample_36.png, PSNR: 10.68, SSIM: 0.1214, JS: 0.2974
# Image: sample_37.png, PSNR: 11.54, SSIM: 0.1898, JS: 0.2363
# Image: sample_38.png, PSNR: 11.13, SSIM: 0.1196, JS: 0.2705
# Image: sample_39.png, PSNR: 11.15, SSIM: 0.1848, JS: 0.2781
# Image: sample_40.png, PSNR: 9.42, SSIM: 0.1261, JS: 0.3070
# Image: sample_41.png, PSNR: 11.77, SSIM: 0.1603, JS: 0.2591
# Image: sample_42.png, PSNR: 11.87, SSIM: 0.1954, JS: 0.2608
# Image: sample_43.png, PSNR: 9.05, SSIM: 0.0693, JS: 0.2765
# Image: sample_44.png, PSNR: 9.92, SSIM: 0.1043, JS: 0.2864
# Image: sample_45.png, PSNR: 12.28, SSIM: 0.2017, JS: 0.2617
# Image: sample_46.png, PSNR: 11.35, SSIM: 0.1151, JS: 0.2486
# Image: sample_47.png, PSNR: 9.67, SSIM: 0.1082, JS: 0.3493
# Image: sample_48.png, PSNR: 10.70, SSIM: 0.1604, JS: 0.2979
# Image: sample_49.png, PSNR: 10.37, SSIM: 0.1082, JS: 0.2682
# Image: sample_50.png, PSNR: 11.93, SSIM: 0.1821, JS: 0.2611
# Image: sample_51.png, PSNR: 10.57, SSIM: 0.1173, JS: 0.3043
# Image: sample_52.png, PSNR: 8.13, SSIM: 0.0654, JS: 0.2621
# Image: sample_53.png, PSNR: 11.42, SSIM: 0.1696, JS: 0.2732
# Image: sample_54.png, PSNR: 10.52, SSIM: 0.1133, JS: 0.3031
# Image: sample_55.png, PSNR: 9.13, SSIM: 0.0878, JS: 0.2800
# Image: sample_56.png, PSNR: 11.21, SSIM: 0.1712, JS: 0.2534
# Image: sample_57.png, PSNR: 9.97, SSIM: 0.1066, JS: 0.3353
# Image: sample_58.png, PSNR: 10.55, SSIM: 0.1342, JS: 0.3089
# Image: sample_59.png, PSNR: 10.50, SSIM: 0.1404, JS: 0.3254
# Image: sample_60.png, PSNR: 11.45, SSIM: 0.1986, JS: 0.2611
# Image: sample_61.png, PSNR: 9.47, SSIM: 0.0932, JS: 0.2573
# Image: sample_62.png, PSNR: 12.02, SSIM: 0.1781, JS: 0.2462
# Image: sample_63.png, PSNR: 11.93, SSIM: 0.1640, JS: 0.2639
# Image: sample_64.png, PSNR: 10.37, SSIM: 0.1493, JS: 0.3210
# Image: sample_65.png, PSNR: 7.49, SSIM: 0.0522, JS: 0.2602
# Image: sample_66.png, PSNR: 10.56, SSIM: 0.1430, JS: 0.3125
# Image: sample_67.png, PSNR: 11.55, SSIM: 0.1797, JS: 0.2524
# Image: sample_68.png, PSNR: 10.50, SSIM: 0.1397, JS: 0.3149
# Image: sample_69.png, PSNR: 11.95, SSIM: 0.2024, JS: 0.2367
# Image: sample_70.png, PSNR: 10.16, SSIM: 0.1237, JS: 0.3003
# Image: sample_71.png, PSNR: 10.67, SSIM: 0.1195, JS: 0.3042
# Image: sample_72.png, PSNR: 8.68, SSIM: 0.0569, JS: 0.3236
# Image: sample_73.png, PSNR: 8.24, SSIM: 0.0699, JS: 0.2874
# Image: sample_74.png, PSNR: 10.21, SSIM: 0.1154, JS: 0.3377
# Image: sample_75.png, PSNR: 11.24, SSIM: 0.1681, JS: 0.2666
# Image: sample_76.png, PSNR: 11.85, SSIM: 0.1510, JS: 0.2401
# Image: sample_77.png, PSNR: 10.86, SSIM: 0.1705, JS: 0.2907
# Image: sample_78.png, PSNR: 10.66, SSIM: 0.1280, JS: 0.3090
# Image: sample_79.png, PSNR: 10.94, SSIM: 0.1299, JS: 0.2853
# Image: sample_80.png, PSNR: 8.42, SSIM: 0.0577, JS: 0.2793
# Image: sample_81.png, PSNR: 8.79, SSIM: 0.0836, JS: 0.2769
# Image: sample_82.png, PSNR: 10.10, SSIM: 0.1113, JS: 0.3261
# Image: sample_83.png, PSNR: 10.75, SSIM: 0.1318, JS: 0.2621
# Image: sample_84.png, PSNR: 11.57, SSIM: 0.2212, JS: 0.2687
# Image: sample_85.png, PSNR: 12.33, SSIM: 0.1917, JS: 0.2547
# Image: sample_86.png, PSNR: 10.10, SSIM: 0.1099, JS: 0.3182
# Image: sample_87.png, PSNR: 12.48, SSIM: 0.1788, JS: 0.2439
# Image: sample_88.png, PSNR: 10.49, SSIM: 0.1379, JS: 0.2602
# Image: sample_89.png, PSNR: 11.12, SSIM: 0.1221, JS: 0.2771
# Image: sample_90.png, PSNR: 9.22, SSIM: 0.0899, JS: 0.3109
# Image: sample_91.png, PSNR: 9.13, SSIM: 0.1111, JS: 0.2735
# Image: sample_92.png, PSNR: 9.43, SSIM: 0.1318, JS: 0.3116
# Image: sample_93.png, PSNR: 10.37, SSIM: 0.1179, JS: 0.3187
# Image: sample_94.png, PSNR: 10.44, SSIM: 0.0780, JS: 0.2784
# Image: sample_95.png, PSNR: 11.65, SSIM: 0.1682, JS: 0.2500
# Image: sample_96.png, PSNR: 11.85, SSIM: 0.2091, JS: 0.2561
# Image: sample_97.png, PSNR: 12.18, SSIM: 0.1856, JS: 0.2340
# Image: sample_98.png, PSNR: 11.28, SSIM: 0.1477, JS: 0.2671
# Image: sample_99.png, PSNR: 12.02, SSIM: 0.1678, JS: 0.2618
# Good images for class 0: 1 images saved to C:\Users\hp\Desktop\fedavg\good_images-arch-A5\0
#
# Class 1 Metrics:
# Image: sample_0.png, PSNR: 11.66, SSIM: 0.0965, JS: 0.2622
# Image: sample_1.png, PSNR: 12.12, SSIM: 0.1011, JS: 0.2326
# Image: sample_2.png, PSNR: 11.07, SSIM: 0.1139, JS: 0.2557
# Image: sample_3.png, PSNR: 12.75, SSIM: 0.1810, JS: 0.2295
# Image: sample_4.png, PSNR: 10.66, SSIM: 0.1187, JS: 0.3056
# Image: sample_5.png, PSNR: 12.72, SSIM: 0.1870, JS: 0.2292
# Image: sample_6.png, PSNR: 12.12, SSIM: 0.2090, JS: 0.2614
# Image: sample_7.png, PSNR: 12.70, SSIM: 0.1929, JS: 0.2329
# Image: sample_8.png, PSNR: 12.68, SSIM: 0.2168, JS: 0.2356
# Image: sample_9.png, PSNR: 11.67, SSIM: 0.1206, JS: 0.2658
# Image: sample_10.png, PSNR: 12.89, SSIM: 0.1744, JS: 0.2231
# Image: sample_11.png, PSNR: 12.70, SSIM: 0.2088, JS: 0.2389
# Image: sample_12.png, PSNR: 12.33, SSIM: 0.1602, JS: 0.2390
# Image: sample_13.png, PSNR: 12.61, SSIM: 0.1462, JS: 0.2393
# Image: sample_14.png, PSNR: 12.20, SSIM: 0.1748, JS: 0.2465
# Image: sample_15.png, PSNR: 11.82, SSIM: 0.1572, JS: 0.2656
# Image: sample_16.png, PSNR: 11.33, SSIM: 0.1379, JS: 0.2869
# Image: sample_17.png, PSNR: 11.33, SSIM: 0.1136, JS: 0.2771
# Image: sample_18.png, PSNR: 12.64, SSIM: 0.1373, JS: 0.2127
# Image: sample_19.png, PSNR: 11.78, SSIM: 0.1382, JS: 0.2584
# Image: sample_20.png, PSNR: 12.74, SSIM: 0.1927, JS: 0.2333
# Image: sample_21.png, PSNR: 12.22, SSIM: 0.1920, JS: 0.2522
# Image: sample_22.png, PSNR: 12.34, SSIM: 0.1690, JS: 0.2506
# Image: sample_23.png, PSNR: 12.73, SSIM: 0.2101, JS: 0.2392
# Image: sample_24.png, PSNR: 12.64, SSIM: 0.1942, JS: 0.2291
# Image: sample_25.png, PSNR: 11.96, SSIM: 0.1537, JS: 0.2552
# Image: sample_26.png, PSNR: 12.82, SSIM: 0.1432, JS: 0.2211
# Image: sample_27.png, PSNR: 10.76, SSIM: 0.0962, JS: 0.2555
# Image: sample_28.png, PSNR: 11.78, SSIM: 0.1185, JS: 0.2668
# Image: sample_29.png, PSNR: 11.79, SSIM: 0.0875, JS: 0.2612
# Image: sample_30.png, PSNR: 11.47, SSIM: 0.0979, JS: 0.2538
# Image: sample_31.png, PSNR: 12.39, SSIM: 0.2004, JS: 0.2542
# Image: sample_32.png, PSNR: 10.68, SSIM: 0.1138, JS: 0.2820
# Image: sample_33.png, PSNR: 11.36, SSIM: 0.0844, JS: 0.2553
# Image: sample_34.png, PSNR: 12.57, SSIM: 0.1744, JS: 0.2377
# Image: sample_35.png, PSNR: 11.85, SSIM: 0.1728, JS: 0.2522
# Image: sample_36.png, PSNR: 12.43, SSIM: 0.1177, JS: 0.2324
# Image: sample_37.png, PSNR: 12.77, SSIM: 0.1272, JS: 0.2288
# Image: sample_38.png, PSNR: 12.74, SSIM: 0.1120, JS: 0.2242
# Image: sample_39.png, PSNR: 12.47, SSIM: 0.1629, JS: 0.2394
# Image: sample_40.png, PSNR: 12.64, SSIM: 0.1425, JS: 0.2211
# Image: sample_41.png, PSNR: 13.01, SSIM: 0.2020, JS: 0.2304
# Image: sample_42.png, PSNR: 11.09, SSIM: 0.1183, JS: 0.2925
# Image: sample_43.png, PSNR: 12.71, SSIM: 0.1910, JS: 0.2312
# Image: sample_44.png, PSNR: 11.60, SSIM: 0.1943, JS: 0.2802
# Image: sample_45.png, PSNR: 11.01, SSIM: 0.1376, JS: 0.2904
# Image: sample_46.png, PSNR: 11.67, SSIM: 0.1721, JS: 0.2563
# Image: sample_47.png, PSNR: 12.04, SSIM: 0.1525, JS: 0.2612
# Image: sample_48.png, PSNR: 12.11, SSIM: 0.1485, JS: 0.2529
# Image: sample_49.png, PSNR: 12.08, SSIM: 0.1218, JS: 0.2323
# Image: sample_50.png, PSNR: 11.62, SSIM: 0.1310, JS: 0.2536
# Image: sample_51.png, PSNR: 12.32, SSIM: 0.1778, JS: 0.2511
# Image: sample_52.png, PSNR: 11.96, SSIM: 0.1560, JS: 0.2569
# Image: sample_53.png, PSNR: 11.28, SSIM: 0.1372, JS: 0.2881
# Image: sample_54.png, PSNR: 12.60, SSIM: 0.2096, JS: 0.2403
# Image: sample_55.png, PSNR: 11.43, SSIM: 0.1468, JS: 0.2829
# Image: sample_56.png, PSNR: 12.36, SSIM: 0.1048, JS: 0.2445
# Image: sample_57.png, PSNR: 11.16, SSIM: 0.1566, JS: 0.2901
# Image: sample_58.png, PSNR: 11.59, SSIM: 0.1892, JS: 0.2742
# Image: sample_59.png, PSNR: 11.48, SSIM: 0.1587, JS: 0.2723
# Image: sample_60.png, PSNR: 11.96, SSIM: 0.1932, JS: 0.2682
# Image: sample_61.png, PSNR: 11.19, SSIM: 0.1095, JS: 0.2823
# Image: sample_62.png, PSNR: 11.71, SSIM: 0.1740, JS: 0.2632
# Image: sample_63.png, PSNR: 12.36, SSIM: 0.1759, JS: 0.2495
# Image: sample_64.png, PSNR: 12.21, SSIM: 0.2316, JS: 0.2585
# Image: sample_65.png, PSNR: 12.34, SSIM: 0.1735, JS: 0.2465
# Image: sample_66.png, PSNR: 12.17, SSIM: 0.1714, JS: 0.2529
# Image: sample_67.png, PSNR: 8.90, SSIM: 0.0745, JS: 0.2712
# Image: sample_68.png, PSNR: 12.27, SSIM: 0.1711, JS: 0.2402
# Image: sample_69.png, PSNR: 11.66, SSIM: 0.1364, JS: 0.2466
# Image: sample_70.png, PSNR: 12.08, SSIM: 0.1552, JS: 0.2522
# Image: sample_71.png, PSNR: 12.05, SSIM: 0.1256, JS: 0.2577
# Image: sample_72.png, PSNR: 9.99, SSIM: 0.0777, JS: 0.2595
# Image: sample_73.png, PSNR: 12.46, SSIM: 0.1590, JS: 0.2458
# Image: sample_74.png, PSNR: 11.52, SSIM: 0.1530, JS: 0.2778
# Image: sample_75.png, PSNR: 11.56, SSIM: 0.1533, JS: 0.2732
# Image: sample_76.png, PSNR: 11.68, SSIM: 0.1676, JS: 0.2702
# Image: sample_77.png, PSNR: 12.15, SSIM: 0.2178, JS: 0.2567
# Image: sample_78.png, PSNR: 11.36, SSIM: 0.1646, JS: 0.2772
# Image: sample_79.png, PSNR: 11.60, SSIM: 0.1156, JS: 0.2567
# Image: sample_80.png, PSNR: 12.26, SSIM: 0.1713, JS: 0.2536
# Image: sample_81.png, PSNR: 10.19, SSIM: 0.0958, JS: 0.2824
# Image: sample_82.png, PSNR: 12.16, SSIM: 0.1772, JS: 0.2481
# Image: sample_83.png, PSNR: 10.63, SSIM: 0.1156, JS: 0.2430
# Image: sample_84.png, PSNR: 11.47, SSIM: 0.1111, JS: 0.2623
# Image: sample_85.png, PSNR: 12.49, SSIM: 0.1691, JS: 0.2431
# Image: sample_86.png, PSNR: 13.18, SSIM: 0.1977, JS: 0.2186
# Image: sample_87.png, PSNR: 11.66, SSIM: 0.1399, JS: 0.2679
# Image: sample_88.png, PSNR: 12.53, SSIM: 0.1919, JS: 0.2425
# Image: sample_89.png, PSNR: 11.15, SSIM: 0.1177, JS: 0.2574
# Image: sample_90.png, PSNR: 11.32, SSIM: 0.1589, JS: 0.2810
# Image: sample_91.png, PSNR: 12.68, SSIM: 0.1641, JS: 0.2328
# Image: sample_92.png, PSNR: 11.35, SSIM: 0.1355, JS: 0.2838
# Image: sample_93.png, PSNR: 8.77, SSIM: 0.0622, JS: 0.2976
# Image: sample_94.png, PSNR: 12.02, SSIM: 0.1573, JS: 0.2575
# Image: sample_95.png, PSNR: 12.23, SSIM: 0.1503, JS: 0.2493
# Image: sample_96.png, PSNR: 11.67, SSIM: 0.2026, JS: 0.2800
# Image: sample_97.png, PSNR: 12.22, SSIM: 0.1403, JS: 0.2466
# Image: sample_98.png, PSNR: 11.85, SSIM: 0.1835, JS: 0.2683
# Image: sample_99.png, PSNR: 12.78, SSIM: 0.1415, JS: 0.2302
# Good images for class 1: 9 images saved to C:\Users\hp\Desktop\fedavg\good_images-arch-A5\1
#
# Class 2 Metrics:
# Image: sample_0.png, PSNR: 10.31, SSIM: 0.0679, JS: 0.2639
# Image: sample_1.png, PSNR: 10.35, SSIM: 0.0702, JS: 0.2655
# Image: sample_2.png, PSNR: 9.98, SSIM: 0.0745, JS: 0.2861
# Image: sample_3.png, PSNR: 11.48, SSIM: 0.1092, JS: 0.2370
# Image: sample_4.png, PSNR: 11.29, SSIM: 0.1753, JS: 0.2459
# Image: sample_5.png, PSNR: 10.73, SSIM: 0.1094, JS: 0.2656
# Image: sample_6.png, PSNR: 9.77, SSIM: 0.0766, JS: 0.3114
# Image: sample_7.png, PSNR: 10.42, SSIM: 0.0943, JS: 0.2903
# Image: sample_8.png, PSNR: 10.41, SSIM: 0.0753, JS: 0.2855
# Image: sample_9.png, PSNR: 10.52, SSIM: 0.0966, JS: 0.2733
# Image: sample_10.png, PSNR: 10.69, SSIM: 0.1004, JS: 0.2751
# Image: sample_11.png, PSNR: 10.80, SSIM: 0.0552, JS: 0.2516
# Image: sample_12.png, PSNR: 10.89, SSIM: 0.1093, JS: 0.2646
# Image: sample_13.png, PSNR: 10.28, SSIM: 0.0881, JS: 0.2928
# Image: sample_14.png, PSNR: 10.44, SSIM: 0.1604, JS: 0.2742
# Image: sample_15.png, PSNR: 10.08, SSIM: 0.1205, JS: 0.3052
# Image: sample_16.png, PSNR: 11.24, SSIM: 0.1257, JS: 0.2240
# Image: sample_17.png, PSNR: 11.63, SSIM: 0.1642, JS: 0.2448
# Image: sample_18.png, PSNR: 10.46, SSIM: 0.1021, JS: 0.2908
# Image: sample_19.png, PSNR: 11.08, SSIM: 0.1179, JS: 0.2588
# Image: sample_20.png, PSNR: 10.48, SSIM: 0.1119, JS: 0.2832
# Image: sample_21.png, PSNR: 9.65, SSIM: 0.0629, JS: 0.2600
# Image: sample_22.png, PSNR: 11.05, SSIM: 0.1120, JS: 0.2629
# Image: sample_23.png, PSNR: 12.68, SSIM: 0.2147, JS: 0.2235
# Image: sample_24.png, PSNR: 10.11, SSIM: 0.0811, JS: 0.2974
# Image: sample_25.png, PSNR: 10.14, SSIM: 0.0936, JS: 0.2996
# Image: sample_26.png, PSNR: 9.83, SSIM: 0.0534, JS: 0.2739
# Image: sample_27.png, PSNR: 9.81, SSIM: 0.0758, JS: 0.3205
# Image: sample_28.png, PSNR: 9.98, SSIM: 0.0842, JS: 0.3067
# Image: sample_29.png, PSNR: 10.59, SSIM: 0.1148, JS: 0.2899
# Image: sample_30.png, PSNR: 14.11, SSIM: 0.2807, JS: 0.2220
# Image: sample_31.png, PSNR: 12.43, SSIM: 0.1996, JS: 0.2303
# Image: sample_32.png, PSNR: 9.81, SSIM: 0.0973, JS: 0.3185
# Image: sample_33.png, PSNR: 10.15, SSIM: 0.1198, JS: 0.2991
# Image: sample_34.png, PSNR: 10.79, SSIM: 0.1168, JS: 0.2720
# Image: sample_35.png, PSNR: 10.64, SSIM: 0.1124, JS: 0.2808
# Image: sample_36.png, PSNR: 9.93, SSIM: 0.0780, JS: 0.2624
# Image: sample_37.png, PSNR: 9.68, SSIM: 0.0891, JS: 0.3137
# Image: sample_38.png, PSNR: 9.62, SSIM: 0.0785, JS: 0.3225
# Image: sample_39.png, PSNR: 11.15, SSIM: 0.1061, JS: 0.2511
# Image: sample_40.png, PSNR: 10.81, SSIM: 0.0840, JS: 0.2645
# Image: sample_41.png, PSNR: 10.90, SSIM: 0.0937, JS: 0.2774
# Image: sample_42.png, PSNR: 10.30, SSIM: 0.0737, JS: 0.2910
# Image: sample_43.png, PSNR: 11.25, SSIM: 0.0876, JS: 0.2366
# Image: sample_44.png, PSNR: 10.35, SSIM: 0.0962, JS: 0.2850
# Image: sample_45.png, PSNR: 11.13, SSIM: 0.1378, JS: 0.2623
# Image: sample_46.png, PSNR: 10.50, SSIM: 0.0945, JS: 0.2748
# Image: sample_47.png, PSNR: 9.76, SSIM: 0.0655, JS: 0.3073
# Image: sample_48.png, PSNR: 10.45, SSIM: 0.1280, JS: 0.2904
# Image: sample_49.png, PSNR: 11.08, SSIM: 0.1535, JS: 0.2581
# Image: sample_50.png, PSNR: 10.79, SSIM: 0.0998, JS: 0.2742
# Image: sample_51.png, PSNR: 10.36, SSIM: 0.1296, JS: 0.2805
# Image: sample_52.png, PSNR: 8.80, SSIM: 0.0615, JS: 0.2939
# Image: sample_53.png, PSNR: 8.85, SSIM: 0.0499, JS: 0.2539
# Image: sample_54.png, PSNR: 9.70, SSIM: 0.0723, JS: 0.2971
# Image: sample_55.png, PSNR: 9.16, SSIM: 0.0533, JS: 0.2861
# Image: sample_56.png, PSNR: 9.85, SSIM: 0.0742, JS: 0.3084
# Image: sample_57.png, PSNR: 10.46, SSIM: 0.1113, JS: 0.2785
# Image: sample_58.png, PSNR: 10.19, SSIM: 0.0726, JS: 0.3019
# Image: sample_59.png, PSNR: 9.85, SSIM: 0.1293, JS: 0.3007
# Image: sample_60.png, PSNR: 12.23, SSIM: 0.1620, JS: 0.2328
# Image: sample_61.png, PSNR: 10.99, SSIM: 0.0948, JS: 0.2697
# Image: sample_62.png, PSNR: 11.38, SSIM: 0.1272, JS: 0.2604
# Image: sample_63.png, PSNR: 10.64, SSIM: 0.0987, JS: 0.2841
# Image: sample_64.png, PSNR: 11.18, SSIM: 0.1074, JS: 0.2579
# Image: sample_65.png, PSNR: 10.86, SSIM: 0.0777, JS: 0.2635
# Image: sample_66.png, PSNR: 10.42, SSIM: 0.1074, JS: 0.2915
# Image: sample_67.png, PSNR: 9.13, SSIM: 0.0569, JS: 0.2805
# Image: sample_68.png, PSNR: 10.15, SSIM: 0.0966, JS: 0.3014
# Image: sample_69.png, PSNR: 9.06, SSIM: 0.0675, JS: 0.2668
# Image: sample_70.png, PSNR: 11.12, SSIM: 0.0957, JS: 0.2628
# Image: sample_71.png, PSNR: 9.58, SSIM: 0.0896, JS: 0.3286
# Image: sample_72.png, PSNR: 11.47, SSIM: 0.0719, JS: 0.2506
# Image: sample_73.png, PSNR: 11.03, SSIM: 0.1079, JS: 0.2606
# Image: sample_74.png, PSNR: 10.84, SSIM: 0.1250, JS: 0.2757
# Image: sample_75.png, PSNR: 11.06, SSIM: 0.1332, JS: 0.2588
# Image: sample_76.png, PSNR: 11.33, SSIM: 0.0998, JS: 0.2581
# Image: sample_77.png, PSNR: 10.52, SSIM: 0.0921, JS: 0.2960
# Image: sample_78.png, PSNR: 9.83, SSIM: 0.0831, JS: 0.2976
# Image: sample_79.png, PSNR: 10.90, SSIM: 0.0765, JS: 0.2728
# Image: sample_80.png, PSNR: 10.44, SSIM: 0.0776, JS: 0.2712
# Image: sample_81.png, PSNR: 10.68, SSIM: 0.0890, JS: 0.2808
# Image: sample_82.png, PSNR: 9.82, SSIM: 0.1027, JS: 0.3191
# Image: sample_83.png, PSNR: 11.37, SSIM: 0.1135, JS: 0.2398
# Image: sample_84.png, PSNR: 10.97, SSIM: 0.1232, JS: 0.2647
# Image: sample_85.png, PSNR: 10.11, SSIM: 0.0650, JS: 0.3014
# Image: sample_86.png, PSNR: 10.59, SSIM: 0.1215, JS: 0.2807
# Image: sample_87.png, PSNR: 10.12, SSIM: 0.0681, JS: 0.3000
# Image: sample_88.png, PSNR: 9.81, SSIM: 0.0689, JS: 0.3155
# Image: sample_89.png, PSNR: 10.15, SSIM: 0.0801, JS: 0.2850
# Image: sample_90.png, PSNR: 9.65, SSIM: 0.1153, JS: 0.2826
# Image: sample_91.png, PSNR: 10.47, SSIM: 0.1035, JS: 0.2902
# Image: sample_92.png, PSNR: 10.14, SSIM: 0.0716, JS: 0.2896
# Image: sample_93.png, PSNR: 10.26, SSIM: 0.1105, JS: 0.2961
# Image: sample_94.png, PSNR: 10.66, SSIM: 0.1162, JS: 0.2827
# Image: sample_95.png, PSNR: 11.34, SSIM: 0.1709, JS: 0.2576
# Image: sample_96.png, PSNR: 10.35, SSIM: 0.1162, JS: 0.2757
# Image: sample_97.png, PSNR: 9.94, SSIM: 0.1222, JS: 0.2699
# Image: sample_98.png, PSNR: 9.82, SSIM: 0.1245, JS: 0.2600
# Image: sample_99.png, PSNR: 10.86, SSIM: 0.1317, JS: 0.2685
# Good images for class 2: 3 images saved to C:\Users\hp\Desktop\fedavg\good_images-arch-A5\2
#
# Class 3 Metrics:
# Image: sample_0.png, PSNR: 10.01, SSIM: 0.1606, JS: 0.2854
# Image: sample_1.png, PSNR: 12.16, SSIM: 0.2292, JS: 0.2071
# Image: sample_2.png, PSNR: 9.79, SSIM: 0.1239, JS: 0.3179
# Image: sample_3.png, PSNR: 9.33, SSIM: 0.1448, JS: 0.3103
# Image: sample_4.png, PSNR: 13.48, SSIM: 0.2969, JS: 0.1883
# Image: sample_5.png, PSNR: 9.82, SSIM: 0.0962, JS: 0.2657
# Image: sample_6.png, PSNR: 8.24, SSIM: 0.1228, JS: 0.3209
# Image: sample_7.png, PSNR: 10.05, SSIM: 0.1438, JS: 0.3022
# Image: sample_8.png, PSNR: 11.12, SSIM: 0.1010, JS: 0.2529
# Image: sample_9.png, PSNR: 8.09, SSIM: 0.0395, JS: 0.2849
# Image: sample_10.png, PSNR: 10.39, SSIM: 0.1442, JS: 0.2957
# Image: sample_11.png, PSNR: 8.90, SSIM: 0.0772, JS: 0.2981
# Image: sample_12.png, PSNR: 11.85, SSIM: 0.2250, JS: 0.2339
# Image: sample_13.png, PSNR: 11.30, SSIM: 0.1961, JS: 0.2288
# Image: sample_14.png, PSNR: 13.05, SSIM: 0.2528, JS: 0.1971
# Image: sample_15.png, PSNR: 11.25, SSIM: 0.1883, JS: 0.2364
# Image: sample_16.png, PSNR: 8.85, SSIM: 0.0728, JS: 0.2836
# Image: sample_17.png, PSNR: 12.95, SSIM: 0.1982, JS: 0.2035
# Image: sample_18.png, PSNR: 13.19, SSIM: 0.2575, JS: 0.1886
# Image: sample_19.png, PSNR: 10.07, SSIM: 0.1433, JS: 0.3042
# Image: sample_20.png, PSNR: 12.11, SSIM: 0.1920, JS: 0.2274
# Image: sample_21.png, PSNR: 8.62, SSIM: 0.0680, JS: 0.2857
# Image: sample_22.png, PSNR: 8.69, SSIM: 0.0660, JS: 0.3554
# Image: sample_23.png, PSNR: 9.72, SSIM: 0.1410, JS: 0.2967
# Image: sample_24.png, PSNR: 9.90, SSIM: 0.0800, JS: 0.2718
# Image: sample_25.png, PSNR: 9.55, SSIM: 0.1476, JS: 0.2875
# Image: sample_26.png, PSNR: 8.77, SSIM: 0.0911, JS: 0.2721
# Image: sample_27.png, PSNR: 10.81, SSIM: 0.1122, JS: 0.2249
# Image: sample_28.png, PSNR: 12.73, SSIM: 0.2768, JS: 0.2135
# Image: sample_29.png, PSNR: 11.66, SSIM: 0.2330, JS: 0.2377
# Image: sample_30.png, PSNR: 11.69, SSIM: 0.1901, JS: 0.2394
# Image: sample_31.png, PSNR: 9.97, SSIM: 0.1505, JS: 0.3103
# Image: sample_32.png, PSNR: 9.50, SSIM: 0.0733, JS: 0.2531
# Image: sample_33.png, PSNR: 9.60, SSIM: 0.1630, JS: 0.2799
# Image: sample_34.png, PSNR: 12.97, SSIM: 0.2297, JS: 0.2067
# Image: sample_35.png, PSNR: 9.71, SSIM: 0.1165, JS: 0.3086
# Image: sample_36.png, PSNR: 9.95, SSIM: 0.1227, JS: 0.3096
# Image: sample_37.png, PSNR: 12.46, SSIM: 0.1727, JS: 0.2182
# Image: sample_38.png, PSNR: 11.87, SSIM: 0.1692, JS: 0.2314
# Image: sample_39.png, PSNR: 12.58, SSIM: 0.2307, JS: 0.2118
# Image: sample_40.png, PSNR: 10.01, SSIM: 0.1689, JS: 0.3092
# Image: sample_41.png, PSNR: 9.97, SSIM: 0.1556, JS: 0.2861
# Image: sample_42.png, PSNR: 13.47, SSIM: 0.2757, JS: 0.1856
# Image: sample_43.png, PSNR: 9.69, SSIM: 0.1178, JS: 0.3117
# Image: sample_44.png, PSNR: 13.68, SSIM: 0.3067, JS: 0.1831
# Image: sample_45.png, PSNR: 9.36, SSIM: 0.0810, JS: 0.2750
# Image: sample_46.png, PSNR: 9.80, SSIM: 0.1639, JS: 0.3200
# Image: sample_47.png, PSNR: 13.15, SSIM: 0.2334, JS: 0.1978
# Image: sample_48.png, PSNR: 10.18, SSIM: 0.0837, JS: 0.2609
# Image: sample_49.png, PSNR: 9.32, SSIM: 0.0967, JS: 0.2835
# Image: sample_50.png, PSNR: 13.03, SSIM: 0.2525, JS: 0.2037
# Image: sample_51.png, PSNR: 9.06, SSIM: 0.1037, JS: 0.2552
# Image: sample_52.png, PSNR: 9.33, SSIM: 0.1366, JS: 0.3105
# Image: sample_53.png, PSNR: 12.01, SSIM: 0.2264, JS: 0.2292
# Image: sample_54.png, PSNR: 11.75, SSIM: 0.1385, JS: 0.2377
# Image: sample_55.png, PSNR: 8.74, SSIM: 0.0579, JS: 0.2879
# Image: sample_56.png, PSNR: 12.72, SSIM: 0.2693, JS: 0.2139
# Image: sample_57.png, PSNR: 12.68, SSIM: 0.2811, JS: 0.2096
# Image: sample_58.png, PSNR: 12.09, SSIM: 0.1886, JS: 0.2326
# Image: sample_59.png, PSNR: 10.06, SSIM: 0.1199, JS: 0.3010
# Image: sample_60.png, PSNR: 10.24, SSIM: 0.1529, JS: 0.2938
# Image: sample_61.png, PSNR: 8.81, SSIM: 0.0854, JS: 0.2956
# Image: sample_62.png, PSNR: 12.46, SSIM: 0.2384, JS: 0.2098
# Image: sample_63.png, PSNR: 9.13, SSIM: 0.1078, JS: 0.3041
# Image: sample_64.png, PSNR: 12.05, SSIM: 0.1622, JS: 0.2208
# Image: sample_65.png, PSNR: 10.08, SSIM: 0.1611, JS: 0.3107
# Image: sample_66.png, PSNR: 12.45, SSIM: 0.2575, JS: 0.2198
# Image: sample_67.png, PSNR: 11.12, SSIM: 0.1122, JS: 0.2552
# Image: sample_68.png, PSNR: 10.00, SSIM: 0.1091, JS: 0.2989
# Image: sample_69.png, PSNR: 12.39, SSIM: 0.2545, JS: 0.2168
# Image: sample_70.png, PSNR: 13.23, SSIM: 0.2842, JS: 0.1964
# Image: sample_71.png, PSNR: 9.87, SSIM: 0.1363, JS: 0.2931
# Image: sample_72.png, PSNR: 8.65, SSIM: 0.1133, JS: 0.2999
# Image: sample_73.png, PSNR: 10.57, SSIM: 0.1406, JS: 0.2811
# Image: sample_74.png, PSNR: 13.35, SSIM: 0.2881, JS: 0.1940
# Image: sample_75.png, PSNR: 10.21, SSIM: 0.1547, JS: 0.2888
# Image: sample_76.png, PSNR: 11.78, SSIM: 0.1702, JS: 0.2343
# Image: sample_77.png, PSNR: 9.11, SSIM: 0.1097, JS: 0.2840
# Image: sample_78.png, PSNR: 11.99, SSIM: 0.1983, JS: 0.2319
# Image: sample_79.png, PSNR: 11.40, SSIM: 0.1763, JS: 0.2535
# Image: sample_80.png, PSNR: 9.35, SSIM: 0.1418, JS: 0.2995
# Image: sample_81.png, PSNR: 10.11, SSIM: 0.1389, JS: 0.3037
# Image: sample_82.png, PSNR: 10.76, SSIM: 0.0851, JS: 0.2469
# Image: sample_83.png, PSNR: 12.10, SSIM: 0.1930, JS: 0.2154
# Image: sample_84.png, PSNR: 9.83, SSIM: 0.1128, JS: 0.2845
# Image: sample_85.png, PSNR: 8.88, SSIM: 0.1325, JS: 0.3098
# Image: sample_86.png, PSNR: 11.30, SSIM: 0.1456, JS: 0.2551
# Image: sample_87.png, PSNR: 9.54, SSIM: 0.1259, JS: 0.2785
# Image: sample_88.png, PSNR: 9.07, SSIM: 0.1482, JS: 0.3158
# Image: sample_89.png, PSNR: 12.36, SSIM: 0.1827, JS: 0.2216
# Image: sample_90.png, PSNR: 10.54, SSIM: 0.0934, JS: 0.2531
# Image: sample_91.png, PSNR: 11.61, SSIM: 0.1837, JS: 0.2487
# Image: sample_92.png, PSNR: 11.12, SSIM: 0.1115, JS: 0.2302
# Image: sample_93.png, PSNR: 9.44, SSIM: 0.1386, JS: 0.3127
# Image: sample_94.png, PSNR: 13.17, SSIM: 0.2352, JS: 0.1972
# Image: sample_95.png, PSNR: 8.83, SSIM: 0.0683, JS: 0.2953
# Image: sample_96.png, PSNR: 9.87, SSIM: 0.1776, JS: 0.3203
# Image: sample_97.png, PSNR: 11.92, SSIM: 0.1984, JS: 0.2187
# Image: sample_98.png, PSNR: 9.94, SSIM: 0.1437, JS: 0.3058
# Image: sample_99.png, PSNR: 9.50, SSIM: 0.1373, JS: 0.3076
# Good images for class 3: 26 images saved to C:\Users\hp\Desktop\fedavg\good_images-arch-A5\3
#
# Class 4 Metrics:
# Image: sample_0.png, PSNR: 10.63, SSIM: 0.1489, JS: 0.2887
# Image: sample_1.png, PSNR: 8.81, SSIM: 0.0692, JS: 0.3413
# Image: sample_2.png, PSNR: 9.16, SSIM: 0.0742, JS: 0.3270
# Image: sample_3.png, PSNR: 9.13, SSIM: 0.0702, JS: 0.3405
# Image: sample_4.png, PSNR: 8.08, SSIM: 0.0423, JS: 0.2934
# Image: sample_5.png, PSNR: 10.20, SSIM: 0.1133, JS: 0.2999
# Image: sample_6.png, PSNR: 8.79, SSIM: 0.0676, JS: 0.3340
# Image: sample_7.png, PSNR: 9.02, SSIM: 0.0642, JS: 0.3323
# Image: sample_8.png, PSNR: 9.54, SSIM: 0.0695, JS: 0.3219
# Image: sample_9.png, PSNR: 9.98, SSIM: 0.1103, JS: 0.3133
# Image: sample_10.png, PSNR: 9.32, SSIM: 0.0794, JS: 0.3300
# Image: sample_11.png, PSNR: 10.29, SSIM: 0.1105, JS: 0.2982
# Image: sample_12.png, PSNR: 8.61, SSIM: 0.0568, JS: 0.3536
# Image: sample_13.png, PSNR: 9.09, SSIM: 0.0860, JS: 0.2931
# Image: sample_14.png, PSNR: 10.69, SSIM: 0.1163, JS: 0.2516
# Image: sample_15.png, PSNR: 9.43, SSIM: 0.0926, JS: 0.3266
# Image: sample_16.png, PSNR: 9.96, SSIM: 0.0936, JS: 0.2760
# Image: sample_17.png, PSNR: 9.37, SSIM: 0.1065, JS: 0.3302
# Image: sample_18.png, PSNR: 8.86, SSIM: 0.0626, JS: 0.3392
# Image: sample_19.png, PSNR: 9.84, SSIM: 0.1292, JS: 0.3007
# Image: sample_20.png, PSNR: 8.67, SSIM: 0.0534, JS: 0.3293
# Image: sample_21.png, PSNR: 9.89, SSIM: 0.0940, JS: 0.2960
# Image: sample_22.png, PSNR: 8.04, SSIM: 0.0622, JS: 0.3286
# Image: sample_23.png, PSNR: 9.92, SSIM: 0.1212, JS: 0.3053
# Image: sample_24.png, PSNR: 8.53, SSIM: 0.0558, JS: 0.2578
# Image: sample_25.png, PSNR: 7.85, SSIM: 0.0633, JS: 0.2677
# Image: sample_26.png, PSNR: 8.71, SSIM: 0.0642, JS: 0.3322
# Image: sample_27.png, PSNR: 10.09, SSIM: 0.0937, JS: 0.3050
# Image: sample_28.png, PSNR: 8.90, SSIM: 0.1032, JS: 0.3567
# Image: sample_29.png, PSNR: 10.05, SSIM: 0.1393, JS: 0.2893
# Image: sample_30.png, PSNR: 9.71, SSIM: 0.0873, JS: 0.2930
# Image: sample_31.png, PSNR: 10.03, SSIM: 0.0913, JS: 0.2818
# Image: sample_32.png, PSNR: 9.47, SSIM: 0.0870, JS: 0.3112
# Image: sample_33.png, PSNR: 10.04, SSIM: 0.1655, JS: 0.2282
# Image: sample_34.png, PSNR: 9.05, SSIM: 0.0588, JS: 0.3130
# Image: sample_35.png, PSNR: 10.19, SSIM: 0.1143, JS: 0.2989
# Image: sample_36.png, PSNR: 9.24, SSIM: 0.0711, JS: 0.3396
# Image: sample_37.png, PSNR: 10.13, SSIM: 0.0917, JS: 0.2985
# Image: sample_38.png, PSNR: 8.38, SSIM: 0.0595, JS: 0.3406
# Image: sample_39.png, PSNR: 8.98, SSIM: 0.0539, JS: 0.3273
# Image: sample_40.png, PSNR: 9.37, SSIM: 0.0733, JS: 0.3321
# Image: sample_41.png, PSNR: 10.00, SSIM: 0.0944, JS: 0.3011
# Image: sample_42.png, PSNR: 8.60, SSIM: 0.0606, JS: 0.3274
# Image: sample_43.png, PSNR: 10.63, SSIM: 0.1391, JS: 0.2338
# Image: sample_44.png, PSNR: 10.29, SSIM: 0.1260, JS: 0.2862
# Image: sample_45.png, PSNR: 8.19, SSIM: 0.0621, JS: 0.3329
# Image: sample_46.png, PSNR: 9.46, SSIM: 0.0863, JS: 0.3189
# Image: sample_47.png, PSNR: 8.29, SSIM: 0.0424, JS: 0.3143
# Image: sample_48.png, PSNR: 9.26, SSIM: 0.0870, JS: 0.3303
# Image: sample_49.png, PSNR: 10.20, SSIM: 0.1042, JS: 0.2934
# Image: sample_50.png, PSNR: 9.75, SSIM: 0.1036, JS: 0.3101
# Image: sample_51.png, PSNR: 8.71, SSIM: 0.0621, JS: 0.3078
# Image: sample_52.png, PSNR: 8.55, SSIM: 0.0658, JS: 0.3379
# Image: sample_53.png, PSNR: 11.12, SSIM: 0.2191, JS: 0.2250
# Image: sample_54.png, PSNR: 10.45, SSIM: 0.1292, JS: 0.2885
# Image: sample_55.png, PSNR: 9.26, SSIM: 0.0908, JS: 0.3140
# Image: sample_56.png, PSNR: 9.77, SSIM: 0.0927, JS: 0.3017
# Image: sample_57.png, PSNR: 10.07, SSIM: 0.1462, JS: 0.2713
# Image: sample_58.png, PSNR: 8.33, SSIM: 0.0738, JS: 0.3357
# Image: sample_59.png, PSNR: 9.45, SSIM: 0.0860, JS: 0.3216
# Image: sample_60.png, PSNR: 8.98, SSIM: 0.0533, JS: 0.3162
# Image: sample_61.png, PSNR: 9.13, SSIM: 0.0808, JS: 0.3432
# Image: sample_62.png, PSNR: 9.78, SSIM: 0.1150, JS: 0.3159
# Image: sample_63.png, PSNR: 9.70, SSIM: 0.0773, JS: 0.2835
# Image: sample_64.png, PSNR: 10.18, SSIM: 0.1132, JS: 0.2430
# Image: sample_65.png, PSNR: 9.51, SSIM: 0.0692, JS: 0.3147
# Image: sample_66.png, PSNR: 10.07, SSIM: 0.1085, JS: 0.2979
# Image: sample_67.png, PSNR: 9.48, SSIM: 0.0679, JS: 0.3251
# Image: sample_68.png, PSNR: 9.21, SSIM: 0.0867, JS: 0.2895
# Image: sample_69.png, PSNR: 8.44, SSIM: 0.0633, JS: 0.3382
# Image: sample_70.png, PSNR: 9.34, SSIM: 0.0708, JS: 0.3267
# Image: sample_71.png, PSNR: 9.61, SSIM: 0.0884, JS: 0.3150
# Image: sample_72.png, PSNR: 10.18, SSIM: 0.1170, JS: 0.2983
# Image: sample_73.png, PSNR: 10.03, SSIM: 0.0990, JS: 0.3027
# Image: sample_74.png, PSNR: 8.37, SSIM: 0.0681, JS: 0.3305
# Image: sample_75.png, PSNR: 9.67, SSIM: 0.0880, JS: 0.3087
# Image: sample_76.png, PSNR: 9.13, SSIM: 0.0880, JS: 0.3486
# Image: sample_77.png, PSNR: 9.58, SSIM: 0.0813, JS: 0.2499
# Image: sample_78.png, PSNR: 9.20, SSIM: 0.0668, JS: 0.3355
# Image: sample_79.png, PSNR: 9.89, SSIM: 0.1298, JS: 0.3105
# Image: sample_80.png, PSNR: 8.11, SSIM: 0.0479, JS: 0.3230
# Image: sample_81.png, PSNR: 9.92, SSIM: 0.0964, JS: 0.3031
# Image: sample_82.png, PSNR: 9.92, SSIM: 0.1038, JS: 0.2891
# Image: sample_83.png, PSNR: 10.18, SSIM: 0.1233, JS: 0.3007
# Image: sample_84.png, PSNR: 9.14, SSIM: 0.0565, JS: 0.3300
# Image: sample_85.png, PSNR: 9.46, SSIM: 0.0854, JS: 0.3301
# Image: sample_86.png, PSNR: 9.21, SSIM: 0.0738, JS: 0.3280
# Image: sample_87.png, PSNR: 9.53, SSIM: 0.0748, JS: 0.2879
# Image: sample_88.png, PSNR: 9.29, SSIM: 0.0680, JS: 0.3316
# Image: sample_89.png, PSNR: 11.06, SSIM: 0.1551, JS: 0.2393
# Image: sample_90.png, PSNR: 9.88, SSIM: 0.1276, JS: 0.3053
# Image: sample_91.png, PSNR: 9.41, SSIM: 0.0942, JS: 0.3145
# Image: sample_92.png, PSNR: 9.28, SSIM: 0.0797, JS: 0.3334
# Image: sample_93.png, PSNR: 9.63, SSIM: 0.0598, JS: 0.2995
# Image: sample_94.png, PSNR: 9.67, SSIM: 0.1264, JS: 0.3206
# Image: sample_95.png, PSNR: 10.12, SSIM: 0.1171, JS: 0.2965
# Image: sample_96.png, PSNR: 9.50, SSIM: 0.0703, JS: 0.3130
# Image: sample_97.png, PSNR: 8.87, SSIM: 0.0510, JS: 0.3048
# Image: sample_98.png, PSNR: 8.94, SSIM: 0.0734, JS: 0.2629
# Image: sample_99.png, PSNR: 10.54, SSIM: 0.1155, JS: 0.2705
# Good images for class 4: 0 images saved to C:\Users\hp\Desktop\fedavg\good_images-arch-A5\4
#
# Total good images across all classes: 39

# %%
##3000epoch image of mine

# %%
import torch
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os
import numpy as np
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim
from scipy.spatial.distance import jensenshannon
import kagglehub

# Define paths
combined_image_path = r"C:\Users\hp\Desktop\fedavg\FL_VEHICLE_CVAE_IMPROVED\sample_epoch_3000.png"  # Replace with the actual path to your combined image
good_images_dir = r"C:\Users\hp\Desktop\fedavg\good_images_3000_mine"
os.makedirs(good_images_dir, exist_ok=True)

# Hyperparameters
RESIZE = 128
num_classes = 5
original_dim = RESIZE * RESIZE * 3

# Custom Dataset for Kaggle Vehicle Type Image Dataset
class VehicleTypeDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = []
        self.class_to_idx = {}
        self.images = []
        self.labels = []

        for root, dirs, files in os.walk(root_dir):
            image_files = [f for f in files if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
            if image_files:
                class_name = os.path.basename(root)
                if class_name not in self.class_to_idx:
                    self.classes.append(class_name)
                    self.class_to_idx[class_name] = len(self.classes) - 1
                for img_file in image_files:
                    img_path = os.path.join(root, img_file)
                    try:
                        Image.open(img_path).verify()
                        self.images.append(img_path)
                        self.labels.append(self.class_to_idx[class_name])
                    except:
                        print(f"Skipping corrupted image: {img_path}")

        if len(self.classes) != num_classes:
            raise ValueError(f"Expected {num_classes} classes, found {len(self.classes)}")
        print(f"Found {len(self.images)} images across {len(self.classes)} classes.")
        print(f"Classes: {self.classes}")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        image = Image.open(img_path).convert('RGB')
        label = self.labels[idx]
        sample = {'image': image, 'label': label}
        if self.transform:
            sample['image'] = self.transform(sample['image'])
        return sample

# Load a subset of real images as references (5 per class)
transform = transforms.Compose([
    transforms.Resize((RESIZE, RESIZE)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

path = kagglehub.dataset_download("sujaykapadnis/vehicle-type-image-dataset")
dataset = VehicleTypeDataset(root_dir=path, transform=transform)

# Collect reference images (5 per class)
reference_images = {i: [] for i in range(num_classes)}
for sample in dataset:
    label = sample['label']
    if len(reference_images[label]) < 5:
        reference_images[label].append(sample['image'])
    if all(len(refs) >= 5 for refs in reference_images.values()):
        break

# Function to compute PSNR, SSIM, and JS divergence
def compute_metrics_for_image(orig, gen):
    orig_np = orig.cpu().numpy() * 0.5 + 0.5
    gen_np = gen.cpu().numpy() * 0.5 + 0.5
    orig_np = np.transpose(orig_np, (1, 2, 0))
    gen_np = np.transpose(gen_np, (1, 2, 0))
    orig_np = np.clip(orig_np, 0, 1)
    gen_np = np.clip(gen_np, 0, 1)

    psnr_score = psnr(orig_np, gen_np, data_range=1.0)
    ssim_score = ssim(orig_np, gen_np, multichannel=True, data_range=1.0, channel_axis=2)

    js_scores = []
    for c in range(3):
        orig_channel = orig_np[:, :, c].flatten()
        gen_channel = gen_np[:, :, c].flatten()
        orig_channel = (orig_channel + 1e-10) / (np.sum(orig_channel) + 1e-10 * RESIZE * RESIZE)
        gen_channel = (gen_channel + 1e-10) / (np.sum(gen_channel) + 1e-10 * RESIZE * RESIZE)
        js_score = jensenshannon(orig_channel, gen_channel)
        if np.isnan(js_score):
            js_score = 1.0
        js_scores.append(js_score)
    js_score = np.mean(js_scores)

    return psnr_score, ssim_score, js_score

# Load and split the combined image
combined_image = Image.open(combined_image_path).convert('RGB')
combined_width, combined_height = combined_image.size

# Assuming a 2x5 grid (2 rows, 5 columns), adjust based on your image layout
rows, cols = 2, 5
subimage_width = combined_width // cols  # Width of each subimage
subimage_height = combined_height // rows  # Height of each subimage

# Check if the subimages match the expected size (128x128)
if subimage_width != RESIZE or subimage_height != RESIZE:
    print(f"Warning: Subimage size is {subimage_width}x{subimage_height}, expected {RESIZE}x{RESIZE}. Resizing subimages.")
    subimage_transform = transforms.Compose([
        transforms.Resize((RESIZE, RESIZE)),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
else:
    subimage_transform = transform

# Split the combined image into 10 subimages
subimages = []
for i in range(rows):
    for j in range(cols):
        left = j * subimage_width
        upper = i * subimage_height
        right = (j + 1) * subimage_width
        lower = (i + 1) * subimage_height
        subimage = combined_image.crop((left, upper, right, lower))
        subimages.append(subimage)

# Process each subimage and compute metrics
class_label = 0  # Assuming all subimages belong to Class 0, adjust if needed
good_class_dir = os.path.join(good_images_dir, str(class_label))
os.makedirs(good_class_dir, exist_ok=True)

metrics_dict = []
good_images = []

# Reference images for this class
ref_images = reference_images[class_label]  # List of 5 reference tensors

# Process each subimage
for idx, subimage in enumerate(subimages):
    # Preprocess the subimage
    gen_tensor = subimage_transform(subimage)

    # Compute metrics against each reference image and average
    psnr_scores, ssim_scores, js_scores = [], [], []
    for ref_tensor in ref_images:
        try:
            psnr_score, ssim_score, js_score = compute_metrics_for_image(ref_tensor, gen_tensor)
            psnr_scores.append(psnr_score)
            ssim_scores.append(ssim_score)
            js_scores.append(js_score)
        except Exception as e:
            print(f"Error computing metrics for subimage {idx}: {str(e)}")
            psnr_scores.append(0.0)
            ssim_scores.append(0.0)
            js_scores.append(1.0)

    avg_psnr = np.mean(psnr_scores)
    avg_ssim = np.mean(ssim_scores)
    avg_js = np.mean(js_scores)

    metrics_dict.append({
        'image': f"subimage_{idx}.png",
        'psnr': avg_psnr,
        'ssim': avg_ssim,
        'js': avg_js
    })

    # Check if the subimage meets the "good" criteria (using adjusted thresholds from previous response)
    if avg_psnr > 11.8 and avg_ssim > 0.19 and avg_js < 0.24:
        good_img_path = os.path.join(good_class_dir, f"subimage_{idx}.png")
        subimage.save(good_img_path)
        good_images.append(f"subimage_{idx}.png")

# Print metrics for the subimages
print(f"\nClass {class_label} Subimage Metrics:")
for metric in metrics_dict:
    print(f"Image: {metric['image']}, PSNR: {metric['psnr']:.2f}, SSIM: {metric['ssim']:.4f}, JS: {metric['js']:.4f}")
print(f"Good subimages for class {class_label}: {len(good_images)} images saved to {good_class_dir}")
# Out:
# Found 4793 images across 5 classes.
# Classes: ['Hatchback', 'Other', 'Pickup', 'Seden', 'SUV']
# Warning: Subimage size is 208x131, expected 128x128. Resizing subimages.
#
# Class 0 Subimage Metrics:
# Image: subimage_0.png, PSNR: 10.24, SSIM: 0.1015, JS: 0.3255
# Image: subimage_1.png, PSNR: 11.08, SSIM: 0.0900, JS: 0.2812
# Image: subimage_2.png, PSNR: 8.47, SSIM: 0.0787, JS: 0.3119
# Image: subimage_3.png, PSNR: 11.58, SSIM: 0.1174, JS: 0.2795
# Image: subimage_4.png, PSNR: 10.04, SSIM: 0.0954, JS: 0.3197
# Image: subimage_5.png, PSNR: 11.00, SSIM: 0.1210, JS: 0.2870
# Image: subimage_6.png, PSNR: 7.59, SSIM: 0.0181, JS: 0.6601
# Image: subimage_7.png, PSNR: 7.53, SSIM: 0.0024, JS: 0.2439
# Image: subimage_8.png, PSNR: 7.53, SSIM: 0.0024, JS: 0.2439
# Image: subimage_9.png, PSNR: 7.53, SSIM: 0.0024, JS: 0.2439
# Good subimages for class 0: 0 images saved to C:\Users\hp\Desktop\fedavg\good_images_3000_mine\0

# %%
##generating_500 samples insted of 100 of sneha code

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms
from PIL import Image
import os
import numpy as np

# Hyperparameters (same as in your original code)
RESIZE = 128
intermediate_dim = 512
latent_dim = 256
num_classes = 5
device = torch.device('cuda:1' if torch.cuda.device_count() > 1 else 'cuda')

# Print GPU information
print(f"Using device: {device}")
if device.type == 'cuda':
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory Allocated: {torch.cuda.memory_allocated(0) / 1024**2:.2f} MB")

# Enhanced Image Grid for Plotting (same as in your original code)
def image_grid(imgs, rows, cols, class_label, height=RESIZE, width=RESIZE):
    assert len(imgs) <= rows * cols
    grid = Image.new('RGB', size=(cols * width, rows * height), color=(255, 255, 255))
    for i, img in enumerate(imgs):
        x = (i % cols) * width + 2
        y = (i // cols) * height + 2
        grid.paste(img, box=(x, y))
    return grid

# Weight initialization function (same as in your original code)
def init_weights(m):
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.ConvTranspose2d):
        nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)
    elif isinstance(m, nn.Linear):
        nn.init.xavier_normal_(m.weight)
        nn.init.constant_(m.bias, 0)

# Encoder class (same as in your original code)
class Encoder(nn.Module):
    def __init__(self, input_size, hidden_dim, latent_dim, num_classes):
        super(Encoder, self).__init__()
        self.encoder_cnn = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(128, 256, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256, 512, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 512, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 1024, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(1024),
            nn.ReLU(),
            nn.Conv2d(1024, 1024, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(1024),
            nn.ReLU()
        )
        self.fc_hidden = nn.Linear(1024 * 2 * 2 + num_classes, hidden_dim)
        self.dropout = nn.Dropout(0.3)
        self.fc_mean = nn.Linear(hidden_dim, latent_dim)
        self.fc_logvar = nn.Linear(hidden_dim, latent_dim)
        self.apply(init_weights)

    def forward(self, x, y):
        x = self.encoder_cnn(x)
        x = x.view(x.size(0), -1)
        x_with_y = torch.cat([x, y], dim=-1)
        h = F.relu(self.fc_hidden(x_with_y))
        h = self.dropout(h)
        z_mean = self.fc_mean(h)
        z_logvar = self.fc_logvar(h)
        z_logvar = torch.clamp(z_logvar, min=-10, max=10)
        return z_mean, z_logvar

# Decoder class (same as in your original code)
class Decoder(nn.Module):
    def __init__(self, latent_dim, hidden_dim, output_size, num_classes):
        super(Decoder, self).__init__()
        self.fc = nn.Linear(latent_dim + num_classes, hidden_dim)
        self.dropout = nn.Dropout(0.3)
        self.fc_to_cnn = nn.Linear(hidden_dim, 1024 * 2 * 2)
        self.decoder_cnn = nn.Sequential(
            nn.ConvTranspose2d(1024, 1024, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(1024),
            nn.ReLU(),
            nn.ConvTranspose2d(1024, 512, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.ConvTranspose2d(512, 512, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.ConvTranspose2d(512, 256, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.ConvTranspose2d(256, 128, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 3, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.Tanh()
        )
        self.apply(init_weights)

    def forward(self, z, y):
        z_with_y = torch.cat([z, y], dim=-1)
        h = F.relu(self.fc(z_with_y))
        h = self.dropout(h)
        h = F.relu(self.fc_to_cnn(h))
        h = h.view(-1, 1024, 2, 2)
        x_reconstructed = self.decoder_cnn(h)
        x_reconstructed = torch.clamp(x_reconstructed, min=-1, max=1)
        return x_reconstructed

# Conditional VAE class (same as in your original code)
class ConditionalVAE(nn.Module):
    def __init__(self, encoder, decoder):
        super(ConditionalVAE, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def reparameterize(self, z_mean, z_logvar):
        std = torch.exp(0.5 * z_logvar)
        eps = torch.randn_like(std)
        return z_mean + eps * std

    def forward(self, data, y):
        z_mean, z_logvar = self.encoder(data, y)
        z = self.reparameterize(z_mean, z_logvar)
        x_reconstructed = self.decoder(z, y)
        return x_reconstructed, z_mean, z_logvar

# Instantiate the model
input_size = (8, 3, RESIZE, RESIZE)  # Batch size is irrelevant for generation, but needed for model definition
encoder = Encoder(input_size, intermediate_dim, latent_dim, num_classes).to(device)
decoder = Decoder(latent_dim, intermediate_dim, input_size, num_classes).to(device)
cvae = ConditionalVAE(encoder, decoder).to(device)

# Load the saved model weights
model_path = "cvae_vehicle_final.pth"
try:
    cvae.load_state_dict(torch.load(model_path, map_location=device))
    print(f"Loaded CVAE model from {model_path}")
except Exception as e:
    print(f"Error loading model: {str(e)}")
    exit()

# Define class names (you can update this list based on your dataset)
class_names = ['Class0', 'Class1', 'Class2', 'Class3', 'Class4']  # Update with actual class names if known

# Modified generate_samples_labelwise function to generate 500 samples per class
def generate_samples_labelwise(cvae, num_samples_per_class, base_dir, latent_dim, device):
    cvae.eval()
    os.makedirs(base_dir, exist_ok=True)
    with torch.no_grad():
        for class_label in range(num_classes):
            print(f"Generating samples for class {class_label}...")
            label_tensor = torch.tensor([class_label]).repeat(num_samples_per_class).to(device)
            one_hot_labels = F.one_hot(label_tensor, num_classes=num_classes).float().to(device)
            
            # Generate samples in smaller batches to avoid memory issues
            batch_size = 50  # Adjust based on your GPU memory
            images = []
            for start_idx in range(0, num_samples_per_class, batch_size):
                end_idx = min(start_idx + batch_size, num_samples_per_class)
                current_batch_size = end_idx - start_idx
                z = torch.randn(current_batch_size, latent_dim).to(device)
                generated_samples = cvae.decoder(z, one_hot_labels[start_idx:end_idx])

                # Process and save each sample
                class_dir = os.path.join(base_dir, str(class_label))
                os.makedirs(class_dir, exist_ok=True)
                for idx, sample in enumerate(generated_samples):
                    global_idx = start_idx + idx
                    sample = sample.cpu().detach().numpy()
                    sample = sample * 0.5 + 0.5  # Denormalize
                    sample = np.nan_to_num(sample, nan=0.0, posinf=0.0, neginf=0.0)
                    sample = (255 * sample).astype(np.uint8)
                    sample = np.transpose(sample, (1, 2, 0))
                    pil_image = Image.fromarray(sample).convert('RGB')
                    pil_image.save(os.path.join(class_dir, f"sample_{global_idx}.png"))
                    if global_idx < 32:  # Save first 32 for the grid
                        images.append(pil_image)

            # Save a grid of the first 32 images
            if images:
                grid = image_grid(images, rows=4, cols=8, class_label=class_names[class_label])
                grid.save(os.path.join(class_dir, f"grid_{class_names[class_label]}.png"))
            print(f"Generated {num_samples_per_class} samples for class {class_label}")

# Generate 500 samples per class
base_dir = "generated_samples-arch-A5-500"  # New directory to avoid overwriting previous samples
try:
    generate_samples_labelwise(cvae, num_samples_per_class=500, base_dir=base_dir, latent_dim=latent_dim, device=device)
    print("Finished generating 500 samples per class")
except Exception as e:
    print(f"Error during sample generation: {str(e)}")

# Clear GPU memory
if device.type == 'cuda':
    torch.cuda.empty_cache()
# Out:
# Using device: cuda:1
# GPU Name: NVIDIA RTX A5000
# GPU Memory Allocated: 0.00 MB
# C:\Users\hp\AppData\Local\Temp\ipykernel_35856\2065658207.py:154: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   cvae.load_state_dict(torch.load(model_path, map_location=device))
# Loaded CVAE model from cvae_vehicle_final.pth
# Generating samples for class 0...
# Generated 500 samples for class 0
# Generating samples for class 1...
# Generated 500 samples for class 1
# Generating samples for class 2...
# Generated 500 samples for class 2
# Generating samples for class 3...
# Generated 500 samples for class 3
# Generating samples for class 4...
# Generated 500 samples for class 4
# Finished generating 500 samples per class

# %%
##generating 500 Images and increase quality and sorting of sneha code

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image, ImageEnhance, ImageFilter
import os
import numpy as np
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim
from scipy.spatial.distance import jensenshannon
import kagglehub

# Hyperparameters (same as in your original code)
RESIZE = 128
intermediate_dim = 512
latent_dim = 256
num_classes = 5
device = torch.device('cuda:1' if torch.cuda.device_count() > 1 else 'cuda')

# Print GPU information
print(f"Using device: {device}")
if device.type == 'cuda':
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory Allocated: {torch.cuda.memory_allocated(0) / 1024**2:.2f} MB")

# Custom Dataset for Kaggle Vehicle Type Image Dataset (for reference images)
class VehicleTypeDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = []
        self.class_to_idx = {}
        self.images = []
        self.labels = []

        for root, dirs, files in os.walk(root_dir):
            image_files = [f for f in files if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
            if image_files:
                class_name = os.path.basename(root)
                if class_name not in self.class_to_idx:
                    self.classes.append(class_name)
                    self.class_to_idx[class_name] = len(self.classes) - 1
                for img_file in image_files:
                    img_path = os.path.join(root, img_file)
                    try:
                        Image.open(img_path).verify()
                        self.images.append(img_path)
                        self.labels.append(self.class_to_idx[class_name])
                    except:
                        print(f"Skipping corrupted image: {img_path}")

        if len(self.classes) != num_classes:
            raise ValueError(f"Expected {num_classes} classes, found {len(self.classes)}")
        print(f"Found {len(self.images)} images across {len(self.classes)} classes.")
        print(f"Classes: {self.classes}")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        image = Image.open(img_path).convert('RGB')
        label = self.labels[idx]
        sample = {'image': image, 'label': label}
        if self.transform:
            sample['image'] = self.transform(sample['image'])
        return sample

# Enhanced Image Grid for Plotting
def image_grid(imgs, rows, cols, class_label, height=RESIZE, width=RESIZE):
    assert len(imgs) <= rows * cols
    grid = Image.new('RGB', size=(cols * width, rows * height), color=(255, 255, 255))
    for i, img in enumerate(imgs):
        x = (i % cols) * width + 2
        y = (i // cols) * height + 2
        grid.paste(img, box=(x, y))
    return grid

# Weight initialization function
def init_weights(m):
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.ConvTranspose2d):
        nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)
    elif isinstance(m, nn.Linear):
        nn.init.xavier_normal_(m.weight)
        nn.init.constant_(m.bias, 0)

# Encoder class (same as in your original code)
class Encoder(nn.Module):
    def __init__(self, input_size, hidden_dim, latent_dim, num_classes):
        super(Encoder, self).__init__()
        self.encoder_cnn = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(128, 256, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256, 512, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 512, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 1024, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(1024),
            nn.ReLU(),
            nn.Conv2d(1024, 1024, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(1024),
            nn.ReLU()
        )
        self.fc_hidden = nn.Linear(1024 * 2 * 2 + num_classes, hidden_dim)
        self.dropout = nn.Dropout(0.3)
        self.fc_mean = nn.Linear(hidden_dim, latent_dim)
        self.fc_logvar = nn.Linear(hidden_dim, latent_dim)
        self.apply(init_weights)

    def forward(self, x, y):
        x = self.encoder_cnn(x)
        x = x.view(x.size(0), -1)
        x_with_y = torch.cat([x, y], dim=-1)
        h = F.relu(self.fc_hidden(x_with_y))
        h = self.dropout(h)
        z_mean = self.fc_mean(h)
        z_logvar = self.fc_logvar(h)
        z_logvar = torch.clamp(z_logvar, min=-10, max=10)
        return z_mean, z_logvar

# Decoder class (same as in your original code)
class Decoder(nn.Module):
    def __init__(self, latent_dim, hidden_dim, output_size, num_classes):
        super(Decoder, self).__init__()
        self.fc = nn.Linear(latent_dim + num_classes, hidden_dim)
        self.dropout = nn.Dropout(0.3)
        self.fc_to_cnn = nn.Linear(hidden_dim, 1024 * 2 * 2)
        self.decoder_cnn = nn.Sequential(
            nn.ConvTranspose2d(1024, 1024, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(1024),
            nn.ReLU(),
            nn.ConvTranspose2d(1024, 512, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.ConvTranspose2d(512, 512, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.ConvTranspose2d(512, 256, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.ConvTranspose2d(256, 128, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 3, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.Tanh()
        )
        self.apply(init_weights)

    def forward(self, z, y):
        z_with_y = torch.cat([z, y], dim=-1)
        h = F.relu(self.fc(z_with_y))
        h = self.dropout(h)
        h = F.relu(self.fc_to_cnn(h))
        h = h.view(-1, 1024, 2, 2)
        x_reconstructed = self.decoder_cnn(h)
        x_reconstructed = torch.clamp(x_reconstructed, min=-1, max=1)
        return x_reconstructed

# Conditional VAE class
class ConditionalVAE(nn.Module):
    def __init__(self, encoder, decoder):
        super(ConditionalVAE, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def reparameterize(self, z_mean, z_logvar):
        std = torch.exp(0.5 * z_logvar)
        eps = torch.randn_like(std)
        return z_mean + eps * std

    def forward(self, data, y):
        z_mean, z_logvar = self.encoder(data, y)
        z = self.reparameterize(z_mean, z_logvar)
        x_reconstructed = self.decoder(z, y)
        return x_reconstructed, z_mean, z_logvar

# Function to enhance image quality (sharpen, adjust contrast, brightness, etc.)
def enhance_image(pil_image):
    # Apply Unsharp Masking for additional sharpness
    pil_image = pil_image.filter(ImageFilter.UnsharpMask(radius=2, percent=150, threshold=3))
    # Enhance sharpness
    pil_image = ImageEnhance.Sharpness(pil_image).enhance(2.0)  # Increase sharpness by a factor of 2
    # Enhance contrast
    pil_image = ImageEnhance.Contrast(pil_image).enhance(1.3)  # Increase contrast by 30%
    # Enhance brightness
    pil_image = ImageEnhance.Brightness(pil_image).enhance(1.1)  # Slightly increase brightness by 10%
    # Optional: Super-resolution-like effect by upscaling and downscaling
    pil_image = pil_image.resize((RESIZE * 2, RESIZE * 2), Image.Resampling.LANCZOS)
    pil_image = pil_image.resize((RESIZE, RESIZE), Image.Resampling.LANCZOS)
    return pil_image

# Function to compute PSNR, SSIM, and JS divergence
def compute_metrics_for_image(orig, gen):
    orig_np = orig.cpu().numpy() * 0.5 + 0.5
    gen_np = gen.cpu().numpy() * 0.5 + 0.5
    orig_np = np.transpose(orig_np, (1, 2, 0))
    gen_np = np.transpose(gen_np, (1, 2, 0))
    orig_np = np.clip(orig_np, 0, 1)
    gen_np = np.clip(gen_np, 0, 1)

    psnr_score = psnr(orig_np, gen_np, data_range=1.0)
    ssim_score = ssim(orig_np, gen_np, multichannel=True, data_range=1.0, channel_axis=2)

    js_scores = []
    for c in range(3):
        orig_channel = orig_np[:, :, c].flatten()
        gen_channel = gen_np[:, :, c].flatten()
        orig_channel = (orig_channel + 1e-10) / (np.sum(orig_channel) + 1e-10 * RESIZE * RESIZE)
        gen_channel = (gen_channel + 1e-10) / (np.sum(gen_channel) + 1e-10 * RESIZE * RESIZE)
        js_score = jensenshannon(orig_channel, gen_channel)
        if np.isnan(js_score):
            js_score = 1.0
        js_scores.append(js_score)
    js_score = np.mean(js_scores)

    return psnr_score, ssim_score, js_score

# Instantiate the model
input_size = (8, 3, RESIZE, RESIZE)  # Batch size is irrelevant for generation
encoder = Encoder(input_size, intermediate_dim, latent_dim, num_classes).to(device)
decoder = Decoder(latent_dim, intermediate_dim, input_size, num_classes).to(device)
cvae = ConditionalVAE(encoder, decoder).to(device)

# Load the saved model weights
model_path = "cvae_vehicle_final.pth"
try:
    cvae.load_state_dict(torch.load(model_path, map_location=device))
    print(f"Loaded CVAE model from {model_path}")
except Exception as e:
    print(f"Error loading model: {str(e)}")
    exit()

# Load reference images for metrics computation
transform = transforms.Compose([
    transforms.Resize((RESIZE, RESIZE)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

path = kagglehub.dataset_download("sujaykapadnis/vehicle-type-image-dataset")
dataset = VehicleTypeDataset(root_dir=path, transform=transform)

# Collect reference images (5 per class)
reference_images = {i: [] for i in range(num_classes)}
for sample in dataset:
    label = sample['label']
    if len(reference_images[label]) < 5:
        reference_images[label].append(sample['image'])
    if all(len(refs) >= 5 for refs in reference_images.values()):
        break

# Define class names (update with actual class names if known)
class_names = ['Class0', 'Class1', 'Class2', 'Class3', 'Class4']

# Modified generate_samples_labelwise function with enhancements
def generate_samples_labelwise(cvae, num_samples_per_class, base_dir, good_images_dir, latent_dim, device):
    cvae.eval()
    os.makedirs(base_dir, exist_ok=True)
    os.makedirs(good_images_dir, exist_ok=True)

    # Initialize dictionaries to store metrics and good images
    all_metrics = {class_label: [] for class_label in range(num_classes)}
    good_images = {class_label: [] for class_label in range(num_classes)}

    with torch.no_grad():
        for class_label in range(num_classes):
            print(f"Generating and processing samples for class {class_label}...")
            label_tensor = torch.tensor([class_label]).repeat(num_samples_per_class).to(device)
            one_hot_labels = F.one_hot(label_tensor, num_classes=num_classes).float().to(device)

            # Generate samples in smaller batches to avoid memory issues
            batch_size = 50
            idx = 0
            for start_idx in range(0, num_samples_per_class, batch_size):
                end_idx = min(start_idx + batch_size, num_samples_per_class)
                current_batch_size = end_idx - start_idx

                # Use truncation trick: Sample from a normal distribution with reduced variance
                z = torch.randn(current_batch_size, latent_dim).to(device) * 0.7  # Reduce variance
                z = torch.clamp(z, -2.0, 2.0)  # Truncation trick to avoid extreme values
                generated_samples = cvae.decoder(z, one_hot_labels[start_idx:end_idx])

                # Process and save each sample
                class_dir = os.path.join(base_dir, str(class_label))
                os.makedirs(class_dir, exist_ok=True)
                good_class_dir = os.path.join(good_images_dir, str(class_label))
                os.makedirs(good_class_dir, exist_ok=True)

                images_for_grid = []
                for batch_idx, sample in enumerate(generated_samples):
                    global_idx = start_idx + batch_idx
                    # Convert tensor to numpy array
                    sample = sample.cpu().detach().numpy()
                    sample = sample * 0.5 + 0.5  # Denormalize
                    sample = np.nan_to_num(sample, nan=0.0, posinf=0.0, neginf=0.0)
                    sample = (255 * sample).astype(np.uint8)
                    sample = np.transpose(sample, (1, 2, 0))
                    pil_image = Image.fromarray(sample).convert('RGB')

                    # Enhance the image
                    pil_image = enhance_image(pil_image)

                    # Save the enhanced image
                    pil_image.save(os.path.join(class_dir, f"sample_{global_idx}.png"))
                    if global_idx < 32:
                        images_for_grid.append(pil_image)

                    # Convert back to tensor for metrics computation
                    gen_tensor = transform(pil_image).to(device)

                    # Compute metrics against reference images
                    ref_images = reference_images[class_label]
                    psnr_scores, ssim_scores, js_scores = [], [], []
                    for ref_tensor in ref_images:
                        psnr_score, ssim_score, js_score = compute_metrics_for_image(ref_tensor, gen_tensor)
                        psnr_scores.append(psnr_score)
                        ssim_scores.append(ssim_score)
                        js_scores.append(js_score)

                    avg_psnr = np.mean(psnr_scores)
                    avg_ssim = np.mean(ssim_scores)
                    avg_js = np.mean(js_scores)

                    all_metrics[class_label].append({
                        'image': f"sample_{global_idx}.png",
                        'psnr': avg_psnr,
                        'ssim': avg_ssim,
                        'js': avg_js
                    })

                    # Check if the image meets the "good" criteria (initial thresholds, will adjust later)
                    if avg_psnr > 11.8 and avg_ssim > 0.19 and avg_js < 0.24:
                        good_img_path = os.path.join(good_class_dir, f"sample_{global_idx}.png")
                        pil_image.save(good_img_path)
                        good_images[class_label].append(f"sample_{global_idx}.png")

                idx += current_batch_size

            # Save a grid of the first 32 images
            if images_for_grid:
                grid = image_grid(images_for_grid, rows=4, cols=8, class_label=class_names[class_label])
                grid.save(os.path.join(class_dir, f"grid_{class_names[class_label]}.png"))
            print(f"Generated {num_samples_per_class} samples for class {class_label}")

    return all_metrics, good_images

# Generate 500 samples per class and compute metrics
base_dir = "generated_samples-arch-A5-500-enhanced"
good_images_dir = "good_images-arch-A5-enhanced"
try:
    all_metrics, good_images = generate_samples_labelwise(
        cvae, num_samples_per_class=500, base_dir=base_dir, 
        good_images_dir=good_images_dir, latent_dim=latent_dim, device=device
    )
    print("Finished generating 500 enhanced samples per class and computing metrics")
except Exception as e:
    print(f"Error during sample generation: {str(e)}")

# Step 3: Analyze Metrics and Adjust Thresholds

# Print metrics for each class
for class_label in range(num_classes):
    print(f"\nClass {class_label} Metrics:")
    for metric in all_metrics[class_label]:
        print(f"Image: {metric['image']}, PSNR: {metric['psnr']:.2f}, SSIM: {metric['ssim']:.4f}, JS: {metric['js']:.4f}")
    print(f"Initially selected good images for class {class_label}: {len(good_images[class_label])}")

# Collect all metrics to determine new thresholds
all_psnr = [metric['psnr'] for class_label in range(num_classes) for metric in all_metrics[class_label]]
all_ssim = [metric['ssim'] for class_label in range(num_classes) for metric in all_metrics[class_label]]
all_js = [metric['js'] for class_label in range(num_classes) for metric in all_metrics[class_label]]

# Compute percentiles for new thresholds (aim for top 20% for PSNR and SSIM, bottom 20% for JS)
psnr_threshold = np.percentile(all_psnr, 80)  # 80th percentile (top 20%)
ssim_threshold = np.percentile(all_ssim, 80)  # 80th percentile (top 20%)
js_threshold = np.percentile(all_js, 20)      # 20th percentile (bottom 20%)

print(f"\nNew Thresholds Based on Percentiles:")
print(f"PSNR > {psnr_threshold:.2f}")
print(f"SSIM > {ssim_threshold:.4f}")
print(f"JS < {js_threshold:.4f}")

# Step 4: Re-filter Good Images with New Thresholds
good_images_new = {class_label: [] for class_label in range(num_classes)}
for class_label in range(num_classes):
    class_dir = os.path.join(base_dir, str(class_label))
    good_class_dir = os.path.join(good_images_dir, str(class_label))
    os.makedirs(good_class_dir, exist_ok=True)

    for metric in all_metrics[class_label]:
        image_name = metric['image']
        avg_psnr = metric['psnr']
        avg_ssim = metric['ssim']
        avg_js = metric['js']

        # Check if the image meets the new criteria
        if avg_psnr > psnr_threshold and avg_ssim > ssim_threshold and avg_js < js_threshold:
            # Copy the image to the good images directory (if not already there)
            src_path = os.path.join(class_dir, image_name)
            dst_path = os.path.join(good_class_dir, image_name)
            if not os.path.exists(dst_path):
                pil_image = Image.open(src_path)
                pil_image.save(dst_path)
            good_images_new[class_label].append(image_name)

# Print the final number of good images
for class_label in range(num_classes):
    print(f"Final good images for class {class_label}: {len(good_images_new[class_label])} images saved to {os.path.join(good_images_dir, str(class_label))}")

# Clear GPU memory
if device.type == 'cuda':
    torch.cuda.empty_cache()
# Out:
# Using device: cuda:1
# GPU Name: NVIDIA RTX A5000
# GPU Memory Allocated: 0.00 MB
# C:\Users\hp\AppData\Local\Temp\ipykernel_35856\4067438651.py:243: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   cvae.load_state_dict(torch.load(model_path, map_location=device))
# Loaded CVAE model from cvae_vehicle_final.pth
# Found 4793 images across 5 classes.
# Classes: ['Hatchback', 'Other', 'Pickup', 'Seden', 'SUV']
# Generating and processing samples for class 0...
# Generated 500 samples for class 0
# Generating and processing samples for class 1...
# Generated 500 samples for class 1
# Generating and processing samples for class 2...
# Generated 500 samples for class 2
# Generating and processing samples for class 3...
# Generated 500 samples for class 3
# Generating and processing samples for class 4...
# Generated 500 samples for class 4
# Finished generating 500 enhanced samples per class and computing metrics
#
# Class 0 Metrics:
# Image: sample_0.png, PSNR: 7.54, SSIM: 0.0163, JS: 0.3810
# Image: sample_1.png, PSNR: 6.92, SSIM: 0.0207, JS: 0.3628
# Image: sample_2.png, PSNR: 9.76, SSIM: 0.0919, JS: 0.3765
# Image: sample_3.png, PSNR: 9.35, SSIM: 0.0765, JS: 0.3468
# Image: sample_4.png, PSNR: 7.78, SSIM: 0.0290, JS: 0.4008
# Image: sample_5.png, PSNR: 6.81, SSIM: 0.0345, JS: 0.3577
# Image: sample_6.png, PSNR: 8.23, SSIM: 0.0426, JS: 0.3345
# Image: sample_7.png, PSNR: 8.35, SSIM: 0.0511, JS: 0.4212
# Image: sample_8.png, PSNR: 7.30, SSIM: 0.0591, JS: 0.3825
# Image: sample_9.png, PSNR: 9.82, SSIM: 0.0869, JS: 0.3561
# Image: sample_10.png, PSNR: 9.23, SSIM: 0.0679, JS: 0.3674
# Image: sample_11.png, PSNR: 9.51, SSIM: 0.0714, JS: 0.3904
# Image: sample_12.png, PSNR: 7.23, SSIM: 0.0327, JS: 0.3325
# Image: sample_13.png, PSNR: 8.80, SSIM: 0.0655, JS: 0.3154
# Image: sample_14.png, PSNR: 9.62, SSIM: 0.0799, JS: 0.3593
# Image: sample_15.png, PSNR: 8.34, SSIM: 0.0577, JS: 0.4150
# Image: sample_16.png, PSNR: 8.69, SSIM: 0.0747, JS: 0.3284
# Image: sample_17.png, PSNR: 7.51, SSIM: 0.0334, JS: 0.4050
# Image: sample_18.png, PSNR: 7.04, SSIM: 0.0377, JS: 0.3578
# Image: sample_19.png, PSNR: 7.39, SSIM: 0.0353, JS: 0.3628
# Image: sample_20.png, PSNR: 9.58, SSIM: 0.0655, JS: 0.3342
# Image: sample_21.png, PSNR: 8.82, SSIM: 0.0544, JS: 0.4102
# Image: sample_22.png, PSNR: 8.78, SSIM: 0.0607, JS: 0.4083
# Image: sample_23.png, PSNR: 9.59, SSIM: 0.0987, JS: 0.3796
# Image: sample_24.png, PSNR: 8.11, SSIM: 0.0522, JS: 0.3935
# Image: sample_25.png, PSNR: 8.47, SSIM: 0.0601, JS: 0.3085
# Image: sample_26.png, PSNR: 7.62, SSIM: 0.0290, JS: 0.4282
# Image: sample_27.png, PSNR: 7.20, SSIM: 0.0398, JS: 0.3891
# Image: sample_28.png, PSNR: 8.95, SSIM: 0.0954, JS: 0.3278
# Image: sample_29.png, PSNR: 5.87, SSIM: 0.0242, JS: 0.3408
# Image: sample_30.png, PSNR: 6.97, SSIM: 0.0179, JS: 0.3688
# Image: sample_31.png, PSNR: 9.43, SSIM: 0.0927, JS: 0.4014
# Image: sample_32.png, PSNR: 7.39, SSIM: 0.0443, JS: 0.3371
# Image: sample_33.png, PSNR: 9.17, SSIM: 0.0613, JS: 0.3710
# Image: sample_34.png, PSNR: 7.13, SSIM: 0.0423, JS: 0.3849
# Image: sample_35.png, PSNR: 7.04, SSIM: 0.0427, JS: 0.3851
# Image: sample_36.png, PSNR: 9.75, SSIM: 0.0869, JS: 0.3489
# Image: sample_37.png, PSNR: 8.67, SSIM: 0.0708, JS: 0.3767
# Image: sample_38.png, PSNR: 9.68, SSIM: 0.0968, JS: 0.3778
# Image: sample_39.png, PSNR: 8.38, SSIM: 0.0390, JS: 0.4106
# Image: sample_40.png, PSNR: 7.28, SSIM: 0.0436, JS: 0.3614
# Image: sample_41.png, PSNR: 9.27, SSIM: 0.0831, JS: 0.3342
# Image: sample_42.png, PSNR: 9.29, SSIM: 0.0737, JS: 0.3871
# Image: sample_43.png, PSNR: 7.31, SSIM: 0.0486, JS: 0.3910
# Image: sample_44.png, PSNR: 9.65, SSIM: 0.1164, JS: 0.3714
# Image: sample_45.png, PSNR: 9.51, SSIM: 0.0882, JS: 0.3689
# Image: sample_46.png, PSNR: 9.95, SSIM: 0.1065, JS: 0.3575
# Image: sample_47.png, PSNR: 9.16, SSIM: 0.0530, JS: 0.3521
# Image: sample_48.png, PSNR: 7.86, SSIM: 0.0624, JS: 0.3255
# Image: sample_49.png, PSNR: 7.71, SSIM: 0.0432, JS: 0.3776
# Image: sample_50.png, PSNR: 8.00, SSIM: 0.0383, JS: 0.4043
# Image: sample_51.png, PSNR: 9.14, SSIM: 0.0477, JS: 0.3614
# Image: sample_52.png, PSNR: 10.00, SSIM: 0.0884, JS: 0.3587
# Image: sample_53.png, PSNR: 8.77, SSIM: 0.0505, JS: 0.3904
# Image: sample_54.png, PSNR: 8.78, SSIM: 0.0552, JS: 0.4073
# Image: sample_55.png, PSNR: 10.04, SSIM: 0.0727, JS: 0.3392
# Image: sample_56.png, PSNR: 7.77, SSIM: 0.0430, JS: 0.4489
# Image: sample_57.png, PSNR: 6.51, SSIM: 0.0405, JS: 0.3603
# Image: sample_58.png, PSNR: 8.76, SSIM: 0.0541, JS: 0.4183
# Image: sample_59.png, PSNR: 9.09, SSIM: 0.0658, JS: 0.3370
# Image: sample_60.png, PSNR: 7.06, SSIM: 0.0430, JS: 0.3691
# Image: sample_61.png, PSNR: 7.69, SSIM: 0.0452, JS: 0.3447
# Image: sample_62.png, PSNR: 8.88, SSIM: 0.0664, JS: 0.3440
# Image: sample_63.png, PSNR: 8.09, SSIM: 0.0372, JS: 0.3273
# Image: sample_64.png, PSNR: 7.17, SSIM: 0.0440, JS: 0.3835
# Image: sample_65.png, PSNR: 8.86, SSIM: 0.0519, JS: 0.3876
# Image: sample_66.png, PSNR: 9.28, SSIM: 0.0977, JS: 0.3269
# Image: sample_67.png, PSNR: 7.76, SSIM: 0.0360, JS: 0.3785
# Image: sample_68.png, PSNR: 8.75, SSIM: 0.0557, JS: 0.3973
# Image: sample_69.png, PSNR: 6.71, SSIM: 0.0230, JS: 0.3529
# Image: sample_70.png, PSNR: 8.52, SSIM: 0.0708, JS: 0.3507
# Image: sample_71.png, PSNR: 7.94, SSIM: 0.0600, JS: 0.4003
# Image: sample_72.png, PSNR: 7.05, SSIM: 0.0388, JS: 0.3696
# Image: sample_73.png, PSNR: 9.88, SSIM: 0.0899, JS: 0.3776
# Image: sample_74.png, PSNR: 6.39, SSIM: 0.0209, JS: 0.3466
# Image: sample_75.png, PSNR: 8.08, SSIM: 0.0465, JS: 0.4004
# Image: sample_76.png, PSNR: 7.74, SSIM: 0.0457, JS: 0.3332
# Image: sample_77.png, PSNR: 9.46, SSIM: 0.0916, JS: 0.3915
# Image: sample_78.png, PSNR: 8.17, SSIM: 0.0342, JS: 0.3441
# Image: sample_79.png, PSNR: 6.23, SSIM: 0.0277, JS: 0.3495
# Image: sample_80.png, PSNR: 6.94, SSIM: 0.0448, JS: 0.3798
# Image: sample_81.png, PSNR: 9.71, SSIM: 0.0862, JS: 0.3639
# Image: sample_82.png, PSNR: 9.43, SSIM: 0.0982, JS: 0.3385
# Image: sample_83.png, PSNR: 8.76, SSIM: 0.0386, JS: 0.3852
# Image: sample_84.png, PSNR: 6.75, SSIM: 0.0329, JS: 0.3340
# Image: sample_85.png, PSNR: 9.36, SSIM: 0.1062, JS: 0.3185
# Image: sample_86.png, PSNR: 9.09, SSIM: 0.0938, JS: 0.3171
# Image: sample_87.png, PSNR: 7.46, SSIM: 0.0327, JS: 0.3478
# Image: sample_88.png, PSNR: 8.30, SSIM: 0.0527, JS: 0.3501
# Image: sample_89.png, PSNR: 6.83, SSIM: 0.0161, JS: 0.3576
# Image: sample_90.png, PSNR: 8.94, SSIM: 0.0746, JS: 0.3860
# Image: sample_91.png, PSNR: 8.27, SSIM: 0.0504, JS: 0.3719
# Image: sample_92.png, PSNR: 9.08, SSIM: 0.0672, JS: 0.3407
# Image: sample_93.png, PSNR: 9.00, SSIM: 0.0703, JS: 0.3251
# Image: sample_94.png, PSNR: 6.81, SSIM: 0.0301, JS: 0.3665
# Image: sample_95.png, PSNR: 9.59, SSIM: 0.1114, JS: 0.3609
# Image: sample_96.png, PSNR: 9.46, SSIM: 0.0572, JS: 0.3583
# Image: sample_97.png, PSNR: 7.38, SSIM: 0.0629, JS: 0.3755
# Image: sample_98.png, PSNR: 9.56, SSIM: 0.0599, JS: 0.3519
# Image: sample_99.png, PSNR: 9.17, SSIM: 0.0849, JS: 0.3364
# Image: sample_100.png, PSNR: 8.85, SSIM: 0.0680, JS: 0.4263
# Image: sample_101.png, PSNR: 8.94, SSIM: 0.0568, JS: 0.3906
# Image: sample_102.png, PSNR: 9.44, SSIM: 0.0558, JS: 0.3306
# Image: sample_103.png, PSNR: 8.70, SSIM: 0.0606, JS: 0.4273
# Image: sample_104.png, PSNR: 9.51, SSIM: 0.0684, JS: 0.3667
# Image: sample_105.png, PSNR: 9.91, SSIM: 0.0957, JS: 0.3657
# Image: sample_106.png, PSNR: 6.58, SSIM: 0.0261, JS: 0.3651
# Image: sample_107.png, PSNR: 9.78, SSIM: 0.0815, JS: 0.3625
# Image: sample_108.png, PSNR: 10.04, SSIM: 0.0936, JS: 0.3578
# Image: sample_109.png, PSNR: 7.93, SSIM: 0.0268, JS: 0.3966
# Image: sample_110.png, PSNR: 8.95, SSIM: 0.0840, JS: 0.3072
# Image: sample_111.png, PSNR: 9.58, SSIM: 0.1115, JS: 0.3785
# Image: sample_112.png, PSNR: 7.97, SSIM: 0.0346, JS: 0.3951
# Image: sample_113.png, PSNR: 8.99, SSIM: 0.0657, JS: 0.3884
# Image: sample_114.png, PSNR: 9.57, SSIM: 0.1116, JS: 0.3866
# Image: sample_115.png, PSNR: 8.20, SSIM: 0.0397, JS: 0.4435
# Image: sample_116.png, PSNR: 9.57, SSIM: 0.0905, JS: 0.3832
# Image: sample_117.png, PSNR: 7.38, SSIM: 0.0375, JS: 0.4067
# Image: sample_118.png, PSNR: 7.78, SSIM: 0.0455, JS: 0.3739
# Image: sample_119.png, PSNR: 9.85, SSIM: 0.0769, JS: 0.3479
# Image: sample_120.png, PSNR: 9.03, SSIM: 0.0822, JS: 0.4009
# Image: sample_121.png, PSNR: 8.93, SSIM: 0.0721, JS: 0.4243
# Image: sample_122.png, PSNR: 8.24, SSIM: 0.0435, JS: 0.3600
# Image: sample_123.png, PSNR: 8.33, SSIM: 0.0481, JS: 0.3921
# Image: sample_124.png, PSNR: 7.31, SSIM: 0.0453, JS: 0.3863
# Image: sample_125.png, PSNR: 8.93, SSIM: 0.0740, JS: 0.3391
# Image: sample_126.png, PSNR: 8.63, SSIM: 0.0511, JS: 0.4094
# Image: sample_127.png, PSNR: 8.65, SSIM: 0.0602, JS: 0.4421
# Image: sample_128.png, PSNR: 8.64, SSIM: 0.0554, JS: 0.4218
# Image: sample_129.png, PSNR: 9.35, SSIM: 0.0770, JS: 0.3397
# Image: sample_130.png, PSNR: 7.26, SSIM: 0.0457, JS: 0.4373
# Image: sample_131.png, PSNR: 8.02, SSIM: 0.0462, JS: 0.3695
# Image: sample_132.png, PSNR: 7.98, SSIM: 0.0545, JS: 0.4177
# Image: sample_133.png, PSNR: 9.44, SSIM: 0.0896, JS: 0.3709
# Image: sample_134.png, PSNR: 8.49, SSIM: 0.0621, JS: 0.3839
# Image: sample_135.png, PSNR: 9.35, SSIM: 0.0668, JS: 0.3817
# Image: sample_136.png, PSNR: 9.65, SSIM: 0.0953, JS: 0.3920
# Image: sample_137.png, PSNR: 8.42, SSIM: 0.0404, JS: 0.3899
# Image: sample_138.png, PSNR: 8.35, SSIM: 0.0373, JS: 0.3316
# Image: sample_139.png, PSNR: 7.55, SSIM: 0.0446, JS: 0.3648
# Image: sample_140.png, PSNR: 9.80, SSIM: 0.0909, JS: 0.3657
# Image: sample_141.png, PSNR: 9.58, SSIM: 0.0873, JS: 0.3721
# Image: sample_142.png, PSNR: 10.08, SSIM: 0.0980, JS: 0.3374
# Image: sample_143.png, PSNR: 7.02, SSIM: 0.0311, JS: 0.3594
# Image: sample_144.png, PSNR: 9.51, SSIM: 0.0649, JS: 0.3286
# Image: sample_145.png, PSNR: 6.37, SSIM: 0.0172, JS: 0.3512
# Image: sample_146.png, PSNR: 7.09, SSIM: 0.0268, JS: 0.3136
# Image: sample_147.png, PSNR: 8.22, SSIM: 0.0445, JS: 0.4311
# Image: sample_148.png, PSNR: 7.12, SSIM: 0.0483, JS: 0.3882
# Image: sample_149.png, PSNR: 8.57, SSIM: 0.0489, JS: 0.3808
# Image: sample_150.png, PSNR: 8.63, SSIM: 0.0485, JS: 0.4122
# Image: sample_151.png, PSNR: 7.64, SSIM: 0.0541, JS: 0.3194
# Image: sample_152.png, PSNR: 9.80, SSIM: 0.0896, JS: 0.3343
# Image: sample_153.png, PSNR: 9.57, SSIM: 0.1053, JS: 0.3882
# Image: sample_154.png, PSNR: 7.33, SSIM: 0.0535, JS: 0.3502
# Image: sample_155.png, PSNR: 8.69, SSIM: 0.0409, JS: 0.4015
# Image: sample_156.png, PSNR: 9.76, SSIM: 0.1052, JS: 0.3728
# Image: sample_157.png, PSNR: 8.66, SSIM: 0.0475, JS: 0.3203
# Image: sample_158.png, PSNR: 7.56, SSIM: 0.0450, JS: 0.4226
# Image: sample_159.png, PSNR: 6.85, SSIM: 0.0248, JS: 0.3890
# Image: sample_160.png, PSNR: 9.57, SSIM: 0.0757, JS: 0.3544
# Image: sample_161.png, PSNR: 8.39, SSIM: 0.0374, JS: 0.3823
# Image: sample_162.png, PSNR: 7.57, SSIM: 0.0350, JS: 0.4474
# Image: sample_163.png, PSNR: 8.62, SSIM: 0.0621, JS: 0.4284
# Image: sample_164.png, PSNR: 8.23, SSIM: 0.0330, JS: 0.3485
# Image: sample_165.png, PSNR: 8.37, SSIM: 0.0427, JS: 0.3952
# Image: sample_166.png, PSNR: 10.08, SSIM: 0.1007, JS: 0.3467
# Image: sample_167.png, PSNR: 9.09, SSIM: 0.0688, JS: 0.3813
# Image: sample_168.png, PSNR: 8.72, SSIM: 0.0561, JS: 0.3845
# Image: sample_169.png, PSNR: 8.53, SSIM: 0.0570, JS: 0.4178
# Image: sample_170.png, PSNR: 9.19, SSIM: 0.0605, JS: 0.3797
# Image: sample_171.png, PSNR: 8.64, SSIM: 0.0382, JS: 0.3954
# Image: sample_172.png, PSNR: 9.15, SSIM: 0.0602, JS: 0.3683
# Image: sample_173.png, PSNR: 7.56, SSIM: 0.0346, JS: 0.3713
# Image: sample_174.png, PSNR: 8.22, SSIM: 0.0294, JS: 0.3505
# Image: sample_175.png, PSNR: 7.93, SSIM: 0.0615, JS: 0.3379
# Image: sample_176.png, PSNR: 7.48, SSIM: 0.0401, JS: 0.3971
# Image: sample_177.png, PSNR: 7.83, SSIM: 0.0451, JS: 0.2999
# Image: sample_178.png, PSNR: 8.66, SSIM: 0.0721, JS: 0.3164
# Image: sample_179.png, PSNR: 9.76, SSIM: 0.0953, JS: 0.3568
# Image: sample_180.png, PSNR: 8.77, SSIM: 0.0861, JS: 0.4209
# Image: sample_181.png, PSNR: 7.30, SSIM: 0.0466, JS: 0.3828
# Image: sample_182.png, PSNR: 8.90, SSIM: 0.0660, JS: 0.4062
# Image: sample_183.png, PSNR: 8.59, SSIM: 0.0552, JS: 0.4211
# Image: sample_184.png, PSNR: 7.98, SSIM: 0.0386, JS: 0.4297
# Image: sample_185.png, PSNR: 8.28, SSIM: 0.0457, JS: 0.3828
# Image: sample_186.png, PSNR: 9.41, SSIM: 0.0726, JS: 0.3355
# Image: sample_187.png, PSNR: 7.71, SSIM: 0.0475, JS: 0.3874
# Image: sample_188.png, PSNR: 10.13, SSIM: 0.1067, JS: 0.3385
# Image: sample_189.png, PSNR: 8.55, SSIM: 0.0470, JS: 0.4165
# Image: sample_190.png, PSNR: 9.59, SSIM: 0.0680, JS: 0.3595
# Image: sample_191.png, PSNR: 9.70, SSIM: 0.0877, JS: 0.3223
# Image: sample_192.png, PSNR: 8.08, SSIM: 0.0441, JS: 0.4126
# Image: sample_193.png, PSNR: 9.40, SSIM: 0.0605, JS: 0.3577
# Image: sample_194.png, PSNR: 9.54, SSIM: 0.0842, JS: 0.3315
# Image: sample_195.png, PSNR: 9.85, SSIM: 0.0824, JS: 0.3502
# Image: sample_196.png, PSNR: 9.74, SSIM: 0.1002, JS: 0.3805
# Image: sample_197.png, PSNR: 9.58, SSIM: 0.0759, JS: 0.3611
# Image: sample_198.png, PSNR: 9.43, SSIM: 0.0884, JS: 0.3814
# Image: sample_199.png, PSNR: 6.60, SSIM: 0.0263, JS: 0.3583
# Image: sample_200.png, PSNR: 8.86, SSIM: 0.0950, JS: 0.3217
# Image: sample_201.png, PSNR: 7.17, SSIM: 0.0435, JS: 0.3289
# Image: sample_202.png, PSNR: 7.26, SSIM: 0.0361, JS: 0.4116
# Image: sample_203.png, PSNR: 9.61, SSIM: 0.0767, JS: 0.3627
# Image: sample_204.png, PSNR: 9.53, SSIM: 0.0741, JS: 0.3592
# Image: sample_205.png, PSNR: 7.75, SSIM: 0.0445, JS: 0.3374
# Image: sample_206.png, PSNR: 9.64, SSIM: 0.0811, JS: 0.3768
# Image: sample_207.png, PSNR: 9.04, SSIM: 0.0481, JS: 0.3986
# Image: sample_208.png, PSNR: 9.00, SSIM: 0.0712, JS: 0.4045
# Image: sample_209.png, PSNR: 7.95, SSIM: 0.0402, JS: 0.4246
# Image: sample_210.png, PSNR: 8.77, SSIM: 0.0505, JS: 0.4001
# Image: sample_211.png, PSNR: 9.58, SSIM: 0.0910, JS: 0.3300
# Image: sample_212.png, PSNR: 8.78, SSIM: 0.0638, JS: 0.3736
# Image: sample_213.png, PSNR: 8.32, SSIM: 0.0480, JS: 0.3911
# Image: sample_214.png, PSNR: 8.62, SSIM: 0.0561, JS: 0.3790
# Image: sample_215.png, PSNR: 9.86, SSIM: 0.0898, JS: 0.3565
# Image: sample_216.png, PSNR: 9.92, SSIM: 0.0760, JS: 0.3569
# Image: sample_217.png, PSNR: 9.78, SSIM: 0.0912, JS: 0.3310
# Image: sample_218.png, PSNR: 8.78, SSIM: 0.0721, JS: 0.3988
# Image: sample_219.png, PSNR: 9.74, SSIM: 0.0796, JS: 0.3579
# Image: sample_220.png, PSNR: 9.03, SSIM: 0.0902, JS: 0.3225
# Image: sample_221.png, PSNR: 8.24, SSIM: 0.0357, JS: 0.3766
# Image: sample_222.png, PSNR: 6.68, SSIM: 0.0339, JS: 0.3602
# Image: sample_223.png, PSNR: 7.56, SSIM: 0.0405, JS: 0.3888
# Image: sample_224.png, PSNR: 8.29, SSIM: 0.0427, JS: 0.4482
# Image: sample_225.png, PSNR: 9.05, SSIM: 0.0713, JS: 0.3841
# Image: sample_226.png, PSNR: 9.49, SSIM: 0.0892, JS: 0.3656
# Image: sample_227.png, PSNR: 8.64, SSIM: 0.0553, JS: 0.4036
# Image: sample_228.png, PSNR: 6.31, SSIM: 0.0222, JS: 0.3572
# Image: sample_229.png, PSNR: 9.21, SSIM: 0.0624, JS: 0.3168
# Image: sample_230.png, PSNR: 7.42, SSIM: 0.0365, JS: 0.4228
# Image: sample_231.png, PSNR: 9.54, SSIM: 0.0906, JS: 0.3749
# Image: sample_232.png, PSNR: 9.30, SSIM: 0.0826, JS: 0.3944
# Image: sample_233.png, PSNR: 7.99, SSIM: 0.0384, JS: 0.4319
# Image: sample_234.png, PSNR: 8.68, SSIM: 0.0705, JS: 0.3063
# Image: sample_235.png, PSNR: 7.32, SSIM: 0.0356, JS: 0.3699
# Image: sample_236.png, PSNR: 8.52, SSIM: 0.0709, JS: 0.3672
# Image: sample_237.png, PSNR: 8.96, SSIM: 0.0715, JS: 0.3568
# Image: sample_238.png, PSNR: 9.31, SSIM: 0.0889, JS: 0.3847
# Image: sample_239.png, PSNR: 9.41, SSIM: 0.0632, JS: 0.3730
# Image: sample_240.png, PSNR: 8.98, SSIM: 0.0569, JS: 0.4227
# Image: sample_241.png, PSNR: 8.46, SSIM: 0.0525, JS: 0.3673
# Image: sample_242.png, PSNR: 8.64, SSIM: 0.0464, JS: 0.4237
# Image: sample_243.png, PSNR: 9.79, SSIM: 0.1096, JS: 0.3700
# Image: sample_244.png, PSNR: 9.87, SSIM: 0.0889, JS: 0.3634
# Image: sample_245.png, PSNR: 8.76, SSIM: 0.0514, JS: 0.4236
# Image: sample_246.png, PSNR: 6.92, SSIM: 0.0190, JS: 0.3150
# Image: sample_247.png, PSNR: 8.46, SSIM: 0.0605, JS: 0.4284
# Image: sample_248.png, PSNR: 7.33, SSIM: 0.0567, JS: 0.3897
# Image: sample_249.png, PSNR: 8.07, SSIM: 0.0535, JS: 0.3336
# Image: sample_250.png, PSNR: 9.18, SSIM: 0.0740, JS: 0.4031
# Image: sample_251.png, PSNR: 9.60, SSIM: 0.1029, JS: 0.3645
# Image: sample_252.png, PSNR: 8.90, SSIM: 0.0397, JS: 0.3979
# Image: sample_253.png, PSNR: 7.41, SSIM: 0.0475, JS: 0.3377
# Image: sample_254.png, PSNR: 9.58, SSIM: 0.0693, JS: 0.3459
# Image: sample_255.png, PSNR: 9.76, SSIM: 0.0973, JS: 0.3630
# Image: sample_256.png, PSNR: 7.57, SSIM: 0.0346, JS: 0.3746
# Image: sample_257.png, PSNR: 6.48, SSIM: 0.0145, JS: 0.3758
# Image: sample_258.png, PSNR: 9.76, SSIM: 0.1038, JS: 0.3852
# Image: sample_259.png, PSNR: 8.16, SSIM: 0.0379, JS: 0.3404
# Image: sample_260.png, PSNR: 8.26, SSIM: 0.0533, JS: 0.3261
# Image: sample_261.png, PSNR: 9.92, SSIM: 0.0807, JS: 0.3410
# Image: sample_262.png, PSNR: 9.30, SSIM: 0.0742, JS: 0.3845
# Image: sample_263.png, PSNR: 7.68, SSIM: 0.0333, JS: 0.4281
# Image: sample_264.png, PSNR: 7.50, SSIM: 0.0652, JS: 0.3352
# Image: sample_265.png, PSNR: 7.00, SSIM: 0.0318, JS: 0.3619
# Image: sample_266.png, PSNR: 9.50, SSIM: 0.0832, JS: 0.3539
# Image: sample_267.png, PSNR: 7.70, SSIM: 0.0298, JS: 0.3875
# Image: sample_268.png, PSNR: 8.97, SSIM: 0.0557, JS: 0.4113
# Image: sample_269.png, PSNR: 8.11, SSIM: 0.0468, JS: 0.4167
# Image: sample_270.png, PSNR: 8.87, SSIM: 0.0553, JS: 0.4144
# Image: sample_271.png, PSNR: 8.87, SSIM: 0.0707, JS: 0.4284
# Image: sample_272.png, PSNR: 8.11, SSIM: 0.0802, JS: 0.3375
# Image: sample_273.png, PSNR: 7.24, SSIM: 0.0360, JS: 0.3308
# Image: sample_274.png, PSNR: 8.26, SSIM: 0.0575, JS: 0.4113
# Image: sample_275.png, PSNR: 9.35, SSIM: 0.0925, JS: 0.3268
# Image: sample_276.png, PSNR: 8.73, SSIM: 0.0741, JS: 0.4090
# Image: sample_277.png, PSNR: 9.96, SSIM: 0.0880, JS: 0.3676
# Image: sample_278.png, PSNR: 7.67, SSIM: 0.0337, JS: 0.3749
# Image: sample_279.png, PSNR: 9.20, SSIM: 0.0503, JS: 0.3351
# Image: sample_280.png, PSNR: 7.51, SSIM: 0.0526, JS: 0.3827
# Image: sample_281.png, PSNR: 9.07, SSIM: 0.0679, JS: 0.3504
# Image: sample_282.png, PSNR: 9.88, SSIM: 0.0884, JS: 0.3345
# Image: sample_283.png, PSNR: 8.83, SSIM: 0.0580, JS: 0.3296
# Image: sample_284.png, PSNR: 8.87, SSIM: 0.0545, JS: 0.4053
# Image: sample_285.png, PSNR: 8.83, SSIM: 0.0466, JS: 0.3774
# Image: sample_286.png, PSNR: 7.13, SSIM: 0.0370, JS: 0.3537
# Image: sample_287.png, PSNR: 8.01, SSIM: 0.0312, JS: 0.4062
# Image: sample_288.png, PSNR: 9.01, SSIM: 0.0764, JS: 0.4128
# Image: sample_289.png, PSNR: 9.06, SSIM: 0.0635, JS: 0.3341
# Image: sample_290.png, PSNR: 8.39, SSIM: 0.0386, JS: 0.4210
# Image: sample_291.png, PSNR: 10.23, SSIM: 0.0892, JS: 0.3383
# Image: sample_292.png, PSNR: 7.71, SSIM: 0.0540, JS: 0.3752
# Image: sample_293.png, PSNR: 9.10, SSIM: 0.0664, JS: 0.3435
# Image: sample_294.png, PSNR: 9.87, SSIM: 0.0953, JS: 0.3690
# Image: sample_295.png, PSNR: 8.19, SSIM: 0.0388, JS: 0.3998
# Image: sample_296.png, PSNR: 8.46, SSIM: 0.0467, JS: 0.4181
# Image: sample_297.png, PSNR: 8.54, SSIM: 0.0449, JS: 0.4206
# Image: sample_298.png, PSNR: 8.53, SSIM: 0.0469, JS: 0.4172
# Image: sample_299.png, PSNR: 7.34, SSIM: 0.0474, JS: 0.3850
# Image: sample_300.png, PSNR: 6.45, SSIM: 0.0183, JS: 0.3450
# Image: sample_301.png, PSNR: 8.53, SSIM: 0.0429, JS: 0.4032
# Image: sample_302.png, PSNR: 8.22, SSIM: 0.0782, JS: 0.3352
# Image: sample_303.png, PSNR: 9.65, SSIM: 0.0815, JS: 0.3344
# Image: sample_304.png, PSNR: 7.73, SSIM: 0.0384, JS: 0.4276
# Image: sample_305.png, PSNR: 8.81, SSIM: 0.0562, JS: 0.4030
# Image: sample_306.png, PSNR: 8.37, SSIM: 0.0590, JS: 0.4231
# Image: sample_307.png, PSNR: 7.82, SSIM: 0.0448, JS: 0.4275
# Image: sample_308.png, PSNR: 8.55, SSIM: 0.0964, JS: 0.3265
# Image: sample_309.png, PSNR: 7.64, SSIM: 0.0418, JS: 0.3462
# Image: sample_310.png, PSNR: 7.17, SSIM: 0.0488, JS: 0.3835
# Image: sample_311.png, PSNR: 7.95, SSIM: 0.0292, JS: 0.4502
# Image: sample_312.png, PSNR: 9.97, SSIM: 0.0898, JS: 0.3583
# Image: sample_313.png, PSNR: 7.80, SSIM: 0.0291, JS: 0.4328
# Image: sample_314.png, PSNR: 9.21, SSIM: 0.0837, JS: 0.3535
# Image: sample_315.png, PSNR: 9.83, SSIM: 0.0773, JS: 0.3633
# Image: sample_316.png, PSNR: 9.15, SSIM: 0.0715, JS: 0.3210
# Image: sample_317.png, PSNR: 9.27, SSIM: 0.0584, JS: 0.3666
# Image: sample_318.png, PSNR: 7.31, SSIM: 0.0600, JS: 0.3785
# Image: sample_319.png, PSNR: 9.77, SSIM: 0.0728, JS: 0.3730
# Image: sample_320.png, PSNR: 8.48, SSIM: 0.0571, JS: 0.4389
# Image: sample_321.png, PSNR: 7.68, SSIM: 0.0523, JS: 0.3884
# Image: sample_322.png, PSNR: 7.27, SSIM: 0.0440, JS: 0.4044
# Image: sample_323.png, PSNR: 7.91, SSIM: 0.0497, JS: 0.3795
# Image: sample_324.png, PSNR: 7.58, SSIM: 0.0319, JS: 0.3382
# Image: sample_325.png, PSNR: 7.23, SSIM: 0.0453, JS: 0.3813
# Image: sample_326.png, PSNR: 9.46, SSIM: 0.1210, JS: 0.3782
# Image: sample_327.png, PSNR: 8.78, SSIM: 0.0569, JS: 0.4313
# Image: sample_328.png, PSNR: 9.25, SSIM: 0.0604, JS: 0.3716
# Image: sample_329.png, PSNR: 7.83, SSIM: 0.0407, JS: 0.3986
# Image: sample_330.png, PSNR: 7.48, SSIM: 0.0449, JS: 0.4167
# Image: sample_331.png, PSNR: 7.65, SSIM: 0.0325, JS: 0.3841
# Image: sample_332.png, PSNR: 7.28, SSIM: 0.0257, JS: 0.3796
# Image: sample_333.png, PSNR: 8.17, SSIM: 0.0480, JS: 0.3508
# Image: sample_334.png, PSNR: 9.28, SSIM: 0.1020, JS: 0.4041
# Image: sample_335.png, PSNR: 7.38, SSIM: 0.0437, JS: 0.3143
# Image: sample_336.png, PSNR: 9.76, SSIM: 0.0940, JS: 0.3781
# Image: sample_337.png, PSNR: 6.73, SSIM: 0.0285, JS: 0.3629
# Image: sample_338.png, PSNR: 9.14, SSIM: 0.0772, JS: 0.3459
# Image: sample_339.png, PSNR: 7.76, SSIM: 0.0454, JS: 0.3918
# Image: sample_340.png, PSNR: 7.96, SSIM: 0.0321, JS: 0.4043
# Image: sample_341.png, PSNR: 7.65, SSIM: 0.0249, JS: 0.4312
# Image: sample_342.png, PSNR: 9.30, SSIM: 0.0969, JS: 0.3157
# Image: sample_343.png, PSNR: 9.50, SSIM: 0.0993, JS: 0.3669
# Image: sample_344.png, PSNR: 7.93, SSIM: 0.0431, JS: 0.3971
# Image: sample_345.png, PSNR: 9.04, SSIM: 0.0686, JS: 0.3821
# Image: sample_346.png, PSNR: 7.50, SSIM: 0.0496, JS: 0.3781
# Image: sample_347.png, PSNR: 7.61, SSIM: 0.0394, JS: 0.4003
# Image: sample_348.png, PSNR: 8.69, SSIM: 0.0548, JS: 0.4031
# Image: sample_349.png, PSNR: 10.47, SSIM: 0.1510, JS: 0.3443
# Image: sample_350.png, PSNR: 9.82, SSIM: 0.0936, JS: 0.3594
# Image: sample_351.png, PSNR: 8.29, SSIM: 0.0490, JS: 0.3801
# Image: sample_352.png, PSNR: 7.39, SSIM: 0.0357, JS: 0.3955
# Image: sample_353.png, PSNR: 8.28, SSIM: 0.0839, JS: 0.3233
# Image: sample_354.png, PSNR: 8.55, SSIM: 0.0402, JS: 0.3985
# Image: sample_355.png, PSNR: 7.46, SSIM: 0.0637, JS: 0.3744
# Image: sample_356.png, PSNR: 9.83, SSIM: 0.0748, JS: 0.3590
# Image: sample_357.png, PSNR: 8.13, SSIM: 0.0440, JS: 0.4297
# Image: sample_358.png, PSNR: 9.89, SSIM: 0.1000, JS: 0.3596
# Image: sample_359.png, PSNR: 7.83, SSIM: 0.0407, JS: 0.3441
# Image: sample_360.png, PSNR: 9.66, SSIM: 0.0963, JS: 0.3723
# Image: sample_361.png, PSNR: 8.33, SSIM: 0.0570, JS: 0.4172
# Image: sample_362.png, PSNR: 7.88, SSIM: 0.0318, JS: 0.4561
# Image: sample_363.png, PSNR: 9.03, SSIM: 0.0492, JS: 0.3813
# Image: sample_364.png, PSNR: 8.69, SSIM: 0.0591, JS: 0.4276
# Image: sample_365.png, PSNR: 8.21, SSIM: 0.0428, JS: 0.4567
# Image: sample_366.png, PSNR: 8.35, SSIM: 0.0394, JS: 0.4313
# Image: sample_367.png, PSNR: 8.97, SSIM: 0.0737, JS: 0.3280
# Image: sample_368.png, PSNR: 9.18, SSIM: 0.0571, JS: 0.3602
# Image: sample_369.png, PSNR: 8.81, SSIM: 0.0690, JS: 0.4323
# Image: sample_370.png, PSNR: 7.95, SSIM: 0.0449, JS: 0.4445
# Image: sample_371.png, PSNR: 7.97, SSIM: 0.0350, JS: 0.3866
# Image: sample_372.png, PSNR: 8.34, SSIM: 0.0505, JS: 0.4506
# Image: sample_373.png, PSNR: 7.70, SSIM: 0.0447, JS: 0.3052
# Image: sample_374.png, PSNR: 7.09, SSIM: 0.0386, JS: 0.3757
# Image: sample_375.png, PSNR: 8.95, SSIM: 0.0798, JS: 0.4245
# Image: sample_376.png, PSNR: 7.06, SSIM: 0.0346, JS: 0.3682
# Image: sample_377.png, PSNR: 8.71, SSIM: 0.0586, JS: 0.4305
# Image: sample_378.png, PSNR: 7.33, SSIM: 0.0482, JS: 0.3948
# Image: sample_379.png, PSNR: 9.48, SSIM: 0.0655, JS: 0.3888
# Image: sample_380.png, PSNR: 8.17, SSIM: 0.0529, JS: 0.3251
# Image: sample_381.png, PSNR: 7.72, SSIM: 0.0503, JS: 0.3991
# Image: sample_382.png, PSNR: 9.81, SSIM: 0.0782, JS: 0.3570
# Image: sample_383.png, PSNR: 6.74, SSIM: 0.0255, JS: 0.3581
# Image: sample_384.png, PSNR: 9.02, SSIM: 0.0567, JS: 0.3349
# Image: sample_385.png, PSNR: 9.14, SSIM: 0.0738, JS: 0.3899
# Image: sample_386.png, PSNR: 8.86, SSIM: 0.0455, JS: 0.3914
# Image: sample_387.png, PSNR: 8.83, SSIM: 0.0713, JS: 0.4244
# Image: sample_388.png, PSNR: 9.59, SSIM: 0.0914, JS: 0.3746
# Image: sample_389.png, PSNR: 8.70, SSIM: 0.0935, JS: 0.3347
# Image: sample_390.png, PSNR: 7.09, SSIM: 0.0408, JS: 0.3496
# Image: sample_391.png, PSNR: 8.63, SSIM: 0.0463, JS: 0.4444
# Image: sample_392.png, PSNR: 8.52, SSIM: 0.0526, JS: 0.3174
# Image: sample_393.png, PSNR: 9.67, SSIM: 0.0866, JS: 0.3633
# Image: sample_394.png, PSNR: 9.45, SSIM: 0.0561, JS: 0.3813
# Image: sample_395.png, PSNR: 8.56, SSIM: 0.0718, JS: 0.4562
# Image: sample_396.png, PSNR: 7.28, SSIM: 0.0410, JS: 0.3806
# Image: sample_397.png, PSNR: 6.81, SSIM: 0.0362, JS: 0.3215
# Image: sample_398.png, PSNR: 9.43, SSIM: 0.0597, JS: 0.3505
# Image: sample_399.png, PSNR: 6.94, SSIM: 0.0409, JS: 0.3573
# Image: sample_400.png, PSNR: 8.06, SSIM: 0.0632, JS: 0.3494
# Image: sample_401.png, PSNR: 9.47, SSIM: 0.0870, JS: 0.3283
# Image: sample_402.png, PSNR: 10.14, SSIM: 0.0959, JS: 0.3623
# Image: sample_403.png, PSNR: 9.60, SSIM: 0.1090, JS: 0.3804
# Image: sample_404.png, PSNR: 7.41, SSIM: 0.0416, JS: 0.3705
# Image: sample_405.png, PSNR: 8.18, SSIM: 0.0359, JS: 0.3890
# Image: sample_406.png, PSNR: 7.36, SSIM: 0.0432, JS: 0.3895
# Image: sample_407.png, PSNR: 7.50, SSIM: 0.0427, JS: 0.4170
# Image: sample_408.png, PSNR: 8.23, SSIM: 0.0396, JS: 0.3743
# Image: sample_409.png, PSNR: 7.88, SSIM: 0.0491, JS: 0.3755
# Image: sample_410.png, PSNR: 7.03, SSIM: 0.0224, JS: 0.3516
# Image: sample_411.png, PSNR: 9.75, SSIM: 0.1056, JS: 0.3399
# Image: sample_412.png, PSNR: 7.81, SSIM: 0.0475, JS: 0.4152
# Image: sample_413.png, PSNR: 9.26, SSIM: 0.0623, JS: 0.3319
# Image: sample_414.png, PSNR: 7.73, SSIM: 0.0572, JS: 0.3086
# Image: sample_415.png, PSNR: 8.43, SSIM: 0.0624, JS: 0.3097
# Image: sample_416.png, PSNR: 9.84, SSIM: 0.0841, JS: 0.3403
# Image: sample_417.png, PSNR: 8.26, SSIM: 0.0400, JS: 0.3692
# Image: sample_418.png, PSNR: 8.75, SSIM: 0.0600, JS: 0.4260
# Image: sample_419.png, PSNR: 8.03, SSIM: 0.0400, JS: 0.4053
# Image: sample_420.png, PSNR: 7.20, SSIM: 0.0524, JS: 0.4136
# Image: sample_421.png, PSNR: 9.16, SSIM: 0.0787, JS: 0.3371
# Image: sample_422.png, PSNR: 7.98, SSIM: 0.0486, JS: 0.3982
# Image: sample_423.png, PSNR: 9.63, SSIM: 0.0687, JS: 0.3650
# Image: sample_424.png, PSNR: 9.69, SSIM: 0.1030, JS: 0.3661
# Image: sample_425.png, PSNR: 7.02, SSIM: 0.0332, JS: 0.4098
# Image: sample_426.png, PSNR: 6.84, SSIM: 0.0480, JS: 0.3782
# Image: sample_427.png, PSNR: 8.17, SSIM: 0.0627, JS: 0.3396
# Image: sample_428.png, PSNR: 9.55, SSIM: 0.1338, JS: 0.3268
# Image: sample_429.png, PSNR: 7.51, SSIM: 0.0466, JS: 0.4029
# Image: sample_430.png, PSNR: 8.26, SSIM: 0.0507, JS: 0.4418
# Image: sample_431.png, PSNR: 5.91, SSIM: 0.0376, JS: 0.3636
# Image: sample_432.png, PSNR: 8.99, SSIM: 0.0569, JS: 0.3669
# Image: sample_433.png, PSNR: 7.68, SSIM: 0.0391, JS: 0.3948
# Image: sample_434.png, PSNR: 7.66, SSIM: 0.0443, JS: 0.4141
# Image: sample_435.png, PSNR: 8.42, SSIM: 0.0253, JS: 0.3924
# Image: sample_436.png, PSNR: 8.19, SSIM: 0.0458, JS: 0.4242
# Image: sample_437.png, PSNR: 9.47, SSIM: 0.0977, JS: 0.3776
# Image: sample_438.png, PSNR: 6.52, SSIM: 0.0398, JS: 0.3570
# Image: sample_439.png, PSNR: 9.61, SSIM: 0.0650, JS: 0.3570
# Image: sample_440.png, PSNR: 9.91, SSIM: 0.0862, JS: 0.3478
# Image: sample_441.png, PSNR: 8.54, SSIM: 0.0567, JS: 0.4318
# Image: sample_442.png, PSNR: 8.14, SSIM: 0.0698, JS: 0.3338
# Image: sample_443.png, PSNR: 8.24, SSIM: 0.0505, JS: 0.3824
# Image: sample_444.png, PSNR: 9.68, SSIM: 0.0799, JS: 0.3528
# Image: sample_445.png, PSNR: 9.25, SSIM: 0.0908, JS: 0.3289
# Image: sample_446.png, PSNR: 7.45, SSIM: 0.0464, JS: 0.3668
# Image: sample_447.png, PSNR: 9.26, SSIM: 0.0977, JS: 0.3192
# Image: sample_448.png, PSNR: 7.33, SSIM: 0.0458, JS: 0.3537
# Image: sample_449.png, PSNR: 9.95, SSIM: 0.1104, JS: 0.3580
# Image: sample_450.png, PSNR: 8.77, SSIM: 0.0641, JS: 0.3346
# Image: sample_451.png, PSNR: 6.60, SSIM: 0.0233, JS: 0.3599
# Image: sample_452.png, PSNR: 8.73, SSIM: 0.0711, JS: 0.4420
# Image: sample_453.png, PSNR: 8.12, SSIM: 0.0515, JS: 0.3186
# Image: sample_454.png, PSNR: 9.82, SSIM: 0.0772, JS: 0.3557
# Image: sample_455.png, PSNR: 7.97, SSIM: 0.0427, JS: 0.4169
# Image: sample_456.png, PSNR: 9.45, SSIM: 0.0967, JS: 0.3692
# Image: sample_457.png, PSNR: 7.64, SSIM: 0.0601, JS: 0.3827
# Image: sample_458.png, PSNR: 8.79, SSIM: 0.0790, JS: 0.3347
# Image: sample_459.png, PSNR: 9.01, SSIM: 0.0739, JS: 0.3434
# Image: sample_460.png, PSNR: 9.05, SSIM: 0.0488, JS: 0.3910
# Image: sample_461.png, PSNR: 8.73, SSIM: 0.0548, JS: 0.3945
# Image: sample_462.png, PSNR: 9.53, SSIM: 0.0586, JS: 0.3765
# Image: sample_463.png, PSNR: 8.95, SSIM: 0.0685, JS: 0.3969
# Image: sample_464.png, PSNR: 9.28, SSIM: 0.0979, JS: 0.3200
# Image: sample_465.png, PSNR: 8.64, SSIM: 0.0609, JS: 0.3647
# Image: sample_466.png, PSNR: 9.51, SSIM: 0.0954, JS: 0.3298
# Image: sample_467.png, PSNR: 6.88, SSIM: 0.0318, JS: 0.3429
# Image: sample_468.png, PSNR: 8.26, SSIM: 0.0531, JS: 0.4310
# Image: sample_469.png, PSNR: 8.05, SSIM: 0.0378, JS: 0.3681
# Image: sample_470.png, PSNR: 9.60, SSIM: 0.1015, JS: 0.3863
# Image: sample_471.png, PSNR: 8.62, SSIM: 0.0603, JS: 0.3220
# Image: sample_472.png, PSNR: 9.99, SSIM: 0.0981, JS: 0.3724
# Image: sample_473.png, PSNR: 7.64, SSIM: 0.0297, JS: 0.3877
# Image: sample_474.png, PSNR: 8.38, SSIM: 0.0551, JS: 0.4331
# Image: sample_475.png, PSNR: 7.51, SSIM: 0.0418, JS: 0.3846
# Image: sample_476.png, PSNR: 9.13, SSIM: 0.0686, JS: 0.3991
# Image: sample_477.png, PSNR: 9.36, SSIM: 0.0969, JS: 0.3935
# Image: sample_478.png, PSNR: 7.93, SSIM: 0.0417, JS: 0.3552
# Image: sample_479.png, PSNR: 9.33, SSIM: 0.0556, JS: 0.3550
# Image: sample_480.png, PSNR: 8.65, SSIM: 0.0391, JS: 0.4254
# Image: sample_481.png, PSNR: 8.68, SSIM: 0.0763, JS: 0.4281
# Image: sample_482.png, PSNR: 9.89, SSIM: 0.0891, JS: 0.3614
# Image: sample_483.png, PSNR: 9.05, SSIM: 0.0691, JS: 0.3312
# Image: sample_484.png, PSNR: 8.96, SSIM: 0.0764, JS: 0.3527
# Image: sample_485.png, PSNR: 7.97, SSIM: 0.0440, JS: 0.4172
# Image: sample_486.png, PSNR: 7.37, SSIM: 0.0491, JS: 0.4095
# Image: sample_487.png, PSNR: 9.55, SSIM: 0.0897, JS: 0.3871
# Image: sample_488.png, PSNR: 7.37, SSIM: 0.0549, JS: 0.3942
# Image: sample_489.png, PSNR: 7.17, SSIM: 0.0396, JS: 0.4066
# Image: sample_490.png, PSNR: 9.40, SSIM: 0.0873, JS: 0.3856
# Image: sample_491.png, PSNR: 7.35, SSIM: 0.0264, JS: 0.3594
# Image: sample_492.png, PSNR: 7.82, SSIM: 0.0461, JS: 0.3822
# Image: sample_493.png, PSNR: 8.56, SSIM: 0.0576, JS: 0.3100
# Image: sample_494.png, PSNR: 8.59, SSIM: 0.0469, JS: 0.4229
# Image: sample_495.png, PSNR: 7.68, SSIM: 0.0319, JS: 0.3173
# Image: sample_496.png, PSNR: 8.04, SSIM: 0.0335, JS: 0.4321
# Image: sample_497.png, PSNR: 8.33, SSIM: 0.0645, JS: 0.3575
# Image: sample_498.png, PSNR: 8.13, SSIM: 0.0338, JS: 0.4542
# Image: sample_499.png, PSNR: 8.83, SSIM: 0.0482, JS: 0.4045
# Initially selected good images for class 0: 0
#
# Class 1 Metrics:
# Image: sample_0.png, PSNR: 9.53, SSIM: 0.0897, JS: 0.3519
# Image: sample_1.png, PSNR: 10.34, SSIM: 0.0832, JS: 0.3279
# Image: sample_2.png, PSNR: 9.23, SSIM: 0.0330, JS: 0.3497
# Image: sample_3.png, PSNR: 9.87, SSIM: 0.0921, JS: 0.3241
# Image: sample_4.png, PSNR: 10.45, SSIM: 0.0767, JS: 0.3314
# Image: sample_5.png, PSNR: 9.05, SSIM: 0.0403, JS: 0.3797
# Image: sample_6.png, PSNR: 8.00, SSIM: 0.0385, JS: 0.4053
# Image: sample_7.png, PSNR: 10.05, SSIM: 0.0891, JS: 0.2974
# Image: sample_8.png, PSNR: 9.98, SSIM: 0.0957, JS: 0.3146
# Image: sample_9.png, PSNR: 9.86, SSIM: 0.0902, JS: 0.3344
# Image: sample_10.png, PSNR: 9.21, SSIM: 0.0499, JS: 0.3212
# Image: sample_11.png, PSNR: 8.59, SSIM: 0.0693, JS: 0.3668
# Image: sample_12.png, PSNR: 9.83, SSIM: 0.0850, JS: 0.3329
# Image: sample_13.png, PSNR: 9.73, SSIM: 0.0991, JS: 0.3449
# Image: sample_14.png, PSNR: 9.29, SSIM: 0.0624, JS: 0.3797
# Image: sample_15.png, PSNR: 9.78, SSIM: 0.0622, JS: 0.3272
# Image: sample_16.png, PSNR: 9.47, SSIM: 0.0724, JS: 0.3484
# Image: sample_17.png, PSNR: 10.19, SSIM: 0.0470, JS: 0.3096
# Image: sample_18.png, PSNR: 10.51, SSIM: 0.0925, JS: 0.3158
# Image: sample_19.png, PSNR: 9.63, SSIM: 0.0798, JS: 0.3048
# Image: sample_20.png, PSNR: 9.54, SSIM: 0.0602, JS: 0.3438
# Image: sample_21.png, PSNR: 10.01, SSIM: 0.0954, JS: 0.3364
# Image: sample_22.png, PSNR: 10.02, SSIM: 0.0603, JS: 0.3435
# Image: sample_23.png, PSNR: 9.72, SSIM: 0.0892, JS: 0.3558
# Image: sample_24.png, PSNR: 10.27, SSIM: 0.0753, JS: 0.3236
# Image: sample_25.png, PSNR: 10.60, SSIM: 0.0972, JS: 0.2882
# Image: sample_26.png, PSNR: 9.69, SSIM: 0.0432, JS: 0.3061
# Image: sample_27.png, PSNR: 10.29, SSIM: 0.0903, JS: 0.3102
# Image: sample_28.png, PSNR: 9.95, SSIM: 0.0908, JS: 0.2991
# Image: sample_29.png, PSNR: 9.36, SSIM: 0.0827, JS: 0.3673
# Image: sample_30.png, PSNR: 10.00, SSIM: 0.0777, JS: 0.3178
# Image: sample_31.png, PSNR: 10.30, SSIM: 0.0756, JS: 0.3229
# Image: sample_32.png, PSNR: 9.90, SSIM: 0.0695, JS: 0.3132
# Image: sample_33.png, PSNR: 9.89, SSIM: 0.0558, JS: 0.3312
# Image: sample_34.png, PSNR: 9.58, SSIM: 0.0881, JS: 0.3510
# Image: sample_35.png, PSNR: 8.54, SSIM: 0.0383, JS: 0.3737
# Image: sample_36.png, PSNR: 9.38, SSIM: 0.0549, JS: 0.3363
# Image: sample_37.png, PSNR: 10.19, SSIM: 0.0696, JS: 0.2944
# Image: sample_38.png, PSNR: 9.21, SSIM: 0.0579, JS: 0.3273
# Image: sample_39.png, PSNR: 9.41, SSIM: 0.0702, JS: 0.3405
# Image: sample_40.png, PSNR: 9.53, SSIM: 0.0665, JS: 0.3739
# Image: sample_41.png, PSNR: 9.82, SSIM: 0.0684, JS: 0.3768
# Image: sample_42.png, PSNR: 9.34, SSIM: 0.0660, JS: 0.3579
# Image: sample_43.png, PSNR: 10.11, SSIM: 0.0808, JS: 0.3151
# Image: sample_44.png, PSNR: 9.59, SSIM: 0.0645, JS: 0.3757
# Image: sample_45.png, PSNR: 9.23, SSIM: 0.0913, JS: 0.3795
# Image: sample_46.png, PSNR: 9.27, SSIM: 0.0612, JS: 0.3044
# Image: sample_47.png, PSNR: 9.93, SSIM: 0.0488, JS: 0.3214
# Image: sample_48.png, PSNR: 10.01, SSIM: 0.1013, JS: 0.3120
# Image: sample_49.png, PSNR: 8.86, SSIM: 0.0324, JS: 0.3469
# Image: sample_50.png, PSNR: 10.68, SSIM: 0.0824, JS: 0.3016
# Image: sample_51.png, PSNR: 9.46, SSIM: 0.0472, JS: 0.3123
# Image: sample_52.png, PSNR: 10.09, SSIM: 0.0753, JS: 0.3188
# Image: sample_53.png, PSNR: 10.29, SSIM: 0.0982, JS: 0.3130
# Image: sample_54.png, PSNR: 9.38, SSIM: 0.0688, JS: 0.3684
# Image: sample_55.png, PSNR: 9.11, SSIM: 0.0490, JS: 0.3539
# Image: sample_56.png, PSNR: 10.12, SSIM: 0.0782, JS: 0.3306
# Image: sample_57.png, PSNR: 10.60, SSIM: 0.1012, JS: 0.3066
# Image: sample_58.png, PSNR: 9.97, SSIM: 0.0954, JS: 0.3111
# Image: sample_59.png, PSNR: 9.43, SSIM: 0.0541, JS: 0.2994
# Image: sample_60.png, PSNR: 9.65, SSIM: 0.0595, JS: 0.3075
# Image: sample_61.png, PSNR: 10.14, SSIM: 0.0670, JS: 0.3141
# Image: sample_62.png, PSNR: 8.54, SSIM: 0.0482, JS: 0.3637
# Image: sample_63.png, PSNR: 10.39, SSIM: 0.1064, JS: 0.2995
# Image: sample_64.png, PSNR: 9.82, SSIM: 0.0628, JS: 0.3435
# Image: sample_65.png, PSNR: 9.72, SSIM: 0.0822, JS: 0.3375
# Image: sample_66.png, PSNR: 10.39, SSIM: 0.0715, JS: 0.3177
# Image: sample_67.png, PSNR: 9.49, SSIM: 0.0813, JS: 0.3348
# Image: sample_68.png, PSNR: 9.27, SSIM: 0.0417, JS: 0.3407
# Image: sample_69.png, PSNR: 9.39, SSIM: 0.0634, JS: 0.3328
# Image: sample_70.png, PSNR: 9.61, SSIM: 0.0828, JS: 0.3509
# Image: sample_71.png, PSNR: 9.57, SSIM: 0.0738, JS: 0.3755
# Image: sample_72.png, PSNR: 10.42, SSIM: 0.0862, JS: 0.2944
# Image: sample_73.png, PSNR: 10.36, SSIM: 0.1029, JS: 0.3032
# Image: sample_74.png, PSNR: 9.21, SSIM: 0.0375, JS: 0.3603
# Image: sample_75.png, PSNR: 10.50, SSIM: 0.1113, JS: 0.2986
# Image: sample_76.png, PSNR: 9.24, SSIM: 0.0476, JS: 0.4020
# Image: sample_77.png, PSNR: 10.33, SSIM: 0.0929, JS: 0.3115
# Image: sample_78.png, PSNR: 9.57, SSIM: 0.0422, JS: 0.3149
# Image: sample_79.png, PSNR: 9.30, SSIM: 0.0534, JS: 0.3417
# Image: sample_80.png, PSNR: 9.74, SSIM: 0.0722, JS: 0.3429
# Image: sample_81.png, PSNR: 9.60, SSIM: 0.0836, JS: 0.3528
# Image: sample_82.png, PSNR: 10.44, SSIM: 0.0948, JS: 0.3005
# Image: sample_83.png, PSNR: 10.27, SSIM: 0.1010, JS: 0.3029
# Image: sample_84.png, PSNR: 10.23, SSIM: 0.0948, JS: 0.3040
# Image: sample_85.png, PSNR: 10.60, SSIM: 0.1064, JS: 0.2925
# Image: sample_86.png, PSNR: 9.09, SSIM: 0.0777, JS: 0.3307
# Image: sample_87.png, PSNR: 9.39, SSIM: 0.0864, JS: 0.3654
# Image: sample_88.png, PSNR: 9.51, SSIM: 0.0333, JS: 0.3174
# Image: sample_89.png, PSNR: 9.34, SSIM: 0.0768, JS: 0.3543
# Image: sample_90.png, PSNR: 9.23, SSIM: 0.0564, JS: 0.3122
# Image: sample_91.png, PSNR: 9.38, SSIM: 0.0839, JS: 0.3766
# Image: sample_92.png, PSNR: 9.71, SSIM: 0.0954, JS: 0.3264
# Image: sample_93.png, PSNR: 9.48, SSIM: 0.0607, JS: 0.3537
# Image: sample_94.png, PSNR: 9.67, SSIM: 0.0582, JS: 0.3344
# Image: sample_95.png, PSNR: 10.45, SSIM: 0.0730, JS: 0.3045
# Image: sample_96.png, PSNR: 9.61, SSIM: 0.0635, JS: 0.3477
# Image: sample_97.png, PSNR: 10.14, SSIM: 0.1032, JS: 0.3146
# Image: sample_98.png, PSNR: 9.40, SSIM: 0.0903, JS: 0.3569
# Image: sample_99.png, PSNR: 9.16, SSIM: 0.0798, JS: 0.3767
# Image: sample_100.png, PSNR: 10.07, SSIM: 0.0851, JS: 0.2916
# Image: sample_101.png, PSNR: 9.51, SSIM: 0.0629, JS: 0.3490
# Image: sample_102.png, PSNR: 9.34, SSIM: 0.0664, JS: 0.3646
# Image: sample_103.png, PSNR: 9.73, SSIM: 0.0813, JS: 0.3302
# Image: sample_104.png, PSNR: 10.46, SSIM: 0.1031, JS: 0.3178
# Image: sample_105.png, PSNR: 10.36, SSIM: 0.0880, JS: 0.3028
# Image: sample_106.png, PSNR: 9.25, SSIM: 0.0676, JS: 0.3260
# Image: sample_107.png, PSNR: 10.06, SSIM: 0.0668, JS: 0.3561
# Image: sample_108.png, PSNR: 9.85, SSIM: 0.0693, JS: 0.3384
# Image: sample_109.png, PSNR: 9.83, SSIM: 0.0727, JS: 0.3201
# Image: sample_110.png, PSNR: 9.83, SSIM: 0.0774, JS: 0.3395
# Image: sample_111.png, PSNR: 10.01, SSIM: 0.1035, JS: 0.3368
# Image: sample_112.png, PSNR: 9.35, SSIM: 0.0608, JS: 0.3656
# Image: sample_113.png, PSNR: 10.17, SSIM: 0.0990, JS: 0.3262
# Image: sample_114.png, PSNR: 9.88, SSIM: 0.0934, JS: 0.3257
# Image: sample_115.png, PSNR: 10.60, SSIM: 0.0755, JS: 0.2909
# Image: sample_116.png, PSNR: 9.67, SSIM: 0.0715, JS: 0.3324
# Image: sample_117.png, PSNR: 9.08, SSIM: 0.0846, JS: 0.3523
# Image: sample_118.png, PSNR: 9.83, SSIM: 0.0581, JS: 0.2952
# Image: sample_119.png, PSNR: 9.47, SSIM: 0.0594, JS: 0.2971
# Image: sample_120.png, PSNR: 10.19, SSIM: 0.0873, JS: 0.3207
# Image: sample_121.png, PSNR: 9.80, SSIM: 0.1074, JS: 0.3167
# Image: sample_122.png, PSNR: 10.55, SSIM: 0.1044, JS: 0.2842
# Image: sample_123.png, PSNR: 9.92, SSIM: 0.0514, JS: 0.3302
# Image: sample_124.png, PSNR: 9.81, SSIM: 0.0475, JS: 0.3187
# Image: sample_125.png, PSNR: 9.96, SSIM: 0.0736, JS: 0.3548
# Image: sample_126.png, PSNR: 10.91, SSIM: 0.0828, JS: 0.2894
# Image: sample_127.png, PSNR: 9.63, SSIM: 0.0862, JS: 0.3454
# Image: sample_128.png, PSNR: 9.94, SSIM: 0.0430, JS: 0.3393
# Image: sample_129.png, PSNR: 9.86, SSIM: 0.0538, JS: 0.3275
# Image: sample_130.png, PSNR: 10.25, SSIM: 0.0889, JS: 0.3352
# Image: sample_131.png, PSNR: 10.02, SSIM: 0.1055, JS: 0.3587
# Image: sample_132.png, PSNR: 9.66, SSIM: 0.0860, JS: 0.3299
# Image: sample_133.png, PSNR: 9.72, SSIM: 0.0769, JS: 0.3531
# Image: sample_134.png, PSNR: 10.54, SSIM: 0.0970, JS: 0.2919
# Image: sample_135.png, PSNR: 10.48, SSIM: 0.0811, JS: 0.2968
# Image: sample_136.png, PSNR: 10.70, SSIM: 0.0790, JS: 0.2934
# Image: sample_137.png, PSNR: 9.65, SSIM: 0.0867, JS: 0.3664
# Image: sample_138.png, PSNR: 9.65, SSIM: 0.0829, JS: 0.3631
# Image: sample_139.png, PSNR: 10.23, SSIM: 0.0938, JS: 0.2923
# Image: sample_140.png, PSNR: 10.49, SSIM: 0.1056, JS: 0.2964
# Image: sample_141.png, PSNR: 10.72, SSIM: 0.0930, JS: 0.2907
# Image: sample_142.png, PSNR: 10.16, SSIM: 0.1031, JS: 0.3152
# Image: sample_143.png, PSNR: 10.00, SSIM: 0.0858, JS: 0.3299
# Image: sample_144.png, PSNR: 10.45, SSIM: 0.0935, JS: 0.3164
# Image: sample_145.png, PSNR: 9.45, SSIM: 0.0615, JS: 0.3635
# Image: sample_146.png, PSNR: 9.05, SSIM: 0.0744, JS: 0.3696
# Image: sample_147.png, PSNR: 9.87, SSIM: 0.0517, JS: 0.3129
# Image: sample_148.png, PSNR: 9.67, SSIM: 0.0790, JS: 0.3223
# Image: sample_149.png, PSNR: 10.12, SSIM: 0.0844, JS: 0.3039
# Image: sample_150.png, PSNR: 9.20, SSIM: 0.0533, JS: 0.3164
# Image: sample_151.png, PSNR: 10.27, SSIM: 0.0846, JS: 0.3080
# Image: sample_152.png, PSNR: 9.32, SSIM: 0.0659, JS: 0.3820
# Image: sample_153.png, PSNR: 10.12, SSIM: 0.0631, JS: 0.3311
# Image: sample_154.png, PSNR: 10.50, SSIM: 0.0970, JS: 0.3113
# Image: sample_155.png, PSNR: 9.43, SSIM: 0.0760, JS: 0.3668
# Image: sample_156.png, PSNR: 9.82, SSIM: 0.0660, JS: 0.3197
# Image: sample_157.png, PSNR: 10.06, SSIM: 0.0723, JS: 0.3230
# Image: sample_158.png, PSNR: 9.83, SSIM: 0.0839, JS: 0.3186
# Image: sample_159.png, PSNR: 9.59, SSIM: 0.0815, JS: 0.3292
# Image: sample_160.png, PSNR: 9.74, SSIM: 0.0860, JS: 0.3540
# Image: sample_161.png, PSNR: 10.14, SSIM: 0.0818, JS: 0.3193
# Image: sample_162.png, PSNR: 9.12, SSIM: 0.0325, JS: 0.3675
# Image: sample_163.png, PSNR: 10.34, SSIM: 0.0956, JS: 0.3154
# Image: sample_164.png, PSNR: 9.92, SSIM: 0.0690, JS: 0.3334
# Image: sample_165.png, PSNR: 9.79, SSIM: 0.0573, JS: 0.3114
# Image: sample_166.png, PSNR: 10.65, SSIM: 0.1158, JS: 0.2567
# Image: sample_167.png, PSNR: 9.21, SSIM: 0.0734, JS: 0.3599
# Image: sample_168.png, PSNR: 8.97, SSIM: 0.0781, JS: 0.3987
# Image: sample_169.png, PSNR: 8.34, SSIM: 0.0260, JS: 0.3023
# Image: sample_170.png, PSNR: 9.68, SSIM: 0.0519, JS: 0.3359
# Image: sample_171.png, PSNR: 10.28, SSIM: 0.0577, JS: 0.3187
# Image: sample_172.png, PSNR: 9.38, SSIM: 0.0510, JS: 0.3583
# Image: sample_173.png, PSNR: 9.59, SSIM: 0.0603, JS: 0.3571
# Image: sample_174.png, PSNR: 9.24, SSIM: 0.0379, JS: 0.3683
# Image: sample_175.png, PSNR: 10.05, SSIM: 0.0593, JS: 0.3318
# Image: sample_176.png, PSNR: 10.20, SSIM: 0.0790, JS: 0.3171
# Image: sample_177.png, PSNR: 9.51, SSIM: 0.0762, JS: 0.3629
# Image: sample_178.png, PSNR: 10.43, SSIM: 0.0852, JS: 0.2839
# Image: sample_179.png, PSNR: 9.40, SSIM: 0.0663, JS: 0.3466
# Image: sample_180.png, PSNR: 9.02, SSIM: 0.0614, JS: 0.3321
# Image: sample_181.png, PSNR: 9.68, SSIM: 0.0515, JS: 0.3399
# Image: sample_182.png, PSNR: 9.92, SSIM: 0.0661, JS: 0.3007
# Image: sample_183.png, PSNR: 10.78, SSIM: 0.1097, JS: 0.2913
# Image: sample_184.png, PSNR: 9.76, SSIM: 0.0923, JS: 0.3421
# Image: sample_185.png, PSNR: 10.47, SSIM: 0.0787, JS: 0.2961
# Image: sample_186.png, PSNR: 10.12, SSIM: 0.0657, JS: 0.3219
# Image: sample_187.png, PSNR: 9.98, SSIM: 0.0710, JS: 0.3171
# Image: sample_188.png, PSNR: 9.64, SSIM: 0.0965, JS: 0.3560
# Image: sample_189.png, PSNR: 10.81, SSIM: 0.0905, JS: 0.2870
# Image: sample_190.png, PSNR: 10.33, SSIM: 0.1031, JS: 0.3039
# Image: sample_191.png, PSNR: 9.59, SSIM: 0.0855, JS: 0.3749
# Image: sample_192.png, PSNR: 9.68, SSIM: 0.0442, JS: 0.3384
# Image: sample_193.png, PSNR: 9.93, SSIM: 0.1071, JS: 0.3230
# Image: sample_194.png, PSNR: 9.69, SSIM: 0.0968, JS: 0.3706
# Image: sample_195.png, PSNR: 10.01, SSIM: 0.0984, JS: 0.3473
# Image: sample_196.png, PSNR: 9.62, SSIM: 0.0537, JS: 0.3411
# Image: sample_197.png, PSNR: 9.53, SSIM: 0.0797, JS: 0.3467
# Image: sample_198.png, PSNR: 9.19, SSIM: 0.0573, JS: 0.2956
# Image: sample_199.png, PSNR: 10.14, SSIM: 0.0649, JS: 0.3044
# Image: sample_200.png, PSNR: 9.39, SSIM: 0.0574, JS: 0.3152
# Image: sample_201.png, PSNR: 9.89, SSIM: 0.0938, JS: 0.3533
# Image: sample_202.png, PSNR: 10.01, SSIM: 0.1036, JS: 0.3497
# Image: sample_203.png, PSNR: 10.19, SSIM: 0.0998, JS: 0.3049
# Image: sample_204.png, PSNR: 9.84, SSIM: 0.0842, JS: 0.3271
# Image: sample_205.png, PSNR: 9.33, SSIM: 0.0795, JS: 0.3662
# Image: sample_206.png, PSNR: 10.24, SSIM: 0.0841, JS: 0.3031
# Image: sample_207.png, PSNR: 9.62, SSIM: 0.0819, JS: 0.3576
# Image: sample_208.png, PSNR: 10.37, SSIM: 0.1040, JS: 0.3170
# Image: sample_209.png, PSNR: 9.32, SSIM: 0.0500, JS: 0.3209
# Image: sample_210.png, PSNR: 10.01, SSIM: 0.0914, JS: 0.3195
# Image: sample_211.png, PSNR: 9.43, SSIM: 0.0518, JS: 0.3368
# Image: sample_212.png, PSNR: 8.66, SSIM: 0.0219, JS: 0.3689
# Image: sample_213.png, PSNR: 10.53, SSIM: 0.0856, JS: 0.3068
# Image: sample_214.png, PSNR: 9.90, SSIM: 0.0708, JS: 0.3469
# Image: sample_215.png, PSNR: 9.72, SSIM: 0.0732, JS: 0.3377
# Image: sample_216.png, PSNR: 10.42, SSIM: 0.0685, JS: 0.3273
# Image: sample_217.png, PSNR: 10.45, SSIM: 0.0835, JS: 0.3209
# Image: sample_218.png, PSNR: 9.49, SSIM: 0.0616, JS: 0.3782
# Image: sample_219.png, PSNR: 10.35, SSIM: 0.1014, JS: 0.3136
# Image: sample_220.png, PSNR: 9.73, SSIM: 0.0758, JS: 0.3356
# Image: sample_221.png, PSNR: 9.28, SSIM: 0.0742, JS: 0.3446
# Image: sample_222.png, PSNR: 10.59, SSIM: 0.1174, JS: 0.2863
# Image: sample_223.png, PSNR: 10.41, SSIM: 0.0842, JS: 0.3356
# Image: sample_224.png, PSNR: 9.40, SSIM: 0.0436, JS: 0.3341
# Image: sample_225.png, PSNR: 10.26, SSIM: 0.0927, JS: 0.3253
# Image: sample_226.png, PSNR: 9.98, SSIM: 0.0614, JS: 0.3320
# Image: sample_227.png, PSNR: 9.51, SSIM: 0.0446, JS: 0.3303
# Image: sample_228.png, PSNR: 8.88, SSIM: 0.0594, JS: 0.4134
# Image: sample_229.png, PSNR: 9.65, SSIM: 0.0932, JS: 0.3316
# Image: sample_230.png, PSNR: 9.18, SSIM: 0.0397, JS: 0.3596
# Image: sample_231.png, PSNR: 9.95, SSIM: 0.0561, JS: 0.3527
# Image: sample_232.png, PSNR: 10.19, SSIM: 0.0687, JS: 0.2944
# Image: sample_233.png, PSNR: 10.21, SSIM: 0.0858, JS: 0.3124
# Image: sample_234.png, PSNR: 10.39, SSIM: 0.0730, JS: 0.3162
# Image: sample_235.png, PSNR: 10.61, SSIM: 0.0978, JS: 0.2948
# Image: sample_236.png, PSNR: 10.30, SSIM: 0.0698, JS: 0.3238
# Image: sample_237.png, PSNR: 9.91, SSIM: 0.1059, JS: 0.3422
# Image: sample_238.png, PSNR: 9.57, SSIM: 0.0712, JS: 0.3413
# Image: sample_239.png, PSNR: 9.35, SSIM: 0.0568, JS: 0.3543
# Image: sample_240.png, PSNR: 10.02, SSIM: 0.1002, JS: 0.2906
# Image: sample_241.png, PSNR: 8.99, SSIM: 0.0587, JS: 0.3808
# Image: sample_242.png, PSNR: 10.24, SSIM: 0.0763, JS: 0.3267
# Image: sample_243.png, PSNR: 9.85, SSIM: 0.0980, JS: 0.3251
# Image: sample_244.png, PSNR: 10.46, SSIM: 0.0666, JS: 0.3344
# Image: sample_245.png, PSNR: 9.57, SSIM: 0.0454, JS: 0.3609
# Image: sample_246.png, PSNR: 9.62, SSIM: 0.0668, JS: 0.3358
# Image: sample_247.png, PSNR: 9.43, SSIM: 0.0496, JS: 0.3732
# Image: sample_248.png, PSNR: 9.55, SSIM: 0.0668, JS: 0.3208
# Image: sample_249.png, PSNR: 9.39, SSIM: 0.0886, JS: 0.3526
# Image: sample_250.png, PSNR: 10.11, SSIM: 0.0810, JS: 0.3433
# Image: sample_251.png, PSNR: 10.08, SSIM: 0.0791, JS: 0.3227
# Image: sample_252.png, PSNR: 10.42, SSIM: 0.0919, JS: 0.3123
# Image: sample_253.png, PSNR: 9.77, SSIM: 0.0711, JS: 0.3318
# Image: sample_254.png, PSNR: 8.03, SSIM: 0.0259, JS: 0.3699
# Image: sample_255.png, PSNR: 9.97, SSIM: 0.0796, JS: 0.3056
# Image: sample_256.png, PSNR: 10.49, SSIM: 0.0948, JS: 0.2911
# Image: sample_257.png, PSNR: 9.02, SSIM: 0.0928, JS: 0.3875
# Image: sample_258.png, PSNR: 9.50, SSIM: 0.0759, JS: 0.3585
# Image: sample_259.png, PSNR: 9.86, SSIM: 0.0767, JS: 0.3197
# Image: sample_260.png, PSNR: 8.46, SSIM: 0.0257, JS: 0.3675
# Image: sample_261.png, PSNR: 9.87, SSIM: 0.1000, JS: 0.3251
# Image: sample_262.png, PSNR: 9.85, SSIM: 0.0639, JS: 0.3530
# Image: sample_263.png, PSNR: 10.32, SSIM: 0.0762, JS: 0.3177
# Image: sample_264.png, PSNR: 9.98, SSIM: 0.0817, JS: 0.3307
# Image: sample_265.png, PSNR: 9.19, SSIM: 0.0595, JS: 0.3619
# Image: sample_266.png, PSNR: 10.70, SSIM: 0.0936, JS: 0.2781
# Image: sample_267.png, PSNR: 10.30, SSIM: 0.0636, JS: 0.3029
# Image: sample_268.png, PSNR: 10.23, SSIM: 0.0980, JS: 0.3112
# Image: sample_269.png, PSNR: 9.52, SSIM: 0.0489, JS: 0.3166
# Image: sample_270.png, PSNR: 9.94, SSIM: 0.0861, JS: 0.3084
# ...
# Image: sample_243.png, PSNR: 8.39, SSIM: 0.0560, JS: 0.4066
# Image: sample_244.png, PSNR: 6.68, SSIM: 0.0349, JS: 0.4159
# Image: sample_245.png, PSNR: 8.02, SSIM: 0.0428, JS: 0.3947
# Image: sample_246.png, PSNR: 7.99, SSIM: 0.0383, JS: 0.4105
# Image: sample_247.png, PSNR: 8.12, SSIM: 0.0538, JS: 0.3877
# Image: sample_248.png, PSNR: 7.07, SSIM: 0.0287, JS: 0.3772
# Image: sample_249.png, PSNR: 7.37, SSIM: 0.0239, JS: 0.4538
# Image: sample_250.png, PSNR: 7.40, SSIM: 0.0398, JS: 0.3638
# Image: sample_251.png, PSNR: 8.05, SSIM: 0.0346, JS: 0.4120
# Image: sample_252.png, PSNR: 8.04, SSIM: 0.0362, JS: 0.3998
# Image: sample_253.png, PSNR: 8.48, SSIM: 0.0541, JS: 0.3478
# Image: sample_254.png, PSNR: 8.06, SSIM: 0.0477, JS: 0.4368
# Image: sample_255.png, PSNR: 7.38, SSIM: 0.0298, JS: 0.4630
# Image: sample_256.png, PSNR: 7.09, SSIM: 0.0190, JS: 0.4346
# Image: sample_257.png, PSNR: 7.23, SSIM: 0.0272, JS: 0.4004
# Image: sample_258.png, PSNR: 7.15, SSIM: 0.0192, JS: 0.4266
# Image: sample_259.png, PSNR: 8.38, SSIM: 0.0624, JS: 0.4200
# Image: sample_260.png, PSNR: 8.70, SSIM: 0.0522, JS: 0.3739
# Image: sample_261.png, PSNR: 8.21, SSIM: 0.0622, JS: 0.3989
# Image: sample_262.png, PSNR: 7.33, SSIM: 0.0430, JS: 0.3838
# Image: sample_263.png, PSNR: 7.93, SSIM: 0.0288, JS: 0.3883
# Image: sample_264.png, PSNR: 7.85, SSIM: 0.0411, JS: 0.4507
# Image: sample_265.png, PSNR: 7.33, SSIM: 0.0273, JS: 0.4465
# Image: sample_266.png, PSNR: 7.56, SSIM: 0.0225, JS: 0.4489
# Image: sample_267.png, PSNR: 7.17, SSIM: 0.0258, JS: 0.4312
# Image: sample_268.png, PSNR: 7.89, SSIM: 0.0308, JS: 0.4124
# Image: sample_269.png, PSNR: 8.51, SSIM: 0.0538, JS: 0.3785
# Image: sample_270.png, PSNR: 7.06, SSIM: 0.0406, JS: 0.3712
# Image: sample_271.png, PSNR: 7.63, SSIM: 0.0327, JS: 0.3865
# Image: sample_272.png, PSNR: 6.91, SSIM: 0.0107, JS: 0.4724
# Image: sample_273.png, PSNR: 8.18, SSIM: 0.0511, JS: 0.4081
# Image: sample_274.png, PSNR: 7.95, SSIM: 0.0375, JS: 0.4231
# Image: sample_275.png, PSNR: 8.00, SSIM: 0.0428, JS: 0.4100
# Image: sample_276.png, PSNR: 7.24, SSIM: 0.0253, JS: 0.4196
# Image: sample_277.png, PSNR: 8.01, SSIM: 0.0560, JS: 0.3536
# Image: sample_278.png, PSNR: 6.96, SSIM: 0.0216, JS: 0.4565
# Image: sample_279.png, PSNR: 6.69, SSIM: 0.0259, JS: 0.3782
# Image: sample_280.png, PSNR: 6.47, SSIM: 0.0172, JS: 0.4129
# Image: sample_281.png, PSNR: 7.52, SSIM: 0.0213, JS: 0.4357
# Image: sample_282.png, PSNR: 8.56, SSIM: 0.0675, JS: 0.3814
# Image: sample_283.png, PSNR: 7.79, SSIM: 0.0381, JS: 0.3998
# Image: sample_284.png, PSNR: 6.66, SSIM: 0.0246, JS: 0.4036
# Image: sample_285.png, PSNR: 7.19, SSIM: 0.0269, JS: 0.3986
# Image: sample_286.png, PSNR: 8.24, SSIM: 0.0433, JS: 0.3959
# Image: sample_287.png, PSNR: 6.92, SSIM: 0.0318, JS: 0.4361
# Image: sample_288.png, PSNR: 7.56, SSIM: 0.0301, JS: 0.3945
# Image: sample_289.png, PSNR: 7.37, SSIM: 0.0272, JS: 0.3528
# Image: sample_290.png, PSNR: 7.12, SSIM: 0.0255, JS: 0.4456
# Image: sample_291.png, PSNR: 7.84, SSIM: 0.0482, JS: 0.4380
# Image: sample_292.png, PSNR: 7.84, SSIM: 0.0347, JS: 0.3877
# Image: sample_293.png, PSNR: 7.58, SSIM: 0.0315, JS: 0.4070
# Image: sample_294.png, PSNR: 7.80, SSIM: 0.0376, JS: 0.4398
# Image: sample_295.png, PSNR: 8.13, SSIM: 0.0473, JS: 0.4143
# Image: sample_296.png, PSNR: 7.02, SSIM: 0.0284, JS: 0.3990
# Image: sample_297.png, PSNR: 8.16, SSIM: 0.0409, JS: 0.3970
# Image: sample_298.png, PSNR: 7.47, SSIM: 0.0204, JS: 0.4256
# Image: sample_299.png, PSNR: 7.75, SSIM: 0.0408, JS: 0.3903
# Image: sample_300.png, PSNR: 6.86, SSIM: 0.0167, JS: 0.3615
# Image: sample_301.png, PSNR: 7.83, SSIM: 0.0355, JS: 0.4393
# Image: sample_302.png, PSNR: 7.07, SSIM: 0.0189, JS: 0.4513
# Image: sample_303.png, PSNR: 6.98, SSIM: 0.0309, JS: 0.4148
# Image: sample_304.png, PSNR: 7.03, SSIM: 0.0199, JS: 0.4208
# Image: sample_305.png, PSNR: 7.23, SSIM: 0.0123, JS: 0.4498
# Image: sample_306.png, PSNR: 8.75, SSIM: 0.0554, JS: 0.3771
# Image: sample_307.png, PSNR: 7.42, SSIM: 0.0310, JS: 0.4366
# Image: sample_308.png, PSNR: 6.77, SSIM: 0.0266, JS: 0.3990
# Image: sample_309.png, PSNR: 7.82, SSIM: 0.0353, JS: 0.4341
# Image: sample_310.png, PSNR: 6.84, SSIM: 0.0345, JS: 0.4003
# Image: sample_311.png, PSNR: 7.25, SSIM: 0.0175, JS: 0.4272
# Image: sample_312.png, PSNR: 7.15, SSIM: 0.0189, JS: 0.3807
# Image: sample_313.png, PSNR: 7.39, SSIM: 0.0328, JS: 0.3933
# Image: sample_314.png, PSNR: 7.78, SSIM: 0.0375, JS: 0.4064
# Image: sample_315.png, PSNR: 8.39, SSIM: 0.0610, JS: 0.4010
# Image: sample_316.png, PSNR: 7.98, SSIM: 0.0345, JS: 0.3932
# Image: sample_317.png, PSNR: 7.68, SSIM: 0.0277, JS: 0.4503
# Image: sample_318.png, PSNR: 7.35, SSIM: 0.0223, JS: 0.4614
# Image: sample_319.png, PSNR: 8.15, SSIM: 0.0400, JS: 0.4110
# Image: sample_320.png, PSNR: 8.68, SSIM: 0.0750, JS: 0.4014
# Image: sample_321.png, PSNR: 7.92, SSIM: 0.0401, JS: 0.4065
# Image: sample_322.png, PSNR: 7.84, SSIM: 0.0286, JS: 0.4028
# Image: sample_323.png, PSNR: 8.24, SSIM: 0.0712, JS: 0.3339
# Image: sample_324.png, PSNR: 6.71, SSIM: 0.0188, JS: 0.4239
# Image: sample_325.png, PSNR: 7.47, SSIM: 0.0510, JS: 0.3770
# Image: sample_326.png, PSNR: 6.89, SSIM: 0.0315, JS: 0.4175
# Image: sample_327.png, PSNR: 7.43, SSIM: 0.0363, JS: 0.4552
# Image: sample_328.png, PSNR: 8.44, SSIM: 0.0520, JS: 0.4029
# Image: sample_329.png, PSNR: 8.15, SSIM: 0.0664, JS: 0.4138
# Image: sample_330.png, PSNR: 7.70, SSIM: 0.0492, JS: 0.3919
# Image: sample_331.png, PSNR: 7.06, SSIM: 0.0312, JS: 0.4224
# Image: sample_332.png, PSNR: 7.41, SSIM: 0.0407, JS: 0.4025
# Image: sample_333.png, PSNR: 7.19, SSIM: 0.0324, JS: 0.4439
# Image: sample_334.png, PSNR: 7.76, SSIM: 0.0348, JS: 0.4384
# Image: sample_335.png, PSNR: 7.10, SSIM: 0.0129, JS: 0.4013
# Image: sample_336.png, PSNR: 8.09, SSIM: 0.0280, JS: 0.4003
# Image: sample_337.png, PSNR: 6.67, SSIM: 0.0311, JS: 0.4031
# Image: sample_338.png, PSNR: 6.80, SSIM: 0.0199, JS: 0.4249
# Image: sample_339.png, PSNR: 7.49, SSIM: 0.0478, JS: 0.3904
# Image: sample_340.png, PSNR: 6.63, SSIM: 0.0229, JS: 0.3531
# Image: sample_341.png, PSNR: 6.89, SSIM: 0.0269, JS: 0.4041
# Image: sample_342.png, PSNR: 8.29, SSIM: 0.0645, JS: 0.3850
# Image: sample_343.png, PSNR: 6.96, SSIM: 0.0232, JS: 0.4154
# Image: sample_344.png, PSNR: 8.36, SSIM: 0.0703, JS: 0.3171
# Image: sample_345.png, PSNR: 7.58, SSIM: 0.0304, JS: 0.4376
# Image: sample_346.png, PSNR: 6.72, SSIM: 0.0303, JS: 0.4185
# Image: sample_347.png, PSNR: 8.18, SSIM: 0.0490, JS: 0.4124
# Image: sample_348.png, PSNR: 7.92, SSIM: 0.0488, JS: 0.3956
# Image: sample_349.png, PSNR: 8.53, SSIM: 0.0760, JS: 0.3883
# Image: sample_350.png, PSNR: 8.13, SSIM: 0.0473, JS: 0.3760
# Image: sample_351.png, PSNR: 6.52, SSIM: 0.0215, JS: 0.4075
# Image: sample_352.png, PSNR: 7.97, SSIM: 0.0391, JS: 0.4189
# Image: sample_353.png, PSNR: 8.24, SSIM: 0.0437, JS: 0.4023
# Image: sample_354.png, PSNR: 7.04, SSIM: 0.0200, JS: 0.3951
# Image: sample_355.png, PSNR: 6.21, SSIM: 0.0110, JS: 0.3711
# Image: sample_356.png, PSNR: 7.46, SSIM: 0.0543, JS: 0.3180
# Image: sample_357.png, PSNR: 7.77, SSIM: 0.0328, JS: 0.4417
# Image: sample_358.png, PSNR: 7.67, SSIM: 0.0281, JS: 0.4438
# Image: sample_359.png, PSNR: 7.05, SSIM: 0.0173, JS: 0.4465
# Image: sample_360.png, PSNR: 8.09, SSIM: 0.0587, JS: 0.4103
# Image: sample_361.png, PSNR: 7.84, SSIM: 0.0357, JS: 0.3521
# Image: sample_362.png, PSNR: 7.56, SSIM: 0.0399, JS: 0.4111
# Image: sample_363.png, PSNR: 6.98, SSIM: 0.0333, JS: 0.4049
# Image: sample_364.png, PSNR: 7.33, SSIM: 0.0171, JS: 0.4390
# Image: sample_365.png, PSNR: 8.21, SSIM: 0.0447, JS: 0.3973
# Image: sample_366.png, PSNR: 6.90, SSIM: 0.0383, JS: 0.3971
# Image: sample_367.png, PSNR: 7.17, SSIM: 0.0257, JS: 0.4274
# Image: sample_368.png, PSNR: 7.85, SSIM: 0.0578, JS: 0.3199
# Image: sample_369.png, PSNR: 7.16, SSIM: 0.0409, JS: 0.3898
# Image: sample_370.png, PSNR: 6.69, SSIM: 0.0243, JS: 0.4198
# Image: sample_371.png, PSNR: 7.30, SSIM: 0.0207, JS: 0.4655
# Image: sample_372.png, PSNR: 7.22, SSIM: 0.0402, JS: 0.4613
# Image: sample_373.png, PSNR: 7.68, SSIM: 0.0256, JS: 0.4286
# Image: sample_374.png, PSNR: 7.99, SSIM: 0.0337, JS: 0.3983
# Image: sample_375.png, PSNR: 7.11, SSIM: 0.0317, JS: 0.3079
# Image: sample_376.png, PSNR: 7.59, SSIM: 0.0411, JS: 0.3771
# Image: sample_377.png, PSNR: 7.61, SSIM: 0.0449, JS: 0.3798
# Image: sample_378.png, PSNR: 7.84, SSIM: 0.0285, JS: 0.4266
# Image: sample_379.png, PSNR: 8.24, SSIM: 0.0355, JS: 0.4048
# Image: sample_380.png, PSNR: 7.84, SSIM: 0.0348, JS: 0.4006
# Image: sample_381.png, PSNR: 7.83, SSIM: 0.0440, JS: 0.4446
# Image: sample_382.png, PSNR: 7.78, SSIM: 0.0378, JS: 0.4316
# Image: sample_383.png, PSNR: 7.08, SSIM: 0.0178, JS: 0.4528
# Image: sample_384.png, PSNR: 7.95, SSIM: 0.0242, JS: 0.4002
# Image: sample_385.png, PSNR: 7.34, SSIM: 0.0271, JS: 0.3724
# Image: sample_386.png, PSNR: 8.33, SSIM: 0.0618, JS: 0.3923
# Image: sample_387.png, PSNR: 7.93, SSIM: 0.0278, JS: 0.4408
# Image: sample_388.png, PSNR: 7.84, SSIM: 0.0446, JS: 0.3781
# Image: sample_389.png, PSNR: 7.92, SSIM: 0.0453, JS: 0.4166
# Image: sample_390.png, PSNR: 8.13, SSIM: 0.0502, JS: 0.4125
# Image: sample_391.png, PSNR: 7.79, SSIM: 0.0213, JS: 0.3863
# Image: sample_392.png, PSNR: 7.37, SSIM: 0.0235, JS: 0.4612
# Image: sample_393.png, PSNR: 7.64, SSIM: 0.0368, JS: 0.4239
# Image: sample_394.png, PSNR: 6.76, SSIM: 0.0224, JS: 0.3962
# Image: sample_395.png, PSNR: 7.58, SSIM: 0.0314, JS: 0.4421
# Image: sample_396.png, PSNR: 7.80, SSIM: 0.0480, JS: 0.3677
# Image: sample_397.png, PSNR: 7.55, SSIM: 0.0356, JS: 0.4490
# Image: sample_398.png, PSNR: 8.32, SSIM: 0.0572, JS: 0.4190
# Image: sample_399.png, PSNR: 6.71, SSIM: 0.0274, JS: 0.4043
# Image: sample_400.png, PSNR: 7.35, SSIM: 0.0226, JS: 0.4737
# Image: sample_401.png, PSNR: 6.91, SSIM: 0.0220, JS: 0.4244
# Image: sample_402.png, PSNR: 7.80, SSIM: 0.0431, JS: 0.4378
# Image: sample_403.png, PSNR: 7.56, SSIM: 0.0350, JS: 0.4008
# Image: sample_404.png, PSNR: 8.13, SSIM: 0.0323, JS: 0.4168
# Image: sample_405.png, PSNR: 8.52, SSIM: 0.0625, JS: 0.3498
# Image: sample_406.png, PSNR: 7.83, SSIM: 0.0432, JS: 0.3837
# Image: sample_407.png, PSNR: 6.62, SSIM: 0.0266, JS: 0.4486
# Image: sample_408.png, PSNR: 8.37, SSIM: 0.0394, JS: 0.4104
# Image: sample_409.png, PSNR: 8.32, SSIM: 0.0461, JS: 0.4064
# Image: sample_410.png, PSNR: 6.42, SSIM: 0.0241, JS: 0.3693
# Image: sample_411.png, PSNR: 7.81, SSIM: 0.0343, JS: 0.4018
# Image: sample_412.png, PSNR: 7.45, SSIM: 0.0454, JS: 0.3628
# Image: sample_413.png, PSNR: 7.14, SSIM: 0.0222, JS: 0.4198
# Image: sample_414.png, PSNR: 7.41, SSIM: 0.0342, JS: 0.3812
# Image: sample_415.png, PSNR: 7.49, SSIM: 0.0253, JS: 0.4507
# Image: sample_416.png, PSNR: 7.20, SSIM: 0.0207, JS: 0.4255
# Image: sample_417.png, PSNR: 7.22, SSIM: 0.0209, JS: 0.4598
# Image: sample_418.png, PSNR: 8.25, SSIM: 0.0571, JS: 0.4063
# Image: sample_419.png, PSNR: 7.30, SSIM: 0.0238, JS: 0.4522
# Image: sample_420.png, PSNR: 7.56, SSIM: 0.0333, JS: 0.4401
# Image: sample_421.png, PSNR: 6.72, SSIM: 0.0303, JS: 0.4013
# Image: sample_422.png, PSNR: 7.92, SSIM: 0.0359, JS: 0.4117
# Image: sample_423.png, PSNR: 8.08, SSIM: 0.0494, JS: 0.4080
# Image: sample_424.png, PSNR: 7.44, SSIM: 0.0293, JS: 0.4574
# Image: sample_425.png, PSNR: 7.11, SSIM: 0.0301, JS: 0.4494
# Image: sample_426.png, PSNR: 8.13, SSIM: 0.0438, JS: 0.4268
# Image: sample_427.png, PSNR: 7.02, SSIM: 0.0231, JS: 0.4126
# Image: sample_428.png, PSNR: 7.47, SSIM: 0.0407, JS: 0.4040
# Image: sample_429.png, PSNR: 7.03, SSIM: 0.0260, JS: 0.4516
# Image: sample_430.png, PSNR: 7.23, SSIM: 0.0281, JS: 0.4183
# Image: sample_431.png, PSNR: 7.80, SSIM: 0.0312, JS: 0.4355
# Image: sample_432.png, PSNR: 7.92, SSIM: 0.0340, JS: 0.4167
# Image: sample_433.png, PSNR: 7.54, SSIM: 0.0382, JS: 0.4558
# Image: sample_434.png, PSNR: 8.15, SSIM: 0.0392, JS: 0.3954
# Image: sample_435.png, PSNR: 8.29, SSIM: 0.0541, JS: 0.4289
# Image: sample_436.png, PSNR: 7.18, SSIM: 0.0254, JS: 0.4450
# Image: sample_437.png, PSNR: 7.80, SSIM: 0.0416, JS: 0.4438
# Image: sample_438.png, PSNR: 8.01, SSIM: 0.0533, JS: 0.4366
# Image: sample_439.png, PSNR: 8.13, SSIM: 0.0565, JS: 0.4186
# Image: sample_440.png, PSNR: 7.67, SSIM: 0.0260, JS: 0.3968
# Image: sample_441.png, PSNR: 6.90, SSIM: 0.0217, JS: 0.4401
# Image: sample_442.png, PSNR: 6.15, SSIM: 0.0141, JS: 0.3733
# Image: sample_443.png, PSNR: 7.90, SSIM: 0.0369, JS: 0.4210
# Image: sample_444.png, PSNR: 7.70, SSIM: 0.0351, JS: 0.4580
# Image: sample_445.png, PSNR: 7.84, SSIM: 0.0380, JS: 0.3653
# Image: sample_446.png, PSNR: 8.06, SSIM: 0.0293, JS: 0.4001
# Image: sample_447.png, PSNR: 7.83, SSIM: 0.0343, JS: 0.4265
# Image: sample_448.png, PSNR: 7.95, SSIM: 0.0434, JS: 0.4037
# Image: sample_449.png, PSNR: 7.56, SSIM: 0.0202, JS: 0.4289
# Image: sample_450.png, PSNR: 7.28, SSIM: 0.0337, JS: 0.4452
# Image: sample_451.png, PSNR: 8.08, SSIM: 0.0484, JS: 0.4291
# Image: sample_452.png, PSNR: 7.11, SSIM: 0.0182, JS: 0.4548
# Image: sample_453.png, PSNR: 6.78, SSIM: 0.0343, JS: 0.3928
# Image: sample_454.png, PSNR: 6.76, SSIM: 0.0196, JS: 0.4118
# Image: sample_455.png, PSNR: 6.82, SSIM: 0.0213, JS: 0.3971
# Image: sample_456.png, PSNR: 7.01, SSIM: 0.0202, JS: 0.4528
# Image: sample_457.png, PSNR: 6.53, SSIM: 0.0142, JS: 0.3960
# Image: sample_458.png, PSNR: 7.95, SSIM: 0.0424, JS: 0.3783
# Image: sample_459.png, PSNR: 7.08, SSIM: 0.0293, JS: 0.4614
# Image: sample_460.png, PSNR: 6.69, SSIM: 0.0267, JS: 0.3841
# Image: sample_461.png, PSNR: 8.50, SSIM: 0.0601, JS: 0.4036
# Image: sample_462.png, PSNR: 8.43, SSIM: 0.0620, JS: 0.4140
# Image: sample_463.png, PSNR: 7.10, SSIM: 0.0315, JS: 0.3950
# Image: sample_464.png, PSNR: 7.53, SSIM: 0.0269, JS: 0.3887
# Image: sample_465.png, PSNR: 6.95, SSIM: 0.0251, JS: 0.4254
# Image: sample_466.png, PSNR: 8.07, SSIM: 0.0477, JS: 0.4167
# Image: sample_467.png, PSNR: 8.11, SSIM: 0.0676, JS: 0.4019
# Image: sample_468.png, PSNR: 8.15, SSIM: 0.0433, JS: 0.4197
# Image: sample_469.png, PSNR: 7.52, SSIM: 0.0269, JS: 0.4384
# Image: sample_470.png, PSNR: 8.19, SSIM: 0.0458, JS: 0.3886
# Image: sample_471.png, PSNR: 8.12, SSIM: 0.0486, JS: 0.4074
# Image: sample_472.png, PSNR: 7.68, SSIM: 0.0434, JS: 0.4057
# Image: sample_473.png, PSNR: 7.69, SSIM: 0.0300, JS: 0.4177
# Image: sample_474.png, PSNR: 8.14, SSIM: 0.0577, JS: 0.4232
# Image: sample_475.png, PSNR: 7.36, SSIM: 0.0396, JS: 0.4367
# Image: sample_476.png, PSNR: 7.34, SSIM: 0.0354, JS: 0.3714
# Image: sample_477.png, PSNR: 7.79, SSIM: 0.0334, JS: 0.4282
# Image: sample_478.png, PSNR: 8.34, SSIM: 0.0517, JS: 0.4149
# Image: sample_479.png, PSNR: 7.75, SSIM: 0.0421, JS: 0.4114
# Image: sample_480.png, PSNR: 8.23, SSIM: 0.0588, JS: 0.4188
# Image: sample_481.png, PSNR: 7.69, SSIM: 0.0310, JS: 0.4240
# Image: sample_482.png, PSNR: 8.35, SSIM: 0.0591, JS: 0.3853
# Image: sample_483.png, PSNR: 6.86, SSIM: 0.0379, JS: 0.4064
# Image: sample_484.png, PSNR: 7.64, SSIM: 0.0396, JS: 0.4034
# Image: sample_485.png, PSNR: 8.07, SSIM: 0.0362, JS: 0.3967
# Image: sample_486.png, PSNR: 7.36, SSIM: 0.0230, JS: 0.4309
# Image: sample_487.png, PSNR: 6.92, SSIM: 0.0169, JS: 0.4461
# Image: sample_488.png, PSNR: 7.03, SSIM: 0.0313, JS: 0.4203
# Image: sample_489.png, PSNR: 8.10, SSIM: 0.0386, JS: 0.4267
# Image: sample_490.png, PSNR: 7.16, SSIM: 0.0324, JS: 0.3750
# Image: sample_491.png, PSNR: 7.23, SSIM: 0.0237, JS: 0.4266
# Image: sample_492.png, PSNR: 7.94, SSIM: 0.0337, JS: 0.4111
# Image: sample_493.png, PSNR: 7.98, SSIM: 0.0550, JS: 0.4049
# Image: sample_494.png, PSNR: 7.97, SSIM: 0.0360, JS: 0.4042
# Image: sample_495.png, PSNR: 8.26, SSIM: 0.0689, JS: 0.4051
# Image: sample_496.png, PSNR: 7.69, SSIM: 0.0394, JS: 0.4443
# Image: sample_497.png, PSNR: 6.16, SSIM: 0.0144, JS: 0.3972
# Image: sample_498.png, PSNR: 7.38, SSIM: 0.0262, JS: 0.4570
# Image: sample_499.png, PSNR: 7.60, SSIM: 0.0236, JS: 0.4463
# Initially selected good images for class 4: 0
#
# New Thresholds Based on Percentiles:
# PSNR > 9.72
# SSIM > 0.0813
# JS < 0.3263
# Final good images for class 0: 0 images saved to good_images-arch-A5-enhanced\0
# Final good images for class 1: 113 images saved to good_images-arch-A5-enhanced\1
# Final good images for class 2: 0 images saved to good_images-arch-A5-enhanced\2
# Final good images for class 3: 130 images saved to good_images-arch-A5-enhanced\3
# Final good images for class 4: 0 images saved to good_images-arch-A5-enhanced\4

# %%
##SORTING GOOG IMAGES OF 500SAMPLES_SNEHA_CODE

# %%
import torch
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os
import numpy as np
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim
# Correct the import path for jensenshannon
from scipy.spatial.distance import jensenshannon
import kagglehub

# Verify scipy version - keep this check for good practice, though importing from spatial.distance
# is more robust across versions where the function might be in both or just spatial.distance.
import scipy
print(f"Using scipy version: {scipy.__version__}")
# The check for > 1.7 is relevant if you strictly wanted it in scipy.stats.
# Since we import from spatial.distance, any version >= 1.6.0 should work.
# Let's adjust the check to reflect the actual requirement for scipy.spatial.distance.jensenshannon
from pkg_resources import parse_version
if parse_version(scipy.__version__) < parse_version("1.6.0"):
     raise ImportError(f"scipy version must be >= 1.6.0 to use jensenshannon from scipy.spatial.distance. Please upgrade scipy using 'pip install --upgrade scipy'. Current version: {scipy.__version__}")


# Define paths
generated_base_dir = r"C:\Users\hp\Desktop\fedavg\generated_samples-arch-A5-500"
good_images_dir = r"C:\Users\hp\Desktop\fedavg\good_images-arch-A5-500"
os.makedirs(good_images_dir, exist_ok=True)

# Hyperparameters
RESIZE = 128
num_classes = 5
original_dim = RESIZE * RESIZE * 3

# Custom Dataset for Kaggle Vehicle Type Image Dataset
class VehicleTypeDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = []
        self.class_to_idx = {}
        self.images = []
        self.labels = []

        print(f"Searching for images in {root_dir}")
        for root, dirs, files in os.walk(root_dir):
            image_files = [f for f in files if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
            if image_files:
                class_name = os.path.basename(root)
                if class_name not in self.class_to_idx:
                    self.classes.append(class_name)
                    self.class_to_idx[class_name] = len(self.classes) - 1
                for img_file in image_files:
                    img_path = os.path.join(root, img_file)
                    try:
                        Image.open(img_path).verify()
                        self.images.append(img_path)
                        self.labels.append(self.class_to_idx[class_name])
                    except:
                        print(f"Skipping corrupted image: {img_path}")

        if len(self.classes) != num_classes:
            raise ValueError(f"Expected {num_classes} classes, found {len(self.classes)}")
        print(f"Found {len(self.images)} images across {len(self.classes)} classes.")
        print(f"Classes: {self.classes}")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        image = Image.open(img_path).convert('RGB')
        label = self.labels[idx]
        sample = {'image': image, 'label': label}
        if self.transform:
            sample['image'] = self.transform(sample['image'])
        return sample

# Load a subset of real images as references (5 per class)
transform = transforms.Compose([
    transforms.Resize((RESIZE, RESIZE)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

path = kagglehub.dataset_download("sujaykapadnis/vehicle-type-image-dataset")
dataset = VehicleTypeDataset(root_dir=path, transform=transform)

# Collect reference images (5 per class)
reference_images = {i: [] for i in range(num_classes)}
for sample in dataset:
    label = sample['label']
    if len(reference_images[label]) < 5:
        reference_images[label].append(sample['image'])
    if all(len(refs) >= 5 for refs in reference_images.values()):
        break

# Function to compute PSNR, SSIM, and JS divergence
def compute_metrics_for_image(orig, gen):
    # Convert tensors to numpy arrays and rescale to [0, 1]
    orig_np = orig.cpu().numpy() * 0.5 + 0.5  # Denormalize
    gen_np = gen.cpu().numpy() * 0.5 + 0.5    # Denormalize
    orig_np = np.transpose(orig_np, (1, 2, 0))  # (C, H, W) -> (H, W, C)
    gen_np = np.transpose(gen_np, (1, 2, 0))    # (C, H, W) -> (H, W, C)
    orig_np = np.clip(orig_np, 0, 1)
    gen_np = np.clip(gen_np, 0, 1)

    # Compute PSNR
    psnr_score = psnr(orig_np, gen_np, data_range=1.0)

    # Compute SSIM (multichannel=True for RGB images)
    ssim_score = ssim(orig_np, gen_np, multichannel=True, data_range=1.0, channel_axis=2)

    # Compute JS divergence per channel
    js_scores = []
    for c in range(3):  # For each RGB channel
        orig_channel = orig_np[:, :, c].flatten()
        gen_channel = gen_np[:, :, c].flatten()
        # Normalize to probability distributions
        orig_channel = (orig_channel + 1e-10) / (np.sum(orig_channel) + 1e-10 * RESIZE * RESIZE)
        gen_channel = (gen_channel + 1e-10) / (np.sum(gen_channel) + 1e-10 * RESIZE * RESIZE)
        js_score = jensenshannon(orig_channel, gen_channel)
        if np.isnan(js_score):
            js_score = 1.0  # Worst case if computation fails
        js_scores.append(js_score)
    js_score = np.mean(js_scores)

    return psnr_score, ssim_score, js_score

# Process generated images and compute metrics
metrics_dict = {i: [] for i in range(num_classes)}  # Store metrics for each class
good_images = {i: [] for i in range(num_classes)}   # Store good images for each class

for class_label in range(num_classes):
    class_dir = os.path.join(generated_base_dir, str(class_label))
    good_class_dir = os.path.join(good_images_dir, str(class_label))
    os.makedirs(good_class_dir, exist_ok=True)

    if not os.path.exists(class_dir):
        print(f"Class directory {class_dir} not found, skipping class {class_label}.")
        continue

    # Reference images for this class
    ref_images = reference_images[class_label]  # List of 5 reference tensors

    # Process each generated image
    idx = 0
    while idx < 500:  # Attempt to process up to 100 samples per class
        img_path = os.path.join(class_dir, f"sample_{idx}.png")
        if not os.path.exists(img_path):
            print(f"Image {img_path} not found, stopping at index {idx} for class {class_label}.")
            break

        # Load and preprocess the generated image
        try:
            gen_image = Image.open(img_path).convert('RGB')
            gen_tensor = transform(gen_image)
        except Exception as e:
            print(f"Error loading image {img_path}: {str(e)}")
            idx += 1
            continue

        # Compute metrics against each reference image and average
        psnr_scores, ssim_scores, js_scores = [], [], []
        for ref_tensor in ref_images:
            try:
                psnr_score, ssim_score, js_score = compute_metrics_for_image(ref_tensor, gen_tensor)
                psnr_scores.append(psnr_score)
                ssim_scores.append(ssim_score)
                js_scores.append(js_score)
            except Exception as e:
                print(f"Error computing metrics for image {img_path}: {str(e)}")
                psnr_scores.append(0.0)  # Worst case
                ssim_scores.append(0.0)  # Worst case
                js_scores.append(1.0)    # Worst case

        avg_psnr = np.mean(psnr_scores)
        avg_ssim = np.mean(ssim_scores)
        avg_js = np.mean(js_scores)

        metrics_dict[class_label].append({
            'image': f"sample_{idx}.png",
            'psnr': avg_psnr,
            'ssim': avg_ssim,
            'js': avg_js
        })

        # Check if the image meets the "good" criteria
        if avg_psnr > 11.8 and avg_ssim > 0.19 and avg_js < 0.24:
            # Save the good image to the new folder
            good_img_path = os.path.join(good_class_dir, f"sample_{idx}.png")
            gen_image.save(good_img_path)
            good_images[class_label].append(f"sample_{idx}.png")

        idx += 1

    print(f"\nClass {class_label} Metrics:")
    for metric in metrics_dict[class_label]:
        print(f"Image: {metric['image']}, PSNR: {metric['psnr']:.2f}, SSIM: {metric['ssim']:.4f}, JS: {metric['js']:.4f}")
    print(f"Good images for class {class_label}: {len(good_images[class_label])} images saved to {good_class_dir}")

# Summary of good images
total_good = sum(len(good_images[cls]) for cls in good_images)
print(f"\nTotal good images across all classes: {total_good}")
# Out:
# Using scipy version: 1.15.3
# Searching for images in C:\Users\hp\.cache\kagglehub\datasets\sujaykapadnis\vehicle-type-image-dataset\versions\1
# Found 4793 images across 5 classes.
# Classes: ['Hatchback', 'Other', 'Pickup', 'Seden', 'SUV']
#
# Class 0 Metrics:
# Image: sample_0.png, PSNR: 11.75, SSIM: 0.1817, JS: 0.2421
# Image: sample_1.png, PSNR: 11.37, SSIM: 0.1130, JS: 0.2580
# Image: sample_2.png, PSNR: 12.03, SSIM: 0.2295, JS: 0.2540
# Image: sample_3.png, PSNR: 11.88, SSIM: 0.1560, JS: 0.2490
# Image: sample_4.png, PSNR: 11.25, SSIM: 0.1965, JS: 0.2783
# Image: sample_5.png, PSNR: 10.42, SSIM: 0.1273, JS: 0.2967
# Image: sample_6.png, PSNR: 10.91, SSIM: 0.1223, JS: 0.2909
# Image: sample_7.png, PSNR: 11.46, SSIM: 0.1890, JS: 0.2681
# Image: sample_8.png, PSNR: 12.32, SSIM: 0.1999, JS: 0.2613
# Image: sample_9.png, PSNR: 9.44, SSIM: 0.1148, JS: 0.3252
# Image: sample_10.png, PSNR: 10.61, SSIM: 0.1197, JS: 0.2362
# Image: sample_11.png, PSNR: 12.53, SSIM: 0.1955, JS: 0.2415
# Image: sample_12.png, PSNR: 10.79, SSIM: 0.1048, JS: 0.2835
# Image: sample_13.png, PSNR: 12.36, SSIM: 0.2125, JS: 0.2469
# Image: sample_14.png, PSNR: 10.53, SSIM: 0.1187, JS: 0.2877
# Image: sample_15.png, PSNR: 11.69, SSIM: 0.1613, JS: 0.2602
# Image: sample_16.png, PSNR: 10.39, SSIM: 0.0986, JS: 0.2769
# Image: sample_17.png, PSNR: 10.95, SSIM: 0.1088, JS: 0.2757
# Image: sample_18.png, PSNR: 11.52, SSIM: 0.1654, JS: 0.2753
# Image: sample_19.png, PSNR: 11.66, SSIM: 0.1900, JS: 0.2613
# Image: sample_20.png, PSNR: 11.76, SSIM: 0.1589, JS: 0.2707
# Image: sample_21.png, PSNR: 10.07, SSIM: 0.1263, JS: 0.3457
# Image: sample_22.png, PSNR: 12.14, SSIM: 0.1845, JS: 0.2636
# Image: sample_23.png, PSNR: 9.76, SSIM: 0.1164, JS: 0.3225
# Image: sample_24.png, PSNR: 12.20, SSIM: 0.2376, JS: 0.2361
# Image: sample_25.png, PSNR: 9.78, SSIM: 0.0941, JS: 0.3074
# Image: sample_26.png, PSNR: 10.24, SSIM: 0.1117, JS: 0.3194
# Image: sample_27.png, PSNR: 10.95, SSIM: 0.1088, JS: 0.2822
# Image: sample_28.png, PSNR: 9.65, SSIM: 0.0836, JS: 0.3098
# Image: sample_29.png, PSNR: 9.12, SSIM: 0.0839, JS: 0.2902
# Image: sample_30.png, PSNR: 9.40, SSIM: 0.0983, JS: 0.3124
# Image: sample_31.png, PSNR: 10.66, SSIM: 0.1242, JS: 0.3083
# Image: sample_32.png, PSNR: 12.43, SSIM: 0.1820, JS: 0.2408
# Image: sample_33.png, PSNR: 11.75, SSIM: 0.1296, JS: 0.2550
# Image: sample_34.png, PSNR: 11.16, SSIM: 0.1688, JS: 0.2823
# Image: sample_35.png, PSNR: 10.39, SSIM: 0.1600, JS: 0.3204
# Image: sample_36.png, PSNR: 8.96, SSIM: 0.0785, JS: 0.2998
# Image: sample_37.png, PSNR: 12.21, SSIM: 0.1960, JS: 0.2520
# Image: sample_38.png, PSNR: 9.39, SSIM: 0.1089, JS: 0.3149
# Image: sample_39.png, PSNR: 10.05, SSIM: 0.0958, JS: 0.2886
# Image: sample_40.png, PSNR: 12.02, SSIM: 0.1719, JS: 0.2630
# Image: sample_41.png, PSNR: 10.38, SSIM: 0.1477, JS: 0.3233
# Image: sample_42.png, PSNR: 12.32, SSIM: 0.2485, JS: 0.2315
# Image: sample_43.png, PSNR: 10.12, SSIM: 0.1260, JS: 0.2456
# Image: sample_44.png, PSNR: 10.30, SSIM: 0.0982, JS: 0.2844
# Image: sample_45.png, PSNR: 11.24, SSIM: 0.0913, JS: 0.2661
# Image: sample_46.png, PSNR: 10.25, SSIM: 0.1252, JS: 0.3323
# Image: sample_47.png, PSNR: 11.04, SSIM: 0.1049, JS: 0.2694
# Image: sample_48.png, PSNR: 10.55, SSIM: 0.1152, JS: 0.3130
# Image: sample_49.png, PSNR: 9.00, SSIM: 0.0529, JS: 0.3062
# Image: sample_50.png, PSNR: 11.11, SSIM: 0.1005, JS: 0.2618
# Image: sample_51.png, PSNR: 9.86, SSIM: 0.1068, JS: 0.2482
# Image: sample_52.png, PSNR: 10.38, SSIM: 0.1500, JS: 0.3138
# Image: sample_53.png, PSNR: 9.92, SSIM: 0.1304, JS: 0.2946
# Image: sample_54.png, PSNR: 10.58, SSIM: 0.1436, JS: 0.3013
# Image: sample_55.png, PSNR: 10.29, SSIM: 0.0804, JS: 0.2739
# Image: sample_56.png, PSNR: 10.30, SSIM: 0.1048, JS: 0.2944
# Image: sample_57.png, PSNR: 9.21, SSIM: 0.1052, JS: 0.3300
# Image: sample_58.png, PSNR: 11.94, SSIM: 0.1802, JS: 0.2597
# Image: sample_59.png, PSNR: 9.94, SSIM: 0.1044, JS: 0.3381
# Image: sample_60.png, PSNR: 9.36, SSIM: 0.0907, JS: 0.3385
# Image: sample_61.png, PSNR: 10.35, SSIM: 0.1131, JS: 0.2931
# Image: sample_62.png, PSNR: 9.85, SSIM: 0.1047, JS: 0.2661
# Image: sample_63.png, PSNR: 10.63, SSIM: 0.1621, JS: 0.2865
# Image: sample_64.png, PSNR: 9.34, SSIM: 0.0694, JS: 0.3192
# Image: sample_65.png, PSNR: 10.63, SSIM: 0.1523, JS: 0.3012
# Image: sample_66.png, PSNR: 9.83, SSIM: 0.1348, JS: 0.3121
# Image: sample_67.png, PSNR: 10.53, SSIM: 0.1443, JS: 0.3113
# Image: sample_68.png, PSNR: 9.55, SSIM: 0.0766, JS: 0.3186
# Image: sample_69.png, PSNR: 11.23, SSIM: 0.1417, JS: 0.2637
# Image: sample_70.png, PSNR: 10.02, SSIM: 0.0959, JS: 0.3055
# Image: sample_71.png, PSNR: 11.83, SSIM: 0.1881, JS: 0.2495
# Image: sample_72.png, PSNR: 8.80, SSIM: 0.0733, JS: 0.2811
# Image: sample_73.png, PSNR: 11.43, SSIM: 0.1678, JS: 0.2701
# Image: sample_74.png, PSNR: 12.45, SSIM: 0.1943, JS: 0.2436
# Image: sample_75.png, PSNR: 9.62, SSIM: 0.0788, JS: 0.3035
# Image: sample_76.png, PSNR: 9.88, SSIM: 0.1000, JS: 0.3206
# Image: sample_77.png, PSNR: 10.41, SSIM: 0.1355, JS: 0.3283
# Image: sample_78.png, PSNR: 10.08, SSIM: 0.1229, JS: 0.3447
# Image: sample_79.png, PSNR: 9.01, SSIM: 0.0883, JS: 0.3101
# Image: sample_80.png, PSNR: 11.57, SSIM: 0.1758, JS: 0.2525
# Image: sample_81.png, PSNR: 11.86, SSIM: 0.1730, JS: 0.2605
# Image: sample_82.png, PSNR: 9.19, SSIM: 0.1070, JS: 0.3156
# Image: sample_83.png, PSNR: 10.54, SSIM: 0.1282, JS: 0.3025
# Image: sample_84.png, PSNR: 10.38, SSIM: 0.0881, JS: 0.2712
# Image: sample_85.png, PSNR: 10.20, SSIM: 0.0723, JS: 0.3180
# Image: sample_86.png, PSNR: 11.01, SSIM: 0.1709, JS: 0.2795
# Image: sample_87.png, PSNR: 9.89, SSIM: 0.1263, JS: 0.2493
# Image: sample_88.png, PSNR: 10.08, SSIM: 0.1417, JS: 0.2590
# Image: sample_89.png, PSNR: 9.53, SSIM: 0.0880, JS: 0.3190
# Image: sample_90.png, PSNR: 12.36, SSIM: 0.1973, JS: 0.2533
# Image: sample_91.png, PSNR: 9.95, SSIM: 0.1144, JS: 0.3128
# Image: sample_92.png, PSNR: 11.24, SSIM: 0.1019, JS: 0.2829
# Image: sample_93.png, PSNR: 10.09, SSIM: 0.1230, JS: 0.2594
# Image: sample_94.png, PSNR: 10.27, SSIM: 0.1013, JS: 0.2615
# Image: sample_95.png, PSNR: 11.04, SSIM: 0.1557, JS: 0.2513
# Image: sample_96.png, PSNR: 7.84, SSIM: 0.1004, JS: 0.2817
# Image: sample_97.png, PSNR: 11.44, SSIM: 0.1298, JS: 0.2336
# Image: sample_98.png, PSNR: 10.92, SSIM: 0.1533, JS: 0.2642
# Image: sample_99.png, PSNR: 12.09, SSIM: 0.1593, JS: 0.2603
# Image: sample_100.png, PSNR: 12.18, SSIM: 0.2082, JS: 0.2343
# Image: sample_101.png, PSNR: 11.62, SSIM: 0.1744, JS: 0.2686
# Image: sample_102.png, PSNR: 9.26, SSIM: 0.0680, JS: 0.2609
# Image: sample_103.png, PSNR: 10.98, SSIM: 0.1566, JS: 0.2784
# Image: sample_104.png, PSNR: 10.20, SSIM: 0.1562, JS: 0.2581
# Image: sample_105.png, PSNR: 9.79, SSIM: 0.1106, JS: 0.3160
# Image: sample_106.png, PSNR: 10.07, SSIM: 0.1118, JS: 0.2980
# Image: sample_107.png, PSNR: 11.38, SSIM: 0.1636, JS: 0.2686
# Image: sample_108.png, PSNR: 9.42, SSIM: 0.0822, JS: 0.2515
# Image: sample_109.png, PSNR: 10.31, SSIM: 0.1276, JS: 0.3281
# Image: sample_110.png, PSNR: 10.32, SSIM: 0.1054, JS: 0.3221
# Image: sample_111.png, PSNR: 11.13, SSIM: 0.1861, JS: 0.2836
# Image: sample_112.png, PSNR: 10.16, SSIM: 0.1286, JS: 0.3096
# Image: sample_113.png, PSNR: 10.90, SSIM: 0.1404, JS: 0.2560
# Image: sample_114.png, PSNR: 9.79, SSIM: 0.1276, JS: 0.3051
# Image: sample_115.png, PSNR: 8.71, SSIM: 0.0834, JS: 0.3125
# Image: sample_116.png, PSNR: 10.28, SSIM: 0.1071, JS: 0.3221
# Image: sample_117.png, PSNR: 11.28, SSIM: 0.1770, JS: 0.2774
# Image: sample_118.png, PSNR: 10.37, SSIM: 0.1271, JS: 0.3302
# Image: sample_119.png, PSNR: 12.29, SSIM: 0.1900, JS: 0.2593
# Image: sample_120.png, PSNR: 11.91, SSIM: 0.1728, JS: 0.2496
# Image: sample_121.png, PSNR: 10.48, SSIM: 0.1028, JS: 0.3141
# Image: sample_122.png, PSNR: 8.54, SSIM: 0.0900, JS: 0.3079
# Image: sample_123.png, PSNR: 8.13, SSIM: 0.0494, JS: 0.2844
# Image: sample_124.png, PSNR: 10.16, SSIM: 0.1030, JS: 0.3184
# Image: sample_125.png, PSNR: 9.77, SSIM: 0.1093, JS: 0.3432
# Image: sample_126.png, PSNR: 10.97, SSIM: 0.1578, JS: 0.2581
# Image: sample_127.png, PSNR: 11.20, SSIM: 0.1800, JS: 0.2824
# Image: sample_128.png, PSNR: 8.97, SSIM: 0.1196, JS: 0.3145
# Image: sample_129.png, PSNR: 8.32, SSIM: 0.0601, JS: 0.2841
# Image: sample_130.png, PSNR: 10.20, SSIM: 0.1257, JS: 0.3091
# Image: sample_131.png, PSNR: 9.83, SSIM: 0.0934, JS: 0.3200
# Image: sample_132.png, PSNR: 9.39, SSIM: 0.0971, JS: 0.3025
# Image: sample_133.png, PSNR: 10.11, SSIM: 0.1233, JS: 0.3010
# Image: sample_134.png, PSNR: 11.67, SSIM: 0.1427, JS: 0.2616
# Image: sample_135.png, PSNR: 10.71, SSIM: 0.1679, JS: 0.3048
# Image: sample_136.png, PSNR: 11.72, SSIM: 0.1918, JS: 0.2611
# Image: sample_137.png, PSNR: 10.22, SSIM: 0.1120, JS: 0.3260
# Image: sample_138.png, PSNR: 12.36, SSIM: 0.1915, JS: 0.2471
# Image: sample_139.png, PSNR: 9.39, SSIM: 0.0982, JS: 0.3370
# Image: sample_140.png, PSNR: 11.08, SSIM: 0.1463, JS: 0.2932
# Image: sample_141.png, PSNR: 8.61, SSIM: 0.0607, JS: 0.2728
# Image: sample_142.png, PSNR: 9.60, SSIM: 0.1105, JS: 0.3211
# Image: sample_143.png, PSNR: 8.56, SSIM: 0.0961, JS: 0.2719
# Image: sample_144.png, PSNR: 10.39, SSIM: 0.1221, JS: 0.3073
# Image: sample_145.png, PSNR: 9.64, SSIM: 0.0897, JS: 0.3041
# Image: sample_146.png, PSNR: 12.21, SSIM: 0.1843, JS: 0.2506
# Image: sample_147.png, PSNR: 10.31, SSIM: 0.1427, JS: 0.3209
# Image: sample_148.png, PSNR: 12.28, SSIM: 0.1724, JS: 0.2432
# Image: sample_149.png, PSNR: 11.20, SSIM: 0.1716, JS: 0.2750
# Image: sample_150.png, PSNR: 9.91, SSIM: 0.1032, JS: 0.3147
# Image: sample_151.png, PSNR: 11.04, SSIM: 0.1606, JS: 0.2502
# Image: sample_152.png, PSNR: 8.66, SSIM: 0.1146, JS: 0.3117
# Image: sample_153.png, PSNR: 10.37, SSIM: 0.1379, JS: 0.3040
# Image: sample_154.png, PSNR: 10.01, SSIM: 0.1098, JS: 0.3454
# Image: sample_155.png, PSNR: 10.70, SSIM: 0.0932, JS: 0.3028
# Image: sample_156.png, PSNR: 12.11, SSIM: 0.1660, JS: 0.2529
# Image: sample_157.png, PSNR: 11.87, SSIM: 0.2006, JS: 0.2642
# Image: sample_158.png, PSNR: 10.37, SSIM: 0.1228, JS: 0.3092
# Image: sample_159.png, PSNR: 10.37, SSIM: 0.1694, JS: 0.2531
# Image: sample_160.png, PSNR: 8.61, SSIM: 0.1116, JS: 0.2992
# Image: sample_161.png, PSNR: 11.09, SSIM: 0.1659, JS: 0.2748
# Image: sample_162.png, PSNR: 10.81, SSIM: 0.1436, JS: 0.2602
# Image: sample_163.png, PSNR: 11.89, SSIM: 0.1657, JS: 0.2406
# Image: sample_164.png, PSNR: 9.48, SSIM: 0.0998, JS: 0.2727
# Image: sample_165.png, PSNR: 9.78, SSIM: 0.0710, JS: 0.2819
# Image: sample_166.png, PSNR: 10.33, SSIM: 0.1522, JS: 0.3283
# Image: sample_167.png, PSNR: 9.64, SSIM: 0.0908, JS: 0.2530
# Image: sample_168.png, PSNR: 11.97, SSIM: 0.1611, JS: 0.2667
# Image: sample_169.png, PSNR: 11.04, SSIM: 0.1279, JS: 0.2393
# Image: sample_170.png, PSNR: 10.16, SSIM: 0.1085, JS: 0.3057
# Image: sample_171.png, PSNR: 10.36, SSIM: 0.1544, JS: 0.3317
# Image: sample_172.png, PSNR: 10.33, SSIM: 0.1495, JS: 0.3326
# Image: sample_173.png, PSNR: 12.09, SSIM: 0.1652, JS: 0.2477
# Image: sample_174.png, PSNR: 10.33, SSIM: 0.1021, JS: 0.2747
# Image: sample_175.png, PSNR: 10.31, SSIM: 0.1118, JS: 0.2524
# Image: sample_176.png, PSNR: 8.89, SSIM: 0.0648, JS: 0.3055
# Image: sample_177.png, PSNR: 9.96, SSIM: 0.1017, JS: 0.2934
# Image: sample_178.png, PSNR: 12.05, SSIM: 0.1769, JS: 0.2458
# Image: sample_179.png, PSNR: 12.20, SSIM: 0.1897, JS: 0.2304
# Image: sample_180.png, PSNR: 12.61, SSIM: 0.1985, JS: 0.2463
# Image: sample_181.png, PSNR: 11.44, SSIM: 0.1717, JS: 0.2566
# Image: sample_182.png, PSNR: 10.15, SSIM: 0.1329, JS: 0.3391
# Image: sample_183.png, PSNR: 9.79, SSIM: 0.1076, JS: 0.3108
# Image: sample_184.png, PSNR: 10.86, SSIM: 0.1712, JS: 0.2894
# Image: sample_185.png, PSNR: 11.30, SSIM: 0.1889, JS: 0.2807
# Image: sample_186.png, PSNR: 10.67, SSIM: 0.1372, JS: 0.3082
# Image: sample_187.png, PSNR: 12.30, SSIM: 0.1637, JS: 0.2403
# Image: sample_188.png, PSNR: 9.56, SSIM: 0.1452, JS: 0.3053
# Image: sample_189.png, PSNR: 11.68, SSIM: 0.1736, JS: 0.2587
# Image: sample_190.png, PSNR: 10.43, SSIM: 0.1073, JS: 0.3031
# Image: sample_191.png, PSNR: 10.89, SSIM: 0.1279, JS: 0.2801
# Image: sample_192.png, PSNR: 10.39, SSIM: 0.0729, JS: 0.3035
# Image: sample_193.png, PSNR: 10.68, SSIM: 0.1234, JS: 0.3047
# Image: sample_194.png, PSNR: 11.29, SSIM: 0.1272, JS: 0.2771
# Image: sample_195.png, PSNR: 8.23, SSIM: 0.0521, JS: 0.2975
# Image: sample_196.png, PSNR: 10.54, SSIM: 0.1070, JS: 0.3108
# Image: sample_197.png, PSNR: 9.31, SSIM: 0.1013, JS: 0.3221
# Image: sample_198.png, PSNR: 9.99, SSIM: 0.1063, JS: 0.3313
# Image: sample_199.png, PSNR: 11.11, SSIM: 0.1335, JS: 0.2820
# Image: sample_200.png, PSNR: 10.05, SSIM: 0.0951, JS: 0.2464
# Image: sample_201.png, PSNR: 11.11, SSIM: 0.1090, JS: 0.2527
# Image: sample_202.png, PSNR: 12.41, SSIM: 0.1778, JS: 0.2445
# Image: sample_203.png, PSNR: 12.06, SSIM: 0.2051, JS: 0.2568
# Image: sample_204.png, PSNR: 10.51, SSIM: 0.1238, JS: 0.3210
# Image: sample_205.png, PSNR: 10.07, SSIM: 0.1170, JS: 0.3414
# Image: sample_206.png, PSNR: 9.73, SSIM: 0.1106, JS: 0.2916
# Image: sample_207.png, PSNR: 12.35, SSIM: 0.2112, JS: 0.2400
# Image: sample_208.png, PSNR: 9.17, SSIM: 0.1029, JS: 0.3036
# Image: sample_209.png, PSNR: 11.83, SSIM: 0.1571, JS: 0.2604
# Image: sample_210.png, PSNR: 9.33, SSIM: 0.0914, JS: 0.2855
# Image: sample_211.png, PSNR: 8.80, SSIM: 0.0647, JS: 0.2625
# Image: sample_212.png, PSNR: 10.87, SSIM: 0.1189, JS: 0.2906
# Image: sample_213.png, PSNR: 11.83, SSIM: 0.1928, JS: 0.2357
# Image: sample_214.png, PSNR: 11.98, SSIM: 0.1921, JS: 0.2557
# Image: sample_215.png, PSNR: 11.66, SSIM: 0.1848, JS: 0.2599
# Image: sample_216.png, PSNR: 10.44, SSIM: 0.1530, JS: 0.3148
# Image: sample_217.png, PSNR: 9.43, SSIM: 0.1066, JS: 0.2727
# Image: sample_218.png, PSNR: 10.58, SSIM: 0.1191, JS: 0.3078
# Image: sample_219.png, PSNR: 9.63, SSIM: 0.1425, JS: 0.3020
# Image: sample_220.png, PSNR: 9.63, SSIM: 0.1050, JS: 0.3106
# Image: sample_221.png, PSNR: 11.49, SSIM: 0.1811, JS: 0.2771
# Image: sample_222.png, PSNR: 10.40, SSIM: 0.1428, JS: 0.3258
# Image: sample_223.png, PSNR: 10.17, SSIM: 0.0988, JS: 0.3244
# Image: sample_224.png, PSNR: 10.10, SSIM: 0.1275, JS: 0.2713
# Image: sample_225.png, PSNR: 10.29, SSIM: 0.1180, JS: 0.3000
# Image: sample_226.png, PSNR: 12.35, SSIM: 0.1973, JS: 0.2518
# Image: sample_227.png, PSNR: 9.09, SSIM: 0.0523, JS: 0.2876
# Image: sample_228.png, PSNR: 10.15, SSIM: 0.1064, JS: 0.3108
# Image: sample_229.png, PSNR: 12.50, SSIM: 0.2017, JS: 0.2474
# Image: sample_230.png, PSNR: 10.44, SSIM: 0.1345, JS: 0.3187
# Image: sample_231.png, PSNR: 9.32, SSIM: 0.0968, JS: 0.3046
# Image: sample_232.png, PSNR: 10.42, SSIM: 0.0898, JS: 0.2753
# Image: sample_233.png, PSNR: 10.97, SSIM: 0.1369, JS: 0.2524
# Image: sample_234.png, PSNR: 9.98, SSIM: 0.1199, JS: 0.3284
# Image: sample_235.png, PSNR: 11.86, SSIM: 0.1820, JS: 0.2624
# Image: sample_236.png, PSNR: 12.65, SSIM: 0.1794, JS: 0.2384
# Image: sample_237.png, PSNR: 10.94, SSIM: 0.1536, JS: 0.2965
# Image: sample_238.png, PSNR: 11.47, SSIM: 0.1412, JS: 0.2483
# Image: sample_239.png, PSNR: 12.15, SSIM: 0.1662, JS: 0.2569
# Image: sample_240.png, PSNR: 11.67, SSIM: 0.1989, JS: 0.2676
# Image: sample_241.png, PSNR: 10.10, SSIM: 0.1098, JS: 0.3054
# Image: sample_242.png, PSNR: 10.46, SSIM: 0.1338, JS: 0.3111
# Image: sample_243.png, PSNR: 10.08, SSIM: 0.1021, JS: 0.3359
# Image: sample_244.png, PSNR: 10.10, SSIM: 0.1059, JS: 0.3143
# Image: sample_245.png, PSNR: 9.86, SSIM: 0.1074, JS: 0.3264
# Image: sample_246.png, PSNR: 9.64, SSIM: 0.1146, JS: 0.3015
# Image: sample_247.png, PSNR: 9.56, SSIM: 0.0756, JS: 0.3281
# Image: sample_248.png, PSNR: 11.48, SSIM: 0.1450, JS: 0.2538
# Image: sample_249.png, PSNR: 11.96, SSIM: 0.1936, JS: 0.2570
# Image: sample_250.png, PSNR: 10.15, SSIM: 0.1028, JS: 0.3009
# Image: sample_251.png, PSNR: 9.19, SSIM: 0.1255, JS: 0.3238
# Image: sample_252.png, PSNR: 12.07, SSIM: 0.1746, JS: 0.2406
# Image: sample_253.png, PSNR: 9.29, SSIM: 0.0870, JS: 0.2937
# Image: sample_254.png, PSNR: 10.84, SSIM: 0.1347, JS: 0.2984
# Image: sample_255.png, PSNR: 11.40, SSIM: 0.1931, JS: 0.2536
# Image: sample_256.png, PSNR: 9.41, SSIM: 0.1033, JS: 0.2883
# Image: sample_257.png, PSNR: 9.90, SSIM: 0.0789, JS: 0.2756
# Image: sample_258.png, PSNR: 10.87, SSIM: 0.1748, JS: 0.3008
# Image: sample_259.png, PSNR: 9.44, SSIM: 0.1174, JS: 0.3240
# Image: sample_260.png, PSNR: 9.60, SSIM: 0.1071, JS: 0.3247
# Image: sample_261.png, PSNR: 9.84, SSIM: 0.1186, JS: 0.2669
# Image: sample_262.png, PSNR: 9.78, SSIM: 0.1218, JS: 0.3104
# Image: sample_263.png, PSNR: 12.25, SSIM: 0.1845, JS: 0.2470
# Image: sample_264.png, PSNR: 12.50, SSIM: 0.1945, JS: 0.2441
# Image: sample_265.png, PSNR: 11.24, SSIM: 0.1555, JS: 0.2478
# Image: sample_266.png, PSNR: 12.31, SSIM: 0.1802, JS: 0.2445
# Image: sample_267.png, PSNR: 9.20, SSIM: 0.0934, JS: 0.3189
# Image: sample_268.png, PSNR: 7.99, SSIM: 0.0569, JS: 0.3268
# Image: sample_269.png, PSNR: 11.73, SSIM: 0.1471, JS: 0.2605
# Image: sample_270.png, PSNR: 9.00, SSIM: 0.0814, JS: 0.3045
# Image: sample_271.png, PSNR: 9.10, SSIM: 0.0659, JS: 0.2760
# Image: sample_272.png, PSNR: 10.26, SSIM: 0.1241, JS: 0.3260
# Image: sample_273.png, PSNR: 10.19, SSIM: 0.1095, JS: 0.3249
# Image: sample_274.png, PSNR: 9.12, SSIM: 0.1016, JS: 0.3338
# Image: sample_275.png, PSNR: 10.98, SSIM: 0.1888, JS: 0.2463
# Image: sample_276.png, PSNR: 10.99, SSIM: 0.1679, JS: 0.2518
# Image: sample_277.png, PSNR: 12.25, SSIM: 0.1788, JS: 0.2489
# Image: sample_278.png, PSNR: 9.87, SSIM: 0.1158, JS: 0.3443
# Image: sample_279.png, PSNR: 10.03, SSIM: 0.1081, JS: 0.3289
# Image: sample_280.png, PSNR: 8.74, SSIM: 0.0863, JS: 0.3017
# Image: sample_281.png, PSNR: 11.04, SSIM: 0.1318, JS: 0.2775
# Image: sample_282.png, PSNR: 10.60, SSIM: 0.0819, JS: 0.2714
# Image: sample_283.png, PSNR: 10.45, SSIM: 0.1064, JS: 0.2691
# Image: sample_284.png, PSNR: 9.20, SSIM: 0.0838, JS: 0.2832
# Image: sample_285.png, PSNR: 11.57, SSIM: 0.1917, JS: 0.2786
# Image: sample_286.png, PSNR: 9.95, SSIM: 0.0961, JS: 0.2644
# Image: sample_287.png, PSNR: 9.77, SSIM: 0.0918, JS: 0.3215
# Image: sample_288.png, PSNR: 11.34, SSIM: 0.1593, JS: 0.2654
# Image: sample_289.png, PSNR: 11.36, SSIM: 0.1379, JS: 0.2644
# Image: sample_290.png, PSNR: 10.48, SSIM: 0.1091, JS: 0.2613
# Image: sample_291.png, PSNR: 10.73, SSIM: 0.1810, JS: 0.2504
# Image: sample_292.png, PSNR: 10.55, SSIM: 0.1366, JS: 0.3029
# Image: sample_293.png, PSNR: 11.88, SSIM: 0.1436, JS: 0.2489
# Image: sample_294.png, PSNR: 11.45, SSIM: 0.1745, JS: 0.2390
# Image: sample_295.png, PSNR: 10.49, SSIM: 0.1359, JS: 0.3088
# Image: sample_296.png, PSNR: 10.78, SSIM: 0.1503, JS: 0.2797
# Image: sample_297.png, PSNR: 9.73, SSIM: 0.0929, JS: 0.2578
# Image: sample_298.png, PSNR: 9.60, SSIM: 0.0935, JS: 0.3504
# Image: sample_299.png, PSNR: 12.45, SSIM: 0.1758, JS: 0.2463
# Image: sample_300.png, PSNR: 10.01, SSIM: 0.0975, JS: 0.3037
# Image: sample_301.png, PSNR: 11.75, SSIM: 0.1790, JS: 0.2453
# Image: sample_302.png, PSNR: 9.76, SSIM: 0.1385, JS: 0.2894
# Image: sample_303.png, PSNR: 12.11, SSIM: 0.1771, JS: 0.2571
# Image: sample_304.png, PSNR: 10.26, SSIM: 0.1173, JS: 0.2613
# Image: sample_305.png, PSNR: 11.75, SSIM: 0.1787, JS: 0.2506
# Image: sample_306.png, PSNR: 9.74, SSIM: 0.0958, JS: 0.3067
# Image: sample_307.png, PSNR: 10.13, SSIM: 0.1033, JS: 0.3212
# Image: sample_308.png, PSNR: 10.98, SSIM: 0.1423, JS: 0.2458
# Image: sample_309.png, PSNR: 10.04, SSIM: 0.1247, JS: 0.2654
# Image: sample_310.png, PSNR: 9.77, SSIM: 0.1011, JS: 0.2927
# Image: sample_311.png, PSNR: 11.46, SSIM: 0.1485, JS: 0.2582
# Image: sample_312.png, PSNR: 9.24, SSIM: 0.0861, JS: 0.2977
# Image: sample_313.png, PSNR: 10.32, SSIM: 0.1194, JS: 0.3213
# Image: sample_314.png, PSNR: 9.93, SSIM: 0.1109, JS: 0.3361
# Image: sample_315.png, PSNR: 10.40, SSIM: 0.1565, JS: 0.3248
# Image: sample_316.png, PSNR: 11.59, SSIM: 0.1657, JS: 0.2525
# Image: sample_317.png, PSNR: 8.38, SSIM: 0.0382, JS: 0.2983
# Image: sample_318.png, PSNR: 11.80, SSIM: 0.1606, JS: 0.2661
# Image: sample_319.png, PSNR: 10.32, SSIM: 0.1107, JS: 0.3152
# Image: sample_320.png, PSNR: 10.38, SSIM: 0.1249, JS: 0.3207
# Image: sample_321.png, PSNR: 7.76, SSIM: 0.0546, JS: 0.2614
# Image: sample_322.png, PSNR: 10.48, SSIM: 0.1550, JS: 0.3215
# Image: sample_323.png, PSNR: 9.29, SSIM: 0.1104, JS: 0.2677
# Image: sample_324.png, PSNR: 12.13, SSIM: 0.1409, JS: 0.2362
# Image: sample_325.png, PSNR: 9.07, SSIM: 0.1007, JS: 0.2858
# Image: sample_326.png, PSNR: 11.19, SSIM: 0.1517, JS: 0.2638
# Image: sample_327.png, PSNR: 10.51, SSIM: 0.1763, JS: 0.2514
# Image: sample_328.png, PSNR: 12.20, SSIM: 0.2114, JS: 0.2530
# Image: sample_329.png, PSNR: 11.83, SSIM: 0.1960, JS: 0.2546
# Image: sample_330.png, PSNR: 10.29, SSIM: 0.1041, JS: 0.3268
# Image: sample_331.png, PSNR: 10.04, SSIM: 0.1272, JS: 0.3414
# Image: sample_332.png, PSNR: 10.08, SSIM: 0.1225, JS: 0.3212
# Image: sample_333.png, PSNR: 11.05, SSIM: 0.1653, JS: 0.2399
# Image: sample_334.png, PSNR: 11.42, SSIM: 0.1904, JS: 0.2756
# Image: sample_335.png, PSNR: 11.69, SSIM: 0.1612, JS: 0.2536
# Image: sample_336.png, PSNR: 9.12, SSIM: 0.0995, JS: 0.2923
# Image: sample_337.png, PSNR: 11.63, SSIM: 0.1642, JS: 0.2777
# Image: sample_338.png, PSNR: 9.48, SSIM: 0.0979, JS: 0.3162
# Image: sample_339.png, PSNR: 10.43, SSIM: 0.1324, JS: 0.3181
# Image: sample_340.png, PSNR: 9.34, SSIM: 0.0970, JS: 0.3082
# Image: sample_341.png, PSNR: 11.59, SSIM: 0.1535, JS: 0.2448
# Image: sample_342.png, PSNR: 11.73, SSIM: 0.1832, JS: 0.2449
# Image: sample_343.png, PSNR: 10.03, SSIM: 0.1066, JS: 0.3407
# Image: sample_344.png, PSNR: 8.60, SSIM: 0.0809, JS: 0.2919
# Image: sample_345.png, PSNR: 11.76, SSIM: 0.1581, JS: 0.2677
# Image: sample_346.png, PSNR: 12.23, SSIM: 0.1814, JS: 0.2425
# Image: sample_347.png, PSNR: 10.81, SSIM: 0.1488, JS: 0.2682
# Image: sample_348.png, PSNR: 11.95, SSIM: 0.1818, JS: 0.2643
# Image: sample_349.png, PSNR: 11.44, SSIM: 0.1992, JS: 0.2690
# Image: sample_350.png, PSNR: 10.14, SSIM: 0.0894, JS: 0.3291
# Image: sample_351.png, PSNR: 11.19, SSIM: 0.1789, JS: 0.2450
# Image: sample_352.png, PSNR: 12.34, SSIM: 0.1946, JS: 0.2412
# Image: sample_353.png, PSNR: 9.14, SSIM: 0.0875, JS: 0.3101
# Image: sample_354.png, PSNR: 10.59, SSIM: 0.1450, JS: 0.3145
# Image: sample_355.png, PSNR: 10.13, SSIM: 0.0971, JS: 0.3209
# Image: sample_356.png, PSNR: 8.70, SSIM: 0.0984, JS: 0.2983
# Image: sample_357.png, PSNR: 10.69, SSIM: 0.1855, JS: 0.2532
# Image: sample_358.png, PSNR: 9.26, SSIM: 0.0795, JS: 0.2709
# Image: sample_359.png, PSNR: 9.23, SSIM: 0.1048, JS: 0.2693
# Image: sample_360.png, PSNR: 9.91, SSIM: 0.0977, JS: 0.3027
# Image: sample_361.png, PSNR: 11.98, SSIM: 0.1816, JS: 0.2539
# Image: sample_362.png, PSNR: 8.61, SSIM: 0.0874, JS: 0.3194
# Image: sample_363.png, PSNR: 11.06, SSIM: 0.1590, JS: 0.2850
# Image: sample_364.png, PSNR: 11.02, SSIM: 0.0934, JS: 0.2749
# Image: sample_365.png, PSNR: 11.66, SSIM: 0.1949, JS: 0.2483
# Image: sample_366.png, PSNR: 9.72, SSIM: 0.0721, JS: 0.2982
# Image: sample_367.png, PSNR: 9.13, SSIM: 0.0958, JS: 0.2741
# Image: sample_368.png, PSNR: 10.36, SSIM: 0.1264, JS: 0.3026
# Image: sample_369.png, PSNR: 10.01, SSIM: 0.1257, JS: 0.2998
# Image: sample_370.png, PSNR: 11.63, SSIM: 0.2141, JS: 0.2787
# Image: sample_371.png, PSNR: 10.33, SSIM: 0.1259, JS: 0.3215
# Image: sample_372.png, PSNR: 10.07, SSIM: 0.0803, JS: 0.2720
# Image: sample_373.png, PSNR: 9.53, SSIM: 0.0830, JS: 0.2693
# Image: sample_374.png, PSNR: 8.12, SSIM: 0.0561, JS: 0.3150
# Image: sample_375.png, PSNR: 11.84, SSIM: 0.1973, JS: 0.2401
# Image: sample_376.png, PSNR: 10.13, SSIM: 0.1456, JS: 0.2506
# Image: sample_377.png, PSNR: 12.05, SSIM: 0.1656, JS: 0.2443
# Image: sample_378.png, PSNR: 10.22, SSIM: 0.1030, JS: 0.3117
# Image: sample_379.png, PSNR: 10.85, SSIM: 0.1349, JS: 0.2993
# Image: sample_380.png, PSNR: 10.67, SSIM: 0.1276, JS: 0.3079
# Image: sample_381.png, PSNR: 10.45, SSIM: 0.1454, JS: 0.3246
# Image: sample_382.png, PSNR: 10.31, SSIM: 0.1490, JS: 0.3035
# Image: sample_383.png, PSNR: 10.34, SSIM: 0.0847, JS: 0.2949
# Image: sample_384.png, PSNR: 12.03, SSIM: 0.1718, JS: 0.2689
# Image: sample_385.png, PSNR: 11.05, SSIM: 0.1301, JS: 0.2713
# Image: sample_386.png, PSNR: 10.71, SSIM: 0.1358, JS: 0.3012
# Image: sample_387.png, PSNR: 10.95, SSIM: 0.1410, JS: 0.2862
# Image: sample_388.png, PSNR: 10.57, SSIM: 0.1254, JS: 0.3068
# Image: sample_389.png, PSNR: 10.90, SSIM: 0.1780, JS: 0.2802
# Image: sample_390.png, PSNR: 10.14, SSIM: 0.0805, JS: 0.2614
# Image: sample_391.png, PSNR: 10.99, SSIM: 0.1231, JS: 0.2905
# Image: sample_392.png, PSNR: 11.74, SSIM: 0.1505, JS: 0.2611
# Image: sample_393.png, PSNR: 12.39, SSIM: 0.1975, JS: 0.2551
# Image: sample_394.png, PSNR: 7.81, SSIM: 0.0554, JS: 0.2735
# Image: sample_395.png, PSNR: 9.32, SSIM: 0.1054, JS: 0.2889
# Image: sample_396.png, PSNR: 9.69, SSIM: 0.0936, JS: 0.3146
# Image: sample_397.png, PSNR: 11.96, SSIM: 0.1684, JS: 0.2522
# Image: sample_398.png, PSNR: 12.05, SSIM: 0.2228, JS: 0.2336
# Image: sample_399.png, PSNR: 10.06, SSIM: 0.1132, JS: 0.2886
# Image: sample_400.png, PSNR: 10.99, SSIM: 0.1221, JS: 0.2737
# Image: sample_401.png, PSNR: 12.18, SSIM: 0.1603, JS: 0.2553
# Image: sample_402.png, PSNR: 11.62, SSIM: 0.1521, JS: 0.2598
# Image: sample_403.png, PSNR: 9.75, SSIM: 0.1186, JS: 0.2461
# Image: sample_404.png, PSNR: 10.06, SSIM: 0.1208, JS: 0.2690
# Image: sample_405.png, PSNR: 8.92, SSIM: 0.0574, JS: 0.3033
# Image: sample_406.png, PSNR: 11.63, SSIM: 0.1355, JS: 0.2559
# Image: sample_407.png, PSNR: 9.41, SSIM: 0.0974, JS: 0.2582
# Image: sample_408.png, PSNR: 12.33, SSIM: 0.1756, JS: 0.2535
# Image: sample_409.png, PSNR: 10.91, SSIM: 0.1798, JS: 0.2907
# Image: sample_410.png, PSNR: 11.42, SSIM: 0.2004, JS: 0.2752
# Image: sample_411.png, PSNR: 11.09, SSIM: 0.1903, JS: 0.2414
# Image: sample_412.png, PSNR: 9.85, SSIM: 0.1112, JS: 0.3160
# Image: sample_413.png, PSNR: 10.36, SSIM: 0.1422, JS: 0.3212
# Image: sample_414.png, PSNR: 11.82, SSIM: 0.1413, JS: 0.2605
# Image: sample_415.png, PSNR: 8.78, SSIM: 0.0707, JS: 0.3030
# Image: sample_416.png, PSNR: 10.57, SSIM: 0.1299, JS: 0.3141
# Image: sample_417.png, PSNR: 11.97, SSIM: 0.1966, JS: 0.2512
# Image: sample_418.png, PSNR: 10.26, SSIM: 0.1008, JS: 0.3254
# Image: sample_419.png, PSNR: 10.86, SSIM: 0.1009, JS: 0.2595
# Image: sample_420.png, PSNR: 12.49, SSIM: 0.1853, JS: 0.2388
# Image: sample_421.png, PSNR: 11.41, SSIM: 0.1104, JS: 0.2775
# Image: sample_422.png, PSNR: 11.67, SSIM: 0.1816, JS: 0.2497
# Image: sample_423.png, PSNR: 11.42, SSIM: 0.1952, JS: 0.2493
# Image: sample_424.png, PSNR: 10.93, SSIM: 0.1008, JS: 0.2882
# Image: sample_425.png, PSNR: 10.09, SSIM: 0.1161, JS: 0.3126
# Image: sample_426.png, PSNR: 10.61, SSIM: 0.1147, JS: 0.2951
# Image: sample_427.png, PSNR: 11.24, SSIM: 0.2142, JS: 0.2818
# Image: sample_428.png, PSNR: 12.09, SSIM: 0.1626, JS: 0.2575
# Image: sample_429.png, PSNR: 10.24, SSIM: 0.1222, JS: 0.3005
# Image: sample_430.png, PSNR: 9.42, SSIM: 0.1213, JS: 0.2967
# Image: sample_431.png, PSNR: 10.24, SSIM: 0.1195, JS: 0.3208
# Image: sample_432.png, PSNR: 10.52, SSIM: 0.1293, JS: 0.2565
# Image: sample_433.png, PSNR: 10.10, SSIM: 0.1025, JS: 0.3329
# Image: sample_434.png, PSNR: 11.44, SSIM: 0.1995, JS: 0.2769
# Image: sample_435.png, PSNR: 10.91, SSIM: 0.1262, JS: 0.2914
# Image: sample_436.png, PSNR: 11.29, SSIM: 0.1520, JS: 0.2526
# Image: sample_437.png, PSNR: 9.17, SSIM: 0.1017, JS: 0.2986
# Image: sample_438.png, PSNR: 10.56, SSIM: 0.1311, JS: 0.3020
# Image: sample_439.png, PSNR: 11.36, SSIM: 0.1798, JS: 0.2812
# Image: sample_440.png, PSNR: 9.06, SSIM: 0.0771, JS: 0.2650
# Image: sample_441.png, PSNR: 12.38, SSIM: 0.1969, JS: 0.2508
# Image: sample_442.png, PSNR: 10.84, SSIM: 0.1139, JS: 0.2854
# Image: sample_443.png, PSNR: 11.89, SSIM: 0.1887, JS: 0.2628
# Image: sample_444.png, PSNR: 10.33, SSIM: 0.1253, JS: 0.3238
# Image: sample_445.png, PSNR: 9.80, SSIM: 0.0687, JS: 0.2685
# Image: sample_446.png, PSNR: 9.35, SSIM: 0.0730, JS: 0.2926
# Image: sample_447.png, PSNR: 10.49, SSIM: 0.1190, JS: 0.3016
# Image: sample_448.png, PSNR: 11.08, SSIM: 0.1716, JS: 0.2440
# Image: sample_449.png, PSNR: 10.50, SSIM: 0.1296, JS: 0.3188
# Image: sample_450.png, PSNR: 11.65, SSIM: 0.1394, JS: 0.2672
# Image: sample_451.png, PSNR: 10.66, SSIM: 0.1503, JS: 0.3061
# Image: sample_452.png, PSNR: 10.14, SSIM: 0.0920, JS: 0.2768
# Image: sample_453.png, PSNR: 9.57, SSIM: 0.1387, JS: 0.2969
# Image: sample_454.png, PSNR: 11.73, SSIM: 0.1912, JS: 0.2683
# Image: sample_455.png, PSNR: 11.99, SSIM: 0.1795, JS: 0.2747
# Image: sample_456.png, PSNR: 11.35, SSIM: 0.2117, JS: 0.2778
# Image: sample_457.png, PSNR: 9.99, SSIM: 0.0844, JS: 0.2967
# Image: sample_458.png, PSNR: 10.52, SSIM: 0.1266, JS: 0.2517
# Image: sample_459.png, PSNR: 10.41, SSIM: 0.0958, JS: 0.2572
# Image: sample_460.png, PSNR: 9.10, SSIM: 0.0930, JS: 0.3166
# Image: sample_461.png, PSNR: 11.19, SSIM: 0.1914, JS: 0.2854
# Image: sample_462.png, PSNR: 10.99, SSIM: 0.1494, JS: 0.2510
# Image: sample_463.png, PSNR: 11.16, SSIM: 0.1846, JS: 0.2852
# Image: sample_464.png, PSNR: 9.21, SSIM: 0.0768, JS: 0.3067
# Image: sample_465.png, PSNR: 12.34, SSIM: 0.1810, JS: 0.2417
# Image: sample_466.png, PSNR: 9.56, SSIM: 0.1019, JS: 0.3091
# Image: sample_467.png, PSNR: 11.49, SSIM: 0.1634, JS: 0.2660
# Image: sample_468.png, PSNR: 9.29, SSIM: 0.0799, JS: 0.2797
# Image: sample_469.png, PSNR: 10.84, SSIM: 0.1953, JS: 0.2996
# Image: sample_470.png, PSNR: 11.06, SSIM: 0.1542, JS: 0.2797
# Image: sample_471.png, PSNR: 11.93, SSIM: 0.1607, JS: 0.2592
# Image: sample_472.png, PSNR: 10.03, SSIM: 0.1261, JS: 0.3248
# Image: sample_473.png, PSNR: 12.20, SSIM: 0.1796, JS: 0.2524
# Image: sample_474.png, PSNR: 11.16, SSIM: 0.1508, JS: 0.2682
# Image: sample_475.png, PSNR: 11.13, SSIM: 0.1745, JS: 0.2888
# Image: sample_476.png, PSNR: 11.95, SSIM: 0.1856, JS: 0.2685
# Image: sample_477.png, PSNR: 10.18, SSIM: 0.1269, JS: 0.2810
# Image: sample_478.png, PSNR: 11.83, SSIM: 0.1596, JS: 0.2627
# Image: sample_479.png, PSNR: 11.03, SSIM: 0.1631, JS: 0.2788
# Image: sample_480.png, PSNR: 9.07, SSIM: 0.1008, JS: 0.3119
# Image: sample_481.png, PSNR: 11.89, SSIM: 0.1738, JS: 0.2397
# Image: sample_482.png, PSNR: 11.53, SSIM: 0.1889, JS: 0.2676
# Image: sample_483.png, PSNR: 9.74, SSIM: 0.1186, JS: 0.3092
# Image: sample_484.png, PSNR: 7.71, SSIM: 0.0526, JS: 0.2744
# Image: sample_485.png, PSNR: 11.54, SSIM: 0.1831, JS: 0.2700
# Image: sample_486.png, PSNR: 10.41, SSIM: 0.1569, JS: 0.3053
# Image: sample_487.png, PSNR: 8.19, SSIM: 0.0431, JS: 0.2891
# Image: sample_488.png, PSNR: 11.24, SSIM: 0.2025, JS: 0.2809
# Image: sample_489.png, PSNR: 11.34, SSIM: 0.1770, JS: 0.2554
# Image: sample_490.png, PSNR: 8.26, SSIM: 0.0630, JS: 0.2859
# Image: sample_491.png, PSNR: 9.81, SSIM: 0.1074, JS: 0.3295
# Image: sample_492.png, PSNR: 11.15, SSIM: 0.1989, JS: 0.2829
# Image: sample_493.png, PSNR: 9.26, SSIM: 0.0775, JS: 0.2882
# Image: sample_494.png, PSNR: 9.88, SSIM: 0.1282, JS: 0.3065
# Image: sample_495.png, PSNR: 10.29, SSIM: 0.1449, JS: 0.3290
# Image: sample_496.png, PSNR: 9.28, SSIM: 0.0839, JS: 0.2824
# Image: sample_497.png, PSNR: 8.51, SSIM: 0.0879, JS: 0.3135
# Image: sample_498.png, PSNR: 9.83, SSIM: 0.1086, JS: 0.3496
# Image: sample_499.png, PSNR: 12.44, SSIM: 0.1886, JS: 0.2371
# Good images for class 0: 6 images saved to C:\Users\hp\Desktop\fedavg\good_images-arch-A5-500\0
#
# Class 1 Metrics:
# Image: sample_0.png, PSNR: 12.24, SSIM: 0.1987, JS: 0.2471
# Image: sample_1.png, PSNR: 13.34, SSIM: 0.2044, JS: 0.2155
# Image: sample_2.png, PSNR: 12.34, SSIM: 0.1921, JS: 0.2440
# Image: sample_3.png, PSNR: 11.51, SSIM: 0.1467, JS: 0.2680
# Image: sample_4.png, PSNR: 12.21, SSIM: 0.1639, JS: 0.2520
# Image: sample_5.png, PSNR: 11.52, SSIM: 0.1580, JS: 0.2698
# Image: sample_6.png, PSNR: 11.39, SSIM: 0.1707, JS: 0.2885
# Image: sample_7.png, PSNR: 11.16, SSIM: 0.1008, JS: 0.2325
# Image: sample_8.png, PSNR: 12.44, SSIM: 0.1644, JS: 0.2420
# Image: sample_9.png, PSNR: 12.00, SSIM: 0.2012, JS: 0.2609
# Image: sample_10.png, PSNR: 11.08, SSIM: 0.1036, JS: 0.2480
# Image: sample_11.png, PSNR: 11.33, SSIM: 0.1229, JS: 0.2787
# Image: sample_12.png, PSNR: 9.90, SSIM: 0.1198, JS: 0.3007
# Image: sample_13.png, PSNR: 12.51, SSIM: 0.1943, JS: 0.2346
# Image: sample_14.png, PSNR: 11.78, SSIM: 0.1085, JS: 0.2365
# Image: sample_15.png, PSNR: 11.95, SSIM: 0.1596, JS: 0.2624
# Image: sample_16.png, PSNR: 12.12, SSIM: 0.1264, JS: 0.2418
# Image: sample_17.png, PSNR: 12.76, SSIM: 0.1652, JS: 0.2333
# Image: sample_18.png, PSNR: 10.47, SSIM: 0.0840, JS: 0.2524
# Image: sample_19.png, PSNR: 13.07, SSIM: 0.2291, JS: 0.2189
# Image: sample_20.png, PSNR: 12.30, SSIM: 0.1687, JS: 0.2470
# Image: sample_21.png, PSNR: 11.86, SSIM: 0.1288, JS: 0.2624
# Image: sample_22.png, PSNR: 13.33, SSIM: 0.2216, JS: 0.2084
# Image: sample_23.png, PSNR: 12.29, SSIM: 0.1659, JS: 0.2519
# Image: sample_24.png, PSNR: 12.06, SSIM: 0.1183, JS: 0.2213
# Image: sample_25.png, PSNR: 12.00, SSIM: 0.1944, JS: 0.2593
# Image: sample_26.png, PSNR: 10.54, SSIM: 0.1123, JS: 0.2867
# Image: sample_27.png, PSNR: 12.29, SSIM: 0.1127, JS: 0.2381
# Image: sample_28.png, PSNR: 11.93, SSIM: 0.1536, JS: 0.2507
# Image: sample_29.png, PSNR: 11.10, SSIM: 0.1241, JS: 0.2795
# Image: sample_30.png, PSNR: 10.11, SSIM: 0.0994, JS: 0.2733
# Image: sample_31.png, PSNR: 13.16, SSIM: 0.2058, JS: 0.2312
# Image: sample_32.png, PSNR: 12.65, SSIM: 0.1700, JS: 0.2283
# Image: sample_33.png, PSNR: 11.62, SSIM: 0.1299, JS: 0.2648
# Image: sample_34.png, PSNR: 12.55, SSIM: 0.2186, JS: 0.2267
# Image: sample_35.png, PSNR: 11.80, SSIM: 0.1542, JS: 0.2489
# Image: sample_36.png, PSNR: 11.92, SSIM: 0.1322, JS: 0.2570
# Image: sample_37.png, PSNR: 12.36, SSIM: 0.1964, JS: 0.2434
# Image: sample_38.png, PSNR: 11.63, SSIM: 0.1968, JS: 0.2779
# Image: sample_39.png, PSNR: 10.53, SSIM: 0.1291, JS: 0.2926
# Image: sample_40.png, PSNR: 11.07, SSIM: 0.1045, JS: 0.2854
# Image: sample_41.png, PSNR: 12.50, SSIM: 0.2115, JS: 0.2436
# Image: sample_42.png, PSNR: 9.45, SSIM: 0.0883, JS: 0.3012
# Image: sample_43.png, PSNR: 12.28, SSIM: 0.1662, JS: 0.2493
# Image: sample_44.png, PSNR: 11.27, SSIM: 0.1375, JS: 0.2807
# Image: sample_45.png, PSNR: 11.24, SSIM: 0.1151, JS: 0.2739
# Image: sample_46.png, PSNR: 11.31, SSIM: 0.1020, JS: 0.2704
# Image: sample_47.png, PSNR: 12.26, SSIM: 0.1542, JS: 0.2495
# Image: sample_48.png, PSNR: 12.15, SSIM: 0.1563, JS: 0.2526
# Image: sample_49.png, PSNR: 11.62, SSIM: 0.1169, JS: 0.2641
# Image: sample_50.png, PSNR: 12.21, SSIM: 0.1612, JS: 0.2468
# Image: sample_51.png, PSNR: 12.73, SSIM: 0.1629, JS: 0.2328
# Image: sample_52.png, PSNR: 9.76, SSIM: 0.0765, JS: 0.2744
# Image: sample_53.png, PSNR: 12.15, SSIM: 0.1709, JS: 0.2524
# Image: sample_54.png, PSNR: 12.67, SSIM: 0.1848, JS: 0.2263
# Image: sample_55.png, PSNR: 12.04, SSIM: 0.1566, JS: 0.2512
# Image: sample_56.png, PSNR: 12.69, SSIM: 0.1478, JS: 0.2301
# Image: sample_57.png, PSNR: 13.37, SSIM: 0.1968, JS: 0.2166
# Image: sample_58.png, PSNR: 12.34, SSIM: 0.2143, JS: 0.2457
# Image: sample_59.png, PSNR: 12.01, SSIM: 0.1229, JS: 0.2497
# Image: sample_60.png, PSNR: 10.81, SSIM: 0.0923, JS: 0.2226
# Image: sample_61.png, PSNR: 12.64, SSIM: 0.1861, JS: 0.2314
# Image: sample_62.png, PSNR: 12.09, SSIM: 0.1571, JS: 0.2511
# Image: sample_63.png, PSNR: 11.88, SSIM: 0.1287, JS: 0.2592
# Image: sample_64.png, PSNR: 11.27, SSIM: 0.1440, JS: 0.2885
# Image: sample_65.png, PSNR: 12.24, SSIM: 0.1372, JS: 0.2448
# Image: sample_66.png, PSNR: 10.88, SSIM: 0.1546, JS: 0.2947
# Image: sample_67.png, PSNR: 11.76, SSIM: 0.1466, JS: 0.2610
# Image: sample_68.png, PSNR: 11.34, SSIM: 0.1253, JS: 0.2831
# Image: sample_69.png, PSNR: 11.92, SSIM: 0.1372, JS: 0.2530
# Image: sample_70.png, PSNR: 11.22, SSIM: 0.1404, JS: 0.2734
# Image: sample_71.png, PSNR: 12.31, SSIM: 0.1746, JS: 0.2510
# Image: sample_72.png, PSNR: 11.49, SSIM: 0.1684, JS: 0.2821
# Image: sample_73.png, PSNR: 12.73, SSIM: 0.1401, JS: 0.2268
# Image: sample_74.png, PSNR: 12.38, SSIM: 0.1614, JS: 0.2236
# Image: sample_75.png, PSNR: 11.88, SSIM: 0.1550, JS: 0.2659
# Image: sample_76.png, PSNR: 12.35, SSIM: 0.1963, JS: 0.2490
# Image: sample_77.png, PSNR: 12.39, SSIM: 0.1152, JS: 0.2293
# Image: sample_78.png, PSNR: 10.51, SSIM: 0.0910, JS: 0.2870
# Image: sample_79.png, PSNR: 12.57, SSIM: 0.1781, JS: 0.2376
# Image: sample_80.png, PSNR: 11.31, SSIM: 0.1327, JS: 0.2716
# Image: sample_81.png, PSNR: 12.13, SSIM: 0.1906, JS: 0.2545
# Image: sample_82.png, PSNR: 12.01, SSIM: 0.1211, JS: 0.2493
# Image: sample_83.png, PSNR: 11.37, SSIM: 0.1340, JS: 0.2740
# Image: sample_84.png, PSNR: 12.21, SSIM: 0.1857, JS: 0.2527
# Image: sample_85.png, PSNR: 12.54, SSIM: 0.1686, JS: 0.2432
# Image: sample_86.png, PSNR: 11.74, SSIM: 0.1329, JS: 0.2633
# Image: sample_87.png, PSNR: 12.32, SSIM: 0.1481, JS: 0.2442
# Image: sample_88.png, PSNR: 11.24, SSIM: 0.0973, JS: 0.2800
# Image: sample_89.png, PSNR: 10.39, SSIM: 0.1473, JS: 0.2926
# Image: sample_90.png, PSNR: 12.50, SSIM: 0.1394, JS: 0.2308
# Image: sample_91.png, PSNR: 11.94, SSIM: 0.1569, JS: 0.2538
# Image: sample_92.png, PSNR: 11.10, SSIM: 0.0882, JS: 0.2595
# Image: sample_93.png, PSNR: 11.42, SSIM: 0.1368, JS: 0.2824
# Image: sample_94.png, PSNR: 12.46, SSIM: 0.1777, JS: 0.2345
# Image: sample_95.png, PSNR: 12.25, SSIM: 0.2005, JS: 0.2486
# Image: sample_96.png, PSNR: 11.88, SSIM: 0.1743, JS: 0.2608
# Image: sample_97.png, PSNR: 11.91, SSIM: 0.1552, JS: 0.2606
# Image: sample_98.png, PSNR: 12.24, SSIM: 0.1681, JS: 0.2548
# Image: sample_99.png, PSNR: 12.40, SSIM: 0.1873, JS: 0.2423
# Image: sample_100.png, PSNR: 10.54, SSIM: 0.1230, JS: 0.3011
# Image: sample_101.png, PSNR: 11.24, SSIM: 0.0984, JS: 0.2807
# Image: sample_102.png, PSNR: 12.19, SSIM: 0.1792, JS: 0.2506
# Image: sample_103.png, PSNR: 12.97, SSIM: 0.2211, JS: 0.2211
# Image: sample_104.png, PSNR: 12.04, SSIM: 0.1930, JS: 0.2619
# Image: sample_105.png, PSNR: 10.40, SSIM: 0.0858, JS: 0.2495
# Image: sample_106.png, PSNR: 13.01, SSIM: 0.1860, JS: 0.2229
# Image: sample_107.png, PSNR: 12.98, SSIM: 0.1721, JS: 0.2083
# Image: sample_108.png, PSNR: 11.96, SSIM: 0.1873, JS: 0.2562
# Image: sample_109.png, PSNR: 12.48, SSIM: 0.1974, JS: 0.2382
# Image: sample_110.png, PSNR: 11.48, SSIM: 0.1457, JS: 0.2519
# Image: sample_111.png, PSNR: 13.25, SSIM: 0.1982, JS: 0.2183
# Image: sample_112.png, PSNR: 12.28, SSIM: 0.1613, JS: 0.2488
# Image: sample_113.png, PSNR: 12.92, SSIM: 0.2044, JS: 0.2299
# Image: sample_114.png, PSNR: 11.47, SSIM: 0.1858, JS: 0.2842
# Image: sample_115.png, PSNR: 11.92, SSIM: 0.1876, JS: 0.2654
# Image: sample_116.png, PSNR: 11.79, SSIM: 0.1014, JS: 0.2494
# Image: sample_117.png, PSNR: 12.39, SSIM: 0.1687, JS: 0.2458
# Image: sample_118.png, PSNR: 12.40, SSIM: 0.1667, JS: 0.2405
# Image: sample_119.png, PSNR: 12.11, SSIM: 0.1504, JS: 0.2492
# Image: sample_120.png, PSNR: 11.29, SSIM: 0.1550, JS: 0.2856
# Image: sample_121.png, PSNR: 12.00, SSIM: 0.1372, JS: 0.2564
# Image: sample_122.png, PSNR: 12.34, SSIM: 0.1589, JS: 0.2462
# Image: sample_123.png, PSNR: 12.59, SSIM: 0.1679, JS: 0.2348
# Image: sample_124.png, PSNR: 12.04, SSIM: 0.1917, JS: 0.2631
# Image: sample_125.png, PSNR: 11.34, SSIM: 0.1024, JS: 0.2830
# Image: sample_126.png, PSNR: 13.19, SSIM: 0.1916, JS: 0.2200
# Image: sample_127.png, PSNR: 12.45, SSIM: 0.1469, JS: 0.2319
# Image: sample_128.png, PSNR: 12.93, SSIM: 0.2001, JS: 0.2317
# Image: sample_129.png, PSNR: 11.64, SSIM: 0.1848, JS: 0.2699
# Image: sample_130.png, PSNR: 12.35, SSIM: 0.1548, JS: 0.2262
# Image: sample_131.png, PSNR: 11.03, SSIM: 0.0940, JS: 0.2761
# Image: sample_132.png, PSNR: 11.82, SSIM: 0.1119, JS: 0.2560
# Image: sample_133.png, PSNR: 11.91, SSIM: 0.1506, JS: 0.2567
# Image: sample_134.png, PSNR: 11.24, SSIM: 0.1285, JS: 0.2887
# Image: sample_135.png, PSNR: 11.73, SSIM: 0.1820, JS: 0.2757
# Image: sample_136.png, PSNR: 12.96, SSIM: 0.1755, JS: 0.2255
# Image: sample_137.png, PSNR: 9.86, SSIM: 0.1488, JS: 0.2951
# Image: sample_138.png, PSNR: 12.00, SSIM: 0.1339, JS: 0.2441
# Image: sample_139.png, PSNR: 12.63, SSIM: 0.1525, JS: 0.2305
# Image: sample_140.png, PSNR: 11.86, SSIM: 0.1381, JS: 0.2586
# Image: sample_141.png, PSNR: 12.28, SSIM: 0.1409, JS: 0.2497
# Image: sample_142.png, PSNR: 12.22, SSIM: 0.1662, JS: 0.2321
# Image: sample_143.png, PSNR: 12.41, SSIM: 0.1790, JS: 0.2393
# Image: sample_144.png, PSNR: 12.60, SSIM: 0.1537, JS: 0.2391
# Image: sample_145.png, PSNR: 11.15, SSIM: 0.1155, JS: 0.2753
# Image: sample_146.png, PSNR: 12.45, SSIM: 0.1653, JS: 0.2426
# Image: sample_147.png, PSNR: 11.94, SSIM: 0.2105, JS: 0.2617
# Image: sample_148.png, PSNR: 11.62, SSIM: 0.1616, JS: 0.2679
# Image: sample_149.png, PSNR: 11.99, SSIM: 0.1547, JS: 0.2445
# Image: sample_150.png, PSNR: 13.14, SSIM: 0.1960, JS: 0.2100
# Image: sample_151.png, PSNR: 12.98, SSIM: 0.1856, JS: 0.2234
# Image: sample_152.png, PSNR: 12.70, SSIM: 0.1656, JS: 0.2268
# Image: sample_153.png, PSNR: 12.93, SSIM: 0.1638, JS: 0.2165
# Image: sample_154.png, PSNR: 11.53, SSIM: 0.1918, JS: 0.2757
# Image: sample_155.png, PSNR: 12.02, SSIM: 0.1557, JS: 0.2497
# Image: sample_156.png, PSNR: 11.73, SSIM: 0.1596, JS: 0.2770
# Image: sample_157.png, PSNR: 11.39, SSIM: 0.1228, JS: 0.2707
# Image: sample_158.png, PSNR: 12.58, SSIM: 0.1898, JS: 0.2369
# Image: sample_159.png, PSNR: 10.72, SSIM: 0.1252, JS: 0.2986
# Image: sample_160.png, PSNR: 11.00, SSIM: 0.1206, JS: 0.2941
# Image: sample_161.png, PSNR: 12.19, SSIM: 0.1736, JS: 0.2452
# Image: sample_162.png, PSNR: 11.18, SSIM: 0.0976, JS: 0.2461
# Image: sample_163.png, PSNR: 11.62, SSIM: 0.1743, JS: 0.2726
# Image: sample_164.png, PSNR: 11.92, SSIM: 0.1555, JS: 0.2631
# Image: sample_165.png, PSNR: 13.62, SSIM: 0.2251, JS: 0.2024
# Image: sample_166.png, PSNR: 12.66, SSIM: 0.1831, JS: 0.2385
# Image: sample_167.png, PSNR: 11.74, SSIM: 0.1859, JS: 0.2739
# Image: sample_168.png, PSNR: 12.38, SSIM: 0.1210, JS: 0.2445
# Image: sample_169.png, PSNR: 11.56, SSIM: 0.1494, JS: 0.2687
# Image: sample_170.png, PSNR: 13.05, SSIM: 0.2024, JS: 0.2220
# Image: sample_171.png, PSNR: 11.68, SSIM: 0.1272, JS: 0.2588
# Image: sample_172.png, PSNR: 12.20, SSIM: 0.1244, JS: 0.2494
# Image: sample_173.png, PSNR: 12.20, SSIM: 0.2210, JS: 0.2570
# Image: sample_174.png, PSNR: 12.09, SSIM: 0.1727, JS: 0.2589
# Image: sample_175.png, PSNR: 11.76, SSIM: 0.1688, JS: 0.2707
# Image: sample_176.png, PSNR: 11.74, SSIM: 0.1531, JS: 0.2682
# Image: sample_177.png, PSNR: 11.72, SSIM: 0.1011, JS: 0.2587
# Image: sample_178.png, PSNR: 13.16, SSIM: 0.1955, JS: 0.2147
# Image: sample_179.png, PSNR: 11.98, SSIM: 0.1378, JS: 0.2468
# Image: sample_180.png, PSNR: 12.53, SSIM: 0.1873, JS: 0.2410
# Image: sample_181.png, PSNR: 12.45, SSIM: 0.1169, JS: 0.2411
# Image: sample_182.png, PSNR: 11.08, SSIM: 0.1206, JS: 0.2697
# Image: sample_183.png, PSNR: 12.50, SSIM: 0.1868, JS: 0.2418
# Image: sample_184.png, PSNR: 12.04, SSIM: 0.1389, JS: 0.2338
# Image: sample_185.png, PSNR: 12.57, SSIM: 0.1484, JS: 0.2257
# Image: sample_186.png, PSNR: 12.42, SSIM: 0.1477, JS: 0.2442
# Image: sample_187.png, PSNR: 12.58, SSIM: 0.1779, JS: 0.2369
# Image: sample_188.png, PSNR: 11.78, SSIM: 0.1677, JS: 0.2705
# Image: sample_189.png, PSNR: 10.78, SSIM: 0.1125, JS: 0.2938
# Image: sample_190.png, PSNR: 12.94, SSIM: 0.1953, JS: 0.2291
# Image: sample_191.png, PSNR: 12.32, SSIM: 0.1861, JS: 0.2462
# Image: sample_192.png, PSNR: 12.30, SSIM: 0.2026, JS: 0.2409
# Image: sample_193.png, PSNR: 13.03, SSIM: 0.1867, JS: 0.2243
# Image: sample_194.png, PSNR: 11.30, SSIM: 0.1230, JS: 0.2698
# Image: sample_195.png, PSNR: 11.10, SSIM: 0.0757, JS: 0.2509
# Image: sample_196.png, PSNR: 11.43, SSIM: 0.1743, JS: 0.2690
# Image: sample_197.png, PSNR: 10.42, SSIM: 0.0973, JS: 0.2956
# Image: sample_198.png, PSNR: 12.37, SSIM: 0.1888, JS: 0.2447
# Image: sample_199.png, PSNR: 12.71, SSIM: 0.1650, JS: 0.2323
# Image: sample_200.png, PSNR: 11.11, SSIM: 0.1488, JS: 0.2820
# Image: sample_201.png, PSNR: 12.95, SSIM: 0.2219, JS: 0.2274
# Image: sample_202.png, PSNR: 10.88, SSIM: 0.1030, JS: 0.2739
# Image: sample_203.png, PSNR: 12.13, SSIM: 0.1717, JS: 0.2475
# Image: sample_204.png, PSNR: 12.65, SSIM: 0.1501, JS: 0.2172
# Image: sample_205.png, PSNR: 11.68, SSIM: 0.1038, JS: 0.2599
# Image: sample_206.png, PSNR: 12.21, SSIM: 0.1861, JS: 0.2527
# Image: sample_207.png, PSNR: 10.72, SSIM: 0.0955, JS: 0.2901
# Image: sample_208.png, PSNR: 11.98, SSIM: 0.1778, JS: 0.2595
# Image: sample_209.png, PSNR: 13.02, SSIM: 0.1818, JS: 0.2179
# Image: sample_210.png, PSNR: 12.86, SSIM: 0.1563, JS: 0.2148
# Image: sample_211.png, PSNR: 12.00, SSIM: 0.1754, JS: 0.2594
# Image: sample_212.png, PSNR: 11.16, SSIM: 0.1138, JS: 0.2804
# Image: sample_213.png, PSNR: 13.22, SSIM: 0.2051, JS: 0.2189
# Image: sample_214.png, PSNR: 10.31, SSIM: 0.1076, JS: 0.3047
# Image: sample_215.png, PSNR: 11.09, SSIM: 0.1694, JS: 0.2587
# Image: sample_216.png, PSNR: 12.07, SSIM: 0.1643, JS: 0.2577
# Image: sample_217.png, PSNR: 11.68, SSIM: 0.1125, JS: 0.2671
# Image: sample_218.png, PSNR: 13.32, SSIM: 0.2063, JS: 0.2162
# Image: sample_219.png, PSNR: 12.17, SSIM: 0.1884, JS: 0.2588
# Image: sample_220.png, PSNR: 11.89, SSIM: 0.1909, JS: 0.2642
# Image: sample_221.png, PSNR: 11.62, SSIM: 0.1236, JS: 0.2342
# Image: sample_222.png, PSNR: 10.60, SSIM: 0.1131, JS: 0.3185
# Image: sample_223.png, PSNR: 13.31, SSIM: 0.2106, JS: 0.2043
# Image: sample_224.png, PSNR: 12.47, SSIM: 0.1913, JS: 0.2314
# Image: sample_225.png, PSNR: 12.21, SSIM: 0.1423, JS: 0.2489
# Image: sample_226.png, PSNR: 12.80, SSIM: 0.1988, JS: 0.2309
# Image: sample_227.png, PSNR: 11.88, SSIM: 0.1672, JS: 0.2606
# Image: sample_228.png, PSNR: 12.92, SSIM: 0.2058, JS: 0.2304
# Image: sample_229.png, PSNR: 10.69, SSIM: 0.0811, JS: 0.2704
# Image: sample_230.png, PSNR: 10.99, SSIM: 0.0963, JS: 0.2550
# Image: sample_231.png, PSNR: 11.91, SSIM: 0.1727, JS: 0.2687
# Image: sample_232.png, PSNR: 12.55, SSIM: 0.1856, JS: 0.2318
# Image: sample_233.png, PSNR: 12.93, SSIM: 0.1710, JS: 0.2268
# Image: sample_234.png, PSNR: 11.91, SSIM: 0.1167, JS: 0.2546
# Image: sample_235.png, PSNR: 12.55, SSIM: 0.1520, JS: 0.2206
# Image: sample_236.png, PSNR: 12.35, SSIM: 0.1107, JS: 0.2493
# Image: sample_237.png, PSNR: 12.55, SSIM: 0.1390, JS: 0.2351
# Image: sample_238.png, PSNR: 11.20, SSIM: 0.1482, JS: 0.2748
# Image: sample_239.png, PSNR: 11.51, SSIM: 0.1386, JS: 0.2735
# Image: sample_240.png, PSNR: 11.76, SSIM: 0.1360, JS: 0.2615
# Image: sample_241.png, PSNR: 12.15, SSIM: 0.1917, JS: 0.2477
# Image: sample_242.png, PSNR: 10.20, SSIM: 0.1242, JS: 0.2911
# Image: sample_243.png, PSNR: 12.50, SSIM: 0.1903, JS: 0.2472
# Image: sample_244.png, PSNR: 12.05, SSIM: 0.1153, JS: 0.2527
# Image: sample_245.png, PSNR: 12.00, SSIM: 0.1827, JS: 0.2588
# Image: sample_246.png, PSNR: 12.17, SSIM: 0.1554, JS: 0.2503
# Image: sample_247.png, PSNR: 11.99, SSIM: 0.1820, JS: 0.2647
# Image: sample_248.png, PSNR: 12.73, SSIM: 0.1467, JS: 0.2312
# Image: sample_249.png, PSNR: 12.42, SSIM: 0.1953, JS: 0.2363
# Image: sample_250.png, PSNR: 12.03, SSIM: 0.1527, JS: 0.2531
# Image: sample_251.png, PSNR: 10.79, SSIM: 0.1396, JS: 0.2651
# Image: sample_252.png, PSNR: 12.63, SSIM: 0.1948, JS: 0.2300
# Image: sample_253.png, PSNR: 12.88, SSIM: 0.1514, JS: 0.2126
# Image: sample_254.png, PSNR: 10.73, SSIM: 0.0722, JS: 0.2668
# Image: sample_255.png, PSNR: 13.03, SSIM: 0.1994, JS: 0.2241
# Image: sample_256.png, PSNR: 10.97, SSIM: 0.0822, JS: 0.2626
# Image: sample_257.png, PSNR: 11.37, SSIM: 0.1121, JS: 0.2730
# Image: sample_258.png, PSNR: 12.46, SSIM: 0.1927, JS: 0.2295
# Image: sample_259.png, PSNR: 11.82, SSIM: 0.1141, JS: 0.2567
# Image: sample_260.png, PSNR: 10.10, SSIM: 0.0785, JS: 0.2797
# Image: sample_261.png, PSNR: 11.65, SSIM: 0.1725, JS: 0.2668
# Image: sample_262.png, PSNR: 11.64, SSIM: 0.1319, JS: 0.2707
# Image: sample_263.png, PSNR: 11.73, SSIM: 0.1892, JS: 0.2743
# Image: sample_264.png, PSNR: 11.93, SSIM: 0.1870, JS: 0.2482
# Image: sample_265.png, PSNR: 12.63, SSIM: 0.2068, JS: 0.2367
# Image: sample_266.png, PSNR: 11.65, SSIM: 0.1691, JS: 0.2736
# Image: sample_267.png, PSNR: 12.24, SSIM: 0.1786, JS: 0.2434
# Image: sample_268.png, PSNR: 11.06, SSIM: 0.0888, JS: 0.2591
# Image: sample_269.png, PSNR: 12.76, SSIM: 0.1934, JS: 0.2251
# Image: sample_270.png, PSNR: 12.01, SSIM: 0.1666, JS: 0.2610
# Image: sample_271.png, PSNR: 11.51, SSIM: 0.1619, JS: 0.2649
# Image: sample_272.png, PSNR: 12.64, SSIM: 0.1757, JS: 0.2373
# Image: sample_273.png, PSNR: 11.73, SSIM: 0.1681, JS: 0.2655
# Image: sample_274.png, PSNR: 11.77, SSIM: 0.1577, JS: 0.2629
# Image: sample_275.png, PSNR: 12.90, SSIM: 0.2059, JS: 0.2342
# Image: sample_276.png, PSNR: 12.03, SSIM: 0.1225, JS: 0.2441
# Image: sample_277.png, PSNR: 12.72, SSIM: 0.1500, JS: 0.2314
# Image: sample_278.png, PSNR: 9.87, SSIM: 0.0744, JS: 0.2571
# Image: sample_279.png, PSNR: 12.14, SSIM: 0.1705, JS: 0.2528
# Image: sample_280.png, PSNR: 12.42, SSIM: 0.1964, JS: 0.2443
# Image: sample_281.png, PSNR: 12.61, SSIM: 0.1564, JS: 0.2349
# Image: sample_282.png, PSNR: 11.46, SSIM: 0.1907, JS: 0.2870
# Image: sample_283.png, PSNR: 11.88, SSIM: 0.1076, JS: 0.2331
# Image: sample_284.png, PSNR: 12.58, SSIM: 0.2025, JS: 0.2405
# Image: sample_285.png, PSNR: 11.23, SSIM: 0.1154, JS: 0.2841
# ...
# Image: sample_237.png, PSNR: 9.24, SSIM: 0.0941, JS: 0.3416
# Image: sample_238.png, PSNR: 9.41, SSIM: 0.0714, JS: 0.3050
# Image: sample_239.png, PSNR: 8.88, SSIM: 0.0715, JS: 0.3410
# Image: sample_240.png, PSNR: 8.12, SSIM: 0.0511, JS: 0.3270
# Image: sample_241.png, PSNR: 9.98, SSIM: 0.0783, JS: 0.2856
# Image: sample_242.png, PSNR: 10.01, SSIM: 0.1141, JS: 0.3083
# Image: sample_243.png, PSNR: 9.92, SSIM: 0.1040, JS: 0.3145
# Image: sample_244.png, PSNR: 9.30, SSIM: 0.0875, JS: 0.3394
# Image: sample_245.png, PSNR: 9.87, SSIM: 0.1282, JS: 0.3026
# Image: sample_246.png, PSNR: 8.61, SSIM: 0.0431, JS: 0.2969
# Image: sample_247.png, PSNR: 9.93, SSIM: 0.1080, JS: 0.3088
# Image: sample_248.png, PSNR: 9.14, SSIM: 0.0615, JS: 0.3384
# Image: sample_249.png, PSNR: 10.15, SSIM: 0.1286, JS: 0.3022
# Image: sample_250.png, PSNR: 9.00, SSIM: 0.0611, JS: 0.3377
# Image: sample_251.png, PSNR: 8.89, SSIM: 0.0571, JS: 0.3383
# Image: sample_252.png, PSNR: 9.25, SSIM: 0.1018, JS: 0.3359
# Image: sample_253.png, PSNR: 8.60, SSIM: 0.0732, JS: 0.3331
# Image: sample_254.png, PSNR: 8.97, SSIM: 0.0676, JS: 0.3381
# Image: sample_255.png, PSNR: 9.32, SSIM: 0.0761, JS: 0.3280
# Image: sample_256.png, PSNR: 9.56, SSIM: 0.0914, JS: 0.2983
# Image: sample_257.png, PSNR: 9.34, SSIM: 0.0918, JS: 0.3387
# Image: sample_258.png, PSNR: 10.32, SSIM: 0.1017, JS: 0.2924
# Image: sample_259.png, PSNR: 8.10, SSIM: 0.0379, JS: 0.3324
# Image: sample_260.png, PSNR: 10.01, SSIM: 0.0907, JS: 0.3013
# Image: sample_261.png, PSNR: 8.85, SSIM: 0.0787, JS: 0.3416
# Image: sample_262.png, PSNR: 8.96, SSIM: 0.0715, JS: 0.3468
# Image: sample_263.png, PSNR: 9.96, SSIM: 0.0730, JS: 0.2757
# Image: sample_264.png, PSNR: 10.07, SSIM: 0.1196, JS: 0.2997
# Image: sample_265.png, PSNR: 9.39, SSIM: 0.0893, JS: 0.3165
# Image: sample_266.png, PSNR: 10.21, SSIM: 0.1268, JS: 0.2971
# Image: sample_267.png, PSNR: 9.10, SSIM: 0.0737, JS: 0.3226
# Image: sample_268.png, PSNR: 8.71, SSIM: 0.0587, JS: 0.3352
# Image: sample_269.png, PSNR: 9.15, SSIM: 0.0678, JS: 0.3401
# Image: sample_270.png, PSNR: 9.62, SSIM: 0.0638, JS: 0.2962
# Image: sample_271.png, PSNR: 8.07, SSIM: 0.0617, JS: 0.3119
# Image: sample_272.png, PSNR: 9.41, SSIM: 0.0746, JS: 0.3300
# Image: sample_273.png, PSNR: 9.01, SSIM: 0.0752, JS: 0.3312
# Image: sample_274.png, PSNR: 10.38, SSIM: 0.1246, JS: 0.2860
# Image: sample_275.png, PSNR: 9.72, SSIM: 0.0860, JS: 0.3115
# Image: sample_276.png, PSNR: 9.57, SSIM: 0.1133, JS: 0.3168
# Image: sample_277.png, PSNR: 9.61, SSIM: 0.0813, JS: 0.3085
# Image: sample_278.png, PSNR: 10.08, SSIM: 0.1254, JS: 0.3055
# Image: sample_279.png, PSNR: 8.55, SSIM: 0.0536, JS: 0.3385
# Image: sample_280.png, PSNR: 8.57, SSIM: 0.0548, JS: 0.3352
# Image: sample_281.png, PSNR: 9.10, SSIM: 0.0787, JS: 0.3419
# Image: sample_282.png, PSNR: 10.23, SSIM: 0.1187, JS: 0.2940
# Image: sample_283.png, PSNR: 9.03, SSIM: 0.0723, JS: 0.3482
# Image: sample_284.png, PSNR: 9.86, SSIM: 0.0565, JS: 0.3003
# Image: sample_285.png, PSNR: 10.12, SSIM: 0.1235, JS: 0.2971
# Image: sample_286.png, PSNR: 9.19, SSIM: 0.0673, JS: 0.2834
# Image: sample_287.png, PSNR: 9.24, SSIM: 0.0589, JS: 0.3287
# Image: sample_288.png, PSNR: 9.27, SSIM: 0.0979, JS: 0.3295
# Image: sample_289.png, PSNR: 10.57, SSIM: 0.1014, JS: 0.2773
# Image: sample_290.png, PSNR: 9.36, SSIM: 0.0863, JS: 0.3210
# Image: sample_291.png, PSNR: 8.27, SSIM: 0.0629, JS: 0.3311
# Image: sample_292.png, PSNR: 9.06, SSIM: 0.0719, JS: 0.3442
# Image: sample_293.png, PSNR: 10.16, SSIM: 0.0925, JS: 0.2554
# Image: sample_294.png, PSNR: 9.31, SSIM: 0.0908, JS: 0.3202
# Image: sample_295.png, PSNR: 9.61, SSIM: 0.0951, JS: 0.3000
# Image: sample_296.png, PSNR: 10.16, SSIM: 0.0919, JS: 0.2675
# Image: sample_297.png, PSNR: 8.50, SSIM: 0.0718, JS: 0.3354
# Image: sample_298.png, PSNR: 10.07, SSIM: 0.1072, JS: 0.2991
# Image: sample_299.png, PSNR: 9.89, SSIM: 0.1105, JS: 0.2753
# Image: sample_300.png, PSNR: 9.02, SSIM: 0.0663, JS: 0.3222
# Image: sample_301.png, PSNR: 9.15, SSIM: 0.0788, JS: 0.3470
# Image: sample_302.png, PSNR: 9.20, SSIM: 0.0725, JS: 0.3102
# Image: sample_303.png, PSNR: 10.46, SSIM: 0.1209, JS: 0.2826
# Image: sample_304.png, PSNR: 9.24, SSIM: 0.0940, JS: 0.2947
# Image: sample_305.png, PSNR: 8.65, SSIM: 0.0610, JS: 0.3302
# Image: sample_306.png, PSNR: 10.37, SSIM: 0.1046, JS: 0.2829
# Image: sample_307.png, PSNR: 9.76, SSIM: 0.0941, JS: 0.3098
# Image: sample_308.png, PSNR: 9.61, SSIM: 0.0889, JS: 0.3218
# Image: sample_309.png, PSNR: 9.38, SSIM: 0.0920, JS: 0.3251
# Image: sample_310.png, PSNR: 8.72, SSIM: 0.0502, JS: 0.3309
# Image: sample_311.png, PSNR: 10.63, SSIM: 0.1154, JS: 0.2501
# Image: sample_312.png, PSNR: 8.93, SSIM: 0.0521, JS: 0.3156
# Image: sample_313.png, PSNR: 9.82, SSIM: 0.1199, JS: 0.2313
# Image: sample_314.png, PSNR: 9.55, SSIM: 0.0914, JS: 0.3165
# Image: sample_315.png, PSNR: 10.32, SSIM: 0.0897, JS: 0.2853
# Image: sample_316.png, PSNR: 9.12, SSIM: 0.0766, JS: 0.3467
# Image: sample_317.png, PSNR: 10.45, SSIM: 0.1168, JS: 0.2717
# Image: sample_318.png, PSNR: 9.73, SSIM: 0.0720, JS: 0.2494
# Image: sample_319.png, PSNR: 9.83, SSIM: 0.1063, JS: 0.3198
# Image: sample_320.png, PSNR: 9.34, SSIM: 0.0807, JS: 0.3266
# Image: sample_321.png, PSNR: 10.30, SSIM: 0.1063, JS: 0.2757
# Image: sample_322.png, PSNR: 9.19, SSIM: 0.0646, JS: 0.2879
# Image: sample_323.png, PSNR: 8.94, SSIM: 0.0668, JS: 0.3424
# Image: sample_324.png, PSNR: 9.25, SSIM: 0.0871, JS: 0.3379
# Image: sample_325.png, PSNR: 9.55, SSIM: 0.1167, JS: 0.3264
# Image: sample_326.png, PSNR: 8.13, SSIM: 0.0630, JS: 0.3312
# Image: sample_327.png, PSNR: 10.15, SSIM: 0.0955, JS: 0.2855
# Image: sample_328.png, PSNR: 8.92, SSIM: 0.0867, JS: 0.3616
# Image: sample_329.png, PSNR: 9.20, SSIM: 0.0787, JS: 0.3388
# Image: sample_330.png, PSNR: 9.45, SSIM: 0.0984, JS: 0.3223
# Image: sample_331.png, PSNR: 8.75, SSIM: 0.0807, JS: 0.3516
# Image: sample_332.png, PSNR: 8.28, SSIM: 0.0453, JS: 0.2704
# Image: sample_333.png, PSNR: 9.35, SSIM: 0.0814, JS: 0.3284
# Image: sample_334.png, PSNR: 10.22, SSIM: 0.1327, JS: 0.2792
# Image: sample_335.png, PSNR: 10.46, SSIM: 0.0892, JS: 0.2738
# Image: sample_336.png, PSNR: 9.11, SSIM: 0.0773, JS: 0.3306
# Image: sample_337.png, PSNR: 10.26, SSIM: 0.1333, JS: 0.2777
# Image: sample_338.png, PSNR: 8.17, SSIM: 0.0349, JS: 0.3241
# Image: sample_339.png, PSNR: 9.53, SSIM: 0.0746, JS: 0.3202
# Image: sample_340.png, PSNR: 8.55, SSIM: 0.0672, JS: 0.3264
# Image: sample_341.png, PSNR: 10.28, SSIM: 0.0963, JS: 0.2778
# Image: sample_342.png, PSNR: 10.32, SSIM: 0.1098, JS: 0.2889
# Image: sample_343.png, PSNR: 9.76, SSIM: 0.1050, JS: 0.3097
# Image: sample_344.png, PSNR: 8.17, SSIM: 0.0687, JS: 0.3259
# Image: sample_345.png, PSNR: 9.16, SSIM: 0.0660, JS: 0.3221
# Image: sample_346.png, PSNR: 8.10, SSIM: 0.0629, JS: 0.3008
# Image: sample_347.png, PSNR: 8.55, SSIM: 0.0578, JS: 0.3284
# Image: sample_348.png, PSNR: 8.55, SSIM: 0.0380, JS: 0.2673
# Image: sample_349.png, PSNR: 8.50, SSIM: 0.0606, JS: 0.3339
# Image: sample_350.png, PSNR: 9.94, SSIM: 0.1115, JS: 0.2970
# Image: sample_351.png, PSNR: 10.56, SSIM: 0.1380, JS: 0.2838
# Image: sample_352.png, PSNR: 10.49, SSIM: 0.1012, JS: 0.2664
# Image: sample_353.png, PSNR: 10.07, SSIM: 0.0965, JS: 0.2822
# Image: sample_354.png, PSNR: 9.00, SSIM: 0.0690, JS: 0.3229
# Image: sample_355.png, PSNR: 9.97, SSIM: 0.1352, JS: 0.3125
# Image: sample_356.png, PSNR: 9.34, SSIM: 0.0730, JS: 0.3368
# Image: sample_357.png, PSNR: 9.06, SSIM: 0.0623, JS: 0.3486
# Image: sample_358.png, PSNR: 9.33, SSIM: 0.0833, JS: 0.3062
# Image: sample_359.png, PSNR: 8.41, SSIM: 0.0644, JS: 0.3341
# Image: sample_360.png, PSNR: 8.56, SSIM: 0.0616, JS: 0.3355
# Image: sample_361.png, PSNR: 8.38, SSIM: 0.0464, JS: 0.2930
# Image: sample_362.png, PSNR: 9.84, SSIM: 0.1112, JS: 0.2993
# Image: sample_363.png, PSNR: 10.04, SSIM: 0.1102, JS: 0.2965
# Image: sample_364.png, PSNR: 10.11, SSIM: 0.1155, JS: 0.2895
# Image: sample_365.png, PSNR: 10.05, SSIM: 0.0984, JS: 0.2979
# Image: sample_366.png, PSNR: 8.38, SSIM: 0.0591, JS: 0.3195
# Image: sample_367.png, PSNR: 8.31, SSIM: 0.0311, JS: 0.2971
# Image: sample_368.png, PSNR: 9.71, SSIM: 0.0990, JS: 0.3201
# Image: sample_369.png, PSNR: 9.97, SSIM: 0.1145, JS: 0.2700
# Image: sample_370.png, PSNR: 10.39, SSIM: 0.1145, JS: 0.2894
# Image: sample_371.png, PSNR: 10.00, SSIM: 0.1000, JS: 0.2940
# Image: sample_372.png, PSNR: 9.96, SSIM: 0.1016, JS: 0.3105
# Image: sample_373.png, PSNR: 9.23, SSIM: 0.0907, JS: 0.3039
# Image: sample_374.png, PSNR: 10.13, SSIM: 0.1110, JS: 0.2729
# Image: sample_375.png, PSNR: 9.80, SSIM: 0.1262, JS: 0.3036
# Image: sample_376.png, PSNR: 10.24, SSIM: 0.1198, JS: 0.2995
# Image: sample_377.png, PSNR: 9.09, SSIM: 0.0820, JS: 0.3102
# Image: sample_378.png, PSNR: 9.80, SSIM: 0.1258, JS: 0.3093
# Image: sample_379.png, PSNR: 9.61, SSIM: 0.0920, JS: 0.2956
# Image: sample_380.png, PSNR: 10.04, SSIM: 0.1307, JS: 0.3023
# Image: sample_381.png, PSNR: 9.16, SSIM: 0.0833, JS: 0.3303
# Image: sample_382.png, PSNR: 9.10, SSIM: 0.0830, JS: 0.3030
# Image: sample_383.png, PSNR: 9.12, SSIM: 0.1031, JS: 0.3467
# Image: sample_384.png, PSNR: 9.96, SSIM: 0.0983, JS: 0.2926
# Image: sample_385.png, PSNR: 8.45, SSIM: 0.0600, JS: 0.3382
# Image: sample_386.png, PSNR: 9.68, SSIM: 0.1100, JS: 0.3148
# Image: sample_387.png, PSNR: 10.28, SSIM: 0.1016, JS: 0.2842
# Image: sample_388.png, PSNR: 9.30, SSIM: 0.0876, JS: 0.3372
# Image: sample_389.png, PSNR: 8.67, SSIM: 0.0573, JS: 0.3268
# Image: sample_390.png, PSNR: 10.13, SSIM: 0.1052, JS: 0.3053
# Image: sample_391.png, PSNR: 10.39, SSIM: 0.1123, JS: 0.2840
# Image: sample_392.png, PSNR: 10.52, SSIM: 0.1292, JS: 0.2871
# Image: sample_393.png, PSNR: 10.09, SSIM: 0.1151, JS: 0.2946
# Image: sample_394.png, PSNR: 9.25, SSIM: 0.0608, JS: 0.3226
# Image: sample_395.png, PSNR: 9.99, SSIM: 0.0829, JS: 0.3094
# Image: sample_396.png, PSNR: 9.83, SSIM: 0.0940, JS: 0.3088
# Image: sample_397.png, PSNR: 9.31, SSIM: 0.0854, JS: 0.3397
# Image: sample_398.png, PSNR: 10.23, SSIM: 0.1272, JS: 0.3050
# Image: sample_399.png, PSNR: 9.19, SSIM: 0.0906, JS: 0.3358
# Image: sample_400.png, PSNR: 9.97, SSIM: 0.0847, JS: 0.2902
# Image: sample_401.png, PSNR: 9.18, SSIM: 0.0738, JS: 0.3447
# Image: sample_402.png, PSNR: 10.23, SSIM: 0.1192, JS: 0.2938
# Image: sample_403.png, PSNR: 10.22, SSIM: 0.1107, JS: 0.2927
# Image: sample_404.png, PSNR: 8.85, SSIM: 0.0595, JS: 0.3306
# Image: sample_405.png, PSNR: 9.89, SSIM: 0.1065, JS: 0.3011
# Image: sample_406.png, PSNR: 10.14, SSIM: 0.1014, JS: 0.2965
# Image: sample_407.png, PSNR: 9.41, SSIM: 0.0793, JS: 0.3345
# Image: sample_408.png, PSNR: 9.98, SSIM: 0.1122, JS: 0.3100
# Image: sample_409.png, PSNR: 9.16, SSIM: 0.0740, JS: 0.3355
# Image: sample_410.png, PSNR: 8.07, SSIM: 0.0619, JS: 0.2998
# Image: sample_411.png, PSNR: 10.10, SSIM: 0.1111, JS: 0.3045
# Image: sample_412.png, PSNR: 9.39, SSIM: 0.0667, JS: 0.2929
# Image: sample_413.png, PSNR: 10.04, SSIM: 0.1030, JS: 0.2968
# Image: sample_414.png, PSNR: 9.99, SSIM: 0.0965, JS: 0.2981
# Image: sample_415.png, PSNR: 9.06, SSIM: 0.0830, JS: 0.3546
# Image: sample_416.png, PSNR: 10.24, SSIM: 0.1248, JS: 0.2929
# Image: sample_417.png, PSNR: 9.33, SSIM: 0.0797, JS: 0.3021
# Image: sample_418.png, PSNR: 10.13, SSIM: 0.1302, JS: 0.3055
# Image: sample_419.png, PSNR: 10.35, SSIM: 0.1143, JS: 0.2829
# Image: sample_420.png, PSNR: 9.67, SSIM: 0.0961, JS: 0.3024
# Image: sample_421.png, PSNR: 9.69, SSIM: 0.0884, JS: 0.3009
# Image: sample_422.png, PSNR: 9.46, SSIM: 0.0796, JS: 0.2986
# Image: sample_423.png, PSNR: 9.17, SSIM: 0.0907, JS: 0.2996
# Image: sample_424.png, PSNR: 9.29, SSIM: 0.0761, JS: 0.3358
# Image: sample_425.png, PSNR: 10.15, SSIM: 0.1144, JS: 0.2859
# Image: sample_426.png, PSNR: 8.65, SSIM: 0.0690, JS: 0.3104
# Image: sample_427.png, PSNR: 10.32, SSIM: 0.0909, JS: 0.2868
# Image: sample_428.png, PSNR: 9.90, SSIM: 0.1234, JS: 0.3053
# Image: sample_429.png, PSNR: 8.74, SSIM: 0.0716, JS: 0.3294
# Image: sample_430.png, PSNR: 8.91, SSIM: 0.0687, JS: 0.3185
# Image: sample_431.png, PSNR: 9.36, SSIM: 0.1020, JS: 0.3208
# Image: sample_432.png, PSNR: 8.99, SSIM: 0.0608, JS: 0.3325
# Image: sample_433.png, PSNR: 8.82, SSIM: 0.0793, JS: 0.3081
# Image: sample_434.png, PSNR: 9.94, SSIM: 0.1326, JS: 0.2906
# Image: sample_435.png, PSNR: 8.93, SSIM: 0.0774, JS: 0.3387
# Image: sample_436.png, PSNR: 9.33, SSIM: 0.0745, JS: 0.2984
# Image: sample_437.png, PSNR: 10.23, SSIM: 0.1377, JS: 0.2800
# Image: sample_438.png, PSNR: 9.41, SSIM: 0.0853, JS: 0.3277
# Image: sample_439.png, PSNR: 8.34, SSIM: 0.0357, JS: 0.2957
# Image: sample_440.png, PSNR: 9.21, SSIM: 0.0882, JS: 0.3382
# Image: sample_441.png, PSNR: 8.33, SSIM: 0.0649, JS: 0.3302
# Image: sample_442.png, PSNR: 10.19, SSIM: 0.1152, JS: 0.2933
# Image: sample_443.png, PSNR: 9.84, SSIM: 0.1064, JS: 0.2853
# Image: sample_444.png, PSNR: 10.40, SSIM: 0.0723, JS: 0.2848
# Image: sample_445.png, PSNR: 8.69, SSIM: 0.0622, JS: 0.3441
# Image: sample_446.png, PSNR: 9.72, SSIM: 0.1219, JS: 0.3174
# Image: sample_447.png, PSNR: 9.48, SSIM: 0.1017, JS: 0.3173
# Image: sample_448.png, PSNR: 10.17, SSIM: 0.1318, JS: 0.2332
# Image: sample_449.png, PSNR: 8.38, SSIM: 0.0610, JS: 0.3549
# Image: sample_450.png, PSNR: 9.13, SSIM: 0.0773, JS: 0.3315
# Image: sample_451.png, PSNR: 9.31, SSIM: 0.0741, JS: 0.3336
# Image: sample_452.png, PSNR: 9.47, SSIM: 0.0785, JS: 0.3197
# Image: sample_453.png, PSNR: 10.14, SSIM: 0.1121, JS: 0.2979
# Image: sample_454.png, PSNR: 9.41, SSIM: 0.0772, JS: 0.3156
# Image: sample_455.png, PSNR: 9.29, SSIM: 0.0791, JS: 0.2886
# Image: sample_456.png, PSNR: 10.26, SSIM: 0.1348, JS: 0.2963
# Image: sample_457.png, PSNR: 9.97, SSIM: 0.0973, JS: 0.3047
# Image: sample_458.png, PSNR: 9.14, SSIM: 0.0717, JS: 0.3274
# Image: sample_459.png, PSNR: 8.96, SSIM: 0.0764, JS: 0.3519
# Image: sample_460.png, PSNR: 10.08, SSIM: 0.1055, JS: 0.2969
# Image: sample_461.png, PSNR: 9.76, SSIM: 0.0795, JS: 0.3057
# Image: sample_462.png, PSNR: 8.93, SSIM: 0.0599, JS: 0.3302
# Image: sample_463.png, PSNR: 9.05, SSIM: 0.0801, JS: 0.3341
# Image: sample_464.png, PSNR: 8.44, SSIM: 0.0585, JS: 0.3358
# Image: sample_465.png, PSNR: 9.72, SSIM: 0.1047, JS: 0.3167
# Image: sample_466.png, PSNR: 9.65, SSIM: 0.0794, JS: 0.2820
# Image: sample_467.png, PSNR: 10.13, SSIM: 0.1155, JS: 0.2923
# Image: sample_468.png, PSNR: 9.60, SSIM: 0.1089, JS: 0.3007
# Image: sample_469.png, PSNR: 8.83, SSIM: 0.0605, JS: 0.3303
# Image: sample_470.png, PSNR: 8.76, SSIM: 0.0728, JS: 0.3493
# Image: sample_471.png, PSNR: 9.97, SSIM: 0.1004, JS: 0.3074
# Image: sample_472.png, PSNR: 10.15, SSIM: 0.1161, JS: 0.2995
# Image: sample_473.png, PSNR: 9.87, SSIM: 0.0909, JS: 0.3046
# Image: sample_474.png, PSNR: 9.50, SSIM: 0.0869, JS: 0.3019
# Image: sample_475.png, PSNR: 9.04, SSIM: 0.0543, JS: 0.2884
# Image: sample_476.png, PSNR: 9.38, SSIM: 0.0866, JS: 0.3321
# Image: sample_477.png, PSNR: 8.79, SSIM: 0.0651, JS: 0.3031
# Image: sample_478.png, PSNR: 9.89, SSIM: 0.0994, JS: 0.3150
# Image: sample_479.png, PSNR: 10.30, SSIM: 0.1115, JS: 0.2862
# Image: sample_480.png, PSNR: 8.98, SSIM: 0.0789, JS: 0.3238
# Image: sample_481.png, PSNR: 9.84, SSIM: 0.0951, JS: 0.2881
# Image: sample_482.png, PSNR: 9.68, SSIM: 0.0972, JS: 0.2822
# Image: sample_483.png, PSNR: 9.78, SSIM: 0.1352, JS: 0.3058
# Image: sample_484.png, PSNR: 9.70, SSIM: 0.1410, JS: 0.3088
# Image: sample_485.png, PSNR: 9.45, SSIM: 0.0932, JS: 0.3245
# Image: sample_486.png, PSNR: 9.16, SSIM: 0.0996, JS: 0.3470
# Image: sample_487.png, PSNR: 9.58, SSIM: 0.1094, JS: 0.2927
# Image: sample_488.png, PSNR: 9.24, SSIM: 0.0513, JS: 0.2982
# Image: sample_489.png, PSNR: 9.11, SSIM: 0.0841, JS: 0.3473
# Image: sample_490.png, PSNR: 9.52, SSIM: 0.1082, JS: 0.2581
# Image: sample_491.png, PSNR: 8.76, SSIM: 0.0840, JS: 0.3575
# Image: sample_492.png, PSNR: 9.33, SSIM: 0.0902, JS: 0.3337
# Image: sample_493.png, PSNR: 8.29, SSIM: 0.0450, JS: 0.3073
# Image: sample_494.png, PSNR: 10.69, SSIM: 0.1424, JS: 0.2816
# Image: sample_495.png, PSNR: 9.52, SSIM: 0.0670, JS: 0.3117
# Image: sample_496.png, PSNR: 10.39, SSIM: 0.1034, JS: 0.2794
# Image: sample_497.png, PSNR: 8.67, SSIM: 0.0687, JS: 0.3379
# Image: sample_498.png, PSNR: 9.32, SSIM: 0.0765, JS: 0.3380
# Image: sample_499.png, PSNR: 8.90, SSIM: 0.0524, JS: 0.3481
# Good images for class 4: 0 images saved to C:\Users\hp\Desktop\fedavg\good_images-arch-A5-500\4
#
# Total good images across all classes: 189

# %%
import torch
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image, ImageEnhance, ImageFilter
import os
import numpy as np
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim
from scipy.spatial.distance import jensenshannon
import kagglehub
import scipy
print(f"Using scipy version: {scipy.__version__}")
from pkg_resources import parse_version
if parse_version(scipy.__version__) < parse_version("1.6.0"):
    raise ImportError(f"scipy version must be >= 1.6.0 for jensenshannon. Current version: {scipy.__version__}")

# Define paths
generated_base_dir = r"C:\Users\hp\Desktop\fedavg\generated_samples-arch-A5-500"
good_images_dir = r"C:\Users\hp\Desktop\fedavg\good_images-arch-A5-500"
os.makedirs(good_images_dir, exist_ok=True)

# Hyperparameters
RESIZE = 128
num_classes = 5
original_dim = RESIZE * RESIZE * 3

# Custom Dataset for Kaggle Vehicle Type Image Dataset
class VehicleTypeDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = []
        self.class_to_idx = {}
        self.images = []
        self.labels = []

        print(f"Searching for images in {root_dir}")
        for root, dirs, files in os.walk(root_dir):
            image_files = [f for f in files if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
            if image_files:
                class_name = os.path.basename(root)
                if class_name not in self.class_to_idx:
                    self.classes.append(class_name)
                    self.class_to_idx[class_name] = len(self.classes) - 1
                for img_file in image_files:
                    img_path = os.path.join(root, img_file)
                    try:
                        Image.open(img_path).verify()
                        self.images.append(img_path)
                        self.labels.append(self.class_to_idx[class_name])
                    except:
                        print(f"Skipping corrupted image: {img_path}")

        if len(self.classes) != num_classes:
            raise ValueError(f"Expected {num_classes} classes, found {len(self.classes)}")
        print(f"Found {len(self.images)} images across {len(self.classes)} classes.")
        print(f"Classes: {self.classes}")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        image = Image.open(img_path).convert('RGB')
        label = self.labels[idx]
        sample = {'image': image, 'label': label}
        if self.transform:
            sample['image'] = self.transform(sample['image'])
        return sample

# Load a subset of real images as references (5 per class)
transform = transforms.Compose([
    transforms.Resize((RESIZE, RESIZE)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

path = kagglehub.dataset_download("sujaykapadnis/vehicle-type-image-dataset")
dataset = VehicleTypeDataset(root_dir=path, transform=transform)

# Collect reference images (5 per class)
reference_images = {i: [] for i in range(num_classes)}
for sample in dataset:
    label = sample['label']
    if len(reference_images[label]) < 5:
        reference_images[label].append(sample['image'])
    if all(len(refs) >= 5 for refs in reference_images.values()):
        break

# Enhanced image processing function with balanced adjustments
def enhance_image(pil_image):
    # Apply a light denoising filter to reduce noise (improves PSNR)
    pil_image = pil_image.filter(ImageFilter.MedianFilter(size=3))
    
    # Apply moderate Unsharp Masking for sharpness (reduced to avoid artifacts)
    pil_image = pil_image.filter(ImageFilter.UnsharpMask(radius=1.5, percent=100, threshold=3))
    
    # Enhance sharpness moderately (reduced factor to avoid over-sharpening)
    pil_image = ImageEnhance.Sharpness(pil_image).enhance(1.5)  # Reduced from 2.0 to 1.5
    
    # Enhance contrast slightly (helps with SSIM)
    pil_image = ImageEnhance.Contrast(pil_image).enhance(1.2)  # Reduced from 1.3 to 1.2
    
    # Enhance brightness very slightly (avoid over-brightening)
    pil_image = ImageEnhance.Brightness(pil_image).enhance(1.05)  # Reduced from 1.1 to 1.05
    
    # Enhance color to improve fidelity (helps with SSIM and JS)
    pil_image = ImageEnhance.Color(pil_image).enhance(1.1)
    
    # Optional: Super-resolution-like effect with careful scaling
    pil_image = pil_image.resize((RESIZE * 2, RESIZE * 2), Image.Resampling.LANCZOS)
    pil_image = pil_image.resize((RESIZE, RESIZE), Image.Resampling.LANCZOS)
    
    return pil_image

# Function to compute PSNR, SSIM, and JS divergence
def compute_metrics_for_image(orig, gen):
    orig_np = orig.cpu().numpy() * 0.5 + 0.5
    gen_np = gen.cpu().numpy() * 0.5 + 0.5
    orig_np = np.transpose(orig_np, (1, 2, 0))
    gen_np = np.transpose(gen_np, (1, 2, 0))
    orig_np = np.clip(orig_np, 0, 1)
    gen_np = np.clip(gen_np, 0, 1)

    psnr_score = psnr(orig_np, gen_np, data_range=1.0)
    ssim_score = ssim(orig_np, gen_np, multichannel=True, data_range=1.0, channel_axis=2)

    js_scores = []
    for c in range(3):
        orig_channel = orig_np[:, :, c].flatten()
        gen_channel = gen_np[:, :, c].flatten()
        orig_channel = (orig_channel + 1e-10) / (np.sum(orig_channel) + 1e-10 * RESIZE * RESIZE)
        gen_channel = (gen_channel + 1e-10) / (np.sum(gen_channel) + 1e-10 * RESIZE * RESIZE)
        js_score = jensenshannon(orig_channel, gen_channel)
        if np.isnan(js_score):
            js_score = 1.0
        js_scores.append(js_score)
    js_score = np.mean(js_scores)

    return psnr_score, ssim_score, js_score

# Process generated images, enhance them, and compute metrics
metrics_dict = {i: [] for i in range(num_classes)}
all_images = {i: [] for i in range(num_classes)}  # Store all images with metrics
good_images = {i: [] for i in range(num_classes)}  # Store good images

for class_label in range(num_classes):
    class_dir = os.path.join(generated_base_dir, str(class_label))
    good_class_dir = os.path.join(good_images_dir, str(class_label))
    os.makedirs(good_class_dir, exist_ok=True)

    if not os.path.exists(class_dir):
        print(f"Class directory {class_dir} not found, skipping class {class_label}.")
        continue

    ref_images = reference_images[class_label]
    idx = 0
    while idx < 500:
        img_path = os.path.join(class_dir, f"sample_{idx}.png")
        if not os.path.exists(img_path):
            print(f"Image {img_path} not found, stopping at index {idx} for class {class_label}.")
            break

        try:
            gen_image = Image.open(img_path).convert('RGB')
            # Enhance the image
            gen_image = enhance_image(gen_image)
            gen_tensor = transform(gen_image)
        except Exception as e:
            print(f"Error processing image {img_path}: {str(e)}")
            idx += 1
            continue

        # Compute metrics
        psnr_scores, ssim_scores, js_scores = [], [], []
        for ref_tensor in ref_images:
            try:
                psnr_score, ssim_score, js_score = compute_metrics_for_image(ref_tensor, gen_tensor)
                psnr_scores.append(psnr_score)
                ssim_scores.append(ssim_score)
                js_scores.append(js_score)
            except Exception as e:
                print(f"Error computing metrics for image {img_path}: {str(e)}")
                psnr_scores.append(0.0)
                ssim_scores.append(0.0)
                js_scores.append(1.0)

        avg_psnr = np.mean(psnr_scores)
        avg_ssim = np.mean(ssim_scores)
        avg_js = np.mean(js_scores)

        all_images[class_label].append({
            'image': f"sample_{idx}.png",
            'psnr': avg_psnr,
            'ssim': avg_ssim,
            'js': avg_js,
            'pil_image': gen_image  # Store the enhanced image for saving if needed
        })

        idx += 1

    # Sort images by a combined score to select the top 100
    # Combined score: Higher PSNR and SSIM, lower JS
    all_images[class_label].sort(key=lambda x: (x['psnr'] + x['ssim'] * 10 - x['js'] * 10), reverse=True)

    # Select top 100 images and save those that meet the criteria
    selected_images = all_images[class_label][:100]  # Take top 100
    for metric in selected_images:
        avg_psnr = metric['psnr']
        avg_ssim = metric['ssim']
        avg_js = metric['js']
        img_name = metric['image']
        gen_image = metric['pil_image']

        # Save metrics for display
        metrics_dict[class_label].append({
            'image': img_name,
            'psnr': avg_psnr,
            'ssim': avg_ssim,
            'js': avg_js
        })

        # Check if the image meets the "good" criteria
        if avg_psnr > 11.8 and avg_ssim > 0.19 and avg_js < 0.24:
            good_img_path = os.path.join(good_class_dir, img_name)
            gen_image.save(good_img_path)
            good_images[class_label].append(img_name)

    print(f"\nClass {class_label} Metrics (Top 100):")
    for metric in metrics_dict[class_label][:100]:  # Display top 100
        print(f"Image: {metric['image']}, PSNR: {metric['psnr']:.2f}, SSIM: {metric['ssim']:.4f}, JS: {metric['js']:.4f}")
    print(f"Good images for class {class_label}: {len(good_images[class_label])} images saved to {good_class_dir}")

# Summary of good images
total_good = sum(len(good_images[cls]) for cls in good_images)
print(f"\nTotal good images across all classes: {total_good}")
# Out:
# Using scipy version: 1.15.3
# Searching for images in C:\Users\hp\.cache\kagglehub\datasets\sujaykapadnis\vehicle-type-image-dataset\versions\1
# Found 4793 images across 5 classes.
# Classes: ['Hatchback', 'Other', 'Pickup', 'Seden', 'SUV']
#
# Class 0 Metrics (Top 100):
# Image: sample_420.png, PSNR: 11.33, SSIM: 0.1461, JS: 0.2814
# Image: sample_180.png, PSNR: 11.39, SSIM: 0.1491, JS: 0.3037
# Image: sample_13.png, PSNR: 11.26, SSIM: 0.1609, JS: 0.3033
# Image: sample_42.png, PSNR: 10.73, SSIM: 0.1888, JS: 0.2793
# Image: sample_24.png, PSNR: 10.75, SSIM: 0.1778, JS: 0.2847
# Image: sample_236.png, PSNR: 11.29, SSIM: 0.1298, JS: 0.2926
# Image: sample_11.png, PSNR: 11.27, SSIM: 0.1341, JS: 0.2980
# Image: sample_179.png, PSNR: 10.79, SSIM: 0.1511, JS: 0.2698
# Image: sample_100.png, PSNR: 10.77, SSIM: 0.1607, JS: 0.2778
# Image: sample_229.png, PSNR: 11.16, SSIM: 0.1498, JS: 0.3077
# Image: sample_417.png, PSNR: 10.98, SSIM: 0.1588, JS: 0.3004
# Image: sample_499.png, PSNR: 11.15, SSIM: 0.1299, JS: 0.2899
# Image: sample_207.png, PSNR: 10.86, SSIM: 0.1593, JS: 0.2915
# Image: sample_393.png, PSNR: 11.25, SSIM: 0.1469, JS: 0.3188
# Image: sample_32.png, PSNR: 11.15, SSIM: 0.1295, JS: 0.2919
# Image: sample_2.png, PSNR: 10.89, SSIM: 0.1760, JS: 0.3141
# Image: sample_264.png, PSNR: 11.20, SSIM: 0.1319, JS: 0.3010
# Image: sample_328.png, PSNR: 11.07, SSIM: 0.1542, JS: 0.3145
# Image: sample_74.png, PSNR: 11.04, SSIM: 0.1420, JS: 0.2995
# Image: sample_202.png, PSNR: 11.18, SSIM: 0.1219, JS: 0.2993
# Image: sample_226.png, PSNR: 11.03, SSIM: 0.1512, JS: 0.3144
# Image: sample_37.png, PSNR: 11.00, SSIM: 0.1451, JS: 0.3067
# Image: sample_214.png, PSNR: 11.05, SSIM: 0.1423, JS: 0.3093
# Image: sample_8.png, PSNR: 11.24, SSIM: 0.1430, JS: 0.3289
# Image: sample_255.png, PSNR: 10.89, SSIM: 0.1531, JS: 0.3044
# Image: sample_299.png, PSNR: 11.17, SSIM: 0.1220, JS: 0.3025
# Image: sample_90.png, PSNR: 11.02, SSIM: 0.1482, JS: 0.3134
# Image: sample_148.png, PSNR: 10.91, SSIM: 0.1355, JS: 0.2903
# Image: sample_441.png, PSNR: 10.98, SSIM: 0.1491, JS: 0.3125
# Image: sample_398.png, PSNR: 10.52, SSIM: 0.1648, JS: 0.2821
# Image: sample_329.png, PSNR: 10.84, SSIM: 0.1529, JS: 0.3035
# Image: sample_138.png, PSNR: 10.93, SSIM: 0.1467, JS: 0.3067
# Image: sample_346.png, PSNR: 10.91, SSIM: 0.1318, JS: 0.2915
# Image: sample_203.png, PSNR: 10.99, SSIM: 0.1487, JS: 0.3195
# Image: sample_119.png, PSNR: 11.09, SSIM: 0.1386, JS: 0.3223
# Image: sample_266.png, PSNR: 10.96, SSIM: 0.1250, JS: 0.2959
# Image: sample_361.png, PSNR: 10.96, SSIM: 0.1343, JS: 0.3081
# Image: sample_0.png, PSNR: 10.62, SSIM: 0.1406, JS: 0.2804
# Image: sample_465.png, PSNR: 10.99, SSIM: 0.1205, JS: 0.2981
# Image: sample_443.png, PSNR: 10.95, SSIM: 0.1457, JS: 0.3190
# Image: sample_352.png, PSNR: 10.88, SSIM: 0.1331, JS: 0.3008
# Image: sample_187.png, PSNR: 10.98, SSIM: 0.1109, JS: 0.2893
# Image: sample_249.png, PSNR: 10.92, SSIM: 0.1433, JS: 0.3176
# Image: sample_277.png, PSNR: 10.84, SSIM: 0.1357, JS: 0.3057
# Image: sample_173.png, PSNR: 10.78, SSIM: 0.1239, JS: 0.2930
# Image: sample_22.png, PSNR: 10.98, SSIM: 0.1384, JS: 0.3281
# Image: sample_408.png, PSNR: 10.93, SSIM: 0.1288, JS: 0.3134
# Image: sample_252.png, PSNR: 10.58, SSIM: 0.1362, JS: 0.2874
# Image: sample_263.png, PSNR: 10.75, SSIM: 0.1382, JS: 0.3062
# Image: sample_136.png, PSNR: 10.74, SSIM: 0.1480, JS: 0.3158
# Image: sample_215.png, PSNR: 10.68, SSIM: 0.1441, JS: 0.3106
# Image: sample_316.png, PSNR: 10.64, SSIM: 0.1254, JS: 0.2883
# Image: sample_146.png, PSNR: 10.71, SSIM: 0.1390, JS: 0.3103
# Image: sample_213.png, PSNR: 10.37, SSIM: 0.1402, JS: 0.2787
# Image: sample_81.png, PSNR: 10.80, SSIM: 0.1289, JS: 0.3124
# Image: sample_157.png, PSNR: 10.85, SSIM: 0.1383, JS: 0.3271
# Image: sample_239.png, PSNR: 10.89, SSIM: 0.1225, JS: 0.3156
# Image: sample_473.png, PSNR: 10.87, SSIM: 0.1233, JS: 0.3146
# Image: sample_3.png, PSNR: 10.70, SSIM: 0.1139, JS: 0.2901
# Image: sample_15.png, PSNR: 10.84, SSIM: 0.1191, JS: 0.3119
# Image: sample_324.png, PSNR: 10.69, SSIM: 0.1002, JS: 0.2782
# Image: sample_375.png, PSNR: 10.27, SSIM: 0.1528, JS: 0.2900
# Image: sample_7.png, PSNR: 10.67, SSIM: 0.1452, JS: 0.3217
# Image: sample_99.png, PSNR: 10.87, SSIM: 0.1191, JS: 0.3194
# Image: sample_181.png, PSNR: 10.49, SSIM: 0.1335, JS: 0.2957
# Image: sample_240.png, PSNR: 10.67, SSIM: 0.1480, JS: 0.3292
# Image: sample_377.png, PSNR: 10.71, SSIM: 0.1098, JS: 0.2959
# Image: sample_178.png, PSNR: 10.47, SSIM: 0.1373, JS: 0.2991
# Image: sample_401.png, PSNR: 10.92, SSIM: 0.1073, JS: 0.3152
# Image: sample_397.png, PSNR: 10.72, SSIM: 0.1179, JS: 0.3068
# Image: sample_209.png, PSNR: 10.84, SSIM: 0.1151, JS: 0.3167
# Image: sample_482.png, PSNR: 10.49, SSIM: 0.1476, JS: 0.3169
# Image: sample_349.png, PSNR: 10.48, SSIM: 0.1514, JS: 0.3228
# Image: sample_454.png, PSNR: 10.77, SSIM: 0.1339, JS: 0.3349
# Image: sample_235.png, PSNR: 10.74, SSIM: 0.1235, JS: 0.3217
# Image: sample_163.png, PSNR: 10.50, SSIM: 0.1115, JS: 0.2876
# Image: sample_456.png, PSNR: 10.45, SSIM: 0.1654, JS: 0.3363
# Image: sample_303.png, PSNR: 10.73, SSIM: 0.1189, JS: 0.3186
# Image: sample_156.png, PSNR: 10.66, SSIM: 0.1171, JS: 0.3104
# Image: sample_101.png, PSNR: 10.62, SSIM: 0.1325, JS: 0.3219
# Image: sample_348.png, PSNR: 10.82, SSIM: 0.1188, JS: 0.3295
# Image: sample_428.png, PSNR: 10.74, SSIM: 0.1164, JS: 0.3192
# Image: sample_134.png, PSNR: 10.82, SSIM: 0.1028, JS: 0.3141
# Image: sample_481.png, PSNR: 10.47, SSIM: 0.1143, JS: 0.2920
# Image: sample_288.png, PSNR: 10.59, SSIM: 0.1235, JS: 0.3145
# Image: sample_293.png, PSNR: 10.53, SSIM: 0.1064, JS: 0.2917
# Image: sample_58.png, PSNR: 10.64, SSIM: 0.1231, JS: 0.3193
# Image: sample_73.png, PSNR: 10.54, SSIM: 0.1294, JS: 0.3195
# Image: sample_40.png, PSNR: 10.65, SSIM: 0.1271, JS: 0.3283
# Image: sample_384.png, PSNR: 10.76, SSIM: 0.1240, JS: 0.3358
# Image: sample_107.png, PSNR: 10.48, SSIM: 0.1293, JS: 0.3139
# Image: sample_71.png, PSNR: 10.38, SSIM: 0.1297, JS: 0.3051
# Image: sample_365.png, PSNR: 10.23, SSIM: 0.1371, JS: 0.2997
# Image: sample_455.png, PSNR: 10.78, SSIM: 0.1263, JS: 0.3443
# Image: sample_269.png, PSNR: 10.58, SSIM: 0.1058, JS: 0.3041
# Image: sample_471.png, PSNR: 10.68, SSIM: 0.1064, JS: 0.3191
# Image: sample_434.png, PSNR: 10.42, SSIM: 0.1506, JS: 0.3377
# Image: sample_476.png, PSNR: 10.65, SSIM: 0.1242, JS: 0.3342
# Image: sample_410.png, PSNR: 10.32, SSIM: 0.1542, JS: 0.3331
# Image: sample_248.png, PSNR: 10.35, SSIM: 0.1093, JS: 0.2919
# Good images for class 0: 0 images saved to C:\Users\hp\Desktop\fedavg\good_images-arch-A5-500\0
#
# Class 1 Metrics (Top 100):
# Image: sample_165.png, PSNR: 12.50, SSIM: 0.1874, JS: 0.2285
# Image: sample_223.png, PSNR: 11.98, SSIM: 0.1674, JS: 0.2335
# Image: sample_218.png, PSNR: 12.10, SSIM: 0.1601, JS: 0.2559
# Image: sample_22.png, PSNR: 11.92, SSIM: 0.1706, JS: 0.2490
# Image: sample_1.png, PSNR: 12.07, SSIM: 0.1590, JS: 0.2564
# Image: sample_57.png, PSNR: 12.19, SSIM: 0.1496, JS: 0.2594
# Image: sample_346.png, PSNR: 11.88, SSIM: 0.1642, JS: 0.2519
# Image: sample_213.png, PSNR: 11.99, SSIM: 0.1593, JS: 0.2599
# Image: sample_494.png, PSNR: 11.89, SSIM: 0.1542, JS: 0.2477
# Image: sample_150.png, PSNR: 11.84, SSIM: 0.1516, JS: 0.2402
# Image: sample_414.png, PSNR: 11.93, SSIM: 0.1578, JS: 0.2592
# Image: sample_111.png, PSNR: 11.99, SSIM: 0.1514, JS: 0.2589
# Image: sample_19.png, PSNR: 11.75, SSIM: 0.1744, JS: 0.2624
# Image: sample_107.png, PSNR: 11.82, SSIM: 0.1329, JS: 0.2318
# Image: sample_357.png, PSNR: 11.96, SSIM: 0.1396, JS: 0.2554
# Image: sample_126.png, PSNR: 11.93, SSIM: 0.1470, JS: 0.2600
# Image: sample_178.png, PSNR: 11.78, SSIM: 0.1536, JS: 0.2523
# Image: sample_438.png, PSNR: 11.87, SSIM: 0.1276, JS: 0.2357
# Image: sample_465.png, PSNR: 11.86, SSIM: 0.1597, JS: 0.2689
# Image: sample_286.png, PSNR: 11.66, SSIM: 0.1741, JS: 0.2655
# Image: sample_490.png, PSNR: 11.74, SSIM: 0.1676, JS: 0.2684
# Image: sample_492.png, PSNR: 11.79, SSIM: 0.1302, JS: 0.2363
# Image: sample_103.png, PSNR: 11.64, SSIM: 0.1706, JS: 0.2634
# Image: sample_486.png, PSNR: 11.71, SSIM: 0.1517, JS: 0.2523
# Image: sample_269.png, PSNR: 11.69, SSIM: 0.1523, JS: 0.2560
# Image: sample_290.png, PSNR: 11.62, SSIM: 0.1619, JS: 0.2604
# Image: sample_190.png, PSNR: 11.81, SSIM: 0.1501, JS: 0.2701
# Image: sample_193.png, PSNR: 11.84, SSIM: 0.1398, JS: 0.2659
# Image: sample_431.png, PSNR: 11.74, SSIM: 0.1513, JS: 0.2682
# Image: sample_477.png, PSNR: 11.66, SSIM: 0.1560, JS: 0.2669
# Image: sample_255.png, PSNR: 11.77, SSIM: 0.1469, JS: 0.2696
# Image: sample_136.png, PSNR: 11.85, SSIM: 0.1307, JS: 0.2619
# Image: sample_311.png, PSNR: 11.70, SSIM: 0.1517, JS: 0.2680
# Image: sample_106.png, PSNR: 11.81, SSIM: 0.1364, JS: 0.2649
# Image: sample_170.png, PSNR: 11.67, SSIM: 0.1532, JS: 0.2685
# Image: sample_425.png, PSNR: 11.59, SSIM: 0.1547, JS: 0.2630
# Image: sample_209.png, PSNR: 11.72, SSIM: 0.1348, JS: 0.2564
# Image: sample_339.png, PSNR: 11.82, SSIM: 0.1221, JS: 0.2540
# Image: sample_445.png, PSNR: 11.78, SSIM: 0.1386, JS: 0.2673
# Image: sample_113.png, PSNR: 11.70, SSIM: 0.1552, JS: 0.2767
# Image: sample_151.png, PSNR: 11.71, SSIM: 0.1412, JS: 0.2634
# Image: sample_201.png, PSNR: 11.58, SSIM: 0.1676, JS: 0.2783
# Image: sample_228.png, PSNR: 11.65, SSIM: 0.1549, JS: 0.2808
# Image: sample_451.png, PSNR: 11.65, SSIM: 0.1365, JS: 0.2649
# Image: sample_275.png, PSNR: 11.71, SSIM: 0.1522, JS: 0.2875
# Image: sample_210.png, PSNR: 11.63, SSIM: 0.1139, JS: 0.2430
# Image: sample_450.png, PSNR: 11.55, SSIM: 0.1489, JS: 0.2698
# Image: sample_224.png, PSNR: 11.37, SSIM: 0.1554, JS: 0.2615
# Image: sample_128.png, PSNR: 11.64, SSIM: 0.1487, JS: 0.2862
# Image: sample_373.png, PSNR: 11.57, SSIM: 0.1572, JS: 0.2875
# Image: sample_31.png, PSNR: 11.70, SSIM: 0.1477, JS: 0.2917
# Image: sample_258.png, PSNR: 11.32, SSIM: 0.1546, JS: 0.2614
# Image: sample_476.png, PSNR: 11.43, SSIM: 0.1220, JS: 0.2396
# Image: sample_351.png, PSNR: 11.54, SSIM: 0.1521, JS: 0.2824
# Image: sample_233.png, PSNR: 11.69, SSIM: 0.1243, JS: 0.2694
# Image: sample_253.png, PSNR: 11.56, SSIM: 0.1089, JS: 0.2433
# Image: sample_288.png, PSNR: 11.65, SSIM: 0.1355, JS: 0.2813
# Image: sample_226.png, PSNR: 11.50, SSIM: 0.1468, JS: 0.2771
# Image: sample_372.png, PSNR: 11.38, SSIM: 0.1460, JS: 0.2663
# Image: sample_434.png, PSNR: 11.32, SSIM: 0.1543, JS: 0.2685
# Image: sample_480.png, PSNR: 11.44, SSIM: 0.1389, JS: 0.2656
# Image: sample_153.png, PSNR: 11.48, SSIM: 0.1219, JS: 0.2543
# Image: sample_427.png, PSNR: 11.62, SSIM: 0.1249, JS: 0.2716
# Image: sample_61.png, PSNR: 11.41, SSIM: 0.1425, JS: 0.2691
# Image: sample_272.png, PSNR: 11.59, SSIM: 0.1325, JS: 0.2783
# Image: sample_395.png, PSNR: 11.67, SSIM: 0.1002, JS: 0.2538
# Image: sample_109.png, PSNR: 11.31, SSIM: 0.1569, JS: 0.2767
# Image: sample_368.png, PSNR: 11.31, SSIM: 0.1208, JS: 0.2408
# Image: sample_481.png, PSNR: 11.37, SSIM: 0.1249, JS: 0.2508
# Image: sample_13.png, PSNR: 11.30, SSIM: 0.1531, JS: 0.2741
# Image: sample_152.png, PSNR: 11.45, SSIM: 0.1256, JS: 0.2626
# Image: sample_265.png, PSNR: 11.34, SSIM: 0.1574, JS: 0.2846
# Image: sample_94.png, PSNR: 11.33, SSIM: 0.1406, JS: 0.2673
# Image: sample_479.png, PSNR: 11.18, SSIM: 0.1757, JS: 0.2879
# Image: sample_359.png, PSNR: 11.43, SSIM: 0.1352, JS: 0.2734
# Image: sample_441.png, PSNR: 11.60, SSIM: 0.1124, JS: 0.2693
# Image: sample_453.png, PSNR: 11.34, SSIM: 0.1464, JS: 0.2784
# Image: sample_34.png, PSNR: 11.05, SSIM: 0.1681, JS: 0.2715
# Image: sample_360.png, PSNR: 11.58, SSIM: 0.0976, JS: 0.2563
# Image: sample_473.png, PSNR: 11.23, SSIM: 0.1526, JS: 0.2760
# Image: sample_54.png, PSNR: 11.27, SSIM: 0.1384, JS: 0.2671
# Image: sample_407.png, PSNR: 11.47, SSIM: 0.1286, JS: 0.2783
# Image: sample_484.png, PSNR: 11.67, SSIM: 0.0945, JS: 0.2657
# Image: sample_296.png, PSNR: 11.53, SSIM: 0.1286, JS: 0.2855
# Image: sample_199.png, PSNR: 11.48, SSIM: 0.1209, JS: 0.2736
# Image: sample_375.png, PSNR: 11.20, SSIM: 0.1526, JS: 0.2778
# Image: sample_281.png, PSNR: 11.47, SSIM: 0.1185, JS: 0.2705
# Image: sample_183.png, PSNR: 11.41, SSIM: 0.1427, JS: 0.2892
# Image: sample_32.png, PSNR: 11.31, SSIM: 0.1280, JS: 0.2655
# Image: sample_284.png, PSNR: 11.36, SSIM: 0.1483, JS: 0.2908
# Image: sample_370.png, PSNR: 11.55, SSIM: 0.1207, JS: 0.2832
# Image: sample_300.png, PSNR: 11.31, SSIM: 0.1554, JS: 0.2947
# Image: sample_248.png, PSNR: 11.56, SSIM: 0.1040, JS: 0.2694
# Image: sample_73.png, PSNR: 11.50, SSIM: 0.1018, JS: 0.2617
# Image: sample_394.png, PSNR: 11.22, SSIM: 0.1523, JS: 0.2846
# Image: sample_37.png, PSNR: 11.18, SSIM: 0.1565, JS: 0.2848
# Image: sample_204.png, PSNR: 11.30, SSIM: 0.1075, JS: 0.2506
# Image: sample_232.png, PSNR: 11.20, SSIM: 0.1401, JS: 0.2739
# Image: sample_185.png, PSNR: 11.33, SSIM: 0.1086, JS: 0.2558
# Image: sample_277.png, PSNR: 11.45, SSIM: 0.1098, JS: 0.2690
# Good images for class 1: 0 images saved to C:\Users\hp\Desktop\fedavg\good_images-arch-A5-500\1
#
# Class 2 Metrics (Top 100):
# Image: sample_406.png, PSNR: 10.85, SSIM: 0.1466, JS: 0.2730
# Image: sample_5.png, PSNR: 10.90, SSIM: 0.1529, JS: 0.2898
# Image: sample_187.png, PSNR: 11.03, SSIM: 0.1210, JS: 0.2742
# Image: sample_247.png, PSNR: 10.60, SSIM: 0.1376, JS: 0.2646
# Image: sample_281.png, PSNR: 10.74, SSIM: 0.1442, JS: 0.2966
# Image: sample_388.png, PSNR: 10.80, SSIM: 0.1183, JS: 0.2938
# Image: sample_84.png, PSNR: 10.65, SSIM: 0.1248, JS: 0.2994
# Image: sample_266.png, PSNR: 10.70, SSIM: 0.1091, JS: 0.2917
# Image: sample_183.png, PSNR: 10.64, SSIM: 0.0860, JS: 0.2701
# Image: sample_79.png, PSNR: 10.56, SSIM: 0.1158, JS: 0.3020
# Image: sample_412.png, PSNR: 10.64, SSIM: 0.0847, JS: 0.2822
# Image: sample_379.png, PSNR: 10.49, SSIM: 0.1137, JS: 0.2974
# Image: sample_464.png, PSNR: 10.50, SSIM: 0.1035, JS: 0.2896
# Image: sample_159.png, PSNR: 10.54, SSIM: 0.0966, JS: 0.2904
# Image: sample_163.png, PSNR: 10.44, SSIM: 0.1195, JS: 0.3045
# Image: sample_432.png, PSNR: 10.49, SSIM: 0.1000, JS: 0.2916
# Image: sample_153.png, PSNR: 10.60, SSIM: 0.0923, JS: 0.2981
# Image: sample_51.png, PSNR: 10.40, SSIM: 0.0939, JS: 0.2799
# Image: sample_207.png, PSNR: 10.59, SSIM: 0.0887, JS: 0.2935
# Image: sample_191.png, PSNR: 10.41, SSIM: 0.1076, JS: 0.2961
# Image: sample_109.png, PSNR: 10.36, SSIM: 0.1212, JS: 0.3188
# Image: sample_38.png, PSNR: 10.15, SSIM: 0.1305, JS: 0.3126
# Image: sample_117.png, PSNR: 10.32, SSIM: 0.1142, JS: 0.3143
# Image: sample_391.png, PSNR: 10.35, SSIM: 0.1165, JS: 0.3201
# Image: sample_128.png, PSNR: 9.99, SSIM: 0.1082, JS: 0.2820
# Image: sample_222.png, PSNR: 10.26, SSIM: 0.1023, JS: 0.3037
# Image: sample_35.png, PSNR: 10.06, SSIM: 0.1218, JS: 0.3050
# Image: sample_152.png, PSNR: 10.27, SSIM: 0.1110, JS: 0.3169
# Image: sample_488.png, PSNR: 10.25, SSIM: 0.0996, JS: 0.3054
# Image: sample_353.png, PSNR: 10.26, SSIM: 0.0831, JS: 0.2915
# Image: sample_381.png, PSNR: 10.30, SSIM: 0.0815, JS: 0.2949
# Image: sample_252.png, PSNR: 10.12, SSIM: 0.0674, JS: 0.2659
# Image: sample_372.png, PSNR: 10.15, SSIM: 0.0942, JS: 0.2954
# Image: sample_66.png, PSNR: 10.42, SSIM: 0.0774, JS: 0.3074
# Image: sample_217.png, PSNR: 10.43, SSIM: 0.0801, JS: 0.3113
# Image: sample_72.png, PSNR: 10.17, SSIM: 0.0874, JS: 0.2960
# Image: sample_221.png, PSNR: 10.34, SSIM: 0.0705, JS: 0.2965
# Image: sample_279.png, PSNR: 10.12, SSIM: 0.1049, JS: 0.3088
# Image: sample_76.png, PSNR: 10.17, SSIM: 0.0885, JS: 0.2984
# Image: sample_213.png, PSNR: 10.41, SSIM: 0.0681, JS: 0.3020
# Image: sample_236.png, PSNR: 10.25, SSIM: 0.0884, JS: 0.3073
# Image: sample_214.png, PSNR: 10.23, SSIM: 0.0917, JS: 0.3107
# Image: sample_477.png, PSNR: 10.38, SSIM: 0.0881, JS: 0.3232
# Image: sample_32.png, PSNR: 10.27, SSIM: 0.0886, JS: 0.3136
# Image: sample_175.png, PSNR: 9.83, SSIM: 0.1051, JS: 0.2858
# Image: sample_226.png, PSNR: 10.01, SSIM: 0.0746, JS: 0.2741
# Image: sample_315.png, PSNR: 10.26, SSIM: 0.0780, JS: 0.3029
# Image: sample_7.png, PSNR: 10.44, SSIM: 0.0727, JS: 0.3159
# Image: sample_25.png, PSNR: 10.26, SSIM: 0.0784, JS: 0.3059
# Image: sample_262.png, PSNR: 10.10, SSIM: 0.0653, JS: 0.2840
# Image: sample_179.png, PSNR: 10.18, SSIM: 0.0825, JS: 0.3105
# Image: sample_196.png, PSNR: 10.20, SSIM: 0.0968, JS: 0.3286
# Image: sample_197.png, PSNR: 10.24, SSIM: 0.0893, JS: 0.3252
# Image: sample_337.png, PSNR: 10.27, SSIM: 0.0907, JS: 0.3298
# Image: sample_312.png, PSNR: 10.02, SSIM: 0.0883, JS: 0.3035
# Image: sample_299.png, PSNR: 9.96, SSIM: 0.0828, JS: 0.2930
# Image: sample_426.png, PSNR: 10.27, SSIM: 0.0654, JS: 0.3101
# Image: sample_70.png, PSNR: 10.21, SSIM: 0.0870, JS: 0.3266
# Image: sample_374.png, PSNR: 9.96, SSIM: 0.0716, JS: 0.2861
# Image: sample_346.png, PSNR: 9.78, SSIM: 0.1312, JS: 0.3291
# Image: sample_470.png, PSNR: 10.19, SSIM: 0.0881, JS: 0.3283
# Image: sample_481.png, PSNR: 9.91, SSIM: 0.0805, JS: 0.2938
# Image: sample_33.png, PSNR: 10.27, SSIM: 0.0796, JS: 0.3294
# Image: sample_417.png, PSNR: 9.87, SSIM: 0.0936, JS: 0.3037
# Image: sample_275.png, PSNR: 9.72, SSIM: 0.0911, JS: 0.2857
# Image: sample_298.png, PSNR: 9.97, SSIM: 0.0959, JS: 0.3162
# Image: sample_181.png, PSNR: 10.14, SSIM: 0.0937, JS: 0.3310
# Image: sample_26.png, PSNR: 10.02, SSIM: 0.0692, JS: 0.2951
# Image: sample_59.png, PSNR: 9.85, SSIM: 0.0691, JS: 0.2784
# Image: sample_75.png, PSNR: 9.87, SSIM: 0.0669, JS: 0.2784
# Image: sample_321.png, PSNR: 9.94, SSIM: 0.0732, JS: 0.2966
# Image: sample_376.png, PSNR: 9.85, SSIM: 0.1146, JS: 0.3286
# Image: sample_445.png, PSNR: 10.01, SSIM: 0.0574, JS: 0.2917
# Image: sample_458.png, PSNR: 10.05, SSIM: 0.0917, JS: 0.3304
# Image: sample_400.png, PSNR: 10.03, SSIM: 0.0838, JS: 0.3200
# Image: sample_42.png, PSNR: 9.90, SSIM: 0.0717, JS: 0.2953
# Image: sample_274.png, PSNR: 9.77, SSIM: 0.1078, JS: 0.3191
# Image: sample_146.png, PSNR: 9.41, SSIM: 0.1031, JS: 0.2785
# Image: sample_286.png, PSNR: 10.01, SSIM: 0.0928, JS: 0.3284
# Image: sample_429.png, PSNR: 9.92, SSIM: 0.0924, JS: 0.3190
# Image: sample_27.png, PSNR: 10.01, SSIM: 0.0662, JS: 0.3024
# Image: sample_220.png, PSNR: 9.99, SSIM: 0.0848, JS: 0.3195
# Image: sample_253.png, PSNR: 10.16, SSIM: 0.0826, JS: 0.3353
# Image: sample_273.png, PSNR: 9.91, SSIM: 0.0660, JS: 0.2941
# Image: sample_427.png, PSNR: 9.97, SSIM: 0.0955, JS: 0.3297
# Image: sample_14.png, PSNR: 9.83, SSIM: 0.0971, JS: 0.3191
# Image: sample_342.png, PSNR: 9.87, SSIM: 0.0919, JS: 0.3177
# Image: sample_249.png, PSNR: 10.17, SSIM: 0.0670, JS: 0.3236
# Image: sample_465.png, PSNR: 9.83, SSIM: 0.0829, JS: 0.3070
# Image: sample_371.png, PSNR: 9.89, SSIM: 0.0712, JS: 0.3009
# Image: sample_255.png, PSNR: 9.94, SSIM: 0.0656, JS: 0.3009
# Image: sample_20.png, PSNR: 9.69, SSIM: 0.1192, JS: 0.3313
# Image: sample_289.png, PSNR: 9.79, SSIM: 0.1212, JS: 0.3430
# Image: sample_164.png, PSNR: 9.99, SSIM: 0.0603, JS: 0.3027
# Image: sample_80.png, PSNR: 10.08, SSIM: 0.0567, JS: 0.3083
# Image: sample_91.png, PSNR: 9.95, SSIM: 0.0991, JS: 0.3389
# Image: sample_401.png, PSNR: 9.85, SSIM: 0.0717, JS: 0.3015
# Image: sample_358.png, PSNR: 9.84, SSIM: 0.1009, JS: 0.3312
# Image: sample_97.png, PSNR: 9.91, SSIM: 0.0949, JS: 0.3324
# Image: sample_58.png, PSNR: 9.96, SSIM: 0.0716, JS: 0.3147
# Good images for class 2: 0 images saved to C:\Users\hp\Desktop\fedavg\good_images-arch-A5-500\2
#
# Class 3 Metrics (Top 100):
# Image: sample_292.png, PSNR: 12.48, SSIM: 0.2311, JS: 0.2271
# Image: sample_455.png, PSNR: 12.38, SSIM: 0.2197, JS: 0.2224
# Image: sample_337.png, PSNR: 12.37, SSIM: 0.2321, JS: 0.2343
# Image: sample_497.png, PSNR: 12.23, SSIM: 0.2295, JS: 0.2255
# Image: sample_273.png, PSNR: 12.20, SSIM: 0.2362, JS: 0.2305
# Image: sample_459.png, PSNR: 12.31, SSIM: 0.2146, JS: 0.2350
# Image: sample_75.png, PSNR: 12.06, SSIM: 0.2271, JS: 0.2350
# Image: sample_159.png, PSNR: 12.22, SSIM: 0.2127, JS: 0.2382
# Image: sample_67.png, PSNR: 12.19, SSIM: 0.2171, JS: 0.2415
# Image: sample_189.png, PSNR: 11.89, SSIM: 0.2307, JS: 0.2259
# Image: sample_102.png, PSNR: 12.27, SSIM: 0.1935, JS: 0.2297
# Image: sample_44.png, PSNR: 12.12, SSIM: 0.1889, JS: 0.2209
# Image: sample_349.png, PSNR: 12.02, SSIM: 0.2103, JS: 0.2329
# Image: sample_378.png, PSNR: 11.98, SSIM: 0.2182, JS: 0.2387
# Image: sample_203.png, PSNR: 12.14, SSIM: 0.1990, JS: 0.2380
# Image: sample_366.png, PSNR: 12.06, SSIM: 0.1921, JS: 0.2236
# Image: sample_483.png, PSNR: 11.83, SSIM: 0.2192, JS: 0.2311
# Image: sample_56.png, PSNR: 12.10, SSIM: 0.2096, JS: 0.2518
# Image: sample_38.png, PSNR: 11.90, SSIM: 0.2068, JS: 0.2373
# Image: sample_319.png, PSNR: 12.04, SSIM: 0.2305, JS: 0.2763
# Image: sample_410.png, PSNR: 12.03, SSIM: 0.2033, JS: 0.2487
# Image: sample_384.png, PSNR: 11.96, SSIM: 0.2031, JS: 0.2415
# Image: sample_70.png, PSNR: 11.82, SSIM: 0.2009, JS: 0.2264
# Image: sample_272.png, PSNR: 11.84, SSIM: 0.2067, JS: 0.2356
# Image: sample_332.png, PSNR: 11.83, SSIM: 0.2091, JS: 0.2372
# Image: sample_141.png, PSNR: 11.72, SSIM: 0.2107, JS: 0.2347
# Image: sample_367.png, PSNR: 12.00, SSIM: 0.1919, JS: 0.2435
# Image: sample_243.png, PSNR: 11.82, SSIM: 0.1928, JS: 0.2288
# Image: sample_82.png, PSNR: 11.91, SSIM: 0.1832, JS: 0.2338
# Image: sample_411.png, PSNR: 11.70, SSIM: 0.2043, JS: 0.2340
# Image: sample_271.png, PSNR: 11.95, SSIM: 0.1769, JS: 0.2350
# Image: sample_231.png, PSNR: 11.78, SSIM: 0.2003, JS: 0.2417
# Image: sample_339.png, PSNR: 11.62, SSIM: 0.2138, JS: 0.2415
# Image: sample_396.png, PSNR: 11.87, SSIM: 0.2013, JS: 0.2551
# Image: sample_490.png, PSNR: 11.80, SSIM: 0.2031, JS: 0.2503
# Image: sample_262.png, PSNR: 11.63, SSIM: 0.2231, JS: 0.2558
# Image: sample_130.png, PSNR: 11.97, SSIM: 0.1616, JS: 0.2308
# Image: sample_15.png, PSNR: 12.09, SSIM: 0.1655, JS: 0.2472
# Image: sample_134.png, PSNR: 11.89, SSIM: 0.1910, JS: 0.2537
# Image: sample_122.png, PSNR: 11.71, SSIM: 0.1972, JS: 0.2423
# Image: sample_125.png, PSNR: 11.69, SSIM: 0.1984, JS: 0.2412
# Image: sample_340.png, PSNR: 11.62, SSIM: 0.1962, JS: 0.2351
# Image: sample_460.png, PSNR: 11.57, SSIM: 0.2062, JS: 0.2410
# Image: sample_60.png, PSNR: 11.78, SSIM: 0.1754, JS: 0.2331
# Image: sample_350.png, PSNR: 11.69, SSIM: 0.2176, JS: 0.2688
# Image: sample_109.png, PSNR: 11.83, SSIM: 0.1855, JS: 0.2520
# Image: sample_465.png, PSNR: 11.74, SSIM: 0.2031, JS: 0.2654
# Image: sample_329.png, PSNR: 11.55, SSIM: 0.2024, JS: 0.2456
# Image: sample_64.png, PSNR: 11.65, SSIM: 0.1794, JS: 0.2332
# Image: sample_95.png, PSNR: 11.68, SSIM: 0.1848, JS: 0.2456
# Image: sample_14.png, PSNR: 11.50, SSIM: 0.1875, JS: 0.2330
# Image: sample_219.png, PSNR: 11.48, SSIM: 0.2040, JS: 0.2494
# Image: sample_73.png, PSNR: 11.89, SSIM: 0.1574, JS: 0.2488
# Image: sample_374.png, PSNR: 11.75, SSIM: 0.1879, JS: 0.2656
# Image: sample_253.png, PSNR: 11.60, SSIM: 0.1975, JS: 0.2616
# Image: sample_415.png, PSNR: 11.48, SSIM: 0.1942, JS: 0.2477
# Image: sample_389.png, PSNR: 11.69, SSIM: 0.1872, JS: 0.2615
# Image: sample_336.png, PSNR: 11.59, SSIM: 0.1692, JS: 0.2362
# Image: sample_166.png, PSNR: 11.53, SSIM: 0.2133, JS: 0.2741
# Image: sample_357.png, PSNR: 11.22, SSIM: 0.1995, JS: 0.2359
# Image: sample_77.png, PSNR: 11.59, SSIM: 0.2058, JS: 0.2804
# Image: sample_380.png, PSNR: 11.31, SSIM: 0.1997, JS: 0.2464
# Image: sample_0.png, PSNR: 11.79, SSIM: 0.1394, JS: 0.2348
# Image: sample_4.png, PSNR: 11.52, SSIM: 0.2040, JS: 0.2759
# Image: sample_235.png, PSNR: 11.71, SSIM: 0.1486, JS: 0.2401
# Image: sample_16.png, PSNR: 11.44, SSIM: 0.1854, JS: 0.2498
# Image: sample_316.png, PSNR: 11.56, SSIM: 0.1679, JS: 0.2453
# Image: sample_311.png, PSNR: 11.35, SSIM: 0.1730, JS: 0.2295
# Image: sample_110.png, PSNR: 11.68, SSIM: 0.1684, JS: 0.2595
# Image: sample_369.png, PSNR: 11.25, SSIM: 0.1895, JS: 0.2415
# Image: sample_217.png, PSNR: 11.63, SSIM: 0.1760, JS: 0.2663
# Image: sample_239.png, PSNR: 11.51, SSIM: 0.1899, JS: 0.2675
# Image: sample_6.png, PSNR: 11.24, SSIM: 0.1996, JS: 0.2535
# Image: sample_274.png, PSNR: 11.58, SSIM: 0.1772, JS: 0.2653
# Image: sample_211.png, PSNR: 11.37, SSIM: 0.1947, JS: 0.2629
# Image: sample_279.png, PSNR: 11.34, SSIM: 0.1816, JS: 0.2484
# Image: sample_46.png, PSNR: 11.31, SSIM: 0.2055, JS: 0.2726
# Image: sample_289.png, PSNR: 11.10, SSIM: 0.1954, JS: 0.2435
# Image: sample_487.png, PSNR: 11.54, SSIM: 0.1735, JS: 0.2660
# Image: sample_115.png, PSNR: 11.45, SSIM: 0.1427, JS: 0.2278
# Image: sample_192.png, PSNR: 11.35, SSIM: 0.1487, JS: 0.2262
# Image: sample_435.png, PSNR: 11.56, SSIM: 0.1757, JS: 0.2753
# Image: sample_127.png, PSNR: 11.31, SSIM: 0.1657, JS: 0.2407
# Image: sample_399.png, PSNR: 11.15, SSIM: 0.1859, JS: 0.2459
# Image: sample_196.png, PSNR: 11.56, SSIM: 0.1599, JS: 0.2623
# Image: sample_148.png, PSNR: 11.30, SSIM: 0.1794, JS: 0.2611
# Image: sample_30.png, PSNR: 11.47, SSIM: 0.1664, JS: 0.2660
# Image: sample_198.png, PSNR: 11.14, SSIM: 0.1603, JS: 0.2348
# Image: sample_132.png, PSNR: 11.46, SSIM: 0.1518, JS: 0.2619
# Image: sample_114.png, PSNR: 11.22, SSIM: 0.1357, JS: 0.2237
# Image: sample_408.png, PSNR: 11.04, SSIM: 0.1741, JS: 0.2452
# Image: sample_294.png, PSNR: 10.85, SSIM: 0.2014, JS: 0.2546
# Image: sample_80.png, PSNR: 11.28, SSIM: 0.1721, JS: 0.2678
# Image: sample_393.png, PSNR: 11.29, SSIM: 0.1880, JS: 0.2892
# Image: sample_260.png, PSNR: 11.17, SSIM: 0.1537, JS: 0.2433
# Image: sample_351.png, PSNR: 11.18, SSIM: 0.1513, JS: 0.2466
# Image: sample_101.png, PSNR: 10.99, SSIM: 0.1815, JS: 0.2584
# Image: sample_171.png, PSNR: 11.12, SSIM: 0.1986, JS: 0.2910
# Image: sample_7.png, PSNR: 11.44, SSIM: 0.1354, JS: 0.2608
# Image: sample_388.png, PSNR: 11.05, SSIM: 0.2003, JS: 0.2887
# Good images for class 3: 20 images saved to C:\Users\hp\Desktop\fedavg\good_images-arch-A5-500\3
#
# Class 4 Metrics (Top 100):
# Image: sample_4.png, PSNR: 10.09, SSIM: 0.1623, JS: 0.2955
# Image: sample_206.png, PSNR: 10.03, SSIM: 0.1374, JS: 0.2848
# Image: sample_126.png, PSNR: 9.50, SSIM: 0.1486, JS: 0.2787
# Image: sample_13.png, PSNR: 9.44, SSIM: 0.1253, JS: 0.2946
# Image: sample_157.png, PSNR: 9.64, SSIM: 0.1193, JS: 0.3190
# Image: sample_119.png, PSNR: 9.56, SSIM: 0.1198, JS: 0.3232
# Image: sample_311.png, PSNR: 9.52, SSIM: 0.0867, JS: 0.2862
# Image: sample_317.png, PSNR: 9.66, SSIM: 0.0910, JS: 0.3175
# Image: sample_136.png, PSNR: 9.68, SSIM: 0.1099, JS: 0.3396
# Image: sample_67.png, PSNR: 9.61, SSIM: 0.0949, JS: 0.3193
# Image: sample_494.png, PSNR: 9.59, SSIM: 0.1115, JS: 0.3433
# Image: sample_437.png, PSNR: 9.39, SSIM: 0.1098, JS: 0.3236
# Image: sample_303.png, PSNR: 9.69, SSIM: 0.0916, JS: 0.3350
# Image: sample_131.png, PSNR: 9.36, SSIM: 0.0731, JS: 0.2856
# Image: sample_334.png, PSNR: 9.48, SSIM: 0.1023, JS: 0.3323
# Image: sample_448.png, PSNR: 8.86, SSIM: 0.1027, JS: 0.2723
# Image: sample_335.png, PSNR: 9.57, SSIM: 0.0648, JS: 0.3133
# Image: sample_391.png, PSNR: 9.59, SSIM: 0.0823, JS: 0.3363
# Image: sample_313.png, PSNR: 8.67, SSIM: 0.0938, JS: 0.2633
# Image: sample_351.png, PSNR: 9.41, SSIM: 0.1049, JS: 0.3486
# Image: sample_352.png, PSNR: 9.36, SSIM: 0.0730, JS: 0.3125
# Image: sample_289.png, PSNR: 9.51, SSIM: 0.0739, JS: 0.3281
# Image: sample_392.png, PSNR: 9.48, SSIM: 0.0947, JS: 0.3486
# Image: sample_102.png, PSNR: 9.10, SSIM: 0.0852, JS: 0.3021
# Image: sample_76.png, PSNR: 9.38, SSIM: 0.1016, JS: 0.3499
# Image: sample_144.png, PSNR: 9.25, SSIM: 0.1089, JS: 0.3452
# Image: sample_44.png, PSNR: 9.46, SSIM: 0.0870, JS: 0.3486
# Image: sample_337.png, PSNR: 9.17, SSIM: 0.0996, JS: 0.3327
# Image: sample_192.png, PSNR: 9.15, SSIM: 0.0659, JS: 0.2989
# Image: sample_123.png, PSNR: 9.39, SSIM: 0.0713, JS: 0.3288
# Image: sample_321.png, PSNR: 9.34, SSIM: 0.0760, JS: 0.3284
# Image: sample_296.png, PSNR: 9.17, SSIM: 0.0651, JS: 0.3025
# Image: sample_133.png, PSNR: 9.37, SSIM: 0.0820, JS: 0.3423
# Image: sample_419.png, PSNR: 9.27, SSIM: 0.0833, JS: 0.3339
# Image: sample_374.png, PSNR: 9.10, SSIM: 0.0840, JS: 0.3179
# Image: sample_162.png, PSNR: 9.18, SSIM: 0.0781, JS: 0.3199
# Image: sample_83.png, PSNR: 9.22, SSIM: 0.0919, JS: 0.3378
# Image: sample_293.png, PSNR: 8.98, SSIM: 0.0708, JS: 0.2942
# Image: sample_218.png, PSNR: 9.42, SSIM: 0.0775, JS: 0.3455
# Image: sample_215.png, PSNR: 9.37, SSIM: 0.0943, JS: 0.3569
# Image: sample_274.png, PSNR: 9.26, SSIM: 0.0926, JS: 0.3439
# Image: sample_191.png, PSNR: 9.24, SSIM: 0.0920, JS: 0.3445
# Image: sample_266.png, PSNR: 9.32, SSIM: 0.0945, JS: 0.3569
# Image: sample_370.png, PSNR: 9.36, SSIM: 0.0833, JS: 0.3498
# Image: sample_496.png, PSNR: 9.30, SSIM: 0.0710, JS: 0.3322
# Image: sample_434.png, PSNR: 9.04, SSIM: 0.1007, JS: 0.3377
# Image: sample_282.png, PSNR: 9.26, SSIM: 0.0888, JS: 0.3511
# Image: sample_99.png, PSNR: 9.44, SSIM: 0.0638, JS: 0.3456
# Image: sample_16.png, PSNR: 9.15, SSIM: 0.0887, JS: 0.3415
# Image: sample_456.png, PSNR: 9.22, SSIM: 0.1014, JS: 0.3628
# Image: sample_209.png, PSNR: 9.18, SSIM: 0.0848, JS: 0.3423
# Image: sample_472.png, PSNR: 9.37, SSIM: 0.0826, JS: 0.3614
# Image: sample_142.png, PSNR: 9.14, SSIM: 0.1006, JS: 0.3567
# Image: sample_234.png, PSNR: 9.12, SSIM: 0.1041, JS: 0.3596
# Image: sample_380.png, PSNR: 9.22, SSIM: 0.0987, JS: 0.3648
# Image: sample_442.png, PSNR: 9.21, SSIM: 0.0855, JS: 0.3501
# Image: sample_393.png, PSNR: 9.33, SSIM: 0.0818, JS: 0.3591
# Image: sample_19.png, PSNR: 9.20, SSIM: 0.1023, JS: 0.3663
# Image: sample_245.png, PSNR: 9.21, SSIM: 0.0974, JS: 0.3627
# Image: sample_258.png, PSNR: 9.33, SSIM: 0.0722, JS: 0.3505
# Image: sample_342.png, PSNR: 9.28, SSIM: 0.0759, JS: 0.3501
# Image: sample_33.png, PSNR: 8.84, SSIM: 0.0592, JS: 0.2897
# Image: sample_139.png, PSNR: 9.33, SSIM: 0.0767, JS: 0.3567
# Image: sample_306.png, PSNR: 9.16, SSIM: 0.0787, JS: 0.3427
# Image: sample_155.png, PSNR: 9.22, SSIM: 0.0970, JS: 0.3673
# Image: sample_217.png, PSNR: 9.17, SSIM: 0.0983, JS: 0.3652
# Image: sample_416.png, PSNR: 9.16, SSIM: 0.0898, JS: 0.3565
# Image: sample_427.png, PSNR: 9.26, SSIM: 0.0622, JS: 0.3388
# Image: sample_341.png, PSNR: 9.16, SSIM: 0.0615, JS: 0.3291
# Image: sample_1.png, PSNR: 9.18, SSIM: 0.0759, JS: 0.3455
# Image: sample_124.png, PSNR: 9.33, SSIM: 0.0604, JS: 0.3468
# Image: sample_222.png, PSNR: 9.18, SSIM: 0.0657, JS: 0.3377
# Image: sample_468.png, PSNR: 9.13, SSIM: 0.0822, JS: 0.3493
# Image: sample_219.png, PSNR: 9.19, SSIM: 0.0829, JS: 0.3572
# Image: sample_479.png, PSNR: 9.13, SSIM: 0.0805, JS: 0.3483
# Image: sample_387.png, PSNR: 9.10, SSIM: 0.0757, JS: 0.3412
# Image: sample_111.png, PSNR: 9.14, SSIM: 0.0891, JS: 0.3586
# Image: sample_174.png, PSNR: 9.11, SSIM: 0.1002, JS: 0.3671
# Image: sample_398.png, PSNR: 9.30, SSIM: 0.0896, JS: 0.3762
# Image: sample_490.png, PSNR: 8.47, SSIM: 0.0859, JS: 0.2894
# Image: sample_376.png, PSNR: 9.22, SSIM: 0.0852, JS: 0.3652
# Image: sample_402.png, PSNR: 9.11, SSIM: 0.0863, JS: 0.3559
# Image: sample_363.png, PSNR: 9.13, SSIM: 0.0802, JS: 0.3522
# Image: sample_444.png, PSNR: 9.39, SSIM: 0.0441, JS: 0.3418
# Image: sample_22.png, PSNR: 8.63, SSIM: 0.0709, JS: 0.2930
# Image: sample_425.png, PSNR: 9.01, SSIM: 0.0823, JS: 0.3449
# Image: sample_483.png, PSNR: 9.00, SSIM: 0.1046, JS: 0.3662
# Image: sample_467.png, PSNR: 9.02, SSIM: 0.0820, JS: 0.3466
# Image: sample_315.png, PSNR: 9.18, SSIM: 0.0598, JS: 0.3409
# Image: sample_152.png, PSNR: 9.19, SSIM: 0.0871, JS: 0.3699
# Image: sample_42.png, PSNR: 9.25, SSIM: 0.0861, JS: 0.3755
# Image: sample_71.png, PSNR: 9.26, SSIM: 0.0613, JS: 0.3517
# Image: sample_172.png, PSNR: 9.02, SSIM: 0.0774, JS: 0.3441
# Image: sample_327.png, PSNR: 9.08, SSIM: 0.0645, JS: 0.3370
# Image: sample_362.png, PSNR: 9.13, SSIM: 0.0798, JS: 0.3577
# Image: sample_403.png, PSNR: 9.07, SSIM: 0.0845, JS: 0.3569
# Image: sample_125.png, PSNR: 8.98, SSIM: 0.0837, JS: 0.3477
# Image: sample_299.png, PSNR: 8.71, SSIM: 0.0840, JS: 0.3224
# Image: sample_106.png, PSNR: 9.02, SSIM: 0.0796, JS: 0.3489
# Image: sample_278.png, PSNR: 9.12, SSIM: 0.0922, JS: 0.3724
# Good images for class 4: 0 images saved to C:\Users\hp\Desktop\fedavg\good_images-arch-A5-500\4
#
# Total good images across all classes: 20

# %%
import torch
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image, ImageEnhance, ImageFilter
import os
import numpy as np
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim
from scipy.spatial.distance import jensenshannon
import kagglehub

# Define paths
generated_base_dir = r"C:\Users\hp\Desktop\fedavg\generated_samples-arch-A5-500"
good_images_dir = r"C:\Users\hp\Desktop\fedavg\good_images-arch-A5-500"
os.makedirs(good_images_dir, exist_ok=True)

# Hyperparameters
RESIZE = 128
num_classes = 5
original_dim = RESIZE * RESIZE * 3

# Custom Dataset for Kaggle Vehicle Type Image Dataset
class VehicleTypeDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = []
        self.class_to_idx = {}
        self.images = []
        self.labels = []

        print(f"Searching for images in {root_dir}")
        for root, dirs, files in os.walk(root_dir):
            image_files = [f for f in files if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
            if image_files:
                class_name = os.path.basename(root)
                if class_name not in self.class_to_idx:
                    self.classes.append(class_name)
                    self.class_to_idx[class_name] = len(self.classes) - 1
                for img_file in image_files:
                    img_path = os.path.join(root, img_file)
                    try:
                        Image.open(img_path).verify()
                        self.images.append(img_path)
                        self.labels.append(self.class_to_idx[class_name])
                    except:
                        print(f"Skipping corrupted image: {img_path}")

        if len(self.classes) != num_classes:
            raise ValueError(f"Expected {num_classes} classes, found {len(self.classes)}")
        print(f"Found {len(self.images)} images across {len(self.classes)} classes.")
        print(f"Classes: {self.classes}")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        image = Image.open(img_path).convert('RGB')
        label = self.labels[idx]
        sample = {'image': image, 'label': label}
        if self.transform:
            sample['image'] = self.transform(sample['image'])
        return sample

# Load a subset of real images as references (5 per class)
transform = transforms.Compose([
    transforms.Resize((RESIZE, RESIZE)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

path = kagglehub.dataset_download("sujaykapadnis/vehicle-type-image-dataset")
dataset = VehicleTypeDataset(root_dir=path, transform=transform)

# Collect reference images (5 per class)
reference_images = {i: [] for i in range(num_classes)}
for sample in dataset:
    label = sample['label']
    if len(reference_images[label]) < 5:
        reference_images[label].append(sample['image'])
    if all(len(refs) >= 5 for refs in reference_images.values()):
        break

# Enhanced image processing function with focus on SSIM
def enhance_image(pil_image):
    # Reduce denoising to preserve structural details (improves SSIM)
    pil_image = pil_image.filter(ImageFilter.MedianFilter(size=1))  # Reduced from size=3
    
    # Apply edge-preserving sharpening
    pil_image = pil_image.filter(ImageFilter.UnsharpMask(radius=1.5, percent=120, threshold=3))  # Increased percent to 120
    
    # Enhance sharpness moderately
    pil_image = ImageEnhance.Sharpness(pil_image).enhance(1.5)
    
    # Increase contrast to emphasize structure (improves SSIM)
    pil_image = ImageEnhance.Contrast(pil_image).enhance(1.3)  # Increased from 1.2 to 1.3
    
    # Keep brightness adjustment minimal
    pil_image = ImageEnhance.Brightness(pil_image).enhance(1.05)
    
    # Enhance color to improve fidelity
    pil_image = ImageEnhance.Color(pil_image).enhance(1.1)
    
    # Super-resolution-like effect
    pil_image = pil_image.resize((RESIZE * 2, RESIZE * 2), Image.Resampling.LANCZOS)
    pil_image = pil_image.resize((RESIZE, RESIZE), Image.Resampling.LANCZOS)
    
    return pil_image

# Function to compute PSNR, SSIM, and JS divergence
def compute_metrics_for_image(orig, gen):
    orig_np = orig.cpu().numpy() * 0.5 + 0.5
    gen_np = gen.cpu().numpy() * 0.5 + 0.5
    orig_np = np.transpose(orig_np, (1, 2, 0))
    gen_np = np.transpose(gen_np, (1, 2, 0))
    orig_np = np.clip(orig_np, 0, 1)
    gen_np = np.clip(gen_np, 0, 1)

    psnr_score = psnr(orig_np, gen_np, data_range=1.0)
    ssim_score = ssim(orig_np, gen_np, multichannel=True, data_range=1.0, channel_axis=2)

    js_scores = []
    for c in range(3):
        orig_channel = orig_np[:, :, c].flatten()
        gen_channel = gen_np[:, :, c].flatten()
        orig_channel = (orig_channel + 1e-10) / (np.sum(orig_channel) + 1e-10 * RESIZE * RESIZE)
        gen_channel = (gen_channel + 1e-10) / (np.sum(gen_channel) + 1e-10 * RESIZE * RESIZE)
        js_score = jensenshannon(orig_channel, gen_channel)
        if np.isnan(js_score):
            js_score = 1.0
        js_scores.append(js_score)
    js_score = np.mean(js_scores)

    return psnr_score, ssim_score, js_score

# Process generated images, enhance them, and compute metrics
metrics_dict = {i: [] for i in range(num_classes)}
all_images = {i: [] for i in range(num_classes)}  # Store all images with metrics
good_images = {i: [] for i in range(num_classes)}  # Store good images

for class_label in range(num_classes):
    class_dir = os.path.join(generated_base_dir, str(class_label))
    good_class_dir = os.path.join(good_images_dir, str(class_label))
    os.makedirs(good_class_dir, exist_ok=True)

    if not os.path.exists(class_dir):
        print(f"Class directory {class_dir} not found, skipping class {class_label}.")
        continue

    ref_images = reference_images[class_label]
    idx = 0
    while idx < 500:
        img_path = os.path.join(class_dir, f"sample_{idx}.png")
        if not os.path.exists(img_path):
            print(f"Image {img_path} not found, stopping at index {idx} for class {class_label}.")
            break

        try:
            gen_image = Image.open(img_path).convert('RGB')
            # Enhance the image
            gen_image = enhance_image(gen_image)
            gen_tensor = transform(gen_image)
        except Exception as e:
            print(f"Error processing image {img_path}: {str(e)}")
            idx += 1
            continue

        # Compute metrics
        psnr_scores, ssim_scores, js_scores = [], [], []
        for ref_tensor in ref_images:
            try:
                psnr_score, ssim_score, js_score = compute_metrics_for_image(ref_tensor, gen_tensor)
                psnr_scores.append(psnr_score)
                ssim_scores.append(ssim_score)
                js_scores.append(js_score)
            except Exception as e:
                print(f"Error computing metrics for image {img_path}: {str(e)}")
                psnr_scores.append(0.0)
                ssim_scores.append(0.0)
                js_scores.append(1.0)

        avg_psnr = np.mean(psnr_scores)
        avg_ssim = np.mean(ssim_scores)
        avg_js = np.mean(js_scores)

        all_images[class_label].append({
            'image': f"sample_{idx}.png",
            'psnr': avg_psnr,
            'ssim': avg_ssim,
            'js': avg_js,
            'pil_image': gen_image
        })

        idx += 1

    # Sort images by a combined score to select the top 100
    all_images[class_label].sort(key=lambda x: (x['psnr'] + x['ssim'] * 10 - x['js'] * 10), reverse=True)

    # Select top 100 images and save those that meet the criteria
    selected_images = all_images[class_label][:100]
    for metric in selected_images:
        avg_psnr = metric['psnr']
        avg_ssim = metric['ssim']
        avg_js = metric['js']
        img_name = metric['image']
        gen_image = metric['pil_image']

        metrics_dict[class_label].append({
            'image': img_name,
            'psnr': avg_psnr,
            'ssim': avg_ssim,
            'js': avg_js
        })

        # Check if the image meets the "good" criteria
        if avg_psnr > 11.8 and avg_ssim > 0.19 and avg_js < 0.24:
            good_img_path = os.path.join(good_class_dir, img_name)
            gen_image.save(good_img_path)
            good_images[class_label].append(img_name)

    print(f"\nClass {class_label} Metrics (Top 100):")
    for metric in metrics_dict[class_label][:100]:
        print(f"Image: {metric['image']}, PSNR: {metric['psnr']:.2f}, SSIM: {metric['ssim']:.4f}, JS: {metric['js']:.4f}")
    print(f"Good images for class {class_label}: {len(good_images[class_label])} images saved to {good_class_dir}")

# Summary of good images
total_good = sum(len(good_images[cls]) for cls in good_images)
print(f"\nTotal good images across all classes: {total_good}")
# Out:
# Searching for images in C:\Users\hp\.cache\kagglehub\datasets\sujaykapadnis\vehicle-type-image-dataset\versions\1
# Found 4793 images across 5 classes.
# Classes: ['Hatchback', 'Other', 'Pickup', 'Seden', 'SUV']
#
# Class 0 Metrics (Top 100):
# Image: sample_42.png, PSNR: 10.13, SSIM: 0.1515, JS: 0.2996
# Image: sample_180.png, PSNR: 10.67, SSIM: 0.1137, JS: 0.3332
# Image: sample_420.png, PSNR: 10.53, SSIM: 0.1075, JS: 0.3144
# Image: sample_24.png, PSNR: 10.12, SSIM: 0.1410, JS: 0.3074
# Image: sample_13.png, PSNR: 10.58, SSIM: 0.1225, JS: 0.3377
# Image: sample_100.png, PSNR: 10.17, SSIM: 0.1252, JS: 0.3011
# Image: sample_417.png, PSNR: 10.42, SSIM: 0.1275, JS: 0.3320
# Image: sample_179.png, PSNR: 10.16, SSIM: 0.1159, JS: 0.2962
# Image: sample_264.png, PSNR: 10.60, SSIM: 0.1003, JS: 0.3270
# Image: sample_32.png, PSNR: 10.47, SSIM: 0.1014, JS: 0.3181
# Image: sample_11.png, PSNR: 10.55, SSIM: 0.1012, JS: 0.3275
# Image: sample_499.png, PSNR: 10.47, SSIM: 0.0990, JS: 0.3202
# Image: sample_229.png, PSNR: 10.47, SSIM: 0.1156, JS: 0.3372
# Image: sample_2.png, PSNR: 10.31, SSIM: 0.1380, JS: 0.3451
# Image: sample_329.png, PSNR: 10.34, SSIM: 0.1208, JS: 0.3320
# Image: sample_0.png, PSNR: 10.14, SSIM: 0.1103, JS: 0.3028
# Image: sample_255.png, PSNR: 10.43, SSIM: 0.1184, JS: 0.3420
# Image: sample_236.png, PSNR: 10.47, SSIM: 0.0967, JS: 0.3249
# Image: sample_398.png, PSNR: 9.92, SSIM: 0.1294, JS: 0.3037
# Image: sample_214.png, PSNR: 10.48, SSIM: 0.1070, JS: 0.3401
# Image: sample_328.png, PSNR: 10.44, SSIM: 0.1168, JS: 0.3483
# Image: sample_207.png, PSNR: 10.10, SSIM: 0.1195, JS: 0.3218
# Image: sample_148.png, PSNR: 10.19, SSIM: 0.1064, JS: 0.3172
# Image: sample_393.png, PSNR: 10.47, SSIM: 0.1127, JS: 0.3522
# Image: sample_299.png, PSNR: 10.49, SSIM: 0.0903, JS: 0.3349
# Image: sample_203.png, PSNR: 10.43, SSIM: 0.1130, JS: 0.3530
# Image: sample_74.png, PSNR: 10.25, SSIM: 0.1077, JS: 0.3309
# Image: sample_90.png, PSNR: 10.28, SSIM: 0.1151, JS: 0.3427
# Image: sample_352.png, PSNR: 10.27, SSIM: 0.1014, JS: 0.3280
# Image: sample_465.png, PSNR: 10.32, SSIM: 0.0896, JS: 0.3231
# Image: sample_316.png, PSNR: 10.19, SSIM: 0.0935, JS: 0.3144
# Image: sample_266.png, PSNR: 10.28, SSIM: 0.0908, JS: 0.3247
# Image: sample_8.png, PSNR: 10.52, SSIM: 0.1070, JS: 0.3650
# Image: sample_136.png, PSNR: 10.24, SSIM: 0.1151, JS: 0.3459
# Image: sample_138.png, PSNR: 10.17, SSIM: 0.1129, JS: 0.3370
# Image: sample_187.png, PSNR: 10.26, SSIM: 0.0822, JS: 0.3154
# Image: sample_249.png, PSNR: 10.32, SSIM: 0.1105, JS: 0.3506
# Image: sample_346.png, PSNR: 10.20, SSIM: 0.0946, JS: 0.3236
# Image: sample_202.png, PSNR: 10.37, SSIM: 0.0873, JS: 0.3344
# Image: sample_252.png, PSNR: 9.90, SSIM: 0.1118, JS: 0.3124
# Image: sample_441.png, PSNR: 10.22, SSIM: 0.1125, JS: 0.3451
# Image: sample_37.png, PSNR: 10.25, SSIM: 0.1058, JS: 0.3420
# Image: sample_226.png, PSNR: 10.25, SSIM: 0.1137, JS: 0.3497
# Image: sample_181.png, PSNR: 10.09, SSIM: 0.1010, JS: 0.3223
# Image: sample_443.png, PSNR: 10.32, SSIM: 0.1106, JS: 0.3564
# Image: sample_361.png, PSNR: 10.27, SSIM: 0.1002, JS: 0.3448
# Image: sample_213.png, PSNR: 9.74, SSIM: 0.1083, JS: 0.2994
# Image: sample_173.png, PSNR: 10.13, SSIM: 0.0911, JS: 0.3225
# Image: sample_375.png, PSNR: 9.71, SSIM: 0.1222, JS: 0.3127
# Image: sample_3.png, PSNR: 10.14, SSIM: 0.0828, JS: 0.3197
# Image: sample_277.png, PSNR: 10.05, SSIM: 0.1049, JS: 0.3381
# Image: sample_473.png, PSNR: 10.24, SSIM: 0.0914, JS: 0.3446
# Image: sample_22.png, PSNR: 10.27, SSIM: 0.1058, JS: 0.3626
# Image: sample_81.png, PSNR: 10.18, SSIM: 0.0970, JS: 0.3455
# Image: sample_157.png, PSNR: 10.29, SSIM: 0.1011, JS: 0.3612
# Image: sample_7.png, PSNR: 10.14, SSIM: 0.1114, JS: 0.3577
# Image: sample_397.png, PSNR: 10.11, SSIM: 0.0899, JS: 0.3340
# Image: sample_263.png, PSNR: 9.99, SSIM: 0.1042, JS: 0.3395
# Image: sample_15.png, PSNR: 10.23, SSIM: 0.0893, JS: 0.3486
# Image: sample_408.png, PSNR: 10.12, SSIM: 0.0973, JS: 0.3458
# Image: sample_324.png, PSNR: 9.98, SSIM: 0.0727, JS: 0.3078
# Image: sample_119.png, PSNR: 10.27, SSIM: 0.0977, JS: 0.3618
# Image: sample_349.png, PSNR: 10.01, SSIM: 0.1177, JS: 0.3562
# Image: sample_107.png, PSNR: 10.03, SSIM: 0.1024, JS: 0.3430
# Image: sample_240.png, PSNR: 10.12, SSIM: 0.1121, JS: 0.3636
# Image: sample_215.png, PSNR: 10.00, SSIM: 0.1089, JS: 0.3484
# Image: sample_71.png, PSNR: 9.83, SSIM: 0.1013, JS: 0.3257
# Image: sample_239.png, PSNR: 10.16, SSIM: 0.0931, JS: 0.3502
# Image: sample_482.png, PSNR: 9.92, SSIM: 0.1160, JS: 0.3501
# Image: sample_377.png, PSNR: 10.00, SSIM: 0.0801, JS: 0.3233
# Image: sample_401.png, PSNR: 10.27, SSIM: 0.0758, JS: 0.3473
# Image: sample_456.png, PSNR: 9.97, SSIM: 0.1283, JS: 0.3710
# Image: sample_235.png, PSNR: 10.20, SSIM: 0.0869, JS: 0.3543
# Image: sample_146.png, PSNR: 9.95, SSIM: 0.1008, JS: 0.3432
# Image: sample_481.png, PSNR: 9.85, SSIM: 0.0839, JS: 0.3170
# Image: sample_348.png, PSNR: 10.25, SSIM: 0.0878, JS: 0.3624
# Image: sample_288.png, PSNR: 10.05, SSIM: 0.0962, JS: 0.3513
# Image: sample_423.png, PSNR: 9.60, SSIM: 0.1077, JS: 0.3178
# Image: sample_178.png, PSNR: 9.71, SSIM: 0.1083, JS: 0.3290
# Image: sample_163.png, PSNR: 9.82, SSIM: 0.0804, JS: 0.3141
# Image: sample_293.png, PSNR: 9.91, SSIM: 0.0791, JS: 0.3210
# Image: sample_365.png, PSNR: 9.66, SSIM: 0.1047, JS: 0.3229
# Image: sample_303.png, PSNR: 10.11, SSIM: 0.0868, JS: 0.3508
# Image: sample_342.png, PSNR: 9.75, SSIM: 0.0917, JS: 0.3199
# Image: sample_101.png, PSNR: 10.03, SSIM: 0.0992, JS: 0.3568
# Image: sample_58.png, PSNR: 10.06, SSIM: 0.0902, JS: 0.3504
# Image: sample_248.png, PSNR: 9.82, SSIM: 0.0819, JS: 0.3212
# Image: sample_411.png, PSNR: 9.27, SSIM: 0.1148, JS: 0.2999
# Image: sample_99.png, PSNR: 10.08, SSIM: 0.0884, JS: 0.3551
# Image: sample_73.png, PSNR: 9.95, SSIM: 0.1008, JS: 0.3542
# Image: sample_134.png, PSNR: 10.17, SSIM: 0.0761, JS: 0.3523
# Image: sample_428.png, PSNR: 10.06, SSIM: 0.0872, JS: 0.3524
# Image: sample_156.png, PSNR: 9.94, SSIM: 0.0864, JS: 0.3417
# Image: sample_454.png, PSNR: 10.16, SSIM: 0.0961, JS: 0.3740
# Image: sample_488.png, PSNR: 9.88, SSIM: 0.1215, JS: 0.3720
# Image: sample_269.png, PSNR: 9.94, SSIM: 0.0755, JS: 0.3332
# Image: sample_97.png, PSNR: 9.47, SSIM: 0.0772, JS: 0.2884
# Image: sample_471.png, PSNR: 10.06, SSIM: 0.0776, JS: 0.3490
# Image: sample_238.png, PSNR: 9.69, SSIM: 0.0800, JS: 0.3144
# Image: sample_434.png, PSNR: 9.89, SSIM: 0.1143, JS: 0.3701
# Good images for class 0: 0 images saved to C:\Users\hp\Desktop\fedavg\good_images-arch-A5-500\0
#
# Class 1 Metrics (Top 100):
# Image: sample_165.png, PSNR: 11.90, SSIM: 0.1523, JS: 0.2496
# Image: sample_223.png, PSNR: 11.36, SSIM: 0.1330, JS: 0.2533
# Image: sample_346.png, PSNR: 11.31, SSIM: 0.1372, JS: 0.2729
# Image: sample_218.png, PSNR: 11.44, SSIM: 0.1281, JS: 0.2812
# Image: sample_1.png, PSNR: 11.43, SSIM: 0.1246, JS: 0.2805
# Image: sample_22.png, PSNR: 11.25, SSIM: 0.1322, JS: 0.2724
# Image: sample_494.png, PSNR: 11.27, SSIM: 0.1239, JS: 0.2701
# Image: sample_414.png, PSNR: 11.32, SSIM: 0.1307, JS: 0.2822
# Image: sample_150.png, PSNR: 11.21, SSIM: 0.1191, JS: 0.2614
# Image: sample_213.png, PSNR: 11.35, SSIM: 0.1258, JS: 0.2824
# Image: sample_57.png, PSNR: 11.46, SSIM: 0.1151, JS: 0.2884
# Image: sample_19.png, PSNR: 11.14, SSIM: 0.1388, JS: 0.2841
# Image: sample_438.png, PSNR: 11.23, SSIM: 0.0968, JS: 0.2552
# Image: sample_107.png, PSNR: 11.13, SSIM: 0.1028, JS: 0.2524
# Image: sample_269.png, PSNR: 11.14, SSIM: 0.1192, JS: 0.2753
# Image: sample_111.png, PSNR: 11.30, SSIM: 0.1132, JS: 0.2878
# Image: sample_357.png, PSNR: 11.29, SSIM: 0.1075, JS: 0.2810
# Image: sample_286.png, PSNR: 11.04, SSIM: 0.1412, JS: 0.2898
# Image: sample_490.png, PSNR: 11.12, SSIM: 0.1316, JS: 0.2882
# Image: sample_492.png, PSNR: 11.12, SSIM: 0.0998, JS: 0.2573
# Image: sample_465.png, PSNR: 11.25, SSIM: 0.1221, JS: 0.2945
# Image: sample_126.png, PSNR: 11.23, SSIM: 0.1144, JS: 0.2860
# Image: sample_103.png, PSNR: 11.03, SSIM: 0.1319, JS: 0.2893
# Image: sample_486.png, PSNR: 11.03, SSIM: 0.1163, JS: 0.2751
# Image: sample_178.png, PSNR: 11.03, SSIM: 0.1197, JS: 0.2785
# Image: sample_425.png, PSNR: 11.05, SSIM: 0.1182, JS: 0.2840
# Image: sample_190.png, PSNR: 11.19, SSIM: 0.1169, JS: 0.2966
# Image: sample_311.png, PSNR: 11.07, SSIM: 0.1218, JS: 0.2896
# Image: sample_477.png, PSNR: 11.07, SSIM: 0.1189, JS: 0.2889
# Image: sample_193.png, PSNR: 11.20, SSIM: 0.1063, JS: 0.2908
# Image: sample_290.png, PSNR: 10.97, SSIM: 0.1253, JS: 0.2864
# Image: sample_431.png, PSNR: 11.11, SSIM: 0.1147, JS: 0.2947
# Image: sample_209.png, PSNR: 11.05, SSIM: 0.1035, JS: 0.2781
# Image: sample_258.png, PSNR: 10.82, SSIM: 0.1263, JS: 0.2800
# Image: sample_106.png, PSNR: 11.15, SSIM: 0.1026, JS: 0.2904
# Image: sample_255.png, PSNR: 11.12, SSIM: 0.1083, JS: 0.2940
# Image: sample_224.png, PSNR: 10.83, SSIM: 0.1254, JS: 0.2830
# Image: sample_339.png, PSNR: 11.08, SSIM: 0.0954, JS: 0.2790
# Image: sample_136.png, PSNR: 11.16, SSIM: 0.0956, JS: 0.2875
# Image: sample_113.png, PSNR: 11.06, SSIM: 0.1200, JS: 0.3033
# Image: sample_445.png, PSNR: 11.09, SSIM: 0.1065, JS: 0.2943
# Image: sample_451.png, PSNR: 11.02, SSIM: 0.1081, JS: 0.2893
# Image: sample_151.png, PSNR: 11.01, SSIM: 0.1087, JS: 0.2900
# Image: sample_170.png, PSNR: 10.98, SSIM: 0.1171, JS: 0.2963
# Image: sample_228.png, PSNR: 11.03, SSIM: 0.1225, JS: 0.3069
# Image: sample_201.png, PSNR: 10.94, SSIM: 0.1303, JS: 0.3064
# Image: sample_450.png, PSNR: 10.92, SSIM: 0.1143, JS: 0.2953
# Image: sample_480.png, PSNR: 10.86, SSIM: 0.1107, JS: 0.2883
# Image: sample_210.png, PSNR: 10.91, SSIM: 0.0819, JS: 0.2646
# Image: sample_373.png, PSNR: 11.00, SSIM: 0.1225, JS: 0.3147
# Image: sample_372.png, PSNR: 10.82, SSIM: 0.1135, JS: 0.2885
# Image: sample_275.png, PSNR: 11.09, SSIM: 0.1132, JS: 0.3184
# Image: sample_476.png, PSNR: 10.73, SSIM: 0.0918, JS: 0.2606
# Image: sample_253.png, PSNR: 10.85, SSIM: 0.0801, JS: 0.2651
# Image: sample_351.png, PSNR: 10.94, SSIM: 0.1162, JS: 0.3116
# Image: sample_233.png, PSNR: 11.01, SSIM: 0.0933, JS: 0.2958
# Image: sample_434.png, PSNR: 10.68, SSIM: 0.1222, JS: 0.2931
# Image: sample_109.png, PSNR: 10.74, SSIM: 0.1209, JS: 0.2982
# Image: sample_128.png, PSNR: 10.97, SSIM: 0.1132, JS: 0.3133
# Image: sample_61.png, PSNR: 10.80, SSIM: 0.1098, JS: 0.2931
# Image: sample_94.png, PSNR: 10.73, SSIM: 0.1125, JS: 0.2897
# Image: sample_13.png, PSNR: 10.74, SSIM: 0.1192, JS: 0.2971
# Image: sample_272.png, PSNR: 10.99, SSIM: 0.1016, JS: 0.3050
# Image: sample_226.png, PSNR: 10.88, SSIM: 0.1101, JS: 0.3025
# Image: sample_288.png, PSNR: 11.01, SSIM: 0.1025, JS: 0.3102
# Image: sample_368.png, PSNR: 10.63, SSIM: 0.0903, JS: 0.2624
# Image: sample_152.png, PSNR: 10.82, SSIM: 0.0958, JS: 0.2870
# Image: sample_153.png, PSNR: 10.73, SSIM: 0.0926, JS: 0.2789
# Image: sample_427.png, PSNR: 10.92, SSIM: 0.0928, JS: 0.2993
# Image: sample_481.png, PSNR: 10.64, SSIM: 0.0959, JS: 0.2746
# Image: sample_31.png, PSNR: 10.90, SSIM: 0.1137, JS: 0.3200
# Image: sample_479.png, PSNR: 10.55, SSIM: 0.1409, JS: 0.3127
# Image: sample_265.png, PSNR: 10.77, SSIM: 0.1169, JS: 0.3123
# Image: sample_395.png, PSNR: 10.90, SSIM: 0.0716, JS: 0.2802
# Image: sample_34.png, PSNR: 10.45, SSIM: 0.1321, JS: 0.2961
# Image: sample_441.png, PSNR: 10.89, SSIM: 0.0856, JS: 0.2943
# Image: sample_360.png, PSNR: 10.88, SSIM: 0.0727, JS: 0.2822
# Image: sample_453.png, PSNR: 10.70, SSIM: 0.1139, JS: 0.3064
# Image: sample_473.png, PSNR: 10.59, SSIM: 0.1192, JS: 0.3013
# Image: sample_204.png, PSNR: 10.69, SSIM: 0.0783, JS: 0.2713
# Image: sample_183.png, PSNR: 10.81, SSIM: 0.1121, JS: 0.3174
# Image: sample_199.png, PSNR: 10.82, SSIM: 0.0925, JS: 0.3004
# Image: sample_186.png, PSNR: 11.07, SSIM: 0.0819, JS: 0.3155
# Image: sample_359.png, PSNR: 10.71, SSIM: 0.1044, JS: 0.3030
# Image: sample_281.png, PSNR: 10.79, SSIM: 0.0906, JS: 0.2976
# Image: sample_375.png, PSNR: 10.58, SSIM: 0.1165, JS: 0.3020
# Image: sample_232.png, PSNR: 10.60, SSIM: 0.1087, JS: 0.2969
# Image: sample_284.png, PSNR: 10.77, SSIM: 0.1123, JS: 0.3181
# Image: sample_484.png, PSNR: 10.95, SSIM: 0.0693, JS: 0.2934
# Image: sample_130.png, PSNR: 10.52, SSIM: 0.0932, JS: 0.2748
# Image: sample_32.png, PSNR: 10.63, SSIM: 0.0974, JS: 0.2903
# Image: sample_37.png, PSNR: 10.59, SSIM: 0.1195, JS: 0.3090
# Image: sample_73.png, PSNR: 10.81, SSIM: 0.0757, JS: 0.2876
# Image: sample_296.png, PSNR: 10.87, SSIM: 0.0963, JS: 0.3141
# Image: sample_394.png, PSNR: 10.62, SSIM: 0.1153, JS: 0.3099
# Image: sample_248.png, PSNR: 10.88, SSIM: 0.0766, JS: 0.2970
# Image: sample_370.png, PSNR: 10.89, SSIM: 0.0908, JS: 0.3133
# Image: sample_277.png, PSNR: 10.76, SSIM: 0.0858, JS: 0.2947
# Image: sample_185.png, PSNR: 10.64, SSIM: 0.0814, JS: 0.2788
# Image: sample_56.png, PSNR: 10.82, SSIM: 0.0744, JS: 0.2904
# Good images for class 1: 0 images saved to C:\Users\hp\Desktop\fedavg\good_images-arch-A5-500\1
#
# Class 2 Metrics (Top 100):
# Image: sample_406.png, PSNR: 10.13, SSIM: 0.1089, JS: 0.2991
# Image: sample_187.png, PSNR: 10.27, SSIM: 0.0940, JS: 0.3059
# Image: sample_5.png, PSNR: 10.12, SSIM: 0.1161, JS: 0.3232
# Image: sample_247.png, PSNR: 9.90, SSIM: 0.0996, JS: 0.2902
# Image: sample_281.png, PSNR: 10.03, SSIM: 0.1046, JS: 0.3301
# Image: sample_388.png, PSNR: 10.07, SSIM: 0.0867, JS: 0.3234
# Image: sample_266.png, PSNR: 10.02, SSIM: 0.0884, JS: 0.3214
# Image: sample_84.png, PSNR: 9.95, SSIM: 0.0980, JS: 0.3276
# Image: sample_183.png, PSNR: 9.88, SSIM: 0.0637, JS: 0.2984
# Image: sample_432.png, PSNR: 9.93, SSIM: 0.0782, JS: 0.3219
# Image: sample_412.png, PSNR: 9.96, SSIM: 0.0621, JS: 0.3129
# Image: sample_379.png, PSNR: 9.88, SSIM: 0.0862, JS: 0.3300
# Image: sample_79.png, PSNR: 9.91, SSIM: 0.0867, JS: 0.3357
# Image: sample_159.png, PSNR: 9.85, SSIM: 0.0755, JS: 0.3223
# Image: sample_191.png, PSNR: 9.80, SSIM: 0.0782, JS: 0.3259
# Image: sample_207.png, PSNR: 9.92, SSIM: 0.0662, JS: 0.3277
# Image: sample_153.png, PSNR: 9.92, SSIM: 0.0685, JS: 0.3311
# Image: sample_51.png, PSNR: 9.65, SSIM: 0.0715, JS: 0.3103
# Image: sample_38.png, PSNR: 9.68, SSIM: 0.1028, JS: 0.3502
# Image: sample_35.png, PSNR: 9.57, SSIM: 0.0983, JS: 0.3360
# Image: sample_109.png, PSNR: 9.81, SSIM: 0.0902, JS: 0.3518
# Image: sample_464.png, PSNR: 9.66, SSIM: 0.0760, JS: 0.3229
# Image: sample_252.png, PSNR: 9.56, SSIM: 0.0496, JS: 0.2873
# Image: sample_222.png, PSNR: 9.68, SSIM: 0.0810, JS: 0.3318
# Image: sample_117.png, PSNR: 9.72, SSIM: 0.0848, JS: 0.3431
# Image: sample_391.png, PSNR: 9.79, SSIM: 0.0895, JS: 0.3560
# Image: sample_128.png, PSNR: 9.38, SSIM: 0.0851, JS: 0.3105
# Image: sample_163.png, PSNR: 9.71, SSIM: 0.0836, JS: 0.3431
# Image: sample_226.png, PSNR: 9.45, SSIM: 0.0560, JS: 0.2961
# Image: sample_488.png, PSNR: 9.66, SSIM: 0.0733, JS: 0.3348
# Image: sample_175.png, PSNR: 9.30, SSIM: 0.0836, JS: 0.3111
# Image: sample_214.png, PSNR: 9.73, SSIM: 0.0696, JS: 0.3437
# Image: sample_76.png, PSNR: 9.58, SSIM: 0.0641, JS: 0.3257
# Image: sample_221.png, PSNR: 9.68, SSIM: 0.0541, JS: 0.3260
# Image: sample_353.png, PSNR: 9.56, SSIM: 0.0616, JS: 0.3226
# Image: sample_72.png, PSNR: 9.56, SSIM: 0.0622, JS: 0.3235
# Image: sample_152.png, PSNR: 9.64, SSIM: 0.0818, JS: 0.3544
# Image: sample_25.png, PSNR: 9.66, SSIM: 0.0591, JS: 0.3351
# Image: sample_213.png, PSNR: 9.78, SSIM: 0.0487, JS: 0.3366
# Image: sample_217.png, PSNR: 9.76, SSIM: 0.0568, JS: 0.3446
# Image: sample_381.png, PSNR: 9.55, SSIM: 0.0593, JS: 0.3280
# Image: sample_372.png, PSNR: 9.44, SSIM: 0.0673, JS: 0.3263
# Image: sample_7.png, PSNR: 9.83, SSIM: 0.0479, JS: 0.3475
# Image: sample_179.png, PSNR: 9.58, SSIM: 0.0618, JS: 0.3406
# Image: sample_481.png, PSNR: 9.37, SSIM: 0.0618, JS: 0.3214
# Image: sample_236.png, PSNR: 9.48, SSIM: 0.0671, JS: 0.3396
# Image: sample_275.png, PSNR: 9.14, SSIM: 0.0722, JS: 0.3111
# Image: sample_232.png, PSNR: 9.37, SSIM: 0.0855, JS: 0.3483
# Image: sample_445.png, PSNR: 9.48, SSIM: 0.0406, JS: 0.3152
# Image: sample_346.png, PSNR: 9.27, SSIM: 0.1076, JS: 0.3616
# Image: sample_262.png, PSNR: 9.40, SSIM: 0.0465, JS: 0.3140
# Image: sample_299.png, PSNR: 9.31, SSIM: 0.0625, JS: 0.3226
# Image: sample_315.png, PSNR: 9.57, SSIM: 0.0549, JS: 0.3413
# Image: sample_279.png, PSNR: 9.39, SSIM: 0.0771, JS: 0.3466
# Image: sample_59.png, PSNR: 9.24, SSIM: 0.0504, JS: 0.3056
# Image: sample_32.png, PSNR: 9.51, SSIM: 0.0653, JS: 0.3479
# Image: sample_26.png, PSNR: 9.42, SSIM: 0.0490, JS: 0.3231
# Image: sample_75.png, PSNR: 9.22, SSIM: 0.0512, JS: 0.3063
# Image: sample_66.png, PSNR: 9.63, SSIM: 0.0475, JS: 0.3435
# Image: sample_298.png, PSNR: 9.47, SSIM: 0.0698, JS: 0.3510
# Image: sample_146.png, PSNR: 8.90, SSIM: 0.0802, JS: 0.3043
# Image: sample_196.png, PSNR: 9.58, SSIM: 0.0724, JS: 0.3646
# Image: sample_321.png, PSNR: 9.34, SSIM: 0.0547, JS: 0.3231
# Image: sample_477.png, PSNR: 9.68, SSIM: 0.0580, JS: 0.3608
# Image: sample_197.png, PSNR: 9.64, SSIM: 0.0610, JS: 0.3618
# Image: sample_417.png, PSNR: 9.27, SSIM: 0.0663, JS: 0.3309
# Image: sample_273.png, PSNR: 9.31, SSIM: 0.0517, JS: 0.3206
# Image: sample_312.png, PSNR: 9.34, SSIM: 0.0642, JS: 0.3366
# Image: sample_33.png, PSNR: 9.67, SSIM: 0.0559, JS: 0.3624
# Image: sample_220.png, PSNR: 9.42, SSIM: 0.0671, JS: 0.3489
# Image: sample_426.png, PSNR: 9.60, SSIM: 0.0420, JS: 0.3419
# Image: sample_70.png, PSNR: 9.58, SSIM: 0.0639, JS: 0.3616
# Image: sample_374.png, PSNR: 9.23, SSIM: 0.0515, JS: 0.3155
# Image: sample_427.png, PSNR: 9.41, SSIM: 0.0732, JS: 0.3559
# Image: sample_337.png, PSNR: 9.55, SSIM: 0.0677, JS: 0.3642
# Image: sample_465.png, PSNR: 9.25, SSIM: 0.0658, JS: 0.3326
# Image: sample_342.png, PSNR: 9.32, SSIM: 0.0724, JS: 0.3469
# Image: sample_164.png, PSNR: 9.41, SSIM: 0.0458, JS: 0.3299
# Image: sample_42.png, PSNR: 9.23, SSIM: 0.0537, JS: 0.3234
# Image: sample_14.png, PSNR: 9.25, SSIM: 0.0752, JS: 0.3490
# Image: sample_27.png, PSNR: 9.38, SSIM: 0.0459, JS: 0.3325
# Image: sample_358.png, PSNR: 9.27, SSIM: 0.0801, JS: 0.3561
# Image: sample_140.png, PSNR: 9.23, SSIM: 0.0604, JS: 0.3334
# Image: sample_289.png, PSNR: 9.29, SSIM: 0.0918, JS: 0.3734
# Image: sample_274.png, PSNR: 9.18, SSIM: 0.0803, JS: 0.3514
# Image: sample_91.png, PSNR: 9.39, SSIM: 0.0739, JS: 0.3660
# Image: sample_458.png, PSNR: 9.39, SSIM: 0.0709, JS: 0.3640
# Image: sample_249.png, PSNR: 9.57, SSIM: 0.0489, JS: 0.3599
# Image: sample_181.png, PSNR: 9.46, SSIM: 0.0659, JS: 0.3665
# Image: sample_470.png, PSNR: 9.47, SSIM: 0.0638, JS: 0.3664
# Image: sample_485.png, PSNR: 8.78, SSIM: 0.0816, JS: 0.3151
# Image: sample_189.png, PSNR: 9.26, SSIM: 0.0751, JS: 0.3590
# Image: sample_58.png, PSNR: 9.30, SSIM: 0.0558, JS: 0.3432
# Image: sample_452.png, PSNR: 8.76, SSIM: 0.0715, JS: 0.3057
# Image: sample_20.png, PSNR: 9.14, SSIM: 0.0900, JS: 0.3630
# Image: sample_429.png, PSNR: 9.27, SSIM: 0.0665, JS: 0.3529
# Image: sample_376.png, PSNR: 9.24, SSIM: 0.0838, JS: 0.3669
# Image: sample_286.png, PSNR: 9.38, SSIM: 0.0650, JS: 0.3626
# Image: sample_401.png, PSNR: 9.17, SSIM: 0.0541, JS: 0.3311
# Image: sample_253.png, PSNR: 9.52, SSIM: 0.0599, JS: 0.3717
# Good images for class 2: 0 images saved to C:\Users\hp\Desktop\fedavg\good_images-arch-A5-500\2
#
# Class 3 Metrics (Top 100):
# Image: sample_292.png, PSNR: 11.85, SSIM: 0.1867, JS: 0.2468
# Image: sample_337.png, PSNR: 11.70, SSIM: 0.1940, JS: 0.2540
# Image: sample_273.png, PSNR: 11.58, SSIM: 0.1954, JS: 0.2488
# Image: sample_455.png, PSNR: 11.69, SSIM: 0.1757, JS: 0.2436
# Image: sample_497.png, PSNR: 11.54, SSIM: 0.1888, JS: 0.2486
# Image: sample_459.png, PSNR: 11.56, SSIM: 0.1768, JS: 0.2549
# Image: sample_189.png, PSNR: 11.23, SSIM: 0.1921, JS: 0.2457
# Image: sample_75.png, PSNR: 11.40, SSIM: 0.1844, JS: 0.2585
# Image: sample_349.png, PSNR: 11.40, SSIM: 0.1747, JS: 0.2502
# Image: sample_67.png, PSNR: 11.54, SSIM: 0.1770, JS: 0.2705
# Image: sample_159.png, PSNR: 11.54, SSIM: 0.1692, JS: 0.2646
# Image: sample_366.png, PSNR: 11.43, SSIM: 0.1560, JS: 0.2439
# Image: sample_483.png, PSNR: 11.22, SSIM: 0.1832, JS: 0.2527
# Image: sample_44.png, PSNR: 11.43, SSIM: 0.1522, JS: 0.2435
# Image: sample_102.png, PSNR: 11.55, SSIM: 0.1479, JS: 0.2539
# Image: sample_378.png, PSNR: 11.30, SSIM: 0.1752, JS: 0.2591
# Image: sample_141.png, PSNR: 11.20, SSIM: 0.1743, JS: 0.2509
# Image: sample_38.png, PSNR: 11.29, SSIM: 0.1697, JS: 0.2564
# Image: sample_203.png, PSNR: 11.41, SSIM: 0.1596, JS: 0.2590
# Image: sample_272.png, PSNR: 11.24, SSIM: 0.1705, JS: 0.2531
# Image: sample_332.png, PSNR: 11.20, SSIM: 0.1757, JS: 0.2547
# Image: sample_411.png, PSNR: 11.12, SSIM: 0.1712, JS: 0.2513
# Image: sample_56.png, PSNR: 11.45, SSIM: 0.1685, JS: 0.2823
# Image: sample_410.png, PSNR: 11.37, SSIM: 0.1652, JS: 0.2714
# Image: sample_243.png, PSNR: 11.17, SSIM: 0.1562, JS: 0.2489
# Image: sample_70.png, PSNR: 11.05, SSIM: 0.1617, JS: 0.2475
# Image: sample_367.png, PSNR: 11.34, SSIM: 0.1501, JS: 0.2672
# Image: sample_122.png, PSNR: 11.10, SSIM: 0.1599, JS: 0.2593
# Image: sample_340.png, PSNR: 11.03, SSIM: 0.1598, JS: 0.2550
# Image: sample_339.png, PSNR: 11.02, SSIM: 0.1685, JS: 0.2648
# Image: sample_82.png, PSNR: 11.26, SSIM: 0.1392, JS: 0.2598
# Image: sample_231.png, PSNR: 11.17, SSIM: 0.1569, JS: 0.2689
# Image: sample_262.png, PSNR: 11.03, SSIM: 0.1769, JS: 0.2848
# Image: sample_460.png, PSNR: 10.89, SSIM: 0.1686, JS: 0.2641
# Image: sample_60.png, PSNR: 11.13, SSIM: 0.1339, JS: 0.2539
# Image: sample_384.png, PSNR: 11.07, SSIM: 0.1588, JS: 0.2733
# Image: sample_219.png, PSNR: 10.90, SSIM: 0.1679, JS: 0.2662
# Image: sample_329.png, PSNR: 10.93, SSIM: 0.1635, JS: 0.2665
# Image: sample_319.png, PSNR: 11.30, SSIM: 0.1728, JS: 0.3139
# Image: sample_64.png, PSNR: 10.99, SSIM: 0.1461, JS: 0.2568
# Image: sample_350.png, PSNR: 11.12, SSIM: 0.1751, JS: 0.2998
# Image: sample_15.png, PSNR: 11.34, SSIM: 0.1264, JS: 0.2747
# Image: sample_125.png, PSNR: 10.89, SSIM: 0.1592, JS: 0.2636
# Image: sample_271.png, PSNR: 11.08, SSIM: 0.1382, JS: 0.2628
# Image: sample_130.png, PSNR: 11.19, SSIM: 0.1214, JS: 0.2584
# Image: sample_396.png, PSNR: 11.11, SSIM: 0.1589, JS: 0.2878
# Image: sample_14.png, PSNR: 10.87, SSIM: 0.1476, JS: 0.2528
# Image: sample_490.png, PSNR: 11.07, SSIM: 0.1556, JS: 0.2821
# Image: sample_465.png, PSNR: 11.21, SSIM: 0.1567, JS: 0.2974
# Image: sample_134.png, PSNR: 11.15, SSIM: 0.1426, JS: 0.2838
# Image: sample_16.png, PSNR: 10.88, SSIM: 0.1531, JS: 0.2672
# Image: sample_109.png, PSNR: 11.12, SSIM: 0.1414, JS: 0.2797
# Image: sample_95.png, PSNR: 11.02, SSIM: 0.1433, JS: 0.2720
# Image: sample_357.png, PSNR: 10.63, SSIM: 0.1640, JS: 0.2561
# Image: sample_415.png, PSNR: 10.90, SSIM: 0.1508, JS: 0.2697
# Image: sample_6.png, PSNR: 10.65, SSIM: 0.1674, JS: 0.2691
# Image: sample_336.png, PSNR: 10.89, SSIM: 0.1296, JS: 0.2616
# Image: sample_253.png, PSNR: 10.99, SSIM: 0.1500, JS: 0.2934
# Image: sample_166.png, PSNR: 10.98, SSIM: 0.1654, JS: 0.3086
# Image: sample_389.png, PSNR: 11.03, SSIM: 0.1423, JS: 0.2914
# Image: sample_0.png, PSNR: 11.11, SSIM: 0.1037, JS: 0.2618
# Image: sample_77.png, PSNR: 11.00, SSIM: 0.1670, JS: 0.3141
# Image: sample_73.png, PSNR: 11.12, SSIM: 0.1182, JS: 0.2779
# Image: sample_369.png, PSNR: 10.67, SSIM: 0.1528, JS: 0.2677
# Image: sample_4.png, PSNR: 10.97, SSIM: 0.1602, JS: 0.3059
# Image: sample_316.png, PSNR: 10.89, SSIM: 0.1291, JS: 0.2677
# Image: sample_374.png, PSNR: 11.05, SSIM: 0.1452, JS: 0.3004
# Image: sample_380.png, PSNR: 10.60, SSIM: 0.1573, JS: 0.2708
# Image: sample_311.png, PSNR: 10.62, SSIM: 0.1374, JS: 0.2531
# Image: sample_399.png, PSNR: 10.50, SSIM: 0.1542, JS: 0.2671
# Image: sample_235.png, PSNR: 10.93, SSIM: 0.1131, JS: 0.2691
# Image: sample_289.png, PSNR: 10.41, SSIM: 0.1605, JS: 0.2647
# Image: sample_211.png, PSNR: 10.79, SSIM: 0.1534, JS: 0.2964
# Image: sample_274.png, PSNR: 10.99, SSIM: 0.1313, JS: 0.2964
# Image: sample_127.png, PSNR: 10.64, SSIM: 0.1326, JS: 0.2636
# Image: sample_239.png, PSNR: 10.90, SSIM: 0.1406, JS: 0.2987
# Image: sample_192.png, PSNR: 10.61, SSIM: 0.1145, JS: 0.2489
# Image: sample_46.png, PSNR: 10.77, SSIM: 0.1563, JS: 0.3069
# Image: sample_408.png, PSNR: 10.50, SSIM: 0.1377, JS: 0.2621
# Image: sample_114.png, PSNR: 10.65, SSIM: 0.1036, JS: 0.2436
# Image: sample_115.png, PSNR: 10.67, SSIM: 0.1089, JS: 0.2521
# Image: sample_279.png, PSNR: 10.61, SSIM: 0.1379, JS: 0.2764
# Image: sample_294.png, PSNR: 10.29, SSIM: 0.1640, JS: 0.2712
# Image: sample_148.png, PSNR: 10.68, SSIM: 0.1430, JS: 0.2896
# Image: sample_487.png, PSNR: 10.84, SSIM: 0.1352, JS: 0.2976
# Image: sample_110.png, PSNR: 10.89, SSIM: 0.1255, JS: 0.2937
# Image: sample_198.png, PSNR: 10.50, SSIM: 0.1251, JS: 0.2546
# Image: sample_196.png, PSNR: 10.86, SSIM: 0.1246, JS: 0.2922
# Image: sample_435.png, PSNR: 10.96, SSIM: 0.1295, JS: 0.3066
# Image: sample_217.png, PSNR: 10.83, SSIM: 0.1306, JS: 0.2961
# Image: sample_101.png, PSNR: 10.49, SSIM: 0.1428, JS: 0.2833
# Image: sample_260.png, PSNR: 10.51, SSIM: 0.1223, JS: 0.2662
# Image: sample_30.png, PSNR: 10.77, SSIM: 0.1266, JS: 0.3001
# Image: sample_351.png, PSNR: 10.55, SSIM: 0.1172, JS: 0.2686
# Image: sample_171.png, PSNR: 10.62, SSIM: 0.1573, JS: 0.3231
# Image: sample_80.png, PSNR: 10.61, SSIM: 0.1302, JS: 0.2966
# Image: sample_364.png, PSNR: 10.11, SSIM: 0.1463, JS: 0.2654
# Image: sample_132.png, PSNR: 10.66, SSIM: 0.1168, JS: 0.2923
# Image: sample_197.png, PSNR: 10.49, SSIM: 0.1375, JS: 0.2968
# Image: sample_119.png, PSNR: 10.17, SSIM: 0.1482, JS: 0.2811
# Good images for class 3: 0 images saved to C:\Users\hp\Desktop\fedavg\good_images-arch-A5-500\3
#
# Class 4 Metrics (Top 100):
# Image: sample_4.png, PSNR: 9.42, SSIM: 0.1328, JS: 0.3218
# Image: sample_206.png, PSNR: 9.35, SSIM: 0.1130, JS: 0.3133
# Image: sample_126.png, PSNR: 8.95, SSIM: 0.1232, JS: 0.3024
# Image: sample_13.png, PSNR: 9.04, SSIM: 0.1026, JS: 0.3192
# Image: sample_157.png, PSNR: 9.17, SSIM: 0.0918, JS: 0.3521
# Image: sample_119.png, PSNR: 9.16, SSIM: 0.0932, JS: 0.3534
# Image: sample_311.png, PSNR: 8.96, SSIM: 0.0658, JS: 0.3130
# Image: sample_67.png, PSNR: 9.24, SSIM: 0.0750, JS: 0.3512
# Image: sample_317.png, PSNR: 9.15, SSIM: 0.0715, JS: 0.3507
# Image: sample_437.png, PSNR: 8.99, SSIM: 0.0862, JS: 0.3528
# Image: sample_131.png, PSNR: 8.84, SSIM: 0.0535, JS: 0.3103
# Image: sample_136.png, PSNR: 9.15, SSIM: 0.0869, JS: 0.3765
# Image: sample_448.png, PSNR: 8.35, SSIM: 0.0839, JS: 0.2947
# Image: sample_303.png, PSNR: 9.19, SSIM: 0.0698, JS: 0.3672
# Image: sample_335.png, PSNR: 9.07, SSIM: 0.0502, JS: 0.3396
# Image: sample_313.png, PSNR: 8.22, SSIM: 0.0751, JS: 0.2849
# Image: sample_334.png, PSNR: 9.00, SSIM: 0.0797, JS: 0.3693
# Image: sample_494.png, PSNR: 8.94, SSIM: 0.0886, JS: 0.3758
# Image: sample_391.png, PSNR: 9.09, SSIM: 0.0601, JS: 0.3708
# Image: sample_289.png, PSNR: 8.95, SSIM: 0.0595, JS: 0.3558
# Image: sample_296.png, PSNR: 8.71, SSIM: 0.0505, JS: 0.3236
# Image: sample_144.png, PSNR: 8.83, SSIM: 0.0873, JS: 0.3747
# Image: sample_102.png, PSNR: 8.53, SSIM: 0.0686, JS: 0.3292
# Image: sample_76.png, PSNR: 8.93, SSIM: 0.0810, JS: 0.3828
# Image: sample_133.png, PSNR: 8.98, SSIM: 0.0630, JS: 0.3727
# Image: sample_162.png, PSNR: 8.71, SSIM: 0.0615, JS: 0.3470
# Image: sample_374.png, PSNR: 8.62, SSIM: 0.0666, JS: 0.3450
# Image: sample_293.png, PSNR: 8.47, SSIM: 0.0562, JS: 0.3197
# Image: sample_352.png, PSNR: 8.74, SSIM: 0.0524, JS: 0.3447
# Image: sample_192.png, PSNR: 8.58, SSIM: 0.0495, JS: 0.3262
# Image: sample_392.png, PSNR: 8.89, SSIM: 0.0711, JS: 0.3811
# Image: sample_83.png, PSNR: 8.76, SSIM: 0.0692, JS: 0.3675
# Image: sample_123.png, PSNR: 8.86, SSIM: 0.0530, JS: 0.3609
# Image: sample_351.png, PSNR: 8.80, SSIM: 0.0791, JS: 0.3819
# Image: sample_44.png, PSNR: 8.94, SSIM: 0.0674, JS: 0.3859
# Image: sample_496.png, PSNR: 8.80, SSIM: 0.0530, JS: 0.3582
# Image: sample_434.png, PSNR: 8.65, SSIM: 0.0751, JS: 0.3673
# Image: sample_419.png, PSNR: 8.77, SSIM: 0.0603, JS: 0.3646
# Image: sample_337.png, PSNR: 8.64, SSIM: 0.0747, JS: 0.3664
# Image: sample_282.png, PSNR: 8.81, SSIM: 0.0706, JS: 0.3792
# Image: sample_490.png, PSNR: 8.11, SSIM: 0.0691, JS: 0.3080
# Image: sample_274.png, PSNR: 8.70, SSIM: 0.0728, JS: 0.3727
# Image: sample_215.png, PSNR: 8.88, SSIM: 0.0724, JS: 0.3912
# Image: sample_321.png, PSNR: 8.78, SSIM: 0.0548, JS: 0.3645
# Image: sample_245.png, PSNR: 8.84, SSIM: 0.0757, JS: 0.3953
# Image: sample_16.png, PSNR: 8.70, SSIM: 0.0691, JS: 0.3746
# Image: sample_266.png, PSNR: 8.85, SSIM: 0.0711, JS: 0.3921
# Image: sample_370.png, PSNR: 8.84, SSIM: 0.0627, JS: 0.3828
# Image: sample_218.png, PSNR: 8.83, SSIM: 0.0595, JS: 0.3789
# Image: sample_191.png, PSNR: 8.74, SSIM: 0.0680, JS: 0.3799
# Image: sample_19.png, PSNR: 8.81, SSIM: 0.0796, JS: 0.3985
# Image: sample_33.png, PSNR: 8.30, SSIM: 0.0456, JS: 0.3141
# Image: sample_380.png, PSNR: 8.81, SSIM: 0.0768, JS: 0.3981
# Image: sample_22.png, PSNR: 8.18, SSIM: 0.0537, JS: 0.3143
# Image: sample_209.png, PSNR: 8.64, SSIM: 0.0633, JS: 0.3705
# Image: sample_142.png, PSNR: 8.67, SSIM: 0.0793, JS: 0.3894
# Image: sample_442.png, PSNR: 8.70, SSIM: 0.0674, JS: 0.3815
# Image: sample_234.png, PSNR: 8.67, SSIM: 0.0820, JS: 0.3928
# Image: sample_258.png, PSNR: 8.83, SSIM: 0.0531, JS: 0.3801
# Image: sample_327.png, PSNR: 8.62, SSIM: 0.0513, JS: 0.3581
# Image: sample_472.png, PSNR: 8.87, SSIM: 0.0627, JS: 0.3950
# Image: sample_341.png, PSNR: 8.67, SSIM: 0.0428, JS: 0.3560
# Image: sample_217.png, PSNR: 8.75, SSIM: 0.0777, JS: 0.3994
# Image: sample_393.png, PSNR: 8.88, SSIM: 0.0597, JS: 0.3947
# Image: sample_468.png, PSNR: 8.76, SSIM: 0.0624, JS: 0.3861
# Image: sample_342.png, PSNR: 8.75, SSIM: 0.0574, JS: 0.3831
# Image: sample_99.png, PSNR: 8.86, SSIM: 0.0453, JS: 0.3816
# Image: sample_139.png, PSNR: 8.83, SSIM: 0.0568, JS: 0.3916
# Image: sample_456.png, PSNR: 8.66, SSIM: 0.0796, JS: 0.3978
# Image: sample_299.png, PSNR: 8.28, SSIM: 0.0655, JS: 0.3470
# Image: sample_111.png, PSNR: 8.69, SSIM: 0.0693, JS: 0.3922
# Image: sample_174.png, PSNR: 8.69, SSIM: 0.0786, JS: 0.4015
# Image: sample_219.png, PSNR: 8.71, SSIM: 0.0620, JS: 0.3879
# Image: sample_427.png, PSNR: 8.70, SSIM: 0.0443, JS: 0.3691
# Image: sample_71.png, PSNR: 8.76, SSIM: 0.0454, JS: 0.3779
# Image: sample_306.png, PSNR: 8.54, SSIM: 0.0618, JS: 0.3738
# Image: sample_155.png, PSNR: 8.72, SSIM: 0.0723, JS: 0.4026
# Image: sample_172.png, PSNR: 8.56, SSIM: 0.0593, JS: 0.3733
# Image: sample_387.png, PSNR: 8.51, SSIM: 0.0603, JS: 0.3700
# Image: sample_78.png, PSNR: 8.33, SSIM: 0.0561, JS: 0.3478
# Image: sample_483.png, PSNR: 8.60, SSIM: 0.0822, JS: 0.4017
# Image: sample_125.png, PSNR: 8.50, SSIM: 0.0649, JS: 0.3757
# Image: sample_362.png, PSNR: 8.72, SSIM: 0.0603, JS: 0.3931
# Image: sample_47.png, PSNR: 8.65, SSIM: 0.0702, JS: 0.3968
# Image: sample_444.png, PSNR: 8.82, SSIM: 0.0301, JS: 0.3736
# Image: sample_124.png, PSNR: 8.74, SSIM: 0.0442, JS: 0.3801
# Image: sample_363.png, PSNR: 8.64, SSIM: 0.0596, JS: 0.3860
# Image: sample_1.png, PSNR: 8.60, SSIM: 0.0568, JS: 0.3789
# Image: sample_376.png, PSNR: 8.71, SSIM: 0.0640, JS: 0.3975
# Image: sample_416.png, PSNR: 8.61, SSIM: 0.0667, JS: 0.3910
# Image: sample_398.png, PSNR: 8.81, SSIM: 0.0653, JS: 0.4098
# Image: sample_65.png, PSNR: 8.50, SSIM: 0.0508, JS: 0.3647
# Image: sample_467.png, PSNR: 8.51, SSIM: 0.0610, JS: 0.3779
# Image: sample_106.png, PSNR: 8.58, SSIM: 0.0580, JS: 0.3828
# Image: sample_232.png, PSNR: 8.61, SSIM: 0.0443, JS: 0.3727
# Image: sample_42.png, PSNR: 8.72, SSIM: 0.0669, JS: 0.4063
# Image: sample_425.png, PSNR: 8.50, SSIM: 0.0598, JS: 0.3779
# Image: sample_403.png, PSNR: 8.51, SSIM: 0.0669, JS: 0.3856
# Image: sample_222.png, PSNR: 8.55, SSIM: 0.0484, JS: 0.3728
# Image: sample_315.png, PSNR: 8.59, SSIM: 0.0421, JS: 0.3713
# Good images for class 4: 0 images saved to C:\Users\hp\Desktop\fedavg\good_images-arch-A5-500\4
#
# Total good images across all classes: 0

# %%
##original_images_parameters

# %%
import torch
from torchvision import transforms
from torch.utils.data import Dataset
from PIL import Image
import os
import numpy as np
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim
from scipy.spatial.distance import jensenshannon
import kagglehub

# Define paths
path = kagglehub.dataset_download("sujaykapadnis/vehicle-type-image-dataset")

# Hyperparameters
RESIZE = 128
num_classes = 5

# Custom Dataset for Kaggle Vehicle Type Image Dataset
class VehicleTypeDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = []
        self.class_to_idx = {}
        self.images = []
        self.labels = []

        print(f"Searching for images in {root_dir}")
        for root, dirs, files in os.walk(root_dir):
            image_files = [f for f in files if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
            if image_files:
                class_name = os.path.basename(root)
                if class_name not in self.class_to_idx:
                    self.classes.append(class_name)
                    self.class_to_idx[class_name] = len(self.classes) - 1
                for img_file in image_files:
                    img_path = os.path.join(root, img_file)
                    try:
                        Image.open(img_path).verify()
                        self.images.append(img_path)
                        self.labels.append(self.class_to_idx[class_name])
                    except:
                        print(f"Skipping corrupted image: {img_path}")

        if len(self.classes) != num_classes:
            raise ValueError(f"Expected {num_classes} classes, found {len(self.classes)}")
        print(f"Found {len(self.images)} images across {len(self.classes)} classes.")
        print(f"Classes: {self.classes}")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        image = Image.open(img_path).convert('RGB')
        label = self.labels[idx]
        sample = {'image': image, 'label': label, 'path': img_path}
        if self.transform:
            sample['image'] = self.transform(sample['image'])
        return sample

# Transform for resizing and normalizing images
transform = transforms.Compose([
    transforms.Resize((RESIZE, RESIZE)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Load dataset
dataset = VehicleTypeDataset(root_dir=path, transform=transform)

# Organize images by class
images_by_class = {i: [] for i in range(num_classes)}
for idx in range(len(dataset)):
    sample = dataset[idx]
    label = sample['label']
    images_by_class[label].append((sample['image'], sample['path']))

# Function to compute PSNR, SSIM, and JS divergence between two images
def compute_metrics_for_image(orig, gen):
    orig_np = orig.cpu().numpy() * 0.5 + 0.5
    gen_np = gen.cpu().numpy() * 0.5 + 0.5
    orig_np = np.transpose(orig_np, (1, 2, 0))
    gen_np = np.transpose(gen_np, (1, 2, 0))
    orig_np = np.clip(orig_np, 0, 1)
    gen_np = np.clip(gen_np, 0, 1)

    psnr_score = psnr(orig_np, gen_np, data_range=1.0)
    ssim_score = ssim(orig_np, gen_np, multichannel=True, data_range=1.0, channel_axis=2)

    js_scores = []
    for c in range(3):
        orig_channel = orig_np[:, :, c].flatten()
        gen_channel = gen_np[:, :, c].flatten()
        orig_channel = (orig_channel + 1e-10) / (np.sum(orig_channel) + 1e-10 * RESIZE * RESIZE)
        gen_channel = (gen_channel + 1e-10) / (np.sum(gen_channel) + 1e-10 * RESIZE * RESIZE)
        js_score = jensenshannon(orig_channel, gen_channel)
        if np.isnan(js_score):
            js_score = 1.0
        js_scores.append(js_score)
    js_score = np.mean(js_scores)

    return psnr_score, ssim_score, js_score

# Compute metrics for all images in each class
metrics_by_class = {i: [] for i in range(num_classes)}

for class_label in range(num_classes):
    class_images = images_by_class[class_label]
    if len(class_images) < 2:
        print(f"Class {class_label} has {len(class_images)} images, not enough for comparison. Skipping.")
        continue

    # Use the first image in the class as the reference
    ref_image, ref_path = class_images[0]
    print(f"\nClass {class_label} ({dataset.classes[class_label]}): Reference Image = {os.path.basename(ref_path)}, Total Images = {len(class_images)}")

    for img_tensor, img_path in class_images:
        if img_tensor is ref_image:  # Skip the reference image itself to avoid perfect scores
            continue
        try:
            psnr_score, ssim_score, js_score = compute_metrics_for_image(ref_image, img_tensor)
            metrics_by_class[class_label].append({
                'image': os.path.basename(img_path),
                'psnr': psnr_score,
                'ssim': ssim_score,
                'js': js_score
            })
        except Exception as e:
            print(f"Error computing metrics for image {img_path}: {str(e)}")

    # Compute max, min, and mean
    if metrics_by_class[class_label]:
        psnr_values = [m['psnr'] for m in metrics_by_class[class_label]]
        ssim_values = [m['ssim'] for m in metrics_by_class[class_label]]
        js_values = [m['js'] for m in metrics_by_class[class_label]]

        print(f"Class {class_label} ({dataset.classes[class_label]}) Statistics:")
        print(f"PSNR - Max: {max(psnr_values):.2f}, Min: {min(psnr_values):.2f}, Mean: {np.mean(psnr_values):.2f}")
        print(f"SSIM - Max: {max(ssim_values):.4f}, Min: {min(ssim_values):.4f}, Mean: {np.mean(ssim_values):.4f}")
        print(f"JS   - Max: {max(js_values):.4f}, Min: {min(js_values):.4f}, Mean: {np.mean(js_values):.4f}")
    else:
        print(f"No metrics computed for class {class_label}.")
# Out:
# Searching for images in C:\Users\hp\.cache\kagglehub\datasets\sujaykapadnis\vehicle-type-image-dataset\versions\1
# Found 4793 images across 5 classes.
# Classes: ['Hatchback', 'Other', 'Pickup', 'Seden', 'SUV']
#
# Class 0 (Hatchback): Reference Image = PHOTO_0.jpg, Total Images = 602
# Class 0 (Hatchback) Statistics:
# PSNR - Max: 39.06, Min: 6.29, Mean: 10.91
# SSIM - Max: 0.9899, Min: 0.0267, Mean: 0.1556
# JS   - Max: 0.3581, Min: 0.0114, Mean: 0.2619
#
# Class 1 (Other): Reference Image = PHOTO_0.jpg, Total Images = 600
# Class 1 (Other) Statistics:
# PSNR - Max: 37.46, Min: 7.67, Mean: 11.44
# SSIM - Max: 0.9915, Min: 0.0513, Mean: 0.1294
# JS   - Max: 0.3745, Min: 0.0151, Mean: 0.2822
#
# Class 2 (Pickup): Reference Image = PHOTO_0.jpg, Total Images = 1689
# Class 2 (Pickup) Statistics:
# PSNR - Max: 49.59, Min: 6.77, Mean: 8.27
# SSIM - Max: 0.9986, Min: 0.0069, Mean: 0.0669
# JS   - Max: 0.3758, Min: 0.0029, Mean: 0.3134
#
# Class 3 (Seden): Reference Image = PHOTO_0.jpg, Total Images = 1222
# Class 3 (Seden) Statistics:
# PSNR - Max: 42.07, Min: 7.85, Mean: 11.95
# SSIM - Max: 0.9936, Min: 0.0328, Mean: 0.2062
# JS   - Max: 0.3506, Min: 0.0069, Mean: 0.2214
#
# Class 4 (SUV): Reference Image = PHOTO_0.jpg, Total Images = 680
# Class 4 (SUV) Statistics:
# PSNR - Max: 40.02, Min: 6.57, Mean: 8.75
# SSIM - Max: 0.9952, Min: 0.0249, Mean: 0.0961
# JS   - Max: 0.3443, Min: 0.0086, Mean: 0.2843

# %%
##adding other para and checking parameters of dataset

# %%
import torch
from torchvision import transforms
from torch.utils.data import Dataset
from PIL import Image
import os
import numpy as np
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim
from scipy.spatial.distance import jensenshannon
from scipy import stats
import kagglehub

# Define paths
path = kagglehub.dataset_download("sujaykapadnis/vehicle-type-image-dataset")

# Hyperparameters
RESIZE = 128
num_classes = 5

# Custom Dataset for Kaggle Vehicle Type Image Dataset
class VehicleTypeDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = []
        self.class_to_idx = {}
        self.images = []
        self.labels = []

        print(f"Searching for images in {root_dir}")
        for root, dirs, files in os.walk(root_dir):
            image_files = [f for f in files if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
            if image_files:
                class_name = os.path.basename(root)
                if class_name not in self.class_to_idx:
                    self.classes.append(class_name)
                    self.class_to_idx[class_name] = len(self.classes) - 1
                for img_file in image_files:
                    img_path = os.path.join(root, img_file)
                    try:
                        Image.open(img_path).verify()
                        self.images.append(img_path)
                        self.labels.append(self.class_to_idx[class_name])
                    except:
                        print(f"Skipping corrupted image: {img_path}")

        if len(self.classes) != num_classes:
            raise ValueError(f"Expected {num_classes} classes, found {len(self.classes)}")
        print(f"Found {len(self.images)} images across {len(self.classes)} classes.")
        print(f"Classes: {self.classes}")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        image = Image.open(img_path).convert('RGB')
        label = self.labels[idx]
        sample = {'image': image, 'label': label, 'path': img_path}
        if self.transform:
            sample['image'] = self.transform(sample['image'])
        return sample

# Transform for resizing and normalizing images
transform = transforms.Compose([
    transforms.Resize((RESIZE, RESIZE)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Load dataset
dataset = VehicleTypeDataset(root_dir=path, transform=transform)

# Organize images by class
images_by_class = {i: [] for i in range(num_classes)}
for idx in range(len(dataset)):
    sample = dataset[idx]
    label = sample['label']
    images_by_class[label].append((sample['image'], sample['path']))

# Function to compute PSNR, SSIM, and JS divergence between two images
def compute_metrics_for_image(orig, gen):
    orig_np = orig.cpu().numpy() * 0.5 + 0.5
    gen_np = gen.cpu().numpy() * 0.5 + 0.5
    orig_np = np.transpose(orig_np, (1, 2, 0))
    gen_np = np.transpose(gen_np, (1, 2, 0))
    orig_np = np.clip(orig_np, 0, 1)
    gen_np = np.clip(gen_np, 0, 1)

    psnr_score = psnr(orig_np, gen_np, data_range=1.0)
    ssim_score = ssim(orig_np, gen_np, multichannel=True, data_range=1.0, channel_axis=2)

    js_scores = []
    for c in range(3):
        orig_channel = orig_np[:, :, c].flatten()
        gen_channel = gen_np[:, :, c].flatten()
        orig_channel = (orig_channel + 1e-10) / (np.sum(orig_channel) + 1e-10 * RESIZE * RESIZE)
        gen_channel = (gen_channel + 1e-10) / (np.sum(gen_channel) + 1e-10 * RESIZE * RESIZE)
        js_score = jensenshannon(orig_channel, gen_channel)
        if np.isnan(js_score):
            js_score = 1.0
        js_scores.append(js_score)
    js_score = np.mean(js_scores)

    return psnr_score, ssim_score, js_score

# Compute metrics for all images in each class
metrics_by_class = {i: [] for i in range(num_classes)}

for class_label in range(num_classes):
    class_images = images_by_class[class_label]
    if len(class_images) < 2:
        print(f"Class {class_label} has {len(class_images)} images, not enough for comparison. Skipping.")
        continue

    # Use the first image in the class as the reference
    ref_image, ref_path = class_images[0]
    print(f"\nClass {class_label} ({dataset.classes[class_label]}): Reference Image = {os.path.basename(ref_path)}, Total Images = {len(class_images)}")

    for img_tensor, img_path in class_images:
        if img_tensor is ref_image:  # Skip the reference image itself to avoid perfect scores
            continue
        try:
            psnr_score, ssim_score, js_score = compute_metrics_for_image(ref_image, img_tensor)
            metrics_by_class[class_label].append({
                'image': os.path.basename(img_path),
                'psnr': psnr_score,
                'ssim': ssim_score,
                'js': js_score
            })
        except Exception as e:
            print(f"Error computing metrics for image {img_path}: {str(e)}")

    # Compute detailed statistics
    if metrics_by_class[class_label]:
        psnr_values = np.array([m['psnr'] for m in metrics_by_class[class_label]])
        ssim_values = np.array([m['ssim'] for m in metrics_by_class[class_label]])
        js_values = np.array([m['js'] for m in metrics_by_class[class_label]])

        # Compute median
        psnr_median = np.median(psnr_values)
        ssim_median = np.median(ssim_values)
        js_median = np.median(js_values)

        # Compute mode (approximate by binning for continuous data)
        psnr_mode = stats.mode(np.round(psnr_values, 1), keepdims=False)[0]
        ssim_mode = stats.mode(np.round(ssim_values, 3), keepdims=False)[0]
        js_mode = stats.mode(np.round(js_values, 3), keepdims=False)[0]

        # Compute standard deviation
        psnr_std = np.std(psnr_values)
        ssim_std = np.std(ssim_values)
        js_std = np.std(js_values)

        # Compute range
        psnr_range = np.max(psnr_values) - np.min(psnr_values)
        ssim_range = np.max(ssim_values) - np.min(ssim_values)
        js_range = np.max(js_values) - np.min(js_values)

        # Compute IQR (Interquartile Range)
        psnr_q1, psnr_q3 = np.percentile(psnr_values, [25, 75])
        ssim_q1, ssim_q3 = np.percentile(ssim_values, [25, 75])
        js_q1, js_q3 = np.percentile(js_values, [25, 75])
        psnr_iqr = psnr_q3 - psnr_q1
        ssim_iqr = ssim_q3 - ssim_q1
        js_iqr = js_q3 - js_q1

        # Detect outliers using IQR method
        psnr_outliers = np.sum((psnr_values < (psnr_q1 - 1.5 * psnr_iqr)) | (psnr_values > (psnr_q3 + 1.5 * psnr_iqr)))
        ssim_outliers = np.sum((ssim_values < (ssim_q1 - 1.5 * ssim_iqr)) | (ssim_values > (ssim_q3 + 1.5 * ssim_iqr)))
        js_outliers = np.sum((js_values < (js_q1 - 1.5 * js_iqr)) | (js_values > (js_q3 + 1.5 * js_iqr)))

        print(f"Class {class_label} ({dataset.classes[class_label]}) Statistics:")
        print(f"PSNR - Max: {np.max(psnr_values):.2f}, Min: {np.min(psnr_values):.2f}, Mean: {np.mean(psnr_values):.2f}, Median: {psnr_median:.2f}, Mode: {psnr_mode:.2f}, Std: {psnr_std:.2f}, Range: {psnr_range:.2f}, IQR: {psnr_iqr:.2f}, Outliers: {psnr_outliers}")
        print(f"SSIM - Max: {np.max(ssim_values):.4f}, Min: {np.min(ssim_values):.4f}, Mean: {np.mean(ssim_values):.4f}, Median: {ssim_median:.4f}, Mode: {ssim_mode:.4f}, Std: {ssim_std:.4f}, Range: {ssim_range:.4f}, IQR: {ssim_iqr:.4f}, Outliers: {ssim_outliers}")
        print(f"JS   - Max: {np.max(js_values):.4f}, Min: {np.min(js_values):.4f}, Mean: {np.mean(js_values):.4f}, Median: {js_median:.4f}, Mode: {js_mode:.4f}, Std: {js_std:.4f}, Range: {js_range:.4f}, IQR: {js_iqr:.4f}, Outliers: {js_outliers}")
    else:
        print(f"No metrics computed for class {class_label}.")
# Out:
# Searching for images in C:\Users\hp\.cache\kagglehub\datasets\sujaykapadnis\vehicle-type-image-dataset\versions\1
# Found 4793 images across 5 classes.
# Classes: ['Hatchback', 'Other', 'Pickup', 'Seden', 'SUV']
#
# Class 0 (Hatchback): Reference Image = PHOTO_0.jpg, Total Images = 602
# Class 0 (Hatchback) Statistics:
# PSNR - Max: 39.06, Min: 6.29, Mean: 10.91, Median: 10.70, Mode: 10.60, Std: 2.20, Range: 32.77, IQR: 1.91, Outliers: 9
# SSIM - Max: 0.9899, Min: 0.0267, Mean: 0.1556, Median: 0.1430, Mode: 0.1230, Std: 0.0853, Range: 0.9632, IQR: 0.0713, Outliers: 29
# JS   - Max: 0.3581, Min: 0.0114, Mean: 0.2619, Median: 0.2649, Mode: 0.2720, Std: 0.0357, Range: 0.3467, IQR: 0.0419, Outliers: 10
#
# Class 1 (Other): Reference Image = PHOTO_0.jpg, Total Images = 600
# Class 1 (Other) Statistics:
# PSNR - Max: 37.46, Min: 7.67, Mean: 11.44, Median: 11.53, Mode: 11.60, Std: 1.36, Range: 29.79, IQR: 1.01, Outliers: 21
# SSIM - Max: 0.9915, Min: 0.0513, Mean: 0.1294, Median: 0.1290, Mode: 0.1230, Std: 0.0433, Range: 0.9402, IQR: 0.0333, Outliers: 9
# JS   - Max: 0.3745, Min: 0.0151, Mean: 0.2822, Median: 0.2791, Mode: 0.2650, Std: 0.0285, Range: 0.3594, IQR: 0.0398, Outliers: 2
#
# Class 2 (Pickup): Reference Image = PHOTO_0.jpg, Total Images = 1689
# Class 2 (Pickup) Statistics:
# PSNR - Max: 49.59, Min: 6.77, Mean: 8.27, Median: 8.16, Mode: 8.00, Std: 1.18, Range: 42.82, IQR: 0.71, Outliers: 46
# SSIM - Max: 0.9986, Min: 0.0069, Mean: 0.0669, Median: 0.0621, Mode: 0.0570, Std: 0.0327, Range: 0.9917, IQR: 0.0232, Outliers: 72
# JS   - Max: 0.3758, Min: 0.0029, Mean: 0.3134, Median: 0.3170, Mode: 0.3210, Std: 0.0293, Range: 0.3728, IQR: 0.0328, Outliers: 48
#
# Class 3 (Seden): Reference Image = PHOTO_0.jpg, Total Images = 1222
# Class 3 (Seden) Statistics:
# PSNR - Max: 42.07, Min: 7.85, Mean: 11.95, Median: 11.61, Mode: 11.60, Std: 2.07, Range: 34.22, IQR: 1.98, Outliers: 20
# SSIM - Max: 0.9936, Min: 0.0328, Mean: 0.2062, Median: 0.1893, Mode: 0.1700, Std: 0.0891, Range: 0.9609, IQR: 0.1093, Outliers: 8
# JS   - Max: 0.3506, Min: 0.0069, Mean: 0.2214, Median: 0.2257, Mode: 0.2260, Std: 0.0458, Range: 0.3437, IQR: 0.0583, Outliers: 12
#
# Class 4 (SUV): Reference Image = PHOTO_0.jpg, Total Images = 680
# Class 4 (SUV) Statistics:
# PSNR - Max: 40.02, Min: 6.57, Mean: 8.75, Median: 7.81, Mode: 8.20, Std: 4.19, Range: 33.44, IQR: 0.99, Outliers: 59
# SSIM - Max: 0.9952, Min: 0.0249, Mean: 0.0961, Median: 0.0482, Mode: 0.0470, Std: 0.1928, Range: 0.9703, IQR: 0.0181, Outliers: 72
# JS   - Max: 0.3443, Min: 0.0086, Mean: 0.2843, Median: 0.2985, Mode: 0.2810, Std: 0.0609, Range: 0.3357, IQR: 0.0224, Outliers: 74

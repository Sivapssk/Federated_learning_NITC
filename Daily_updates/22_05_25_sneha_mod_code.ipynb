# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset, random_split
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt
import kagglehub

# Hyperparameters
RESIZE = 128
original_dim = RESIZE * RESIZE * 3
intermediate_dim = 512
latent_dim = 256
num_classes = 5
batch_size = 8  # Further reduced to 4 if needed (see below)
epochs = 3000  # Temporarily reduced for debugging; set back to 3000 once confirmed working
learning_rate = 1e-4
beta_start = 1
beta_end = 10
device = torch.device('cuda:1' if torch.cuda.device_count() > 1 else 'cuda')

# Print GPU information
print(f"Using device: {device}")
if device.type == 'cuda':
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory Allocated: {torch.cuda.memory_allocated(0) / 1024**2:.2f} MB")

# Custom Dataset for Kaggle Vehicle Type Image Dataset with Preloading
class VehicleTypeDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = []
        self.class_to_idx = {}
        self.images = []
        self.labels = []
        self.preloaded_images = []

        print(f"Searching for images in {root_dir}")
        for root, dirs, files in os.walk(root_dir):
            image_files = [f for f in files if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
            if image_files:
                class_name = os.path.basename(root)
                if class_name not in self.class_to_idx:
                    self.classes.append(class_name)
                    self.class_to_idx[class_name] = len(self.classes) - 1
                for img_file in image_files:
                    img_path = os.path.join(root, img_file)
                    try:
                        Image.open(img_path).verify()
                        self.images.append(img_path)
                        self.labels.append(self.class_to_idx[class_name])
                    except:
                        print(f"Skipping corrupted image: {img_path}")

        if len(self.classes) != num_classes:
            raise ValueError(f"Expected {num_classes} classes, found {len(self.classes)}")
        print(f"Found {len(self.images)} images across {len(self.classes)} classes.")
        print(f"Classes: {self.classes}")

        # Preload images into memory
        print("Preloading images into memory...")
        for img_path in self.images:
            try:
                image = Image.open(img_path).convert('RGB')
                self.preloaded_images.append(image)
            except:
                print(f"Failed to preload image: {img_path}")
                self.preloaded_images.append(None)  # Placeholder for failed images

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.preloaded_images[idx]
        if image is None:
            raise ValueError(f"Image at index {idx} failed to load during preloading")
        label = self.labels[idx]
        sample = {'image': image, 'label': label}
        if self.transform:
            sample['image'] = self.transform(sample['image'])
        return sample

# Enhanced Image Grid for Plotting
def image_grid(imgs, rows, cols, class_label, height=RESIZE, width=RESIZE):
    assert len(imgs) <= rows * cols
    grid = Image.new('RGB', size=(cols * width, rows * height), color=(255, 255, 255))
    for i, img in enumerate(imgs):
        x = (i % cols) * width + 2
        y = (i // cols) * height + 2
        grid.paste(img, box=(x, y))
    return grid

# Weight initialization function
def init_weights(m):
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.ConvTranspose2d):
        nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)
    elif isinstance(m, nn.Linear):
        nn.init.xavier_normal_(m.weight)
        nn.init.constant_(m.bias, 0)

# Encoder with kernel_size=5
class Encoder(nn.Module):
    def __init__(self, input_size, hidden_dim, latent_dim, num_classes):
        super(Encoder, self).__init__()
        self.encoder_cnn = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=5, stride=2, padding=2),    # Output: 64 x 64 x 64
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=5, stride=2, padding=2),  # Output: 128 x 32 x 32
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(128, 256, kernel_size=5, stride=2, padding=2), # Output: 256 x 16 x 16
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256, 512, kernel_size=5, stride=2, padding=2), # Output: 512 x 8 x 8
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 512, kernel_size=5, stride=2, padding=2), # Output: 512 x 4 x 4
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 1024, kernel_size=5, stride=2, padding=2),# Output: 1024 x 2 x 2
            nn.BatchNorm2d(1024),
            nn.ReLU(),
            nn.Conv2d(1024, 1024, kernel_size=5, stride=1, padding=2),# Output: 1024 x 2 x 2
            nn.BatchNorm2d(1024),
            nn.ReLU()
        )
        self.fc_hidden = nn.Linear(1024 * 2 * 2 + num_classes, hidden_dim)
        self.dropout = nn.Dropout(0.3)
        self.fc_mean = nn.Linear(hidden_dim, latent_dim)
        self.fc_logvar = nn.Linear(hidden_dim, latent_dim)
        self.apply(init_weights)

    def forward(self, x, y):
        x = self.encoder_cnn(x)
        x = x.view(x.size(0), -1)
        x_with_y = torch.cat([x, y], dim=-1)
        h = F.relu(self.fc_hidden(x_with_y))
        h = self.dropout(h)
        z_mean = self.fc_mean(h)
        z_logvar = self.fc_logvar(h)
        z_logvar = torch.clamp(z_logvar, min=-10, max=10)
        return z_mean, z_logvar

# Decoder with kernel_size=5
class Decoder(nn.Module):
    def __init__(self, latent_dim, hidden_dim, output_size, num_classes):
        super(Decoder, self).__init__()
        self.fc = nn.Linear(latent_dim + num_classes, hidden_dim)
        self.dropout = nn.Dropout(0.3)
        self.fc_to_cnn = nn.Linear(hidden_dim, 1024 * 2 * 2)
        self.decoder_cnn = nn.Sequential(
            nn.ConvTranspose2d(1024, 1024, kernel_size=5, stride=1, padding=2), # Output: 1024 x 2 x 2
            nn.BatchNorm2d(1024),
            nn.ReLU(),
            nn.ConvTranspose2d(1024, 512, kernel_size=5, stride=2, padding=2, output_padding=1), # Output: 512 x 4 x 4
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.ConvTranspose2d(512, 512, kernel_size=5, stride=2, padding=2, output_padding=1),  # Output: 512 x 8 x 8
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.ConvTranspose2d(512, 256, kernel_size=5, stride=2, padding=2, output_padding=1),  # Output: 256 x 16 x 16
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.ConvTranspose2d(256, 128, kernel_size=5, stride=2, padding=2, output_padding=1),  # Output: 128 x 32 x 32
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, kernel_size=5, stride=2, padding=2, output_padding=1),   # Output: 64 x 64 x 64
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 3, kernel_size=5, stride=2, padding=2, output_padding=1),     # Output: 3 x 128 x 128
            nn.Tanh()
        )
        self.apply(init_weights)

    def forward(self, z, y):
        z_with_y = torch.cat([z, y], dim=-1)
        h = F.relu(self.fc(z_with_y))
        h = self.dropout(h)
        h = F.relu(self.fc_to_cnn(h))
        h = h.view(-1, 1024, 2, 2)
        x_reconstructed = self.decoder_cnn(h)
        x_reconstructed = torch.clamp(x_reconstructed, min=-1, max=1)
        return x_reconstructed

# Conditional VAE
class ConditionalVAE(nn.Module):
    def __init__(self, encoder, decoder):
        super(ConditionalVAE, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def reparameterize(self, z_mean, z_logvar):
        std = torch.exp(0.5 * z_logvar)
        eps = torch.randn_like(std)
        return z_mean + eps * std

    def forward(self, data, y):
        z_mean, z_logvar = self.encoder(data, y)
        z = self.reparameterize(z_mean, z_logvar)
        x_reconstructed = self.decoder(z, y)
        return x_reconstructed, z_mean, z_logvar

# Download and prepare dataset
path = kagglehub.dataset_download("sujaykapadnis/vehicle-type-image-dataset")
print("Path to dataset files:", path)

# Data preparation with train/validation split
train_transform = transforms.Compose([
    transforms.Resize((RESIZE, RESIZE), interpolation=Image.BILINEAR),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

dataset = VehicleTypeDataset(root_dir=path, transform=train_transform)
train_size = int(0.8 * len(dataset))  # ~3834 images
val_size = len(dataset) - train_size  # ~959 images
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True, drop_last=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True, drop_last=True)

# Instantiate model
input_size = (batch_size, 3, RESIZE, RESIZE)
encoder = Encoder(input_size, intermediate_dim, latent_dim, num_classes).to(device)
decoder = Decoder(latent_dim, intermediate_dim, input_size, num_classes).to(device)
cvae = ConditionalVAE(encoder, decoder).to(device)

# Optimizer with learning rate scheduler
optimizer = optim.Adam(cvae.parameters(), lr=learning_rate)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=500, gamma=0.5)

# Loss function with normalization
def cvae_loss(data, x_reconstructed, z_mean, z_logvar, beta=1.0):
    batch_size = data.size(0)
    mse_loss = F.mse_loss(x_reconstructed, data, reduction='sum') / batch_size
    kl_loss = -0.5 * torch.sum(1 + z_logvar - z_mean.pow(2) - z_logvar.exp()) / batch_size
    return mse_loss + beta * kl_loss

# Training loop with gradient clipping and progress monitoring
cvae.train()
train_losses, val_losses = [], []

for epoch in range(epochs):
    print(f"Starting epoch {epoch + 1}/{epochs}", flush=True)
    beta = beta_start + (beta_end - beta_start) * (epoch / (epochs - 1)) if epochs > 1 else beta_end
    train_loss = 0
    batches_processed = 0

    for batch_idx, sample in enumerate(train_loader):
        try:
            data = sample['image'].to(device)
            labels = sample['label'].to(device)
            one_hot_labels = F.one_hot(labels, num_classes=num_classes).float()

            optimizer.zero_grad()
            x_reconstructed, z_mean, z_logvar = cvae(data, one_hot_labels)
            loss = cvae_loss(data, x_reconstructed, z_mean, z_logvar, beta)

            if torch.isnan(loss) or torch.isinf(loss):
                print(f"NaN/Inf loss detected at epoch {epoch+1}, batch {batch_idx+1}", flush=True)
                continue

            loss.backward()
            torch.nn.utils.clip_grad_norm_(cvae.parameters(), max_norm=1.0)
            optimizer.step()
            train_loss += loss.item() * data.size(0)
            batches_processed += 1

            # Print progress every 100 batches
            if (batch_idx + 1) % 100 == 0:
                print(f"Epoch {epoch + 1}, Batch {batch_idx + 1}/{len(train_loader)}, Loss: {loss.item():.4f}", flush=True)

        except RuntimeError as e:
            print(f"Error at epoch {epoch + 1}, batch {batch_idx + 1}: {str(e)}", flush=True)
            if "out of memory" in str(e).lower():
                print("Out of memory error detected. Clearing cache and continuing...", flush=True)
                if device.type == 'cuda':
                    torch.cuda.empty_cache()
            continue

    avg_train_loss = train_loss / len(train_loader.dataset)
    train_losses.append(avg_train_loss)

    # Validation loss
    cvae.eval()
    val_loss = 0
    with torch.no_grad():
        for sample in val_loader:
            data = sample['image'].to(device)
            labels = sample['label'].to(device)
            one_hot_labels = F.one_hot(labels, num_classes=num_classes).float()
            x_reconstructed, z_mean, z_logvar = cvae(data, one_hot_labels)
            loss = cvae_loss(data, x_reconstructed, z_mean, z_logvar, beta)
            val_loss += loss.item() * data.size(0)
    avg_val_loss = val_loss / len(val_loader.dataset) if len(val_loader.dataset) > 0 else 0
    val_losses.append(avg_val_loss)

    print(f'Epoch {epoch + 1}/{epochs}, Batches Processed: {batches_processed}, Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}', flush=True)
    scheduler.step()

    # Clear GPU memory
    if device.type == 'cuda':
        torch.cuda.empty_cache()

    # Save model and generate samples only at the last epoch
    if epoch == epochs - 1:
        try:
            # Save the model
            model_path = "cvae_vehicle_final.pth"
            torch.save(cvae.state_dict(), model_path)
            print(f"Saved final CVAE model to {model_path}", flush=True)

            # Generate 100 samples per class
            def generate_samples_labelwise(cvae, num_samples_per_class, base_dir, latent_dim, device):
                cvae.eval()
                os.makedirs(base_dir, exist_ok=True)
                class_names = dataset.classes
                with torch.no_grad():
                    for class_label in range(num_classes):
                        label_tensor = torch.tensor([class_label]).repeat(num_samples_per_class).to(device)
                        one_hot_labels = F.one_hot(label_tensor, num_classes=num_classes).float().to(device)
                        z = torch.randn(num_samples_per_class, latent_dim).to(device)
                        generated_samples = cvae.decoder(z, one_hot_labels)

                        class_dir = os.path.join(base_dir, str(class_label))
                        os.makedirs(class_dir, exist_ok=True)
                        images = []
                        for idx, sample in enumerate(generated_samples):
                            sample = sample.cpu().detach().numpy()
                            sample = sample * 0.5 + 0.5
                            sample = np.nan_to_num(sample, nan=0.0, posinf=0.0, neginf=0.0)
                            sample = (255 * sample).astype(np.uint8)
                            sample = np.transpose(sample, (1, 2, 0))
                            pil_image = Image.fromarray(sample).convert('RGB')
                            pil_image.save(os.path.join(class_dir, f"sample_{idx}.png"))
                            if idx < 32:
                                images.append(pil_image)
                        if images:
                            grid = image_grid(images, rows=4, cols=8, class_label=class_names[class_label])
                            grid.save(os.path.join(class_dir, f"grid_{class_names[class_label]}.png"))

            base_dir = "generated_samples-arch-A5"
            generate_samples_labelwise(cvae, num_samples_per_class=100, base_dir=base_dir, latent_dim=latent_dim, device=device)
            print("Finished generating samples", flush=True)

        except Exception as e:
            print(f"Error during saving/generation at last epoch: {str(e)}", flush=True)

# Plot training and validation losses
try:
    plt.figure(figsize=(8, 6))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Val Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.savefig("training_validation_losses-A5.png")
    plt.close()
    print("Saved loss plot to training_validation_losses-A5.png", flush=True)
except Exception as e:
    print(f"Error plotting losses: {str(e)}", flush=True)
# Out:
# Using device: cuda:1
# GPU Name: NVIDIA RTX A5000
# GPU Memory Allocated: 1632.76 MB
# Path to dataset files: C:\Users\hp\.cache\kagglehub\datasets\sujaykapadnis\vehicle-type-image-dataset\versions\1
# Searching for images in C:\Users\hp\.cache\kagglehub\datasets\sujaykapadnis\vehicle-type-image-dataset\versions\1
# Found 4793 images across 5 classes.
# Classes: ['Hatchback', 'Other', 'Pickup', 'Seden', 'SUV']
# Preloading images into memory...
# Starting epoch 1/3000
# Epoch 1, Batch 100/479, Loss: 8330.7422
# Epoch 1, Batch 200/479, Loss: 8530.8848
# Epoch 1, Batch 300/479, Loss: 7411.3530
# Epoch 1, Batch 400/479, Loss: 7409.0112
# Epoch 1/3000, Batches Processed: 479, Train Loss: 9118.5234, Val Loss: 7856.2977
# Starting epoch 2/3000
# Epoch 2, Batch 100/479, Loss: 7354.0107
# Epoch 2, Batch 200/479, Loss: 5924.6113
# Epoch 2, Batch 300/479, Loss: 7629.7148
# Epoch 2, Batch 400/479, Loss: 8198.4824
# Epoch 2/3000, Batches Processed: 479, Train Loss: 7342.5527, Val Loss: 7084.9774
# Starting epoch 3/3000
# Epoch 3, Batch 100/479, Loss: 7152.3018
# Epoch 3, Batch 200/479, Loss: 6028.7705
# Epoch 3, Batch 300/479, Loss: 6491.1914
# Epoch 3, Batch 400/479, Loss: 7017.5117
# Epoch 3/3000, Batches Processed: 479, Train Loss: 6758.9236, Val Loss: 6543.5008
# Starting epoch 4/3000
# Epoch 4, Batch 100/479, Loss: 10098.1152
# Epoch 4, Batch 200/479, Loss: 6860.9688
# Epoch 4, Batch 300/479, Loss: 7236.1865
# Epoch 4, Batch 400/479, Loss: 5389.2695
# Epoch 4/3000, Batches Processed: 479, Train Loss: 6447.1834, Val Loss: 6192.2422
# Starting epoch 5/3000
# Epoch 5, Batch 100/479, Loss: 7011.7998
# Epoch 5, Batch 200/479, Loss: 5960.2476
# Epoch 5, Batch 300/479, Loss: 5568.6626
# Epoch 5, Batch 400/479, Loss: 6585.5493
# Epoch 5/3000, Batches Processed: 479, Train Loss: 6129.8938, Val Loss: 6074.2049
# Starting epoch 6/3000
# Epoch 6, Batch 100/479, Loss: 6269.7793
# Epoch 6, Batch 200/479, Loss: 4929.5332
# Epoch 6, Batch 300/479, Loss: 5909.3730
# Epoch 6, Batch 400/479, Loss: 5157.8535
# Epoch 6/3000, Batches Processed: 479, Train Loss: 5865.5051, Val Loss: 5672.4159
# Starting epoch 7/3000
# Epoch 7, Batch 100/479, Loss: 5849.7017
# Epoch 7, Batch 200/479, Loss: 5158.2275
# Epoch 7, Batch 300/479, Loss: 5120.0254
# Epoch 7, Batch 400/479, Loss: 5166.4834
# Epoch 7/3000, Batches Processed: 479, Train Loss: 5627.0248, Val Loss: 5435.3582
# Starting epoch 8/3000
# Epoch 8, Batch 100/479, Loss: 5226.3291
# Epoch 8, Batch 200/479, Loss: 4676.9326
# Epoch 8, Batch 300/479, Loss: 5053.4077
# Epoch 8, Batch 400/479, Loss: 4590.0581
# Epoch 8/3000, Batches Processed: 479, Train Loss: 5403.5556, Val Loss: 5273.1634
# Starting epoch 9/3000
# Epoch 9, Batch 100/479, Loss: 5293.9111
# Epoch 9, Batch 200/479, Loss: 3983.7822
# Epoch 9, Batch 300/479, Loss: 4772.5913
# Epoch 9, Batch 400/479, Loss: 4525.3672
# Epoch 9/3000, Batches Processed: 479, Train Loss: 5197.5434, Val Loss: 5117.8259
# Starting epoch 10/3000
# Epoch 10, Batch 100/479, Loss: 4574.6494
# Epoch 10, Batch 200/479, Loss: 4607.5591
# Epoch 10, Batch 300/479, Loss: 5542.5601
# Epoch 10, Batch 400/479, Loss: 4749.5166
# Epoch 10/3000, Batches Processed: 479, Train Loss: 5053.1389, Val Loss: 4882.3393
# Starting epoch 11/3000
# Epoch 11, Batch 100/479, Loss: 5048.4180
# Epoch 11, Batch 200/479, Loss: 4639.2197
# Epoch 11, Batch 300/479, Loss: 4727.0752
# Epoch 11, Batch 400/479, Loss: 4110.5732
# Epoch 11/3000, Batches Processed: 479, Train Loss: 4879.3156, Val Loss: 4806.3378
# Starting epoch 12/3000
# Epoch 12, Batch 100/479, Loss: 3610.2305
# Epoch 12, Batch 200/479, Loss: 5215.3584
# Epoch 12, Batch 300/479, Loss: 4796.5020
# Epoch 12, Batch 400/479, Loss: 4701.1753
# Epoch 12/3000, Batches Processed: 479, Train Loss: 4731.4420, Val Loss: 4791.8407
# Starting epoch 13/3000
# Epoch 13, Batch 100/479, Loss: 4357.6299
# Epoch 13, Batch 200/479, Loss: 5425.2817
# Epoch 13, Batch 300/479, Loss: 5122.4541
# Epoch 13, Batch 400/479, Loss: 4768.9102
# Epoch 13/3000, Batches Processed: 479, Train Loss: 4581.5187, Val Loss: 4662.6119
# Starting epoch 14/3000
# Epoch 14, Batch 100/479, Loss: 4152.2290
# Epoch 14, Batch 200/479, Loss: 4555.4146
# Epoch 14, Batch 300/479, Loss: 4717.3062
# Epoch 14, Batch 400/479, Loss: 3900.2786
# Epoch 14/3000, Batches Processed: 479, Train Loss: 4443.6919, Val Loss: 4507.0781
# Starting epoch 15/3000
# Epoch 15, Batch 100/479, Loss: 3252.3384
# Epoch 15, Batch 200/479, Loss: 4268.2554
# Epoch 15, Batch 300/479, Loss: 3777.8726
# Epoch 15, Batch 400/479, Loss: 4370.8560
# Epoch 15/3000, Batches Processed: 479, Train Loss: 4331.9707, Val Loss: 4376.4314
# Starting epoch 16/3000
# Epoch 16, Batch 100/479, Loss: 4501.3062
# Epoch 16, Batch 200/479, Loss: 4497.9912
# Epoch 16, Batch 300/479, Loss: 3950.6436
# Epoch 16, Batch 400/479, Loss: 3845.3884
# Epoch 16/3000, Batches Processed: 479, Train Loss: 4172.8402, Val Loss: 4304.6856
# Starting epoch 17/3000
# Epoch 17, Batch 100/479, Loss: 4243.5479
# Epoch 17, Batch 200/479, Loss: 3342.5876
# Epoch 17, Batch 300/479, Loss: 3543.1860
# Epoch 17, Batch 400/479, Loss: 3971.2710
# Epoch 17/3000, Batches Processed: 479, Train Loss: 4064.1559, Val Loss: 4173.5817
# Starting epoch 18/3000
# Epoch 18, Batch 100/479, Loss: 3956.5315
# Epoch 18, Batch 200/479, Loss: 4567.5122
# Epoch 18, Batch 300/479, Loss: 3175.9075
# Epoch 18, Batch 400/479, Loss: 4378.1016
# Epoch 18/3000, Batches Processed: 479, Train Loss: 3946.6084, Val Loss: 4123.6860
# Starting epoch 19/3000
# Epoch 19, Batch 100/479, Loss: 2855.2996
# Epoch 19, Batch 200/479, Loss: 3491.9529
# Epoch 19, Batch 300/479, Loss: 3827.7458
# Epoch 19, Batch 400/479, Loss: 3814.0325
# Epoch 19/3000, Batches Processed: 479, Train Loss: 3816.1357, Val Loss: 4080.7316
# Starting epoch 20/3000
# Epoch 20, Batch 100/479, Loss: 4095.2498
# Epoch 20, Batch 200/479, Loss: 3682.6436
# Epoch 20, Batch 300/479, Loss: 3096.5925
# Epoch 20, Batch 400/479, Loss: 4478.9297
# Epoch 20/3000, Batches Processed: 479, Train Loss: 3713.3870, Val Loss: 3971.6933
# Starting epoch 21/3000
# Epoch 21, Batch 100/479, Loss: 5430.3970
# Epoch 21, Batch 200/479, Loss: 3656.2107
# Epoch 21, Batch 300/479, Loss: 4207.5605
# Epoch 21, Batch 400/479, Loss: 3096.1130
# Epoch 21/3000, Batches Processed: 479, Train Loss: 3612.0600, Val Loss: 3842.7606
# Starting epoch 22/3000
# Epoch 22, Batch 100/479, Loss: 3429.9573
# Epoch 22, Batch 200/479, Loss: 3371.5618
# Epoch 22, Batch 300/479, Loss: 3751.1838
# Epoch 22, Batch 400/479, Loss: 3887.6624
# Epoch 22/3000, Batches Processed: 479, Train Loss: 3504.0085, Val Loss: 3772.2393
# Starting epoch 23/3000
# Epoch 23, Batch 100/479, Loss: 2755.3257
# Epoch 23, Batch 200/479, Loss: 3076.7878
# Epoch 23, Batch 300/479, Loss: 3262.9785
# Epoch 23, Batch 400/479, Loss: 3066.7683
# Epoch 23/3000, Batches Processed: 479, Train Loss: 3413.4842, Val Loss: 3743.9383
# Starting epoch 24/3000
# Epoch 24, Batch 100/479, Loss: 3563.2432
# Epoch 24, Batch 200/479, Loss: 2910.5896
# Epoch 24, Batch 300/479, Loss: 2818.7754
# Epoch 24, Batch 400/479, Loss: 3067.4656
# Epoch 24/3000, Batches Processed: 479, Train Loss: 3321.1168, Val Loss: 3617.5362
# Starting epoch 25/3000
# Epoch 25, Batch 100/479, Loss: 2998.5737
# Epoch 25, Batch 200/479, Loss: 3029.9697
# Epoch 25, Batch 300/479, Loss: 2453.8552
# Epoch 25, Batch 400/479, Loss: 3441.9102
# Epoch 25/3000, Batches Processed: 479, Train Loss: 3224.1719, Val Loss: 3640.3977
# Starting epoch 26/3000
# Epoch 26, Batch 100/479, Loss: 3080.1265
# Epoch 26, Batch 200/479, Loss: 2910.6360
# Epoch 26, Batch 300/479, Loss: 4400.0796
# Epoch 26, Batch 400/479, Loss: 2896.6714
# Epoch 26/3000, Batches Processed: 479, Train Loss: 3152.3383, Val Loss: 3560.3723
# Starting epoch 27/3000
# Epoch 27, Batch 100/479, Loss: 3306.1016
# Epoch 27, Batch 200/479, Loss: 3148.1382
# Epoch 27, Batch 300/479, Loss: 3277.4717
# Epoch 27, Batch 400/479, Loss: 3421.6775
# Epoch 27/3000, Batches Processed: 479, Train Loss: 3075.1101, Val Loss: 3572.9312
# Starting epoch 28/3000
# Epoch 28, Batch 100/479, Loss: 2983.1960
# Epoch 28, Batch 200/479, Loss: 2581.6602
# Epoch 28, Batch 300/479, Loss: 3321.4995
# Epoch 28, Batch 400/479, Loss: 3197.5972
# Epoch 28/3000, Batches Processed: 479, Train Loss: 2997.0750, Val Loss: 3490.3156
# Starting epoch 29/3000
# Epoch 29, Batch 100/479, Loss: 2921.4978
# Epoch 29, Batch 200/479, Loss: 3368.8994
# Epoch 29, Batch 300/479, Loss: 2617.9185
# Epoch 29, Batch 400/479, Loss: 2723.9221
# Epoch 29/3000, Batches Processed: 479, Train Loss: 2922.0063, Val Loss: 3363.7499
# Starting epoch 30/3000
# Epoch 30, Batch 100/479, Loss: 2336.5710
# Epoch 30, Batch 200/479, Loss: 2246.7927
# Epoch 30, Batch 300/479, Loss: 2915.3931
# Epoch 30, Batch 400/479, Loss: 3158.5542
# Epoch 30/3000, Batches Processed: 479, Train Loss: 2848.9542, Val Loss: 3357.0149
# Starting epoch 31/3000
# Epoch 31, Batch 100/479, Loss: 2294.2698
# Epoch 31, Batch 200/479, Loss: 2833.6062
# Epoch 31, Batch 300/479, Loss: 2303.3005
# Epoch 31, Batch 400/479, Loss: 2888.6858
# Epoch 31/3000, Batches Processed: 479, Train Loss: 2768.6353, Val Loss: 3261.0384
# Starting epoch 32/3000
# Epoch 32, Batch 100/479, Loss: 3983.2927
# Epoch 32, Batch 200/479, Loss: 2367.4358
# Epoch 32, Batch 300/479, Loss: 2984.7756
# Epoch 32, Batch 400/479, Loss: 2711.5823
# Epoch 32/3000, Batches Processed: 479, Train Loss: 2704.9374, Val Loss: 3237.7296
# Starting epoch 33/3000
# Epoch 33, Batch 100/479, Loss: 2874.3123
# Epoch 33, Batch 200/479, Loss: 2776.2361
# Epoch 33, Batch 300/479, Loss: 2407.2827
# Epoch 33, Batch 400/479, Loss: 2324.2681
# Epoch 33/3000, Batches Processed: 479, Train Loss: 2659.2612, Val Loss: 3149.2544
# Starting epoch 34/3000
# Epoch 34, Batch 100/479, Loss: 2720.1304
# Epoch 34, Batch 200/479, Loss: 2313.7410
# Epoch 34, Batch 300/479, Loss: 2713.0188
# Epoch 34, Batch 400/479, Loss: 2229.6643
# Epoch 34/3000, Batches Processed: 479, Train Loss: 2595.9227, Val Loss: 3087.6787
# Starting epoch 35/3000
# Epoch 35, Batch 100/479, Loss: 2322.8342
# Epoch 35, Batch 200/479, Loss: 2778.4065
# Epoch 35, Batch 300/479, Loss: 2257.8184
# Epoch 35, Batch 400/479, Loss: 2606.6414
# Epoch 35/3000, Batches Processed: 479, Train Loss: 2523.6966, Val Loss: 3025.5094
# Starting epoch 36/3000
# Epoch 36, Batch 100/479, Loss: 2515.4456
# Epoch 36, Batch 200/479, Loss: 2317.3457
# Epoch 36, Batch 300/479, Loss: 2551.6306
# Epoch 36, Batch 400/479, Loss: 2327.6267
# Epoch 36/3000, Batches Processed: 479, Train Loss: 2477.3489, Val Loss: 3032.9102
# Starting epoch 37/3000
# Epoch 37, Batch 100/479, Loss: 2379.1409
# Epoch 37, Batch 200/479, Loss: 2711.9265
# Epoch 37, Batch 300/479, Loss: 2536.3364
# Epoch 37, Batch 400/479, Loss: 2377.2371
# Epoch 37/3000, Batches Processed: 479, Train Loss: 2420.6863, Val Loss: 2970.3157
# Starting epoch 38/3000
# Epoch 38, Batch 100/479, Loss: 1834.1913
# Epoch 38, Batch 200/479, Loss: 1686.5443
# Epoch 38, Batch 300/479, Loss: 2773.9551
# Epoch 38, Batch 400/479, Loss: 2275.5547
# Epoch 38/3000, Batches Processed: 479, Train Loss: 2379.7069, Val Loss: 2960.9561
# Starting epoch 39/3000
# Epoch 39, Batch 100/479, Loss: 1804.0037
# Epoch 39, Batch 200/479, Loss: 1794.3834
# Epoch 39, Batch 300/479, Loss: 2871.6165
# Epoch 39, Batch 400/479, Loss: 2093.1860
# Epoch 39/3000, Batches Processed: 479, Train Loss: 2322.3423, Val Loss: 2896.3683
# Starting epoch 40/3000
# Epoch 40, Batch 100/479, Loss: 2126.6711
# Epoch 40, Batch 200/479, Loss: 2034.4531
# Epoch 40, Batch 300/479, Loss: 2103.0696
# Epoch 40, Batch 400/479, Loss: 1707.0110
# Epoch 40/3000, Batches Processed: 479, Train Loss: 2278.3976, Val Loss: 2896.1525
# Starting epoch 41/3000
# Epoch 41, Batch 100/479, Loss: 2603.8955
# Epoch 41, Batch 200/479, Loss: 2133.1501
# Epoch 41, Batch 300/479, Loss: 2096.4580
# Epoch 41, Batch 400/479, Loss: 2289.1467
# Epoch 41/3000, Batches Processed: 479, Train Loss: 2219.7943, Val Loss: 2796.5022
# Starting epoch 42/3000
# Epoch 42, Batch 100/479, Loss: 2057.9995
# Epoch 42, Batch 200/479, Loss: 2186.1494
# Epoch 42, Batch 300/479, Loss: 2237.5164
# Epoch 42, Batch 400/479, Loss: 2035.4463
# Epoch 42/3000, Batches Processed: 479, Train Loss: 2178.7878, Val Loss: 2773.7655
# Starting epoch 43/3000
# Epoch 43, Batch 100/479, Loss: 1626.4280
# Epoch 43, Batch 200/479, Loss: 2283.6038
# Epoch 43, Batch 300/479, Loss: 1933.0294
# Epoch 43, Batch 400/479, Loss: 2062.2690
# Epoch 43/3000, Batches Processed: 479, Train Loss: 2147.8308, Val Loss: 2719.8593
# Starting epoch 44/3000
# Epoch 44, Batch 100/479, Loss: 2010.4178
# Epoch 44, Batch 200/479, Loss: 1932.1543
# Epoch 44, Batch 300/479, Loss: 2342.1169
# Epoch 44, Batch 400/479, Loss: 2187.1714
# Epoch 44/3000, Batches Processed: 479, Train Loss: 2096.0904, Val Loss: 2683.6390
# Starting epoch 45/3000
# Epoch 45, Batch 100/479, Loss: 1696.1689
# Epoch 45, Batch 200/479, Loss: 2247.6379
# Epoch 45, Batch 300/479, Loss: 1839.7649
# Epoch 45, Batch 400/479, Loss: 1814.8080
# Epoch 45/3000, Batches Processed: 479, Train Loss: 2058.0185, Val Loss: 2684.1820
# Starting epoch 46/3000
# Epoch 46, Batch 100/479, Loss: 1845.5939
# Epoch 46, Batch 200/479, Loss: 1925.6302
# Epoch 46, Batch 300/479, Loss: 1809.1022
# Epoch 46, Batch 400/479, Loss: 2233.3530
# Epoch 46/3000, Batches Processed: 479, Train Loss: 2016.1569, Val Loss: 2623.4390
# Starting epoch 47/3000
# Epoch 47, Batch 100/479, Loss: 1740.4019
# Epoch 47, Batch 200/479, Loss: 1512.7854
# Epoch 47, Batch 300/479, Loss: 1571.1041
# Epoch 47, Batch 400/479, Loss: 1910.9351
# Epoch 47/3000, Batches Processed: 479, Train Loss: 1987.2849, Val Loss: 2607.3894
# Starting epoch 48/3000
# Epoch 48, Batch 100/479, Loss: 2048.5059
# Epoch 48, Batch 200/479, Loss: 2251.6919
# Epoch 48, Batch 300/479, Loss: 1907.0034
# Epoch 48, Batch 400/479, Loss: 1480.1740
# Epoch 48/3000, Batches Processed: 479, Train Loss: 1951.3215, Val Loss: 2628.3955
# Starting epoch 49/3000
# Epoch 49, Batch 100/479, Loss: 2236.3301
# Epoch 49, Batch 200/479, Loss: 1651.7042
# Epoch 49, Batch 300/479, Loss: 1808.1244
# Epoch 49, Batch 400/479, Loss: 2076.6338
# Epoch 49/3000, Batches Processed: 479, Train Loss: 1915.3391, Val Loss: 2551.4364
# Starting epoch 50/3000
# Epoch 50, Batch 100/479, Loss: 1758.4241
# Epoch 50, Batch 200/479, Loss: 1620.9828
# Epoch 50, Batch 300/479, Loss: 1943.0699
# Epoch 50, Batch 400/479, Loss: 1792.0514
# Epoch 50/3000, Batches Processed: 479, Train Loss: 1877.5358, Val Loss: 2517.1597
# Starting epoch 51/3000
# Epoch 51, Batch 100/479, Loss: 2276.6313
# Epoch 51, Batch 200/479, Loss: 1962.1333
# Epoch 51, Batch 300/479, Loss: 1691.6499
# Epoch 51, Batch 400/479, Loss: 1519.7043
# Epoch 51/3000, Batches Processed: 479, Train Loss: 1846.6470, Val Loss: 2541.2197
# Starting epoch 52/3000
# Epoch 52, Batch 100/479, Loss: 1946.8396
# Epoch 52, Batch 200/479, Loss: 2270.2219
# Epoch 52, Batch 300/479, Loss: 1725.4340
# Epoch 52, Batch 400/479, Loss: 1556.4224
# Epoch 52/3000, Batches Processed: 479, Train Loss: 1815.4399, Val Loss: 2467.3219
# Starting epoch 53/3000
# Epoch 53, Batch 100/479, Loss: 1824.5681
# Epoch 53, Batch 200/479, Loss: 1640.0079
# Epoch 53, Batch 300/479, Loss: 1955.3435
# Epoch 53, Batch 400/479, Loss: 1597.4114
# Epoch 53/3000, Batches Processed: 479, Train Loss: 1784.5500, Val Loss: 2443.6967
# Starting epoch 54/3000
# Epoch 54, Batch 100/479, Loss: 1411.4420
# Epoch 54, Batch 200/479, Loss: 1432.1067
# Epoch 54, Batch 300/479, Loss: 1955.4014
# Epoch 54, Batch 400/479, Loss: 1769.5315
# Epoch 54/3000, Batches Processed: 479, Train Loss: 1751.2604, Val Loss: 2469.3169
# Starting epoch 55/3000
# Epoch 55, Batch 100/479, Loss: 1244.4907
# Epoch 55, Batch 200/479, Loss: 1395.2510
# Epoch 55, Batch 300/479, Loss: 2045.7737
# Epoch 55, Batch 400/479, Loss: 1356.2377
# Epoch 55/3000, Batches Processed: 479, Train Loss: 1730.4171, Val Loss: 2406.4156
# Starting epoch 56/3000
# Epoch 56, Batch 100/479, Loss: 1925.9464
# Epoch 56, Batch 200/479, Loss: 2190.4512
# Epoch 56, Batch 300/479, Loss: 1556.1892
# Epoch 56, Batch 400/479, Loss: 1889.8938
# Epoch 56/3000, Batches Processed: 479, Train Loss: 1713.2618, Val Loss: 2367.1135
# Starting epoch 57/3000
# Epoch 57, Batch 100/479, Loss: 1420.8680
# Epoch 57, Batch 200/479, Loss: 2327.5811
# Epoch 57, Batch 300/479, Loss: 1546.1842
# Epoch 57, Batch 400/479, Loss: 1639.6320
# Epoch 57/3000, Batches Processed: 479, Train Loss: 1665.6441, Val Loss: 2391.3561
# Starting epoch 58/3000
# Epoch 58, Batch 100/479, Loss: 1670.0253
# Epoch 58, Batch 200/479, Loss: 1493.5765
# Epoch 58, Batch 300/479, Loss: 1258.6796
# Epoch 58, Batch 400/479, Loss: 1525.1240
# Epoch 58/3000, Batches Processed: 479, Train Loss: 1651.0265, Val Loss: 2348.5421
# Starting epoch 59/3000
# Epoch 59, Batch 100/479, Loss: 1800.7028
# Epoch 59, Batch 200/479, Loss: 1496.2563
# Epoch 59, Batch 300/479, Loss: 1639.1138
# Epoch 59, Batch 400/479, Loss: 1946.3824
# Epoch 59/3000, Batches Processed: 479, Train Loss: 1619.5096, Val Loss: 2324.9132
# Starting epoch 60/3000
# Epoch 60, Batch 100/479, Loss: 1757.4110
# Epoch 60, Batch 200/479, Loss: 1573.4550
# Epoch 60, Batch 300/479, Loss: 1591.1880
# Epoch 60, Batch 400/479, Loss: 1552.5780
# Epoch 60/3000, Batches Processed: 479, Train Loss: 1604.4454, Val Loss: 2320.9028
# Starting epoch 61/3000
# Epoch 61, Batch 100/479, Loss: 1446.3154
# Epoch 61, Batch 200/479, Loss: 1586.4954
# Epoch 61, Batch 300/479, Loss: 1842.8082
# Epoch 61, Batch 400/479, Loss: 1402.6250
# Epoch 61/3000, Batches Processed: 479, Train Loss: 1577.3510, Val Loss: 2305.8148
# Starting epoch 62/3000
# Epoch 62, Batch 100/479, Loss: 1596.0028
# Epoch 62, Batch 200/479, Loss: 1973.6593
# Epoch 62, Batch 300/479, Loss: 1168.5892
# Epoch 62, Batch 400/479, Loss: 1427.0908
# Epoch 62/3000, Batches Processed: 479, Train Loss: 1554.2822, Val Loss: 2289.1919
# Starting epoch 63/3000
# Epoch 63, Batch 100/479, Loss: 1569.9818
# Epoch 63, Batch 200/479, Loss: 1521.6820
# Epoch 63, Batch 300/479, Loss: 1135.7646
# Epoch 63, Batch 400/479, Loss: 1459.6316
# Epoch 63/3000, Batches Processed: 479, Train Loss: 1538.3050, Val Loss: 2248.8323
# Starting epoch 64/3000
# Epoch 64, Batch 100/479, Loss: 1144.0844
# Epoch 64, Batch 200/479, Loss: 1732.6184
# Epoch 64, Batch 300/479, Loss: 1521.8713
# Epoch 64, Batch 400/479, Loss: 1463.2664
# Epoch 64/3000, Batches Processed: 479, Train Loss: 1511.8155, Val Loss: 2209.9525
# Starting epoch 65/3000
# Epoch 65, Batch 100/479, Loss: 1479.8105
# Epoch 65, Batch 200/479, Loss: 1464.2773
# Epoch 65, Batch 300/479, Loss: 1518.4543
# Epoch 65, Batch 400/479, Loss: 1438.3016
# Epoch 65/3000, Batches Processed: 479, Train Loss: 1487.0539, Val Loss: 2186.2493
# Starting epoch 66/3000
# Epoch 66, Batch 100/479, Loss: 1311.6428
# Epoch 66, Batch 200/479, Loss: 1075.1481
# Epoch 66, Batch 300/479, Loss: 1436.1294
# Epoch 66, Batch 400/479, Loss: 1417.9165
# Epoch 66/3000, Batches Processed: 479, Train Loss: 1473.6311, Val Loss: 2202.9143
# Starting epoch 67/3000
# Epoch 67, Batch 100/479, Loss: 1168.9259
# Epoch 67, Batch 200/479, Loss: 1099.5573
# Epoch 67, Batch 300/479, Loss: 1537.0220
# Epoch 67, Batch 400/479, Loss: 1541.8987
# Epoch 67/3000, Batches Processed: 479, Train Loss: 1450.9734, Val Loss: 2184.5977
# Starting epoch 68/3000
# Epoch 68, Batch 100/479, Loss: 1623.3019
# Epoch 68, Batch 200/479, Loss: 1307.9222
# Epoch 68, Batch 300/479, Loss: 1425.9744
# Epoch 68, Batch 400/479, Loss: 1364.0387
# Epoch 68/3000, Batches Processed: 479, Train Loss: 1434.8646, Val Loss: 2186.6433
# Starting epoch 69/3000
# Epoch 69, Batch 100/479, Loss: 1365.6917
# Epoch 69, Batch 200/479, Loss: 1516.5347
# Epoch 69, Batch 300/479, Loss: 1478.7278
# Epoch 69, Batch 400/479, Loss: 1137.5917
# Epoch 69/3000, Batches Processed: 479, Train Loss: 1416.3095, Val Loss: 2135.5855
# Starting epoch 70/3000
# Epoch 70, Batch 100/479, Loss: 1193.9818
# Epoch 70, Batch 200/479, Loss: 1382.4858
# Epoch 70, Batch 300/479, Loss: 1785.2924
# Epoch 70, Batch 400/479, Loss: 1381.9374
# Epoch 70/3000, Batches Processed: 479, Train Loss: 1396.7863, Val Loss: 2152.0766
# Starting epoch 71/3000
# Epoch 71, Batch 100/479, Loss: 1445.9513
# Epoch 71, Batch 200/479, Loss: 1181.0011
# Epoch 71, Batch 300/479, Loss: 1397.8522
# Epoch 71, Batch 400/479, Loss: 1829.9453
# Epoch 71/3000, Batches Processed: 479, Train Loss: 1384.2569, Val Loss: 2140.6199
# Starting epoch 72/3000
# Epoch 72, Batch 100/479, Loss: 1236.6289
# Epoch 72, Batch 200/479, Loss: 1390.2526
# Epoch 72, Batch 300/479, Loss: 1823.5969
# Epoch 72, Batch 400/479, Loss: 1268.4070
# Epoch 72/3000, Batches Processed: 479, Train Loss: 1369.5070, Val Loss: 2100.4184
# Starting epoch 73/3000
# Epoch 73, Batch 100/479, Loss: 1024.6688
# Epoch 73, Batch 200/479, Loss: 1247.6833
# Epoch 73, Batch 300/479, Loss: 1509.1322
# Epoch 73, Batch 400/479, Loss: 1270.8708
# Epoch 73/3000, Batches Processed: 479, Train Loss: 1355.7790, Val Loss: 2069.1632
# Starting epoch 74/3000
# Epoch 74, Batch 100/479, Loss: 1301.9342
# Epoch 74, Batch 200/479, Loss: 1369.4924
# Epoch 74, Batch 300/479, Loss: 1424.7809
# Epoch 74, Batch 400/479, Loss: 1444.9963
# Epoch 74/3000, Batches Processed: 479, Train Loss: 1336.3246, Val Loss: 2057.7078
# Starting epoch 75/3000
# Epoch 75, Batch 100/479, Loss: 1205.7456
# Epoch 75, Batch 200/479, Loss: 1431.4202
# Epoch 75, Batch 300/479, Loss: 1265.7949
# Epoch 75, Batch 400/479, Loss: 1003.7965
# Epoch 75/3000, Batches Processed: 479, Train Loss: 1319.7736, Val Loss: 2047.0585
# Starting epoch 76/3000
# Epoch 76, Batch 100/479, Loss: 1130.3959
# Epoch 76, Batch 200/479, Loss: 1065.0431
# Epoch 76, Batch 300/479, Loss: 1226.1880
# Epoch 76, Batch 400/479, Loss: 1151.2914
# Epoch 76/3000, Batches Processed: 479, Train Loss: 1305.7732, Val Loss: 2068.1265
# Starting epoch 77/3000
# Epoch 77, Batch 100/479, Loss: 1155.0497
# Epoch 77, Batch 200/479, Loss: 1332.4525
# Epoch 77, Batch 300/479, Loss: 1146.5555
# Epoch 77, Batch 400/479, Loss: 1247.0804
# Epoch 77/3000, Batches Processed: 479, Train Loss: 1295.3300, Val Loss: 2025.8332
# Starting epoch 78/3000
# Epoch 78, Batch 100/479, Loss: 1683.5394
# Epoch 78, Batch 200/479, Loss: 1120.2736
# Epoch 78, Batch 300/479, Loss: 1092.4908
# Epoch 78, Batch 400/479, Loss: 1166.5182
# Epoch 78/3000, Batches Processed: 479, Train Loss: 1275.3920, Val Loss: 2037.4368
# Starting epoch 79/3000
# Epoch 79, Batch 100/479, Loss: 1715.5411
# Epoch 79, Batch 200/479, Loss: 1426.5653
# Epoch 79, Batch 300/479, Loss: 1309.7465
# Epoch 79, Batch 400/479, Loss: 1266.1006
# Epoch 79/3000, Batches Processed: 479, Train Loss: 1257.5450, Val Loss: 2020.4264
# Starting epoch 80/3000
# Epoch 80, Batch 100/479, Loss: 988.6864
# Epoch 80, Batch 200/479, Loss: 1190.6040
# Epoch 80, Batch 300/479, Loss: 1265.7197
# Epoch 80, Batch 400/479, Loss: 1247.4794
# Epoch 80/3000, Batches Processed: 479, Train Loss: 1256.6089, Val Loss: 2024.5748
# Starting epoch 81/3000
# Epoch 81, Batch 100/479, Loss: 968.2320
# Epoch 81, Batch 200/479, Loss: 1400.0704
# Epoch 81, Batch 300/479, Loss: 1085.8121
# Epoch 81, Batch 400/479, Loss: 1379.5631
# Epoch 81/3000, Batches Processed: 479, Train Loss: 1238.3887, Val Loss: 2004.7424
# Starting epoch 82/3000
# Epoch 82, Batch 100/479, Loss: 1057.1587
# Epoch 82, Batch 200/479, Loss: 1081.9995
# Epoch 82, Batch 300/479, Loss: 1169.7706
# Epoch 82, Batch 400/479, Loss: 1153.9188
# Epoch 82/3000, Batches Processed: 479, Train Loss: 1220.1404, Val Loss: 1977.8545
# Starting epoch 83/3000
# Epoch 83, Batch 100/479, Loss: 1320.0420
# Epoch 83, Batch 200/479, Loss: 1128.4037
# Epoch 83, Batch 300/479, Loss: 1189.0317
# Epoch 83, Batch 400/479, Loss: 1177.2877
# Epoch 83/3000, Batches Processed: 479, Train Loss: 1216.2262, Val Loss: 1974.8132
# Starting epoch 84/3000
# Epoch 84, Batch 100/479, Loss: 1267.3779
# Epoch 84, Batch 200/479, Loss: 1304.8835
# Epoch 84, Batch 300/479, Loss: 988.1686
# Epoch 84, Batch 400/479, Loss: 1203.4318
# Epoch 84/3000, Batches Processed: 479, Train Loss: 1207.7718, Val Loss: 1935.8239
# Starting epoch 85/3000
# Epoch 85, Batch 100/479, Loss: 1004.6924
# Epoch 85, Batch 200/479, Loss: 1171.5736
# Epoch 85, Batch 300/479, Loss: 1248.4661
# Epoch 85, Batch 400/479, Loss: 1105.8326
# Epoch 85/3000, Batches Processed: 479, Train Loss: 1195.3945, Val Loss: 1935.4919
# Starting epoch 86/3000
# Epoch 86, Batch 100/479, Loss: 1612.5599
# Epoch 86, Batch 200/479, Loss: 1300.0066
# Epoch 86, Batch 300/479, Loss: 1034.9070
# Epoch 86, Batch 400/479, Loss: 1332.9430
# Epoch 86/3000, Batches Processed: 479, Train Loss: 1190.6265, Val Loss: 1939.3545
# Starting epoch 87/3000
# Epoch 87, Batch 100/479, Loss: 1338.3506
# Epoch 87, Batch 200/479, Loss: 1005.2363
# Epoch 87, Batch 300/479, Loss: 1445.1302
# Epoch 87, Batch 400/479, Loss: 1025.9363
# Epoch 87/3000, Batches Processed: 479, Train Loss: 1178.0528, Val Loss: 1926.6745
# Starting epoch 88/3000
# Epoch 88, Batch 100/479, Loss: 1069.5005
# Epoch 88, Batch 200/479, Loss: 1161.7144
# Epoch 88, Batch 300/479, Loss: 1078.5044
# Epoch 88, Batch 400/479, Loss: 1132.5129
# Epoch 88/3000, Batches Processed: 479, Train Loss: 1161.6723, Val Loss: 1914.5998
# Starting epoch 89/3000
# Epoch 89, Batch 100/479, Loss: 1011.1470
# Epoch 89, Batch 200/479, Loss: 1071.8461
# Epoch 89, Batch 300/479, Loss: 1172.1353
# Epoch 89, Batch 400/479, Loss: 1257.9377
# Epoch 89/3000, Batches Processed: 479, Train Loss: 1148.2493, Val Loss: 1930.3664
# Starting epoch 90/3000
# Epoch 90, Batch 100/479, Loss: 1106.0454
# Epoch 90, Batch 200/479, Loss: 1097.2910
# Epoch 90, Batch 300/479, Loss: 1047.4010
# Epoch 90, Batch 400/479, Loss: 900.4943
# Epoch 90/3000, Batches Processed: 479, Train Loss: 1138.9611, Val Loss: 1923.4169
# Starting epoch 91/3000
# Epoch 91, Batch 100/479, Loss: 972.1299
# Epoch 91, Batch 200/479, Loss: 1079.9165
# Epoch 91, Batch 300/479, Loss: 1043.2279
# Epoch 91, Batch 400/479, Loss: 955.5858
# Epoch 91/3000, Batches Processed: 479, Train Loss: 1129.8261, Val Loss: 1894.4728
# Starting epoch 92/3000
# Epoch 92, Batch 100/479, Loss: 1160.8877
# Epoch 92, Batch 200/479, Loss: 1373.6545
# Epoch 92, Batch 300/479, Loss: 1355.5520
# Epoch 92, Batch 400/479, Loss: 950.0251
# Epoch 92/3000, Batches Processed: 479, Train Loss: 1122.6514, Val Loss: 1880.5703
# Starting epoch 93/3000
# Epoch 93, Batch 100/479, Loss: 1110.7252
# Epoch 93, Batch 200/479, Loss: 1097.3602
# Epoch 93, Batch 300/479, Loss: 1255.4875
# Epoch 93, Batch 400/479, Loss: 1008.2853
# Epoch 93/3000, Batches Processed: 479, Train Loss: 1109.2271, Val Loss: 1886.1434
# Starting epoch 94/3000
# Epoch 94, Batch 100/479, Loss: 1073.9705
# Epoch 94, Batch 200/479, Loss: 979.9395
# Epoch 94, Batch 300/479, Loss: 960.0037
# Epoch 94, Batch 400/479, Loss: 798.8397
# Epoch 94/3000, Batches Processed: 479, Train Loss: 1099.5962, Val Loss: 1901.3254
# Starting epoch 95/3000
# Epoch 95, Batch 100/479, Loss: 1312.1971
# Epoch 95, Batch 200/479, Loss: 825.7042
# Epoch 95, Batch 300/479, Loss: 1134.2275
# Epoch 95, Batch 400/479, Loss: 935.7548
# Epoch 95/3000, Batches Processed: 479, Train Loss: 1096.8769, Val Loss: 1876.9528
# Starting epoch 96/3000
# Epoch 96, Batch 100/479, Loss: 1219.5590
# Epoch 96, Batch 200/479, Loss: 922.8193
# Epoch 96, Batch 300/479, Loss: 919.1163
# Epoch 96, Batch 400/479, Loss: 1243.7986
# Epoch 96/3000, Batches Processed: 479, Train Loss: 1084.3252, Val Loss: 1850.1409
# Starting epoch 97/3000
# Epoch 97, Batch 100/479, Loss: 1046.4089
# Epoch 97, Batch 200/479, Loss: 1331.3082
# Epoch 97, Batch 300/479, Loss: 1409.1996
# Epoch 97, Batch 400/479, Loss: 1221.1486
# Epoch 97/3000, Batches Processed: 479, Train Loss: 1083.9228, Val Loss: 1843.9384
# Starting epoch 98/3000
# Epoch 98, Batch 100/479, Loss: 1484.8735
# Epoch 98, Batch 200/479, Loss: 1049.0476
# Epoch 98, Batch 300/479, Loss: 996.8856
# Epoch 98, Batch 400/479, Loss: 1091.3807
# Epoch 98/3000, Batches Processed: 479, Train Loss: 1068.9172, Val Loss: 1818.5813
# Starting epoch 99/3000
# Epoch 99, Batch 100/479, Loss: 1003.4868
# Epoch 99, Batch 200/479, Loss: 955.7644
# Epoch 99, Batch 300/479, Loss: 1134.8088
# Epoch 99, Batch 400/479, Loss: 1440.4420
# Epoch 99/3000, Batches Processed: 479, Train Loss: 1062.9341, Val Loss: 1848.4248
# Starting epoch 100/3000
# Epoch 100, Batch 100/479, Loss: 998.7942
# Epoch 100, Batch 200/479, Loss: 937.9401
# Epoch 100, Batch 300/479, Loss: 1069.2349
# Epoch 100, Batch 400/479, Loss: 898.7264
# Epoch 100/3000, Batches Processed: 479, Train Loss: 1055.7873, Val Loss: 1813.1248
# Starting epoch 101/3000
# Epoch 101, Batch 100/479, Loss: 896.4769
# Epoch 101, Batch 200/479, Loss: 852.0304
# Epoch 101, Batch 300/479, Loss: 1162.4750
# Epoch 101, Batch 400/479, Loss: 932.5991
# Epoch 101/3000, Batches Processed: 479, Train Loss: 1041.3989, Val Loss: 1825.3110
# Starting epoch 102/3000
# Epoch 102, Batch 100/479, Loss: 1066.0262
# Epoch 102, Batch 200/479, Loss: 969.7868
# Epoch 102, Batch 300/479, Loss: 1192.0673
# Epoch 102, Batch 400/479, Loss: 1220.6097
# Epoch 102/3000, Batches Processed: 479, Train Loss: 1042.3729, Val Loss: 1793.8755
# Starting epoch 103/3000
# Epoch 103, Batch 100/479, Loss: 1119.4352
# Epoch 103, Batch 200/479, Loss: 933.3949
# Epoch 103, Batch 300/479, Loss: 992.0787
# Epoch 103, Batch 400/479, Loss: 847.3271
# Epoch 103/3000, Batches Processed: 479, Train Loss: 1040.1661, Val Loss: 1813.7163
# Starting epoch 104/3000
# Epoch 104, Batch 100/479, Loss: 908.8246
# Epoch 104, Batch 200/479, Loss: 942.3638
# Epoch 104, Batch 300/479, Loss: 947.4589
# Epoch 104, Batch 400/479, Loss: 982.7824
# Epoch 104/3000, Batches Processed: 479, Train Loss: 1024.9212, Val Loss: 1816.1029
# Starting epoch 105/3000
# Epoch 105, Batch 100/479, Loss: 1085.6815
# Epoch 105, Batch 200/479, Loss: 1213.8042
# Epoch 105, Batch 300/479, Loss: 1009.0760
# Epoch 105, Batch 400/479, Loss: 1041.6090
# Epoch 105/3000, Batches Processed: 479, Train Loss: 1017.0346, Val Loss: 1786.5305
# Starting epoch 106/3000
# Epoch 106, Batch 100/479, Loss: 1338.4968
# Epoch 106, Batch 200/479, Loss: 981.6961
# Epoch 106, Batch 300/479, Loss: 1117.0626
# Epoch 106, Batch 400/479, Loss: 1101.9930
# Epoch 106/3000, Batches Processed: 479, Train Loss: 1011.5214, Val Loss: 1790.2808
# Starting epoch 107/3000
# Epoch 107, Batch 100/479, Loss: 999.6530
# Epoch 107, Batch 200/479, Loss: 795.1356
# Epoch 107, Batch 300/479, Loss: 959.3283
# Epoch 107, Batch 400/479, Loss: 972.4095
# Epoch 107/3000, Batches Processed: 479, Train Loss: 1002.8049, Val Loss: 1764.5233
# Starting epoch 108/3000
# Epoch 108, Batch 100/479, Loss: 1078.6194
# Epoch 108, Batch 200/479, Loss: 991.3873
# Epoch 108, Batch 300/479, Loss: 1001.3089
# Epoch 108, Batch 400/479, Loss: 1014.1720
# Epoch 108/3000, Batches Processed: 479, Train Loss: 989.6636, Val Loss: 1776.8545
# Starting epoch 109/3000
# Epoch 109, Batch 100/479, Loss: 1174.9285
# Epoch 109, Batch 200/479, Loss: 878.7079
# Epoch 109, Batch 300/479, Loss: 999.5686
# Epoch 109, Batch 400/479, Loss: 923.2592
# Epoch 109/3000, Batches Processed: 479, Train Loss: 993.3778, Val Loss: 1757.3771
# Starting epoch 110/3000
# Epoch 110, Batch 100/479, Loss: 1038.6807
# Epoch 110, Batch 200/479, Loss: 792.0989
# Epoch 110, Batch 300/479, Loss: 813.9415
# Epoch 110, Batch 400/479, Loss: 1005.2837
# Epoch 110/3000, Batches Processed: 479, Train Loss: 984.3944, Val Loss: 1771.5064
# Starting epoch 111/3000
# Epoch 111, Batch 100/479, Loss: 1101.5167
# Epoch 111, Batch 200/479, Loss: 994.0511
# Epoch 111, Batch 300/479, Loss: 1114.3533
# Epoch 111, Batch 400/479, Loss: 1039.5591
# Epoch 111/3000, Batches Processed: 479, Train Loss: 978.6749, Val Loss: 1745.6480
# Starting epoch 112/3000
# Epoch 112, Batch 100/479, Loss: 1035.0282
# Epoch 112, Batch 200/479, Loss: 1005.4725
# Epoch 112, Batch 300/479, Loss: 1139.8594
# Epoch 112, Batch 400/479, Loss: 982.2133
# Epoch 112/3000, Batches Processed: 479, Train Loss: 970.3975, Val Loss: 1746.8801
# Starting epoch 113/3000
# Epoch 113, Batch 100/479, Loss: 963.4150
# Epoch 113, Batch 200/479, Loss: 964.1177
# Epoch 113, Batch 300/479, Loss: 947.6340
# Epoch 113, Batch 400/479, Loss: 1103.2222
# Epoch 113/3000, Batches Processed: 479, Train Loss: 962.0877, Val Loss: 1752.6545
# Starting epoch 114/3000
# Epoch 114, Batch 100/479, Loss: 1082.1661
# Epoch 114, Batch 200/479, Loss: 841.7648
# Epoch 114, Batch 300/479, Loss: 836.3897
# Epoch 114, Batch 400/479, Loss: 925.9758
# Epoch 114/3000, Batches Processed: 479, Train Loss: 961.5890, Val Loss: 1745.2605
# Starting epoch 115/3000
# Epoch 115, Batch 100/479, Loss: 869.6422
# Epoch 115, Batch 200/479, Loss: 919.6550
# Epoch 115, Batch 300/479, Loss: 757.2023
# Epoch 115, Batch 400/479, Loss: 820.5082
# Epoch 115/3000, Batches Processed: 479, Train Loss: 956.2178, Val Loss: 1739.0481
# Starting epoch 116/3000
# Epoch 116, Batch 100/479, Loss: 937.3383
# Epoch 116, Batch 200/479, Loss: 755.5323
# Epoch 116, Batch 300/479, Loss: 928.7521
# Epoch 116, Batch 400/479, Loss: 931.6424
# Epoch 116/3000, Batches Processed: 479, Train Loss: 947.4354, Val Loss: 1727.8048
# Starting epoch 117/3000
# Epoch 117, Batch 100/479, Loss: 784.1864
# Epoch 117, Batch 200/479, Loss: 1094.0531
# Epoch 117, Batch 300/479, Loss: 898.9982
# Epoch 117, Batch 400/479, Loss: 1029.3882
# Epoch 117/3000, Batches Processed: 479, Train Loss: 940.0317, Val Loss: 1745.1922
# Starting epoch 118/3000
# Epoch 118, Batch 100/479, Loss: 893.9524
# Epoch 118, Batch 200/479, Loss: 1060.5243
# Epoch 118, Batch 300/479, Loss: 835.7964
# Epoch 118, Batch 400/479, Loss: 806.9249
# Epoch 118/3000, Batches Processed: 479, Train Loss: 937.7071, Val Loss: 1716.9842
# Starting epoch 119/3000
# Epoch 119, Batch 100/479, Loss: 977.9513
# Epoch 119, Batch 200/479, Loss: 896.8055
# Epoch 119, Batch 300/479, Loss: 803.3957
# Epoch 119, Batch 400/479, Loss: 1076.7729
# Epoch 119/3000, Batches Processed: 479, Train Loss: 932.5617, Val Loss: 1711.9330
# Starting epoch 120/3000
# Epoch 120, Batch 100/479, Loss: 933.9991
# Epoch 120, Batch 200/479, Loss: 862.2485
# Epoch 120, Batch 300/479, Loss: 848.0176
# Epoch 120, Batch 400/479, Loss: 1119.7467
# Epoch 120/3000, Batches Processed: 479, Train Loss: 928.3285, Val Loss: 1693.7565
# Starting epoch 121/3000
# Epoch 121, Batch 100/479, Loss: 1097.1804
# Epoch 121, Batch 200/479, Loss: 866.1194
# Epoch 121, Batch 300/479, Loss: 1062.7383
# Epoch 121, Batch 400/479, Loss: 768.1930
# Epoch 121/3000, Batches Processed: 479, Train Loss: 919.5378, Val Loss: 1711.1084
# Starting epoch 122/3000
# Epoch 122, Batch 100/479, Loss: 1178.3325
# Epoch 122, Batch 200/479, Loss: 1074.5189
# Epoch 122, Batch 300/479, Loss: 942.4008
# Epoch 122, Batch 400/479, Loss: 947.0511
# Epoch 122/3000, Batches Processed: 479, Train Loss: 914.9267, Val Loss: 1701.8722
# Starting epoch 123/3000
# Epoch 123, Batch 100/479, Loss: 827.3317
# Epoch 123, Batch 200/479, Loss: 825.0507
# Epoch 123, Batch 300/479, Loss: 978.1678
# Epoch 123, Batch 400/479, Loss: 906.6242
# Epoch 123/3000, Batches Processed: 479, Train Loss: 912.9343, Val Loss: 1708.6636
# Starting epoch 124/3000
# Epoch 124, Batch 100/479, Loss: 879.0699
# Epoch 124, Batch 200/479, Loss: 917.1080
# Epoch 124, Batch 300/479, Loss: 822.7712
# Epoch 124, Batch 400/479, Loss: 971.7366
# Epoch 124/3000, Batches Processed: 479, Train Loss: 909.4874, Val Loss: 1692.7869
# Starting epoch 125/3000
# Epoch 125, Batch 100/479, Loss: 866.5412
# Epoch 125, Batch 200/479, Loss: 934.9230
# Epoch 125, Batch 300/479, Loss: 883.5901
# Epoch 125, Batch 400/479, Loss: 1095.2354
# Epoch 125/3000, Batches Processed: 479, Train Loss: 901.3097, Val Loss: 1688.5847
# Starting epoch 126/3000
# Epoch 126, Batch 100/479, Loss: 885.5558
# Epoch 126, Batch 200/479, Loss: 916.9258
# Epoch 126, Batch 300/479, Loss: 848.3610
# Epoch 126, Batch 400/479, Loss: 976.9067
# Epoch 126/3000, Batches Processed: 479, Train Loss: 895.4953, Val Loss: 1680.9028
# Starting epoch 127/3000
# Epoch 127, Batch 100/479, Loss: 706.6637
# Epoch 127, Batch 200/479, Loss: 994.7606
# Epoch 127, Batch 300/479, Loss: 1140.0880
# Epoch 127, Batch 400/479, Loss: 811.8419
# Epoch 127/3000, Batches Processed: 479, Train Loss: 891.3766, Val Loss: 1696.8066
# Starting epoch 128/3000
# Epoch 128, Batch 100/479, Loss: 823.2158
# Epoch 128, Batch 200/479, Loss: 1120.0791
# Epoch 128, Batch 300/479, Loss: 995.8605
# Epoch 128, Batch 400/479, Loss: 860.0767
# Epoch 128/3000, Batches Processed: 479, Train Loss: 889.8041, Val Loss: 1674.9842
# Starting epoch 129/3000
# Epoch 129, Batch 100/479, Loss: 1023.4189
# Epoch 129, Batch 200/479, Loss: 761.2737
# Epoch 129, Batch 300/479, Loss: 1025.8885
# Epoch 129, Batch 400/479, Loss: 727.0448
# Epoch 129/3000, Batches Processed: 479, Train Loss: 882.2040, Val Loss: 1671.4070
# Starting epoch 130/3000
# Epoch 130, Batch 100/479, Loss: 672.4801
# Epoch 130, Batch 200/479, Loss: 805.7197
# Epoch 130, Batch 300/479, Loss: 973.4069
# Epoch 130, Batch 400/479, Loss: 955.4678
# Epoch 130/3000, Batches Processed: 479, Train Loss: 876.0801, Val Loss: 1672.1815
# Starting epoch 131/3000
# Epoch 131, Batch 100/479, Loss: 724.4164
# Epoch 131, Batch 200/479, Loss: 762.5753
# Epoch 131, Batch 300/479, Loss: 835.7316
# Epoch 131, Batch 400/479, Loss: 811.3806
# Epoch 131/3000, Batches Processed: 479, Train Loss: 871.4011, Val Loss: 1667.5169
# Starting epoch 132/3000
# Epoch 132, Batch 100/479, Loss: 928.9127
# Epoch 132, Batch 200/479, Loss: 789.4664
# Epoch 132, Batch 300/479, Loss: 870.8367
# Epoch 132, Batch 400/479, Loss: 935.3126
# Epoch 132/3000, Batches Processed: 479, Train Loss: 867.7818, Val Loss: 1653.3685
# Starting epoch 133/3000
# Epoch 133, Batch 100/479, Loss: 748.1493
# Epoch 133, Batch 200/479, Loss: 739.9848
# Epoch 133, Batch 300/479, Loss: 785.4103
# Epoch 133, Batch 400/479, Loss: 887.4272
# Epoch 133/3000, Batches Processed: 479, Train Loss: 863.4103, Val Loss: 1665.0492
# Starting epoch 134/3000
# Epoch 134, Batch 100/479, Loss: 926.3975
# Epoch 134, Batch 200/479, Loss: 859.5308
# Epoch 134, Batch 300/479, Loss: 768.7655
# Epoch 134, Batch 400/479, Loss: 1023.8449
# Epoch 134/3000, Batches Processed: 479, Train Loss: 855.5921, Val Loss: 1654.8608
# Starting epoch 135/3000
# Epoch 135, Batch 100/479, Loss: 872.9567
# Epoch 135, Batch 200/479, Loss: 875.8399
# Epoch 135, Batch 300/479, Loss: 1006.7709
# Epoch 135, Batch 400/479, Loss: 815.5756
# Epoch 135/3000, Batches Processed: 479, Train Loss: 855.0054, Val Loss: 1643.4346
# Starting epoch 136/3000
# Epoch 136, Batch 100/479, Loss: 630.8954
# Epoch 136, Batch 200/479, Loss: 873.2860
# Epoch 136, Batch 300/479, Loss: 832.4022
# Epoch 136, Batch 400/479, Loss: 748.6382
# Epoch 136/3000, Batches Processed: 479, Train Loss: 850.7243, Val Loss: 1626.3710
# Starting epoch 137/3000
# Epoch 137, Batch 100/479, Loss: 803.4388
# Epoch 137, Batch 200/479, Loss: 830.5337
# Epoch 137, Batch 300/479, Loss: 843.5647
# Epoch 137, Batch 400/479, Loss: 1041.7494
# Epoch 137/3000, Batches Processed: 479, Train Loss: 846.3781, Val Loss: 1637.8259
# Starting epoch 138/3000
# Epoch 138, Batch 100/479, Loss: 903.6740
# Epoch 138, Batch 200/479, Loss: 781.0789
# Epoch 138, Batch 300/479, Loss: 854.5708
# Epoch 138, Batch 400/479, Loss: 743.7169
# Epoch 138/3000, Batches Processed: 479, Train Loss: 844.9325, Val Loss: 1630.3909
# Starting epoch 139/3000
# Epoch 139, Batch 100/479, Loss: 837.6065
# Epoch 139, Batch 200/479, Loss: 675.7539
# Epoch 139, Batch 300/479, Loss: 886.7640
# Epoch 139, Batch 400/479, Loss: 1009.7904
# Epoch 139/3000, Batches Processed: 479, Train Loss: 841.5583, Val Loss: 1633.8911
# Starting epoch 140/3000
# Epoch 140, Batch 100/479, Loss: 792.4566
# Epoch 140, Batch 200/479, Loss: 753.0114
# Epoch 140, Batch 300/479, Loss: 797.5879
# Epoch 140, Batch 400/479, Loss: 825.0623
# Epoch 140/3000, Batches Processed: 479, Train Loss: 835.1871, Val Loss: 1639.0087
# Starting epoch 141/3000
# Epoch 141, Batch 100/479, Loss: 1073.8162
# Epoch 141, Batch 200/479, Loss: 947.9292
# Epoch 141, Batch 300/479, Loss: 805.5890
# Epoch 141, Batch 400/479, Loss: 1050.3153
# Epoch 141/3000, Batches Processed: 479, Train Loss: 832.7427, Val Loss: 1643.2713
# Starting epoch 142/3000
# Epoch 142, Batch 100/479, Loss: 924.6423
# Epoch 142, Batch 200/479, Loss: 800.1213
# Epoch 142, Batch 300/479, Loss: 1032.7059
# Epoch 142, Batch 400/479, Loss: 847.6157
# Epoch 142/3000, Batches Processed: 479, Train Loss: 832.4179, Val Loss: 1646.1833
# Starting epoch 143/3000
# Epoch 143, Batch 100/479, Loss: 817.6167
# Epoch 143, Batch 200/479, Loss: 694.3085
# Epoch 143, Batch 300/479, Loss: 943.7974
# Epoch 143, Batch 400/479, Loss: 900.4009
# Epoch 143/3000, Batches Processed: 479, Train Loss: 824.8774, Val Loss: 1645.2353
# Starting epoch 144/3000
# Epoch 144, Batch 100/479, Loss: 1064.5240
# Epoch 144, Batch 200/479, Loss: 884.6090
# Epoch 144, Batch 300/479, Loss: 881.3088
# Epoch 144, Batch 400/479, Loss: 729.2520
# Epoch 144/3000, Batches Processed: 479, Train Loss: 823.3072, Val Loss: 1621.2561
# Starting epoch 145/3000
# Epoch 145, Batch 100/479, Loss: 1109.1670
# Epoch 145, Batch 200/479, Loss: 660.6483
# Epoch 145, Batch 300/479, Loss: 976.5918
# Epoch 145, Batch 400/479, Loss: 682.2662
# Epoch 145/3000, Batches Processed: 479, Train Loss: 817.2088, Val Loss: 1628.1781
# Starting epoch 146/3000
# Epoch 146, Batch 100/479, Loss: 882.5200
# Epoch 146, Batch 200/479, Loss: 859.8647
# Epoch 146, Batch 300/479, Loss: 784.3265
# Epoch 146, Batch 400/479, Loss: 825.5146
# Epoch 146/3000, Batches Processed: 479, Train Loss: 815.8744, Val Loss: 1606.8693
# Starting epoch 147/3000
# Epoch 147, Batch 100/479, Loss: 952.1831
# Epoch 147, Batch 200/479, Loss: 775.2792
# Epoch 147, Batch 300/479, Loss: 680.8207
# Epoch 147, Batch 400/479, Loss: 668.1418
# Epoch 147/3000, Batches Processed: 479, Train Loss: 811.6058, Val Loss: 1605.6506
# Starting epoch 148/3000
# Epoch 148, Batch 100/479, Loss: 652.3535
# Epoch 148, Batch 200/479, Loss: 971.7973
# Epoch 148, Batch 300/479, Loss: 785.0605
# Epoch 148, Batch 400/479, Loss: 700.6254
# Epoch 148/3000, Batches Processed: 479, Train Loss: 808.3261, Val Loss: 1594.5513
# Starting epoch 149/3000
# Epoch 149, Batch 100/479, Loss: 768.4520
# Epoch 149, Batch 200/479, Loss: 726.9229
# Epoch 149, Batch 300/479, Loss: 878.0165
# Epoch 149, Batch 400/479, Loss: 909.1121
# Epoch 149/3000, Batches Processed: 479, Train Loss: 801.2571, Val Loss: 1608.6151
# Starting epoch 150/3000
# Epoch 150, Batch 100/479, Loss: 768.2026
# Epoch 150, Batch 200/479, Loss: 828.8619
# Epoch 150, Batch 300/479, Loss: 849.1182
# Epoch 150, Batch 400/479, Loss: 974.1375
# Epoch 150/3000, Batches Processed: 479, Train Loss: 798.8003, Val Loss: 1614.0288
# Starting epoch 151/3000
# Epoch 151, Batch 100/479, Loss: 912.5081
# Epoch 151, Batch 200/479, Loss: 739.3679
# Epoch 151, Batch 300/479, Loss: 840.9319
# Epoch 151, Batch 400/479, Loss: 961.2266
# Epoch 151/3000, Batches Processed: 479, Train Loss: 797.6594, Val Loss: 1583.6733
# Starting epoch 152/3000
# Epoch 152, Batch 100/479, Loss: 856.0686
# Epoch 152, Batch 200/479, Loss: 899.5653
# Epoch 152, Batch 300/479, Loss: 830.6039
# Epoch 152, Batch 400/479, Loss: 951.1503
# Epoch 152/3000, Batches Processed: 479, Train Loss: 793.4928, Val Loss: 1576.7683
# Starting epoch 153/3000
# Epoch 153, Batch 100/479, Loss: 838.5280
# Epoch 153, Batch 200/479, Loss: 629.9225
# Epoch 153, Batch 300/479, Loss: 827.8358
# Epoch 153, Batch 400/479, Loss: 878.9952
# Epoch 153/3000, Batches Processed: 479, Train Loss: 787.7150, Val Loss: 1595.6345
# Starting epoch 154/3000
# Epoch 154, Batch 100/479, Loss: 675.3023
# Epoch 154, Batch 200/479, Loss: 751.0702
# Epoch 154, Batch 300/479, Loss: 735.1423
# Epoch 154, Batch 400/479, Loss: 669.4766
# Epoch 154/3000, Batches Processed: 479, Train Loss: 787.6590, Val Loss: 1580.3375
# Starting epoch 155/3000
# Epoch 155, Batch 100/479, Loss: 706.4810
# Epoch 155, Batch 200/479, Loss: 870.7083
# Epoch 155, Batch 300/479, Loss: 913.7325
# Epoch 155, Batch 400/479, Loss: 787.4390
# Epoch 155/3000, Batches Processed: 479, Train Loss: 779.9824, Val Loss: 1597.0364
# Starting epoch 156/3000
# Epoch 156, Batch 100/479, Loss: 752.2373
# Epoch 156, Batch 200/479, Loss: 788.6530
# Epoch 156, Batch 300/479, Loss: 828.2839
# Epoch 156, Batch 400/479, Loss: 910.8943
# Epoch 156/3000, Batches Processed: 479, Train Loss: 781.0698, Val Loss: 1563.0590
# Starting epoch 157/3000
# Epoch 157, Batch 100/479, Loss: 585.9694
# Epoch 157, Batch 200/479, Loss: 694.1330
# Epoch 157, Batch 300/479, Loss: 862.9536
# Epoch 157, Batch 400/479, Loss: 791.6919
# Epoch 157/3000, Batches Processed: 479, Train Loss: 775.2533, Val Loss: 1569.2414
# Starting epoch 158/3000
# Epoch 158, Batch 100/479, Loss: 884.7954
# Epoch 158, Batch 200/479, Loss: 714.4208
# Epoch 158, Batch 300/479, Loss: 985.1682
# Epoch 158, Batch 400/479, Loss: 815.2345
# Epoch 158/3000, Batches Processed: 479, Train Loss: 768.4878, Val Loss: 1568.2577
# Starting epoch 159/3000
# Epoch 159, Batch 100/479, Loss: 668.2153
# Epoch 159, Batch 200/479, Loss: 725.3965
# Epoch 159, Batch 300/479, Loss: 889.0963
# Epoch 159, Batch 400/479, Loss: 824.6874
# Epoch 159/3000, Batches Processed: 479, Train Loss: 769.4385, Val Loss: 1583.0181
# Starting epoch 160/3000
# Epoch 160, Batch 100/479, Loss: 686.2749
# Epoch 160, Batch 200/479, Loss: 748.2079
# Epoch 160, Batch 300/479, Loss: 793.1252
# Epoch 160, Batch 400/479, Loss: 739.3813
# Epoch 160/3000, Batches Processed: 479, Train Loss: 764.8590, Val Loss: 1575.4541
# Starting epoch 161/3000
# Epoch 161, Batch 100/479, Loss: 707.9733
# Epoch 161, Batch 200/479, Loss: 674.9238
# Epoch 161, Batch 300/479, Loss: 810.3673
# Epoch 161, Batch 400/479, Loss: 892.1750
# Epoch 161/3000, Batches Processed: 479, Train Loss: 759.8868, Val Loss: 1570.9825
# Starting epoch 162/3000
# Epoch 162, Batch 100/479, Loss: 747.2753
# Epoch 162, Batch 200/479, Loss: 691.0228
# Epoch 162, Batch 300/479, Loss: 851.7111
# Epoch 162, Batch 400/479, Loss: 912.3651
# Epoch 162/3000, Batches Processed: 479, Train Loss: 758.9662, Val Loss: 1572.9547
# Starting epoch 163/3000
# Epoch 163, Batch 100/479, Loss: 851.6293
# Epoch 163, Batch 200/479, Loss: 706.0595
# Epoch 163, Batch 300/479, Loss: 662.7640
# Epoch 163, Batch 400/479, Loss: 797.9037
# Epoch 163/3000, Batches Processed: 479, Train Loss: 756.5269, Val Loss: 1561.8636
# Starting epoch 164/3000
# Epoch 164, Batch 100/479, Loss: 747.9520
# Epoch 164, Batch 200/479, Loss: 852.5588
# Epoch 164, Batch 300/479, Loss: 749.8364
# Epoch 164, Batch 400/479, Loss: 860.6075
# Epoch 164/3000, Batches Processed: 479, Train Loss: 753.6849, Val Loss: 1574.0616
# Starting epoch 165/3000
# Epoch 165, Batch 100/479, Loss: 705.2018
# Epoch 165, Batch 200/479, Loss: 727.1378
# Epoch 165, Batch 300/479, Loss: 773.5977
# Epoch 165, Batch 400/479, Loss: 741.1603
# Epoch 165/3000, Batches Processed: 479, Train Loss: 748.0121, Val Loss: 1554.7458
# Starting epoch 166/3000
# Epoch 166, Batch 100/479, Loss: 743.1632
# Epoch 166, Batch 200/479, Loss: 819.0465
# Epoch 166, Batch 300/479, Loss: 932.6318
# Epoch 166, Batch 400/479, Loss: 636.7349
# Epoch 166/3000, Batches Processed: 479, Train Loss: 743.6885, Val Loss: 1531.4314
# Starting epoch 167/3000
# Epoch 167, Batch 100/479, Loss: 786.7379
# Epoch 167, Batch 200/479, Loss: 905.8366
# Epoch 167, Batch 300/479, Loss: 714.7950
# Epoch 167, Batch 400/479, Loss: 854.2842
# Epoch 167/3000, Batches Processed: 479, Train Loss: 742.1388, Val Loss: 1556.1906
# Starting epoch 168/3000
# Epoch 168, Batch 100/479, Loss: 664.9278
# Epoch 168, Batch 200/479, Loss: 656.1357
# Epoch 168, Batch 300/479, Loss: 713.1819
# Epoch 168, Batch 400/479, Loss: 751.6102
# Epoch 168/3000, Batches Processed: 479, Train Loss: 739.4844, Val Loss: 1537.2904
# Starting epoch 169/3000
# Epoch 169, Batch 100/479, Loss: 829.4019
# Epoch 169, Batch 200/479, Loss: 693.8442
# Epoch 169, Batch 300/479, Loss: 1012.9338
# Epoch 169, Batch 400/479, Loss: 671.7665
# Epoch 169/3000, Batches Processed: 479, Train Loss: 735.8427, Val Loss: 1534.2985
# Starting epoch 170/3000
# Epoch 170, Batch 100/479, Loss: 858.8774
# Epoch 170, Batch 200/479, Loss: 878.1314
# Epoch 170, Batch 300/479, Loss: 655.0739
# Epoch 170, Batch 400/479, Loss: 620.5013
# Epoch 170/3000, Batches Processed: 479, Train Loss: 733.2279, Val Loss: 1536.4597
# Starting epoch 171/3000
# Epoch 171, Batch 100/479, Loss: 681.6058
# Epoch 171, Batch 200/479, Loss: 648.3054
# Epoch 171, Batch 300/479, Loss: 893.9982
# Epoch 171, Batch 400/479, Loss: 651.3789
# Epoch 171/3000, Batches Processed: 479, Train Loss: 731.6636, Val Loss: 1531.1775
# Starting epoch 172/3000
# Epoch 172, Batch 100/479, Loss: 709.5192
# Epoch 172, Batch 200/479, Loss: 900.9328
# Epoch 172, Batch 300/479, Loss: 710.9840
# Epoch 172, Batch 400/479, Loss: 645.3546
# Epoch 172/3000, Batches Processed: 479, Train Loss: 725.6450, Val Loss: 1541.9279
# Starting epoch 173/3000
# Epoch 173, Batch 100/479, Loss: 578.0497
# Epoch 173, Batch 200/479, Loss: 682.0554
# Epoch 173, Batch 300/479, Loss: 741.5668
# Epoch 173, Batch 400/479, Loss: 668.6433
# Epoch 173/3000, Batches Processed: 479, Train Loss: 724.6942, Val Loss: 1550.4001
# Starting epoch 174/3000
# Epoch 174, Batch 100/479, Loss: 869.0074
# Epoch 174, Batch 200/479, Loss: 701.6975
# Epoch 174, Batch 300/479, Loss: 673.1793
# Epoch 174, Batch 400/479, Loss: 772.6280
# Epoch 174/3000, Batches Processed: 479, Train Loss: 724.3622, Val Loss: 1523.2098
# Starting epoch 175/3000
# Epoch 175, Batch 100/479, Loss: 732.7679
# Epoch 175, Batch 200/479, Loss: 674.3412
# Epoch 175, Batch 300/479, Loss: 854.1621
# Epoch 175, Batch 400/479, Loss: 569.6005
# Epoch 175/3000, Batches Processed: 479, Train Loss: 720.0123, Val Loss: 1506.9665
# Starting epoch 176/3000
# Epoch 176, Batch 100/479, Loss: 920.6706
# Epoch 176, Batch 200/479, Loss: 578.8733
# Epoch 176, Batch 300/479, Loss: 782.4781
# Epoch 176, Batch 400/479, Loss: 612.1308
# Epoch 176/3000, Batches Processed: 479, Train Loss: 718.0816, Val Loss: 1523.2168
# Starting epoch 177/3000
# Epoch 177, Batch 100/479, Loss: 675.4014
# Epoch 177, Batch 200/479, Loss: 638.7960
# Epoch 177, Batch 300/479, Loss: 838.0665
# ...
# Epoch 2943, Batch 300/479, Loss: 307.7547
# Epoch 2943, Batch 400/479, Loss: 378.5086
# Epoch 2943/3000, Batches Processed: 479, Train Loss: 353.2376, Val Loss: 1267.1435
# Starting epoch 2944/3000
# Epoch 2944, Batch 100/479, Loss: 325.7487
# Epoch 2944, Batch 200/479, Loss: 339.1791
# Epoch 2944, Batch 300/479, Loss: 365.5521
# Epoch 2944, Batch 400/479, Loss: 333.3116
# Epoch 2944/3000, Batches Processed: 479, Train Loss: 352.7909, Val Loss: 1305.5810
# Starting epoch 2945/3000
# Epoch 2945, Batch 100/479, Loss: 311.4454
# Epoch 2945, Batch 200/479, Loss: 323.4698
# Epoch 2945, Batch 300/479, Loss: 349.0970
# Epoch 2945, Batch 400/479, Loss: 350.0660
# Epoch 2945/3000, Batches Processed: 479, Train Loss: 354.5264, Val Loss: 1268.1236
# Starting epoch 2946/3000
# Epoch 2946, Batch 100/479, Loss: 361.8623
# Epoch 2946, Batch 200/479, Loss: 343.5297
# Epoch 2946, Batch 300/479, Loss: 345.1526
# Epoch 2946, Batch 400/479, Loss: 426.7766
# Epoch 2946/3000, Batches Processed: 479, Train Loss: 354.6742, Val Loss: 1295.0481
# Starting epoch 2947/3000
# Epoch 2947, Batch 100/479, Loss: 338.8451
# Epoch 2947, Batch 200/479, Loss: 369.4993
# Epoch 2947, Batch 300/479, Loss: 360.3983
# Epoch 2947, Batch 400/479, Loss: 340.0070
# Epoch 2947/3000, Batches Processed: 479, Train Loss: 356.6262, Val Loss: 1286.5514
# Starting epoch 2948/3000
# Epoch 2948, Batch 100/479, Loss: 341.2482
# Epoch 2948, Batch 200/479, Loss: 383.5157
# Epoch 2948, Batch 300/479, Loss: 364.8774
# Epoch 2948, Batch 400/479, Loss: 328.5840
# Epoch 2948/3000, Batches Processed: 479, Train Loss: 355.0552, Val Loss: 1270.5160
# Starting epoch 2949/3000
# Epoch 2949, Batch 100/479, Loss: 341.0047
# Epoch 2949, Batch 200/479, Loss: 1072.2515
# Epoch 2949, Batch 300/479, Loss: 382.6115
# Epoch 2949, Batch 400/479, Loss: 316.4924
# Epoch 2949/3000, Batches Processed: 479, Train Loss: 358.0601, Val Loss: 1268.6755
# Starting epoch 2950/3000
# Epoch 2950, Batch 100/479, Loss: 369.0767
# Epoch 2950, Batch 200/479, Loss: 350.2658
# Epoch 2950, Batch 300/479, Loss: 371.9892
# Epoch 2950, Batch 400/479, Loss: 336.8392
# Epoch 2950/3000, Batches Processed: 479, Train Loss: 356.4850, Val Loss: 1276.4108
# Starting epoch 2951/3000
# Epoch 2951, Batch 100/479, Loss: 289.6218
# Epoch 2951, Batch 200/479, Loss: 355.3796
# Epoch 2951, Batch 300/479, Loss: 347.2433
# Epoch 2951, Batch 400/479, Loss: 345.0545
# Epoch 2951/3000, Batches Processed: 479, Train Loss: 354.7078, Val Loss: 1278.5306
# Starting epoch 2952/3000
# Epoch 2952, Batch 100/479, Loss: 355.6682
# Epoch 2952, Batch 200/479, Loss: 337.2401
# Epoch 2952, Batch 300/479, Loss: 344.1258
# Epoch 2952, Batch 400/479, Loss: 372.6895
# Epoch 2952/3000, Batches Processed: 479, Train Loss: 357.3480, Val Loss: 1276.6921
# Starting epoch 2953/3000
# Epoch 2953, Batch 100/479, Loss: 297.7310
# Epoch 2953, Batch 200/479, Loss: 359.3046
# Epoch 2953, Batch 300/479, Loss: 313.5829
# Epoch 2953, Batch 400/479, Loss: 398.9908
# Epoch 2953/3000, Batches Processed: 479, Train Loss: 355.8124, Val Loss: 1281.7617
# Starting epoch 2954/3000
# Epoch 2954, Batch 100/479, Loss: 375.0486
# Epoch 2954, Batch 200/479, Loss: 387.4911
# Epoch 2954, Batch 300/479, Loss: 329.3305
# Epoch 2954, Batch 400/479, Loss: 384.2546
# Epoch 2954/3000, Batches Processed: 479, Train Loss: 355.6983, Val Loss: 1306.3753
# Starting epoch 2955/3000
# Epoch 2955, Batch 100/479, Loss: 353.2573
# Epoch 2955, Batch 200/479, Loss: 358.7405
# Epoch 2955, Batch 300/479, Loss: 351.8334
# Epoch 2955, Batch 400/479, Loss: 322.5864
# Epoch 2955/3000, Batches Processed: 479, Train Loss: 356.2006, Val Loss: 1262.6842
# Starting epoch 2956/3000
# Epoch 2956, Batch 100/479, Loss: 333.8284
# Epoch 2956, Batch 200/479, Loss: 333.2689
# Epoch 2956, Batch 300/479, Loss: 291.3413
# Epoch 2956, Batch 400/479, Loss: 363.4506
# Epoch 2956/3000, Batches Processed: 479, Train Loss: 355.1458, Val Loss: 1287.8078
# Starting epoch 2957/3000
# Epoch 2957, Batch 100/479, Loss: 419.5540
# Epoch 2957, Batch 200/479, Loss: 328.5856
# Epoch 2957, Batch 300/479, Loss: 293.3072
# Epoch 2957, Batch 400/479, Loss: 400.2310
# Epoch 2957/3000, Batches Processed: 479, Train Loss: 354.1267, Val Loss: 1278.9489
# Starting epoch 2958/3000
# Epoch 2958, Batch 100/479, Loss: 379.6960
# Epoch 2958, Batch 200/479, Loss: 385.7084
# Epoch 2958, Batch 300/479, Loss: 343.9048
# Epoch 2958, Batch 400/479, Loss: 324.8751
# Epoch 2958/3000, Batches Processed: 479, Train Loss: 357.4389, Val Loss: 1269.7638
# Starting epoch 2959/3000
# Epoch 2959, Batch 100/479, Loss: 333.1907
# Epoch 2959, Batch 200/479, Loss: 377.4161
# Epoch 2959, Batch 300/479, Loss: 393.2264
# Epoch 2959, Batch 400/479, Loss: 289.3579
# Epoch 2959/3000, Batches Processed: 479, Train Loss: 357.1443, Val Loss: 1290.0387
# Starting epoch 2960/3000
# Epoch 2960, Batch 100/479, Loss: 351.6809
# Epoch 2960, Batch 200/479, Loss: 332.2483
# Epoch 2960, Batch 300/479, Loss: 370.4967
# Epoch 2960, Batch 400/479, Loss: 377.8174
# Epoch 2960/3000, Batches Processed: 479, Train Loss: 353.6933, Val Loss: 1282.3133
# Starting epoch 2961/3000
# Epoch 2961, Batch 100/479, Loss: 386.2688
# Epoch 2961, Batch 200/479, Loss: 368.2409
# Epoch 2961, Batch 300/479, Loss: 369.5322
# Epoch 2961, Batch 400/479, Loss: 306.6749
# Epoch 2961/3000, Batches Processed: 479, Train Loss: 356.0867, Val Loss: 1275.9065
# Starting epoch 2962/3000
# Epoch 2962, Batch 100/479, Loss: 345.1023
# Epoch 2962, Batch 200/479, Loss: 380.0412
# Epoch 2962, Batch 300/479, Loss: 342.1231
# Epoch 2962, Batch 400/479, Loss: 376.1081
# Epoch 2962/3000, Batches Processed: 479, Train Loss: 355.9923, Val Loss: 1270.5342
# Starting epoch 2963/3000
# Epoch 2963, Batch 100/479, Loss: 390.5983
# Epoch 2963, Batch 200/479, Loss: 383.3588
# Epoch 2963, Batch 300/479, Loss: 387.9975
# Epoch 2963, Batch 400/479, Loss: 320.6010
# Epoch 2963/3000, Batches Processed: 479, Train Loss: 356.4553, Val Loss: 1291.2867
# Starting epoch 2964/3000
# Epoch 2964, Batch 100/479, Loss: 327.1112
# Epoch 2964, Batch 200/479, Loss: 399.7455
# Epoch 2964, Batch 300/479, Loss: 396.9528
# Epoch 2964, Batch 400/479, Loss: 338.1388
# Epoch 2964/3000, Batches Processed: 479, Train Loss: 355.9825, Val Loss: 1268.7110
# Starting epoch 2965/3000
# Epoch 2965, Batch 100/479, Loss: 468.6442
# Epoch 2965, Batch 200/479, Loss: 330.7994
# Epoch 2965, Batch 300/479, Loss: 395.5157
# Epoch 2965, Batch 400/479, Loss: 356.3535
# Epoch 2965/3000, Batches Processed: 479, Train Loss: 356.9027, Val Loss: 1293.7869
# Starting epoch 2966/3000
# Epoch 2966, Batch 100/479, Loss: 433.7275
# Epoch 2966, Batch 200/479, Loss: 383.3928
# Epoch 2966, Batch 300/479, Loss: 355.5099
# Epoch 2966, Batch 400/479, Loss: 324.5677
# Epoch 2966/3000, Batches Processed: 479, Train Loss: 354.7152, Val Loss: 1267.5748
# Starting epoch 2967/3000
# Epoch 2967, Batch 100/479, Loss: 345.0726
# Epoch 2967, Batch 200/479, Loss: 387.2131
# Epoch 2967, Batch 300/479, Loss: 390.1645
# Epoch 2967, Batch 400/479, Loss: 339.8587
# Epoch 2967/3000, Batches Processed: 479, Train Loss: 355.5188, Val Loss: 1263.3456
# Starting epoch 2968/3000
# Epoch 2968, Batch 100/479, Loss: 348.4831
# Epoch 2968, Batch 200/479, Loss: 358.9344
# Epoch 2968, Batch 300/479, Loss: 367.2065
# Epoch 2968, Batch 400/479, Loss: 303.0594
# Epoch 2968/3000, Batches Processed: 479, Train Loss: 358.1395, Val Loss: 1283.0454
# Starting epoch 2969/3000
# Epoch 2969, Batch 100/479, Loss: 347.9713
# Epoch 2969, Batch 200/479, Loss: 344.1748
# Epoch 2969, Batch 300/479, Loss: 356.2740
# Epoch 2969, Batch 400/479, Loss: 379.1474
# Epoch 2969/3000, Batches Processed: 479, Train Loss: 354.0372, Val Loss: 1255.5550
# Starting epoch 2970/3000
# Epoch 2970, Batch 100/479, Loss: 333.2957
# Epoch 2970, Batch 200/479, Loss: 370.9980
# Epoch 2970, Batch 300/479, Loss: 361.2990
# Epoch 2970, Batch 400/479, Loss: 337.7617
# Epoch 2970/3000, Batches Processed: 479, Train Loss: 355.3052, Val Loss: 1296.2695
# Starting epoch 2971/3000
# Epoch 2971, Batch 100/479, Loss: 343.8747
# Epoch 2971, Batch 200/479, Loss: 354.0268
# Epoch 2971, Batch 300/479, Loss: 346.3061
# Epoch 2971, Batch 400/479, Loss: 323.1911
# Epoch 2971/3000, Batches Processed: 479, Train Loss: 353.3713, Val Loss: 1294.9907
# Starting epoch 2972/3000
# Epoch 2972, Batch 100/479, Loss: 328.3576
# Epoch 2972, Batch 200/479, Loss: 322.1770
# Epoch 2972, Batch 300/479, Loss: 355.2996
# Epoch 2972, Batch 400/479, Loss: 392.2079
# Epoch 2972/3000, Batches Processed: 479, Train Loss: 356.8168, Val Loss: 1288.4542
# Starting epoch 2973/3000
# Epoch 2973, Batch 100/479, Loss: 336.3546
# Epoch 2973, Batch 200/479, Loss: 366.3689
# Epoch 2973, Batch 300/479, Loss: 334.3939
# Epoch 2973, Batch 400/479, Loss: 324.2670
# Epoch 2973/3000, Batches Processed: 479, Train Loss: 355.4146, Val Loss: 1287.1442
# Starting epoch 2974/3000
# Epoch 2974, Batch 100/479, Loss: 356.9536
# Epoch 2974, Batch 200/479, Loss: 367.0414
# Epoch 2974, Batch 300/479, Loss: 392.8519
# Epoch 2974, Batch 400/479, Loss: 373.1345
# Epoch 2974/3000, Batches Processed: 479, Train Loss: 356.2593, Val Loss: 1271.6777
# Starting epoch 2975/3000
# Epoch 2975, Batch 100/479, Loss: 369.2642
# Epoch 2975, Batch 200/479, Loss: 388.8984
# Epoch 2975, Batch 300/479, Loss: 385.9656
# Epoch 2975, Batch 400/479, Loss: 391.3891
# Epoch 2975/3000, Batches Processed: 479, Train Loss: 358.8977, Val Loss: 1282.6351
# Starting epoch 2976/3000
# Epoch 2976, Batch 100/479, Loss: 308.3728
# Epoch 2976, Batch 200/479, Loss: 384.9409
# Epoch 2976, Batch 300/479, Loss: 373.3242
# Epoch 2976, Batch 400/479, Loss: 351.5084
# Epoch 2976/3000, Batches Processed: 479, Train Loss: 355.8992, Val Loss: 1280.7646
# Starting epoch 2977/3000
# Epoch 2977, Batch 100/479, Loss: 352.8170
# Epoch 2977, Batch 200/479, Loss: 336.8443
# Epoch 2977, Batch 300/479, Loss: 370.9770
# Epoch 2977, Batch 400/479, Loss: 384.8947
# Epoch 2977/3000, Batches Processed: 479, Train Loss: 356.8611, Val Loss: 1289.5625
# Starting epoch 2978/3000
# Epoch 2978, Batch 100/479, Loss: 388.3988
# Epoch 2978, Batch 200/479, Loss: 369.3022
# Epoch 2978, Batch 300/479, Loss: 331.0019
# Epoch 2978, Batch 400/479, Loss: 341.4536
# Epoch 2978/3000, Batches Processed: 479, Train Loss: 357.3399, Val Loss: 1284.7852
# Starting epoch 2979/3000
# Epoch 2979, Batch 100/479, Loss: 320.0119
# Epoch 2979, Batch 200/479, Loss: 345.8546
# Epoch 2979, Batch 300/479, Loss: 370.0701
# Epoch 2979, Batch 400/479, Loss: 380.0250
# Epoch 2979/3000, Batches Processed: 479, Train Loss: 357.1422, Val Loss: 1266.9939
# Starting epoch 2980/3000
# Epoch 2980, Batch 100/479, Loss: 323.3314
# Epoch 2980, Batch 200/479, Loss: 326.7758
# Epoch 2980, Batch 300/479, Loss: 334.9408
# Epoch 2980, Batch 400/479, Loss: 350.1201
# Epoch 2980/3000, Batches Processed: 479, Train Loss: 357.2757, Val Loss: 1267.0595
# Starting epoch 2981/3000
# Epoch 2981, Batch 100/479, Loss: 344.3902
# Epoch 2981, Batch 200/479, Loss: 357.5383
# Epoch 2981, Batch 300/479, Loss: 357.3153
# Epoch 2981, Batch 400/479, Loss: 317.1649
# Epoch 2981/3000, Batches Processed: 479, Train Loss: 356.3399, Val Loss: 1270.8131
# Starting epoch 2982/3000
# Epoch 2982, Batch 100/479, Loss: 333.8173
# Epoch 2982, Batch 200/479, Loss: 325.7531
# Epoch 2982, Batch 300/479, Loss: 348.7307
# Epoch 2982, Batch 400/479, Loss: 346.4576
# Epoch 2982/3000, Batches Processed: 479, Train Loss: 357.4234, Val Loss: 1269.6058
# Starting epoch 2983/3000
# Epoch 2983, Batch 100/479, Loss: 347.2072
# Epoch 2983, Batch 200/479, Loss: 317.1822
# Epoch 2983, Batch 300/479, Loss: 343.1301
# Epoch 2983, Batch 400/479, Loss: 391.1941
# Epoch 2983/3000, Batches Processed: 479, Train Loss: 354.8649, Val Loss: 1296.5665
# Starting epoch 2984/3000
# Epoch 2984, Batch 100/479, Loss: 335.6744
# Epoch 2984, Batch 200/479, Loss: 330.8269
# Epoch 2984, Batch 300/479, Loss: 420.1663
# Epoch 2984, Batch 400/479, Loss: 392.2457
# Epoch 2984/3000, Batches Processed: 479, Train Loss: 357.9854, Val Loss: 1285.4179
# Starting epoch 2985/3000
# Epoch 2985, Batch 100/479, Loss: 320.5925
# Epoch 2985, Batch 200/479, Loss: 400.7519
# Epoch 2985, Batch 300/479, Loss: 346.3770
# Epoch 2985, Batch 400/479, Loss: 294.2003
# Epoch 2985/3000, Batches Processed: 479, Train Loss: 356.1373, Val Loss: 1273.0563
# Starting epoch 2986/3000
# Epoch 2986, Batch 100/479, Loss: 354.6325
# Epoch 2986, Batch 200/479, Loss: 357.3257
# Epoch 2986, Batch 300/479, Loss: 346.4210
# Epoch 2986, Batch 400/479, Loss: 323.0203
# Epoch 2986/3000, Batches Processed: 479, Train Loss: 356.2321, Val Loss: 1275.0088
# Starting epoch 2987/3000
# Epoch 2987, Batch 100/479, Loss: 372.0471
# Epoch 2987, Batch 200/479, Loss: 390.7085
# Epoch 2987, Batch 300/479, Loss: 398.5355
# Epoch 2987, Batch 400/479, Loss: 362.4732
# Epoch 2987/3000, Batches Processed: 479, Train Loss: 358.6267, Val Loss: 1277.0136
# Starting epoch 2988/3000
# Epoch 2988, Batch 100/479, Loss: 322.8535
# Epoch 2988, Batch 200/479, Loss: 351.0151
# Epoch 2988, Batch 300/479, Loss: 301.5201
# Epoch 2988, Batch 400/479, Loss: 336.5106
# Epoch 2988/3000, Batches Processed: 479, Train Loss: 361.4760, Val Loss: 1282.8331
# Starting epoch 2989/3000
# Epoch 2989, Batch 100/479, Loss: 381.9484
# Epoch 2989, Batch 200/479, Loss: 342.6814
# Epoch 2989, Batch 300/479, Loss: 365.8924
# Epoch 2989, Batch 400/479, Loss: 396.0748
# Epoch 2989/3000, Batches Processed: 479, Train Loss: 356.6545, Val Loss: 1270.5461
# Starting epoch 2990/3000
# Epoch 2990, Batch 100/479, Loss: 355.3673
# Epoch 2990, Batch 200/479, Loss: 351.2958
# Epoch 2990, Batch 300/479, Loss: 282.8859
# Epoch 2990, Batch 400/479, Loss: 305.8792
# Epoch 2990/3000, Batches Processed: 479, Train Loss: 357.6670, Val Loss: 1266.3020
# Starting epoch 2991/3000
# Epoch 2991, Batch 100/479, Loss: 372.4119
# Epoch 2991, Batch 200/479, Loss: 397.0078
# Epoch 2991, Batch 300/479, Loss: 382.3853
# Epoch 2991, Batch 400/479, Loss: 490.2797
# Epoch 2991/3000, Batches Processed: 479, Train Loss: 362.0758, Val Loss: 1268.9645
# Starting epoch 2992/3000
# Epoch 2992, Batch 100/479, Loss: 368.7687
# Epoch 2992, Batch 200/479, Loss: 376.5945
# Epoch 2992, Batch 300/479, Loss: 372.0264
# Epoch 2992, Batch 400/479, Loss: 343.8972
# Epoch 2992/3000, Batches Processed: 479, Train Loss: 360.3085, Val Loss: 1303.3167
# Starting epoch 2993/3000
# Epoch 2993, Batch 100/479, Loss: 375.3589
# Epoch 2993, Batch 200/479, Loss: 379.0378
# Epoch 2993, Batch 300/479, Loss: 333.8683
# Epoch 2993, Batch 400/479, Loss: 321.3226
# Epoch 2993/3000, Batches Processed: 479, Train Loss: 358.3209, Val Loss: 1280.1791
# Starting epoch 2994/3000
# Epoch 2994, Batch 100/479, Loss: 328.7589
# Epoch 2994, Batch 200/479, Loss: 351.2852
# Epoch 2994, Batch 300/479, Loss: 358.1876
# Epoch 2994, Batch 400/479, Loss: 378.6158
# Epoch 2994/3000, Batches Processed: 479, Train Loss: 361.0679, Val Loss: 1302.9759
# Starting epoch 2995/3000
# Epoch 2995, Batch 100/479, Loss: 367.7794
# Epoch 2995, Batch 200/479, Loss: 322.4611
# Epoch 2995, Batch 300/479, Loss: 394.3887
# Epoch 2995, Batch 400/479, Loss: 354.3337
# Epoch 2995/3000, Batches Processed: 479, Train Loss: 357.2184, Val Loss: 1271.0246
# Starting epoch 2996/3000
# Epoch 2996, Batch 100/479, Loss: 350.1974
# Epoch 2996, Batch 200/479, Loss: 414.7521
# Epoch 2996, Batch 300/479, Loss: 345.5392
# Epoch 2996, Batch 400/479, Loss: 365.2813
# Epoch 2996/3000, Batches Processed: 479, Train Loss: 357.9587, Val Loss: 1284.1151
# Starting epoch 2997/3000
# Epoch 2997, Batch 100/479, Loss: 423.0880
# Epoch 2997, Batch 200/479, Loss: 361.9792
# Epoch 2997, Batch 300/479, Loss: 350.3069
# Epoch 2997, Batch 400/479, Loss: 400.0926
# Epoch 2997/3000, Batches Processed: 479, Train Loss: 359.0321, Val Loss: 1294.0258
# Starting epoch 2998/3000
# Epoch 2998, Batch 100/479, Loss: 330.0697
# Epoch 2998, Batch 200/479, Loss: 342.1293
# Epoch 2998, Batch 300/479, Loss: 358.2664
# Epoch 2998, Batch 400/479, Loss: 372.9394
# Epoch 2998/3000, Batches Processed: 479, Train Loss: 357.0651, Val Loss: 1298.2721
# Starting epoch 2999/3000
# Epoch 2999, Batch 100/479, Loss: 418.5677
# Epoch 2999, Batch 200/479, Loss: 330.0312
# Epoch 2999, Batch 300/479, Loss: 340.0224
# Epoch 2999, Batch 400/479, Loss: 353.1158
# Epoch 2999/3000, Batches Processed: 479, Train Loss: 356.5712, Val Loss: 1284.3488
# Starting epoch 3000/3000
# Epoch 3000, Batch 100/479, Loss: 382.5230
# Epoch 3000, Batch 200/479, Loss: 301.8844
# Epoch 3000, Batch 300/479, Loss: 382.9857
# Epoch 3000, Batch 400/479, Loss: 336.1129
# Epoch 3000/3000, Batches Processed: 479, Train Loss: 357.2150, Val Loss: 1270.8426
# Saved final CVAE model to cvae_vehicle_final.pth
# Finished generating samples

# %%
##increasing epoches

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset, random_split
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt
import kagglehub

# Hyperparameters
RESIZE = 128
original_dim = RESIZE * RESIZE * 3
intermediate_dim = 512
latent_dim = 256
num_classes = 5
batch_size = 8
previous_epochs = 3000  # Number of epochs already trained
additional_epochs = 2000  # Additional epochs to train
total_epochs = previous_epochs + additional_epochs  # 5000 epochs total
learning_rate = 1e-4
beta_start = 1
beta_end = 10
device = torch.device('cuda:1' if torch.cuda.device_count() > 1 else 'cuda')

# Print GPU information
print(f"Using device: {device}")
if device.type == 'cuda':
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory Allocated: {torch.cuda.memory_allocated(0) / 1024**2:.2f} MB")

# Custom Dataset for Kaggle Vehicle Type Image Dataset with Preloading
class VehicleTypeDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = []
        self.class_to_idx = {}
        self.images = []
        self.labels = []
        self.preloaded_images = []

        print(f"Searching for images in {root_dir}")
        for root, dirs, files in os.walk(root_dir):
            image_files = [f for f in files if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
            if image_files:
                class_name = os.path.basename(root)
                if class_name not in self.class_to_idx:
                    self.classes.append(class_name)
                    self.class_to_idx[class_name] = len(self.classes) - 1
                for img_file in image_files:
                    img_path = os.path.join(root, img_file)
                    try:
                        Image.open(img_path).verify()
                        self.images.append(img_path)
                        self.labels.append(self.class_to_idx[class_name])
                    except:
                        print(f"Skipping corrupted image: {img_path}")

        if len(self.classes) != num_classes:
            raise ValueError(f"Expected {num_classes} classes, found {len(self.classes)}")
        print(f"Found {len(self.images)} images across {len(self.classes)} classes.")
        print(f"Classes: {self.classes}")

        # Preload images into memory
        print("Preloading images into memory...")
        for img_path in self.images:
            try:
                image = Image.open(img_path).convert('RGB')
                self.preloaded_images.append(image)
            except:
                print(f"Failed to preload image: {img_path}")
                self.preloaded_images.append(None)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.preloaded_images[idx]
        if image is None:
            raise ValueError(f"Image at index {idx} failed to load during preloading")
        label = self.labels[idx]
        sample = {'image': image, 'label': label}
        if self.transform:
            sample['image'] = self.transform(sample['image'])
        return sample

# Enhanced Image Grid for Plotting
def image_grid(imgs, rows, cols, class_label, height=RESIZE, width=RESIZE):
    assert len(imgs) <= rows * cols
    grid = Image.new('RGB', size=(cols * width, rows * height), color=(255, 255, 255))
    for i, img in enumerate(imgs):
        x = (i % cols) * width + 2
        y = (i // cols) * height + 2
        grid.paste(img, box=(x, y))
    return grid

# Weight initialization function
def init_weights(m):
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.ConvTranspose2d):
        nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)
    elif isinstance(m, nn.Linear):
        nn.init.xavier_normal_(m.weight)
        nn.init.constant_(m.bias, 0)

# Encoder with kernel_size=5
class Encoder(nn.Module):
    def __init__(self, input_size, hidden_dim, latent_dim, num_classes):
        super(Encoder, self).__init__()
        self.encoder_cnn = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(128, 256, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256, 512, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 512, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 1024, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(1024),
            nn.ReLU(),
            nn.Conv2d(1024, 1024, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(1024),
            nn.ReLU()
        )
        self.fc_hidden = nn.Linear(1024 * 2 * 2 + num_classes, hidden_dim)
        self.dropout = nn.Dropout(0.3)
        self.fc_mean = nn.Linear(hidden_dim, latent_dim)
        self.fc_logvar = nn.Linear(hidden_dim, latent_dim)
        self.apply(init_weights)

    def forward(self, x, y):
        x = self.encoder_cnn(x)
        x = x.view(x.size(0), -1)
        x_with_y = torch.cat([x, y], dim=-1)
        h = F.relu(self.fc_hidden(x_with_y))
        h = self.dropout(h)
        z_mean = self.fc_mean(h)
        z_logvar = self.fc_logvar(h)
        z_logvar = torch.clamp(z_logvar, min=-10, max=10)
        return z_mean, z_logvar

# Decoder with kernel_size=5
class Decoder(nn.Module):
    def __init__(self, latent_dim, hidden_dim, output_size, num_classes):
        super(Decoder, self).__init__()
        self.fc = nn.Linear(latent_dim + num_classes, hidden_dim)
        self.dropout = nn.Dropout(0.3)
        self.fc_to_cnn = nn.Linear(hidden_dim, 1024 * 2 * 2)
        self.decoder_cnn = nn.Sequential(
            nn.ConvTranspose2d(1024, 1024, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(1024),
            nn.ReLU(),
            nn.ConvTranspose2d(1024, 512, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.ConvTranspose2d(512, 512, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.ConvTranspose2d(512, 256, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.ConvTranspose2d(256, 128, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 3, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.Tanh()
        )
        self.apply(init_weights)

    def forward(self, z, y):
        z_with_y = torch.cat([z, y], dim=-1)
        h = F.relu(self.fc(z_with_y))
        h = self.dropout(h)
        h = F.relu(self.fc_to_cnn(h))
        h = h.view(-1, 1024, 2, 2)
        x_reconstructed = self.decoder_cnn(h)
        x_reconstructed = torch.clamp(x_reconstructed, min=-1, max=1)
        return x_reconstructed

# Conditional VAE
class ConditionalVAE(nn.Module):
    def __init__(self, encoder, decoder):
        super(ConditionalVAE, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def reparameterize(self, z_mean, z_logvar):
        std = torch.exp(0.5 * z_logvar)
        eps = torch.randn_like(std)
        return z_mean + eps * std

    def forward(self, data, y):
        z_mean, z_logvar = self.encoder(data, y)
        z = self.reparameterize(z_mean, z_logvar)
        x_reconstructed = self.decoder(z, y)
        return x_reconstructed, z_mean, z_logvar

# Download and prepare dataset
path = kagglehub.dataset_download("sujaykapadnis/vehicle-type-image-dataset")
print("Path to dataset files:", path)

# Data preparation with train/validation split
train_transform = transforms.Compose([
    transforms.Resize((RESIZE, RESIZE), interpolation=Image.BILINEAR),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

dataset = VehicleTypeDataset(root_dir=path, transform=train_transform)
train_size = int(0.8 * len(dataset))  # ~3834 images
val_size = len(dataset) - train_size  # ~959 images
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True, drop_last=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True, drop_last=True)

# Instantiate model
input_size = (batch_size, 3, RESIZE, RESIZE)
encoder = Encoder(input_size, intermediate_dim, latent_dim, num_classes).to(device)
decoder = Decoder(latent_dim, intermediate_dim, input_size, num_classes).to(device)
cvae = ConditionalVAE(encoder, decoder).to(device)

# Load the saved model checkpoint
model_path = "cvae_vehicle_final.pth"
if os.path.exists(model_path):
    cvae.load_state_dict(torch.load(model_path, map_location=device))
    print(f"Loaded saved model from {model_path}", flush=True)
else:
    raise FileNotFoundError(f"Model checkpoint {model_path} not found. Please ensure the file exists.")

# Optimizer with learning rate scheduler
optimizer = optim.Adam(cvae.parameters(), lr=learning_rate)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=500, gamma=0.5)

# Simulate scheduler steps for the previous 3000 epochs to match the learning rate
for _ in range(previous_epochs):
    scheduler.step()

# Loss function with normalization
def cvae_loss(data, x_reconstructed, z_mean, z_logvar, beta=1.0):
    batch_size = data.size(0)
    mse_loss = F.mse_loss(x_reconstructed, data, reduction='sum') / batch_size
    kl_loss = -0.5 * torch.sum(1 + z_logvar - z_mean.pow(2) - z_logvar.exp()) / batch_size
    return mse_loss + beta * kl_loss

# Initialize loss lists with placeholders for the first 3000 epochs
# Note: If you have the actual train_losses and val_losses from the previous run, load them instead
train_losses = [0] * previous_epochs  # Placeholder
val_losses = [0] * previous_epochs    # Placeholder
# If you saved the losses previously, you can load them here:
# train_losses = np.load("train_losses.npy").tolist()
# val_losses = np.load("val_losses.npy").tolist()
# For now, we'll append the last known values for continuity in plotting
train_losses[-1] = 357.2150  # Last known train loss
val_losses[-1] = 1270.8426   # Last known val loss

# Training loop for additional 2000 epochs (3001 to 5000)
cvae.train()
for epoch in range(previous_epochs, total_epochs):
    epoch_display = epoch + 1  # Display epoch as 3001, 3002, ..., 5000
    print(f"Starting epoch {epoch_display}/{total_epochs}", flush=True)
    
    # Beta annealing (continuing from epoch 3000 where beta was already at beta_end)
    beta = beta_end  # Beta was already at 10 by epoch 3000, so we keep it there
    
    train_loss = 0
    batches_processed = 0

    for batch_idx, sample in enumerate(train_loader):
        try:
            data = sample['image'].to(device)
            labels = sample['label'].to(device)
            one_hot_labels = F.one_hot(labels, num_classes=num_classes).float()

            optimizer.zero_grad()
            x_reconstructed, z_mean, z_logvar = cvae(data, one_hot_labels)
            loss = cvae_loss(data, x_reconstructed, z_mean, z_logvar, beta)

            if torch.isnan(loss) or torch.isinf(loss):
                print(f"NaN/Inf loss detected at epoch {epoch_display}, batch {batch_idx+1}", flush=True)
                continue

            loss.backward()
            torch.nn.utils.clip_grad_norm_(cvae.parameters(), max_norm=1.0)
            optimizer.step()
            train_loss += loss.item() * data.size(0)
            batches_processed += 1

            # Print progress every 100 batches
            if (batch_idx + 1) % 100 == 0:
                print(f"Epoch {epoch_display}, Batch {batch_idx + 1}/{len(train_loader)}, Loss: {loss.item():.4f}", flush=True)

        except RuntimeError as e:
            print(f"Error at epoch {epoch_display}, batch {batch_idx + 1}: {str(e)}", flush=True)
            if "out of memory" in str(e).lower():
                print("Out of memory error detected. Clearing cache and continuing...", flush=True)
                if device.type == 'cuda':
                    torch.cuda.empty_cache()
            continue

    avg_train_loss = train_loss / len(train_loader.dataset)
    train_losses.append(avg_train_loss)

    # Validation loss
    cvae.eval()
    val_loss = 0
    with torch.no_grad():
        for sample in val_loader:
            data = sample['image'].to(device)
            labels = sample['label'].to(device)
            one_hot_labels = F.one_hot(labels, num_classes=num_classes).float()
            x_reconstructed, z_mean, z_logvar = cvae(data, one_hot_labels)
            loss = cvae_loss(data, x_reconstructed, z_mean, z_logvar, beta)
            val_loss += loss.item() * data.size(0)
    avg_val_loss = val_loss / len(val_loader.dataset) if len(val_loader.dataset) > 0 else 0
    val_losses.append(avg_val_loss)

    print(f'Epoch {epoch_display}/{total_epochs}, Batches Processed: {batches_processed}, Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}', flush=True)
    scheduler.step()

    # Clear GPU memory
    if device.type == 'cuda':
        torch.cuda.empty_cache()

    # Save model and generate samples only at the last epoch (5000)
    if epoch == total_epochs - 1:
        try:
            # Save the model
            model_path = "cvae_vehicle_final_epoch5000.pth"
            torch.save(cvae.state_dict(), model_path)
            print(f"Saved final CVAE model to {model_path}", flush=True)

            # Generate 100 samples per class
            def generate_samples_labelwise(cvae, num_samples_per_class, base_dir, latent_dim, device):
                cvae.eval()
                os.makedirs(base_dir, exist_ok=True)
                class_names = dataset.classes
                with torch.no_grad():
                    for class_label in range(num_classes):
                        label_tensor = torch.tensor([class_label]).repeat(num_samples_per_class).to(device)
                        one_hot_labels = F.one_hot(label_tensor, num_classes=num_classes).float().to(device)
                        z = torch.randn(num_samples_per_class, latent_dim).to(device)
                        generated_samples = cvae.decoder(z, one_hot_labels)

                        class_dir = os.path.join(base_dir, str(class_label))
                        os.makedirs(class_dir, exist_ok=True)
                        images = []
                        for idx, sample in enumerate(generated_samples):
                            sample = sample.cpu().detach().numpy()
                            sample = sample * 0.5 + 0.5
                            sample = np.nan_to_num(sample, nan=0.0, posinf=0.0, neginf=0.0)
                            sample = (255 * sample).astype(np.uint8)
                            sample = np.transpose(sample, (1, 2, 0))
                            pil_image = Image.fromarray(sample).convert('RGB')
                            pil_image.save(os.path.join(class_dir, f"sample_{idx}.png"))
                            if idx < 32:
                                images.append(pil_image)
                        if images:
                            grid = image_grid(images, rows=4, cols=8, class_label=class_names[class_label])
                            grid.save(os.path.join(class_dir, f"grid_{class_names[class_label]}.png"))

            base_dir = "generated_samples-arch-A5-epoch5000"
            generate_samples_labelwise(cvae, num_samples_per_class=100, base_dir=base_dir, latent_dim=latent_dim, device=device)
            print("Finished generating samples", flush=True)

        except Exception as e:
            print(f"Error during saving/generation at last epoch: {str(e)}", flush=True)

# Plot training and validation losses
try:
    plt.figure(figsize=(8, 6))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Val Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.savefig("training_validation_losses-A5-epoch5000.png")
    plt.close()
    print("Saved loss plot to training_validation_losses-A5-epoch5000.png", flush=True)
except Exception as e:
    print(f"Error plotting losses: {str(e)}", flush=True)
# Out:
# Using device: cuda:1
# GPU Name: NVIDIA RTX A5000
# GPU Memory Allocated: 0.00 MB
# Path to dataset files: C:\Users\hp\.cache\kagglehub\datasets\sujaykapadnis\vehicle-type-image-dataset\versions\1
# Searching for images in C:\Users\hp\.cache\kagglehub\datasets\sujaykapadnis\vehicle-type-image-dataset\versions\1
# Found 4793 images across 5 classes.
# Classes: ['Hatchback', 'Other', 'Pickup', 'Seden', 'SUV']
# Preloading images into memory...
# C:\Users\hp\AppData\Local\Temp\ipykernel_23176\891973405.py:241: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   cvae.load_state_dict(torch.load(model_path, map_location=device))
# Loaded saved model from cvae_vehicle_final.pth
# Starting epoch 3001/5000
# C:\Users\hp\Desktop\New folder\Lib\site-packages\torch\optim\lr_scheduler.py:224: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# Epoch 3001, Batch 100/479, Loss: 15672.8477
# Epoch 3001, Batch 200/479, Loss: 15397.9023
# Epoch 3001, Batch 300/479, Loss: 16449.3066
# Epoch 3001, Batch 400/479, Loss: 16850.7617
# Epoch 3001/5000, Batches Processed: 479, Train Loss: 18745.6700, Val Loss: 16731.6559
# Starting epoch 3002/5000
# Epoch 3002, Batch 100/479, Loss: 18578.0859
# Epoch 3002, Batch 200/479, Loss: 10942.2852
# Epoch 3002, Batch 300/479, Loss: 11249.3809
# Epoch 3002, Batch 400/479, Loss: 14757.4131
# Epoch 3002/5000, Batches Processed: 479, Train Loss: 13883.8601, Val Loss: 12317.9610
# Starting epoch 3003/5000
# Epoch 3003, Batch 100/479, Loss: 10846.0088
# Epoch 3003, Batch 200/479, Loss: 11713.5244
# Epoch 3003, Batch 300/479, Loss: 13184.1279
# Epoch 3003, Batch 400/479, Loss: 12124.3184
# Epoch 3003/5000, Batches Processed: 479, Train Loss: 11577.0236, Val Loss: 10782.1390
# Starting epoch 3004/5000
# Epoch 3004, Batch 100/479, Loss: 11554.3125
# Epoch 3004, Batch 200/479, Loss: 10980.0859
# Epoch 3004, Batch 300/479, Loss: 15027.5361
# Epoch 3004, Batch 400/479, Loss: 8986.8066
# Epoch 3004/5000, Batches Processed: 479, Train Loss: 10465.7630, Val Loss: 9945.4392
# Starting epoch 3005/5000
# Epoch 3005, Batch 100/479, Loss: 9721.0088
# Epoch 3005, Batch 200/479, Loss: 8387.4922
# Epoch 3005, Batch 300/479, Loss: 10388.6416
# Epoch 3005, Batch 400/479, Loss: 9026.2822
# Epoch 3005/5000, Batches Processed: 479, Train Loss: 9781.3334, Val Loss: 9388.0917
# Starting epoch 3006/5000
# Epoch 3006, Batch 100/479, Loss: 8670.6152
# Epoch 3006, Batch 200/479, Loss: 9548.4189
# Epoch 3006, Batch 300/479, Loss: 7603.5361
# Epoch 3006, Batch 400/479, Loss: 12223.4746
# Epoch 3006/5000, Batches Processed: 479, Train Loss: 9367.1039, Val Loss: 9004.7736
# Starting epoch 3007/5000
# Epoch 3007, Batch 100/479, Loss: 9215.2832
# Epoch 3007, Batch 200/479, Loss: 8787.1816
# Epoch 3007, Batch 300/479, Loss: 11334.8027
# Epoch 3007, Batch 400/479, Loss: 8691.6504
# Epoch 3007/5000, Batches Processed: 479, Train Loss: 9012.9744, Val Loss: 8670.9045
# Starting epoch 3008/5000
# Epoch 3008, Batch 100/479, Loss: 10600.8926
# Epoch 3008, Batch 200/479, Loss: 9629.6250
# Epoch 3008, Batch 300/479, Loss: 9155.8496
# Epoch 3008, Batch 400/479, Loss: 8711.5068
# Epoch 3008/5000, Batches Processed: 479, Train Loss: 8707.9898, Val Loss: 8380.2674
# Starting epoch 3009/5000
# Epoch 3009, Batch 100/479, Loss: 11459.4385
# Epoch 3009, Batch 200/479, Loss: 8008.1392
# Epoch 3009, Batch 300/479, Loss: 8851.2344
# Epoch 3009, Batch 400/479, Loss: 8763.7412
# Epoch 3009/5000, Batches Processed: 479, Train Loss: 8390.8109, Val Loss: 8073.1120
# Starting epoch 3010/5000
# Epoch 3010, Batch 100/479, Loss: 7502.8896
# Epoch 3010, Batch 200/479, Loss: 7507.2075
# Epoch 3010, Batch 300/479, Loss: 10431.7148
# Epoch 3010, Batch 400/479, Loss: 6833.2471
# Epoch 3010/5000, Batches Processed: 479, Train Loss: 8129.4971, Val Loss: 7790.7268
# Starting epoch 3011/5000
# Epoch 3011, Batch 100/479, Loss: 7997.1812
# Epoch 3011, Batch 200/479, Loss: 7476.8721
# Epoch 3011, Batch 300/479, Loss: 9889.6777
# Epoch 3011, Batch 400/479, Loss: 8944.3330
# Epoch 3011/5000, Batches Processed: 479, Train Loss: 7853.2647, Val Loss: 7559.0189
# Starting epoch 3012/5000
# Epoch 3012, Batch 100/479, Loss: 7854.3096
# Epoch 3012, Batch 200/479, Loss: 7132.4648
# Epoch 3012, Batch 300/479, Loss: 8204.7715
# Epoch 3012, Batch 400/479, Loss: 5885.3584
# Epoch 3012/5000, Batches Processed: 479, Train Loss: 7639.4805, Val Loss: 7327.8516
# Starting epoch 3013/5000
# Epoch 3013, Batch 100/479, Loss: 6486.4521
# Epoch 3013, Batch 200/479, Loss: 6323.2197
# Epoch 3013, Batch 300/479, Loss: 6718.2808
# Epoch 3013, Batch 400/479, Loss: 7548.5615
# Epoch 3013/5000, Batches Processed: 479, Train Loss: 7421.0040, Val Loss: 7180.4779
# Starting epoch 3014/5000
# Epoch 3014, Batch 100/479, Loss: 7042.4316
# Epoch 3014, Batch 200/479, Loss: 5699.1895
# Epoch 3014, Batch 300/479, Loss: 8053.6943
# Epoch 3014, Batch 400/479, Loss: 6043.3198
# Epoch 3014/5000, Batches Processed: 479, Train Loss: 7269.2504, Val Loss: 7007.8443
# Starting epoch 3015/5000
# Epoch 3015, Batch 100/479, Loss: 6754.0195
# Epoch 3015, Batch 200/479, Loss: 7082.4492
# Epoch 3015, Batch 300/479, Loss: 6878.3364
# Epoch 3015, Batch 400/479, Loss: 6354.1904
# Epoch 3015/5000, Batches Processed: 479, Train Loss: 7135.1945, Val Loss: 6929.3230
# Starting epoch 3016/5000
# Epoch 3016, Batch 100/479, Loss: 6764.7051
# Epoch 3016, Batch 200/479, Loss: 6693.4502
# Epoch 3016, Batch 300/479, Loss: 7308.2627
# Epoch 3016, Batch 400/479, Loss: 6169.4849
# Epoch 3016/5000, Batches Processed: 479, Train Loss: 7020.6014, Val Loss: 6817.5909
# Starting epoch 3017/5000
# Epoch 3017, Batch 100/479, Loss: 7214.1865
# Epoch 3017, Batch 200/479, Loss: 6905.9316
# Epoch 3017, Batch 300/479, Loss: 7510.4336
# Epoch 3017, Batch 400/479, Loss: 6448.9688
# Epoch 3017/5000, Batches Processed: 479, Train Loss: 6924.5895, Val Loss: 6723.0513
# Starting epoch 3018/5000
# Epoch 3018, Batch 100/479, Loss: 7182.9072
# Epoch 3018, Batch 200/479, Loss: 6381.3618
# Epoch 3018, Batch 300/479, Loss: 7129.0620
# Epoch 3018, Batch 400/479, Loss: 7725.7207
# Epoch 3018/5000, Batches Processed: 479, Train Loss: 6874.4071, Val Loss: 6695.4604
# Starting epoch 3019/5000
# Epoch 3019, Batch 100/479, Loss: 6827.6270
# Epoch 3019, Batch 200/479, Loss: 7556.6489
# Epoch 3019, Batch 300/479, Loss: 6290.5571
# Epoch 3019, Batch 400/479, Loss: 6984.2524
# Epoch 3019/5000, Batches Processed: 479, Train Loss: 6816.0138, Val Loss: 6619.6245
# Starting epoch 3020/5000
# Epoch 3020, Batch 100/479, Loss: 6330.4829
# Epoch 3020, Batch 200/479, Loss: 5845.5586
# Epoch 3020, Batch 300/479, Loss: 6150.6631
# Epoch 3020, Batch 400/479, Loss: 7046.8311
# Epoch 3020/5000, Batches Processed: 479, Train Loss: 6774.8247, Val Loss: 6616.7681
# Starting epoch 3021/5000
# Epoch 3021, Batch 100/479, Loss: 6951.8086
# Epoch 3021, Batch 200/479, Loss: 5655.3174
# Epoch 3021, Batch 300/479, Loss: 7139.8076
# Epoch 3021, Batch 400/479, Loss: 6034.6631
# Epoch 3021/5000, Batches Processed: 479, Train Loss: 6742.5759, Val Loss: 6692.5350
# Starting epoch 3022/5000
# Epoch 3022, Batch 100/479, Loss: 6117.5874
# Epoch 3022, Batch 200/479, Loss: 7876.2285
# Epoch 3022, Batch 300/479, Loss: 8410.1064
# Epoch 3022, Batch 400/479, Loss: 5275.5908
# Epoch 3022/5000, Batches Processed: 479, Train Loss: 6715.3005, Val Loss: 6504.0137
# Starting epoch 3023/5000
# Epoch 3023, Batch 100/479, Loss: 6632.8027
# Epoch 3023, Batch 200/479, Loss: 6033.8999
# Epoch 3023, Batch 300/479, Loss: 6309.3008
# Epoch 3023, Batch 400/479, Loss: 6628.2681
# Epoch 3023/5000, Batches Processed: 479, Train Loss: 6646.5454, Val Loss: 6488.2267
# Starting epoch 3024/5000
# Epoch 3024, Batch 100/479, Loss: 7613.5503
# Epoch 3024, Batch 200/479, Loss: 4944.1187
# Epoch 3024, Batch 300/479, Loss: 6456.7085
# Epoch 3024, Batch 400/479, Loss: 5088.8843
# Epoch 3024/5000, Batches Processed: 479, Train Loss: 6524.5543, Val Loss: 6317.7803
# Starting epoch 3025/5000
# Epoch 3025, Batch 100/479, Loss: 5897.1567
# Epoch 3025, Batch 200/479, Loss: 7025.3301
# Epoch 3025, Batch 300/479, Loss: 5988.2842
# Epoch 3025, Batch 400/479, Loss: 6539.9409
# Epoch 3025/5000, Batches Processed: 479, Train Loss: 6430.3811, Val Loss: 6243.5480
# Starting epoch 3026/5000
# Epoch 3026, Batch 100/479, Loss: 7093.4033
# Epoch 3026, Batch 200/479, Loss: 7126.3960
# Epoch 3026, Batch 300/479, Loss: 6714.5137
# Epoch 3026, Batch 400/479, Loss: 6837.4087
# Epoch 3026/5000, Batches Processed: 479, Train Loss: 6376.1490, Val Loss: 6204.2966
# Starting epoch 3027/5000
# Epoch 3027, Batch 100/479, Loss: 6953.8188
# Epoch 3027, Batch 200/479, Loss: 5058.2803
# Epoch 3027, Batch 300/479, Loss: 7677.3794
# Epoch 3027, Batch 400/479, Loss: 7931.6943
# Epoch 3027/5000, Batches Processed: 479, Train Loss: 6333.5628, Val Loss: 6188.5916
# Starting epoch 3028/5000
# Epoch 3028, Batch 100/479, Loss: 5643.3545
# Epoch 3028, Batch 200/479, Loss: 6224.9858
# Epoch 3028, Batch 300/479, Loss: 4875.7466
# Epoch 3028, Batch 400/479, Loss: 6463.6802
# Epoch 3028/5000, Batches Processed: 479, Train Loss: 6301.5697, Val Loss: 6137.0517
# Starting epoch 3029/5000
# Epoch 3029, Batch 100/479, Loss: 5733.3013
# Epoch 3029, Batch 200/479, Loss: 6936.8638
# Epoch 3029, Batch 300/479, Loss: 5776.6401
# Epoch 3029, Batch 400/479, Loss: 7832.7080
# Epoch 3029/5000, Batches Processed: 479, Train Loss: 6276.4387, Val Loss: 6113.1273
# Starting epoch 3030/5000
# Epoch 3030, Batch 100/479, Loss: 5390.0854
# Epoch 3030, Batch 200/479, Loss: 6577.2104
# Epoch 3030, Batch 300/479, Loss: 5398.5674
# Epoch 3030, Batch 400/479, Loss: 6612.6270
# Epoch 3030/5000, Batches Processed: 479, Train Loss: 6252.4404, Val Loss: 6086.8546
# Starting epoch 3031/5000
# Epoch 3031, Batch 100/479, Loss: 5729.9922
# Epoch 3031, Batch 200/479, Loss: 5707.4829
# Epoch 3031, Batch 300/479, Loss: 6524.7900
# Epoch 3031, Batch 400/479, Loss: 4840.9351
# Epoch 3031/5000, Batches Processed: 479, Train Loss: 6229.1759, Val Loss: 6070.5538
# Starting epoch 3032/5000
# Epoch 3032, Batch 100/479, Loss: 5867.8071
# Epoch 3032, Batch 200/479, Loss: 5095.1235
# Epoch 3032, Batch 300/479, Loss: 5156.7773
# Epoch 3032, Batch 400/479, Loss: 5495.7769
# Epoch 3032/5000, Batches Processed: 479, Train Loss: 6212.4632, Val Loss: 6053.0972
# Starting epoch 3033/5000
# Epoch 3033, Batch 100/479, Loss: 6169.0991
# Epoch 3033, Batch 200/479, Loss: 5561.1436
# Epoch 3033, Batch 300/479, Loss: 6928.5527
# Epoch 3033, Batch 400/479, Loss: 6878.7153
# Epoch 3033/5000, Batches Processed: 479, Train Loss: 6190.7923, Val Loss: 6031.3867
# Starting epoch 3034/5000
# Epoch 3034, Batch 100/479, Loss: 5285.5073
# Epoch 3034, Batch 200/479, Loss: 5577.1050
# Epoch 3034, Batch 300/479, Loss: 7412.3105
# Epoch 3034, Batch 400/479, Loss: 6269.7295
# Epoch 3034/5000, Batches Processed: 479, Train Loss: 6178.7448, Val Loss: 6017.5409
# Starting epoch 3035/5000
# Epoch 3035, Batch 100/479, Loss: 6027.0366
# Epoch 3035, Batch 200/479, Loss: 5381.8691
# Epoch 3035, Batch 300/479, Loss: 5836.8032
# Epoch 3035, Batch 400/479, Loss: 4980.0474
# Epoch 3035/5000, Batches Processed: 479, Train Loss: 6161.9961, Val Loss: 6005.6142
# Starting epoch 3036/5000
# Epoch 3036, Batch 100/479, Loss: 6007.6265
# Epoch 3036, Batch 200/479, Loss: 5502.8291
# Epoch 3036, Batch 300/479, Loss: 5550.6064
# Epoch 3036, Batch 400/479, Loss: 7199.5791
# Epoch 3036/5000, Batches Processed: 479, Train Loss: 6146.9652, Val Loss: 5986.8339
# Starting epoch 3037/5000
# Epoch 3037, Batch 100/479, Loss: 6376.8682
# Epoch 3037, Batch 200/479, Loss: 5817.6191
# Epoch 3037, Batch 300/479, Loss: 6643.4380
# Epoch 3037, Batch 400/479, Loss: 5640.1992
# Epoch 3037/5000, Batches Processed: 479, Train Loss: 6133.2177, Val Loss: 5974.1817
# Starting epoch 3038/5000
# Epoch 3038, Batch 100/479, Loss: 4836.3145
# Epoch 3038, Batch 200/479, Loss: 7276.8823
# Epoch 3038, Batch 300/479, Loss: 7493.3989
# Epoch 3038, Batch 400/479, Loss: 6950.8706
# Epoch 3038/5000, Batches Processed: 479, Train Loss: 6116.1148, Val Loss: 5961.2049
# Starting epoch 3039/5000
# Epoch 3039, Batch 100/479, Loss: 5958.3926
# Epoch 3039, Batch 200/479, Loss: 5502.2305
# Epoch 3039, Batch 300/479, Loss: 6135.4717
# Epoch 3039, Batch 400/479, Loss: 6353.0532
# Epoch 3039/5000, Batches Processed: 479, Train Loss: 6103.2383, Val Loss: 5948.4232
# Starting epoch 3040/5000
# Epoch 3040, Batch 100/479, Loss: 5952.2954
# Epoch 3040, Batch 200/479, Loss: 5293.1870
# Epoch 3040, Batch 300/479, Loss: 6904.9082
# Epoch 3040, Batch 400/479, Loss: 5953.7046
# Epoch 3040/5000, Batches Processed: 479, Train Loss: 6093.1921, Val Loss: 5935.5371
# Starting epoch 3041/5000
# Epoch 3041, Batch 100/479, Loss: 6209.6689
# Epoch 3041, Batch 200/479, Loss: 6597.3193
# Epoch 3041, Batch 300/479, Loss: 6013.4238
# Epoch 3041, Batch 400/479, Loss: 5832.7871
# Epoch 3041/5000, Batches Processed: 479, Train Loss: 6077.7286, Val Loss: 5925.0876
# Starting epoch 3042/5000
# Epoch 3042, Batch 100/479, Loss: 6059.3691
# Epoch 3042, Batch 200/479, Loss: 6427.7876
# Epoch 3042, Batch 300/479, Loss: 6799.1929
# Epoch 3042, Batch 400/479, Loss: 6339.1279
# Epoch 3042/5000, Batches Processed: 479, Train Loss: 6064.6991, Val Loss: 5908.5631
# Starting epoch 3043/5000
# Epoch 3043, Batch 100/479, Loss: 5248.5107
# Epoch 3043, Batch 200/479, Loss: 5152.9131
# Epoch 3043, Batch 300/479, Loss: 7752.6602
# Epoch 3043, Batch 400/479, Loss: 6492.4814
# Epoch 3043/5000, Batches Processed: 479, Train Loss: 6055.4751, Val Loss: 5903.0061
# Starting epoch 3044/5000
# Epoch 3044, Batch 100/479, Loss: 5735.4946
# Epoch 3044, Batch 200/479, Loss: 6251.6460
# Epoch 3044, Batch 300/479, Loss: 8364.8613
# Epoch 3044, Batch 400/479, Loss: 5064.1436
# Epoch 3044/5000, Batches Processed: 479, Train Loss: 6044.7708, Val Loss: 5889.1256
# Starting epoch 3045/5000
# Epoch 3045, Batch 100/479, Loss: 5679.6074
# Epoch 3045, Batch 200/479, Loss: 6083.1475
# Epoch 3045, Batch 300/479, Loss: 7200.3857
# Epoch 3045, Batch 400/479, Loss: 5627.9824
# Epoch 3045/5000, Batches Processed: 479, Train Loss: 6035.1044, Val Loss: 5887.1137
# Starting epoch 3046/5000
# Epoch 3046, Batch 100/479, Loss: 6300.2676
# Epoch 3046, Batch 200/479, Loss: 5986.1860
# Epoch 3046, Batch 300/479, Loss: 6909.9102
# Epoch 3046, Batch 400/479, Loss: 6917.2988
# Epoch 3046/5000, Batches Processed: 479, Train Loss: 6021.3842, Val Loss: 5873.4784
# Starting epoch 3047/5000
# Epoch 3047, Batch 100/479, Loss: 5426.1162
# Epoch 3047, Batch 200/479, Loss: 6553.5005
# Epoch 3047, Batch 300/479, Loss: 4889.6333
# Epoch 3047, Batch 400/479, Loss: 6290.0835
# Epoch 3047/5000, Batches Processed: 479, Train Loss: 6015.7836, Val Loss: 5856.3426
# Starting epoch 3048/5000
# Epoch 3048, Batch 100/479, Loss: 6241.5327
# Epoch 3048, Batch 200/479, Loss: 6327.6387
# Epoch 3048, Batch 300/479, Loss: 6515.5049
# Epoch 3048, Batch 400/479, Loss: 5804.8164
# Epoch 3048/5000, Batches Processed: 479, Train Loss: 6003.4455, Val Loss: 5854.1886
# Starting epoch 3049/5000
# Epoch 3049, Batch 100/479, Loss: 5600.1821
# Epoch 3049, Batch 200/479, Loss: 7081.2998
# Epoch 3049, Batch 300/479, Loss: 5768.3276
# Epoch 3049, Batch 400/479, Loss: 5784.7441
# Epoch 3049/5000, Batches Processed: 479, Train Loss: 5993.9449, Val Loss: 5849.1857
# Starting epoch 3050/5000
# Epoch 3050, Batch 100/479, Loss: 6933.7910
# Epoch 3050, Batch 200/479, Loss: 5381.2998
# Epoch 3050, Batch 300/479, Loss: 5577.8823
# Epoch 3050, Batch 400/479, Loss: 5566.8867
# Epoch 3050/5000, Batches Processed: 479, Train Loss: 5981.6742, Val Loss: 5832.9138
# Starting epoch 3051/5000
# Epoch 3051, Batch 100/479, Loss: 5573.3550
# Epoch 3051, Batch 200/479, Loss: 6989.6523
# Epoch 3051, Batch 300/479, Loss: 5145.4351
# Epoch 3051, Batch 400/479, Loss: 7056.2944
# Epoch 3051/5000, Batches Processed: 479, Train Loss: 5973.3285, Val Loss: 5824.2392
# Starting epoch 3052/5000
# Epoch 3052, Batch 100/479, Loss: 6159.7949
# Epoch 3052, Batch 200/479, Loss: 6076.3770
# Epoch 3052, Batch 300/479, Loss: 5449.3223
# Epoch 3052, Batch 400/479, Loss: 5616.3125
# Epoch 3052/5000, Batches Processed: 479, Train Loss: 5963.1344, Val Loss: 5812.9165
# Starting epoch 3053/5000
# Epoch 3053, Batch 100/479, Loss: 5480.0889
# Epoch 3053, Batch 200/479, Loss: 6348.9951
# Epoch 3053, Batch 300/479, Loss: 6137.4111
# Epoch 3053, Batch 400/479, Loss: 5534.8623
# Epoch 3053/5000, Batches Processed: 479, Train Loss: 5956.7575, Val Loss: 5803.9420
# Starting epoch 3054/5000
# Epoch 3054, Batch 100/479, Loss: 4872.3008
# Epoch 3054, Batch 200/479, Loss: 5679.9810
# Epoch 3054, Batch 300/479, Loss: 5494.6475
# Epoch 3054, Batch 400/479, Loss: 5482.0933
# Epoch 3054/5000, Batches Processed: 479, Train Loss: 5944.7456, Val Loss: 5799.6110
# Starting epoch 3055/5000
# Epoch 3055, Batch 100/479, Loss: 6341.3989
# Epoch 3055, Batch 200/479, Loss: 4329.0674
# Epoch 3055, Batch 300/479, Loss: 5777.0181
# Epoch 3055, Batch 400/479, Loss: 4224.1860
# Epoch 3055/5000, Batches Processed: 479, Train Loss: 5934.2286, Val Loss: 5795.1080
# Starting epoch 3056/5000
# Epoch 3056, Batch 100/479, Loss: 6598.1045
# Epoch 3056, Batch 200/479, Loss: 5022.3403
# Epoch 3056, Batch 300/479, Loss: 5467.9023
# Epoch 3056, Batch 400/479, Loss: 4594.2646
# Epoch 3056/5000, Batches Processed: 479, Train Loss: 5928.0415, Val Loss: 5780.9004
# Starting epoch 3057/5000
# Epoch 3057, Batch 100/479, Loss: 5849.5112
# Epoch 3057, Batch 200/479, Loss: 5922.1509
# Epoch 3057, Batch 300/479, Loss: 7022.0132
# Epoch 3057, Batch 400/479, Loss: 5746.4727
# Epoch 3057/5000, Batches Processed: 479, Train Loss: 5915.8593, Val Loss: 5772.7112
# Starting epoch 3058/5000
# Epoch 3058, Batch 100/479, Loss: 5953.6182
# Epoch 3058, Batch 200/479, Loss: 4684.7329
# Epoch 3058, Batch 300/479, Loss: 4747.9453
# Epoch 3058, Batch 400/479, Loss: 4774.5312
# Epoch 3058/5000, Batches Processed: 479, Train Loss: 5908.8371, Val Loss: 5767.8463
# Starting epoch 3059/5000
# Epoch 3059, Batch 100/479, Loss: 6507.2529
# Epoch 3059, Batch 200/479, Loss: 5891.7803
# Epoch 3059, Batch 300/479, Loss: 5956.2700
# Epoch 3059, Batch 400/479, Loss: 6211.6748
# Epoch 3059/5000, Batches Processed: 479, Train Loss: 5899.6994, Val Loss: 5757.6986
# Starting epoch 3060/5000
# Epoch 3060, Batch 100/479, Loss: 5162.9668
# Epoch 3060, Batch 200/479, Loss: 6256.3589
# Epoch 3060, Batch 300/479, Loss: 6302.9580
# Epoch 3060, Batch 400/479, Loss: 7670.8164
# Epoch 3060/5000, Batches Processed: 479, Train Loss: 5892.7737, Val Loss: 5751.6663
# Starting epoch 3061/5000
# Epoch 3061, Batch 100/479, Loss: 6315.7666
# Epoch 3061, Batch 200/479, Loss: 6043.5493
# Epoch 3061, Batch 300/479, Loss: 6142.8057
# Epoch 3061, Batch 400/479, Loss: 5537.8574
# Epoch 3061/5000, Batches Processed: 479, Train Loss: 5886.5180, Val Loss: 5746.6114
# Starting epoch 3062/5000
# Epoch 3062, Batch 100/479, Loss: 5654.9390
# Epoch 3062, Batch 200/479, Loss: 6049.2603
# Epoch 3062, Batch 300/479, Loss: 4292.1704
# Epoch 3062, Batch 400/479, Loss: 4281.1572
# Epoch 3062/5000, Batches Processed: 479, Train Loss: 5875.9364, Val Loss: 5733.1629
# Starting epoch 3063/5000
# Epoch 3063, Batch 100/479, Loss: 6426.6924
# Epoch 3063, Batch 200/479, Loss: 5246.4746
# Epoch 3063, Batch 300/479, Loss: 7421.5713
# Epoch 3063, Batch 400/479, Loss: 6848.7021
# Epoch 3063/5000, Batches Processed: 479, Train Loss: 5869.7619, Val Loss: 5726.6682
# Starting epoch 3064/5000
# Epoch 3064, Batch 100/479, Loss: 6019.2036
# Epoch 3064, Batch 200/479, Loss: 5668.2046
# Epoch 3064, Batch 300/479, Loss: 4811.2905
# Epoch 3064, Batch 400/479, Loss: 5516.3711
# Epoch 3064/5000, Batches Processed: 479, Train Loss: 5860.0104, Val Loss: 5726.0535
# Starting epoch 3065/5000
# Epoch 3065, Batch 100/479, Loss: 4978.7026
# Epoch 3065, Batch 200/479, Loss: 4463.1797
# Epoch 3065, Batch 300/479, Loss: 5503.5034
# Epoch 3065, Batch 400/479, Loss: 5842.5859
# Epoch 3065/5000, Batches Processed: 479, Train Loss: 5853.7712, Val Loss: 5715.1353
# Starting epoch 3066/5000
# Epoch 3066, Batch 100/479, Loss: 7701.4434
# Epoch 3066, Batch 200/479, Loss: 5221.0547
# Epoch 3066, Batch 300/479, Loss: 5679.5874
# Epoch 3066, Batch 400/479, Loss: 5832.8838
# Epoch 3066/5000, Batches Processed: 479, Train Loss: 5846.4365, Val Loss: 5706.8883
# Starting epoch 3067/5000
# Epoch 3067, Batch 100/479, Loss: 4725.7666
# Epoch 3067, Batch 200/479, Loss: 5377.3794
# Epoch 3067, Batch 300/479, Loss: 6556.1543
# Epoch 3067, Batch 400/479, Loss: 5830.4858
# Epoch 3067/5000, Batches Processed: 479, Train Loss: 5837.7343, Val Loss: 5706.9003
# Starting epoch 3068/5000
# Epoch 3068, Batch 100/479, Loss: 5695.1616
# Epoch 3068, Batch 200/479, Loss: 5338.5205
# Epoch 3068, Batch 300/479, Loss: 5381.2729
# Epoch 3068, Batch 400/479, Loss: 6225.3247
# Epoch 3068/5000, Batches Processed: 479, Train Loss: 5831.2658, Val Loss: 5699.0412
# Starting epoch 3069/5000
# Epoch 3069, Batch 100/479, Loss: 6178.7012
# Epoch 3069, Batch 200/479, Loss: 7022.8530
# Epoch 3069, Batch 300/479, Loss: 5989.5659
# Epoch 3069, Batch 400/479, Loss: 6188.4810
# Epoch 3069/5000, Batches Processed: 479, Train Loss: 5828.5227, Val Loss: 5687.1157
# Starting epoch 3070/5000
# Epoch 3070, Batch 100/479, Loss: 4952.8013
# Epoch 3070, Batch 200/479, Loss: 5757.4395
# Epoch 3070, Batch 300/479, Loss: 5251.6553
# Epoch 3070, Batch 400/479, Loss: 5157.7456
# Epoch 3070/5000, Batches Processed: 479, Train Loss: 5818.4301, Val Loss: 5682.5921
# Starting epoch 3071/5000
# Epoch 3071, Batch 100/479, Loss: 7141.2080
# Epoch 3071, Batch 200/479, Loss: 6808.6519
# Epoch 3071, Batch 300/479, Loss: 5195.3452
# Epoch 3071, Batch 400/479, Loss: 5445.6323
# Epoch 3071/5000, Batches Processed: 479, Train Loss: 5809.0248, Val Loss: 5674.1580
# Starting epoch 3072/5000
# Epoch 3072, Batch 100/479, Loss: 4864.2280
# Epoch 3072, Batch 200/479, Loss: 5320.4209
# Epoch 3072, Batch 300/479, Loss: 5556.1318
# Epoch 3072, Batch 400/479, Loss: 6215.1499
# Epoch 3072/5000, Batches Processed: 479, Train Loss: 5802.3392, Val Loss: 5670.9647
# Starting epoch 3073/5000
# Epoch 3073, Batch 100/479, Loss: 6146.4355
# Epoch 3073, Batch 200/479, Loss: 4405.9766
# Epoch 3073, Batch 300/479, Loss: 5192.0669
# Epoch 3073, Batch 400/479, Loss: 7337.3926
# Epoch 3073/5000, Batches Processed: 479, Train Loss: 5796.5764, Val Loss: 5663.9852
# Starting epoch 3074/5000
# Epoch 3074, Batch 100/479, Loss: 5881.0449
# Epoch 3074, Batch 200/479, Loss: 4681.0244
# Epoch 3074, Batch 300/479, Loss: 7296.9043
# Epoch 3074, Batch 400/479, Loss: 6004.2036
# Epoch 3074/5000, Batches Processed: 479, Train Loss: 5791.2283, Val Loss: 5656.2168
# Starting epoch 3075/5000
# Epoch 3075, Batch 100/479, Loss: 5173.3354
# Epoch 3075, Batch 200/479, Loss: 4934.0391
# Epoch 3075, Batch 300/479, Loss: 6401.2578
# Epoch 3075, Batch 400/479, Loss: 4629.8281
# Epoch 3075/5000, Batches Processed: 479, Train Loss: 5781.7227, Val Loss: 5651.8806
# Starting epoch 3076/5000
# Epoch 3076, Batch 100/479, Loss: 5812.1172
# Epoch 3076, Batch 200/479, Loss: 5307.4487
# Epoch 3076, Batch 300/479, Loss: 6189.4570
# Epoch 3076, Batch 400/479, Loss: 4957.6182
# Epoch 3076/5000, Batches Processed: 479, Train Loss: 5773.7270, Val Loss: 5642.4969
# Starting epoch 3077/5000
# Epoch 3077, Batch 100/479, Loss: 6320.1460
# Epoch 3077, Batch 200/479, Loss: 5994.1431
# Epoch 3077, Batch 300/479, Loss: 4255.5347
# Epoch 3077, Batch 400/479, Loss: 6855.0034
# Epoch 3077/5000, Batches Processed: 479, Train Loss: 5769.9812, Val Loss: 5639.7481
# Starting epoch 3078/5000
# Epoch 3078, Batch 100/479, Loss: 5561.5352
# Epoch 3078, Batch 200/479, Loss: 5233.4341
# Epoch 3078, Batch 300/479, Loss: 6997.4224
# Epoch 3078, Batch 400/479, Loss: 5252.2686
# Epoch 3078/5000, Batches Processed: 479, Train Loss: 5762.6907, Val Loss: 5627.1789
# Starting epoch 3079/5000
# Epoch 3079, Batch 100/479, Loss: 5555.9341
# Epoch 3079, Batch 200/479, Loss: 5553.9961
# Epoch 3079, Batch 300/479, Loss: 4934.3179
# Epoch 3079, Batch 400/479, Loss: 5089.3286
# Epoch 3079/5000, Batches Processed: 479, Train Loss: 5758.1821, Val Loss: 5626.6830
# Starting epoch 3080/5000
# Epoch 3080, Batch 100/479, Loss: 6048.8525
# Epoch 3080, Batch 200/479, Loss: 6628.8945
# Epoch 3080, Batch 300/479, Loss: 5034.8018
# Epoch 3080, Batch 400/479, Loss: 5088.7495
# Epoch 3080/5000, Batches Processed: 479, Train Loss: 5752.5699, Val Loss: 5619.0083
# Starting epoch 3081/5000
# Epoch 3081, Batch 100/479, Loss: 4488.9814
# Epoch 3081, Batch 200/479, Loss: 4555.3027
# Epoch 3081, Batch 300/479, Loss: 5303.2749
# Epoch 3081, Batch 400/479, Loss: 5528.8354
# Epoch 3081/5000, Batches Processed: 479, Train Loss: 5745.8289, Val Loss: 5617.5738
# Starting epoch 3082/5000
# Epoch 3082, Batch 100/479, Loss: 6089.0444
# Epoch 3082, Batch 200/479, Loss: 4923.2480
# Epoch 3082, Batch 300/479, Loss: 6585.2007
# Epoch 3082, Batch 400/479, Loss: 5565.8647
# Epoch 3082/5000, Batches Processed: 479, Train Loss: 5740.1721, Val Loss: 5612.8585
# Starting epoch 3083/5000
# Epoch 3083, Batch 100/479, Loss: 5740.5347
# Epoch 3083, Batch 200/479, Loss: 5105.1162
# Epoch 3083, Batch 300/479, Loss: 5290.0054
# Epoch 3083, Batch 400/479, Loss: 5939.2095
# Epoch 3083/5000, Batches Processed: 479, Train Loss: 5729.3286, Val Loss: 5602.5458
# Starting epoch 3084/5000
# Epoch 3084, Batch 100/479, Loss: 6004.1602
# Epoch 3084, Batch 200/479, Loss: 6751.3418
# Epoch 3084, Batch 300/479, Loss: 5196.5742
# Epoch 3084, Batch 400/479, Loss: 4792.2666
# Epoch 3084/5000, Batches Processed: 479, Train Loss: 5725.9548, Val Loss: 5603.5132
# Starting epoch 3085/5000
# Epoch 3085, Batch 100/479, Loss: 4821.9321
# Epoch 3085, Batch 200/479, Loss: 5852.2520
# Epoch 3085, Batch 300/479, Loss: 6479.4570
# Epoch 3085, Batch 400/479, Loss: 5322.2471
# Epoch 3085/5000, Batches Processed: 479, Train Loss: 5720.1961, Val Loss: 5589.8795
# Starting epoch 3086/5000
# Epoch 3086, Batch 100/479, Loss: 5543.6777
# Epoch 3086, Batch 200/479, Loss: 5450.2939
# Epoch 3086, Batch 300/479, Loss: 6411.4395
# Epoch 3086, Batch 400/479, Loss: 6043.8735
# Epoch 3086/5000, Batches Processed: 479, Train Loss: 5711.3535, Val Loss: 5588.7720
# Starting epoch 3087/5000
# Epoch 3087, Batch 100/479, Loss: 5280.5850
# Epoch 3087, Batch 200/479, Loss: 6006.0513
# Epoch 3087, Batch 300/479, Loss: 6721.2139
# Epoch 3087, Batch 400/479, Loss: 4691.8037
# Epoch 3087/5000, Batches Processed: 479, Train Loss: 5710.4527, Val Loss: 5587.5509
# Starting epoch 3088/5000
# Epoch 3088, Batch 100/479, Loss: 5934.1445
# Epoch 3088, Batch 200/479, Loss: 6233.9956
# Epoch 3088, Batch 300/479, Loss: 6108.0591
# Epoch 3088, Batch 400/479, Loss: 6207.9536
# Epoch 3088/5000, Batches Processed: 479, Train Loss: 5700.6104, Val Loss: 5572.6511
# Starting epoch 3089/5000
# Epoch 3089, Batch 100/479, Loss: 5745.2173
# Epoch 3089, Batch 200/479, Loss: 4859.2227
# Epoch 3089, Batch 300/479, Loss: 5917.7876
# Epoch 3089, Batch 400/479, Loss: 5306.5903
# Epoch 3089/5000, Batches Processed: 479, Train Loss: 5698.8818, Val Loss: 5571.0268
# Starting epoch 3090/5000
# Epoch 3090, Batch 100/479, Loss: 4843.6240
# Epoch 3090, Batch 200/479, Loss: 5506.4839
# Epoch 3090, Batch 300/479, Loss: 5544.1240
# Epoch 3090, Batch 400/479, Loss: 5686.2979
# Epoch 3090/5000, Batches Processed: 479, Train Loss: 5688.7835, Val Loss: 5564.6509
# Starting epoch 3091/5000
# Epoch 3091, Batch 100/479, Loss: 6216.5352
# Epoch 3091, Batch 200/479, Loss: 5920.0981
# Epoch 3091, Batch 300/479, Loss: 4999.4873
# Epoch 3091, Batch 400/479, Loss: 4607.8799
# Epoch 3091/5000, Batches Processed: 479, Train Loss: 5684.8264, Val Loss: 5557.5299
# Starting epoch 3092/5000
# Epoch 3092, Batch 100/479, Loss: 4485.8428
# Epoch 3092, Batch 200/479, Loss: 5621.3794
# Epoch 3092, Batch 300/479, Loss: 5242.4478
# Epoch 3092, Batch 400/479, Loss: 6712.0791
# Epoch 3092/5000, Batches Processed: 479, Train Loss: 5678.9677, Val Loss: 5558.2596
# Starting epoch 3093/5000
# Epoch 3093, Batch 100/479, Loss: 5928.8394
# Epoch 3093, Batch 200/479, Loss: 4769.9985
# Epoch 3093, Batch 300/479, Loss: 5952.1099
# Epoch 3093, Batch 400/479, Loss: 4789.5581
# Epoch 3093/5000, Batches Processed: 479, Train Loss: 5674.2446, Val Loss: 5553.4199
# Starting epoch 3094/5000
# Epoch 3094, Batch 100/479, Loss: 6087.1177
# Epoch 3094, Batch 200/479, Loss: 7610.9395
# Epoch 3094, Batch 300/479, Loss: 5639.2383
# Epoch 3094, Batch 400/479, Loss: 4623.2793
# Epoch 3094/5000, Batches Processed: 479, Train Loss: 5669.9792, Val Loss: 5551.1696
# Starting epoch 3095/5000
# Epoch 3095, Batch 100/479, Loss: 5020.7988
# Epoch 3095, Batch 200/479, Loss: 4517.8657
# Epoch 3095, Batch 300/479, Loss: 5425.3843
# Epoch 3095, Batch 400/479, Loss: 6484.2964
# Epoch 3095/5000, Batches Processed: 479, Train Loss: 5663.8995, Val Loss: 5540.7441
# Starting epoch 3096/5000
# Epoch 3096, Batch 100/479, Loss: 6478.8818
# Epoch 3096, Batch 200/479, Loss: 5358.1924
# Epoch 3096, Batch 300/479, Loss: 5169.1284
# Epoch 3096, Batch 400/479, Loss: 5025.6997
# Epoch 3096/5000, Batches Processed: 479, Train Loss: 5654.8817, Val Loss: 5536.9885
# Starting epoch 3097/5000
# Epoch 3097, Batch 100/479, Loss: 6324.8208
# Epoch 3097, Batch 200/479, Loss: 6097.2725
# Epoch 3097, Batch 300/479, Loss: 6478.7598
# Epoch 3097, Batch 400/479, Loss: 5615.5542
# Epoch 3097/5000, Batches Processed: 479, Train Loss: 5652.0842, Val Loss: 5533.8412
# Starting epoch 3098/5000
# Epoch 3098, Batch 100/479, Loss: 6286.3555
# Epoch 3098, Batch 200/479, Loss: 5960.0322
# Epoch 3098, Batch 300/479, Loss: 5734.1226
# Epoch 3098, Batch 400/479, Loss: 5290.3198
# Epoch 3098/5000, Batches Processed: 479, Train Loss: 5647.4683, Val Loss: 5529.7152
# Starting epoch 3099/5000
# Epoch 3099, Batch 100/479, Loss: 6351.1826
# Epoch 3099, Batch 200/479, Loss: 5540.7402
# Epoch 3099, Batch 300/479, Loss: 5668.5029
# Epoch 3099, Batch 400/479, Loss: 6273.4541
# Epoch 3099/5000, Batches Processed: 479, Train Loss: 5642.0247, Val Loss: 5522.6037
# Starting epoch 3100/5000
# Epoch 3100, Batch 100/479, Loss: 6158.0479
# Epoch 3100, Batch 200/479, Loss: 5658.8506
# Epoch 3100, Batch 300/479, Loss: 5799.2720
# Epoch 3100, Batch 400/479, Loss: 4988.0132
# Epoch 3100/5000, Batches Processed: 479, Train Loss: 5638.2352, Val Loss: 5521.8115
# Starting epoch 3101/5000
# Epoch 3101, Batch 100/479, Loss: 5172.4326
# Epoch 3101, Batch 200/479, Loss: 5872.2578
# Epoch 3101, Batch 300/479, Loss: 5274.8242
# Epoch 3101, Batch 400/479, Loss: 6975.9556
# Epoch 3101/5000, Batches Processed: 479, Train Loss: 5633.7940, Val Loss: 5514.8291
# Starting epoch 3102/5000
# Epoch 3102, Batch 100/479, Loss: 6062.1694
# Epoch 3102, Batch 200/479, Loss: 5697.3115
# Epoch 3102, Batch 300/479, Loss: 4634.5229
# Epoch 3102, Batch 400/479, Loss: 4625.0288
# Epoch 3102/5000, Batches Processed: 479, Train Loss: 5626.0366, Val Loss: 5506.4228
# Starting epoch 3103/5000
# Epoch 3103, Batch 100/479, Loss: 4703.6426
# Epoch 3103, Batch 200/479, Loss: 6685.4185
# Epoch 3103, Batch 300/479, Loss: 5892.4014
# Epoch 3103, Batch 400/479, Loss: 6132.0166
# Epoch 3103/5000, Batches Processed: 479, Train Loss: 5622.2440, Val Loss: 5507.5292
# Starting epoch 3104/5000
# Epoch 3104, Batch 100/479, Loss: 5223.9233
# Epoch 3104, Batch 200/479, Loss: 4864.5889
# Epoch 3104, Batch 300/479, Loss: 4694.0142
# Epoch 3104, Batch 400/479, Loss: 5583.1284
# Epoch 3104/5000, Batches Processed: 479, Train Loss: 5617.1556, Val Loss: 5498.7649
# Starting epoch 3105/5000
# Epoch 3105, Batch 100/479, Loss: 4883.1294
# Epoch 3105, Batch 200/479, Loss: 4877.4062
# Epoch 3105, Batch 300/479, Loss: 5890.2817
# Epoch 3105, Batch 400/479, Loss: 5978.6460
# Epoch 3105/5000, Batches Processed: 479, Train Loss: 5612.0660, Val Loss: 5502.8272
# Starting epoch 3106/5000
# Epoch 3106, Batch 100/479, Loss: 5349.4624
# Epoch 3106, Batch 200/479, Loss: 6296.2173
# Epoch 3106, Batch 300/479, Loss: 5177.1514
# Epoch 3106, Batch 400/479, Loss: 5380.6216
# Epoch 3106/5000, Batches Processed: 479, Train Loss: 5607.9515, Val Loss: 5492.4815
# Starting epoch 3107/5000
# Epoch 3107, Batch 100/479, Loss: 6453.1714
# Epoch 3107, Batch 200/479, Loss: 5380.7412
# Epoch 3107, Batch 300/479, Loss: 4824.5010
# Epoch 3107, Batch 400/479, Loss: 6494.1514
# Epoch 3107/5000, Batches Processed: 479, Train Loss: 5604.9482, Val Loss: 5493.7078
# Starting epoch 3108/5000
# Epoch 3108, Batch 100/479, Loss: 5271.1816
# Epoch 3108, Batch 200/479, Loss: 6497.5371
# Epoch 3108, Batch 300/479, Loss: 5686.2319
# Epoch 3108, Batch 400/479, Loss: 5589.5986
# Epoch 3108/5000, Batches Processed: 479, Train Loss: 5596.1306, Val Loss: 5480.9138
# Starting epoch 3109/5000
# Epoch 3109, Batch 100/479, Loss: 4776.8442
# Epoch 3109, Batch 200/479, Loss: 5958.8477
# Epoch 3109, Batch 300/479, Loss: 5467.8003
# Epoch 3109, Batch 400/479, Loss: 4960.9990
# Epoch 3109/5000, Batches Processed: 479, Train Loss: 5594.4747, Val Loss: 5481.5005
# Starting epoch 3110/5000
# Epoch 3110, Batch 100/479, Loss: 5854.4233
# Epoch 3110, Batch 200/479, Loss: 5141.8857
# Epoch 3110, Batch 300/479, Loss: 6520.2563
# Epoch 3110, Batch 400/479, Loss: 4797.6533
# Epoch 3110/5000, Batches Processed: 479, Train Loss: 5586.7920, Val Loss: 5478.7338
# Starting epoch 3111/5000
# Epoch 3111, Batch 100/479, Loss: 6044.7871
# Epoch 3111, Batch 200/479, Loss: 4883.8574
# Epoch 3111, Batch 300/479, Loss: 5502.3735
# Epoch 3111, Batch 400/479, Loss: 4444.5039
# Epoch 3111/5000, Batches Processed: 479, Train Loss: 5586.3082, Val Loss: 5471.4591
# Starting epoch 3112/5000
# Epoch 3112, Batch 100/479, Loss: 5917.2744
# Epoch 3112, Batch 200/479, Loss: 5405.0249
# Epoch 3112, Batch 300/479, Loss: 5064.2520
# Epoch 3112, Batch 400/479, Loss: 5963.2925
# Epoch 3112/5000, Batches Processed: 479, Train Loss: 5574.9983, Val Loss: 5469.0565
# Starting epoch 3113/5000
# Epoch 3113, Batch 100/479, Loss: 5010.5254
# Epoch 3113, Batch 200/479, Loss: 4949.3950
# Epoch 3113, Batch 300/479, Loss: 5559.5322
# Epoch 3113, Batch 400/479, Loss: 5771.4751
# Epoch 3113/5000, Batches Processed: 479, Train Loss: 5574.1864, Val Loss: 5469.7851
# Starting epoch 3114/5000
# Epoch 3114, Batch 100/479, Loss: 6656.1553
# Epoch 3114, Batch 200/479, Loss: 5881.0161
# Epoch 3114, Batch 300/479, Loss: 6202.6016
# Epoch 3114, Batch 400/479, Loss: 5948.3877
# Epoch 3114/5000, Batches Processed: 479, Train Loss: 5572.6938, Val Loss: 5461.0566
# Starting epoch 3115/5000
# Epoch 3115, Batch 100/479, Loss: 6353.5630
# Epoch 3115, Batch 200/479, Loss: 5324.6592
# Epoch 3115, Batch 300/479, Loss: 5587.3315
# Epoch 3115, Batch 400/479, Loss: 5155.3149
# Epoch 3115/5000, Batches Processed: 479, Train Loss: 5565.0237, Val Loss: 5456.6257
# Starting epoch 3116/5000
# Epoch 3116, Batch 100/479, Loss: 5360.2695
# Epoch 3116, Batch 200/479, Loss: 5867.1787
# Epoch 3116, Batch 300/479, Loss: 5577.0576
# Epoch 3116, Batch 400/479, Loss: 6457.6885
# Epoch 3116/5000, Batches Processed: 479, Train Loss: 5562.8603, Val Loss: 5455.2273
# Starting epoch 3117/5000
# Epoch 3117, Batch 100/479, Loss: 4482.1187
# Epoch 3117, Batch 200/479, Loss: 5136.7207
# Epoch 3117, Batch 300/479, Loss: 5958.0439
# Epoch 3117, Batch 400/479, Loss: 5005.5527
# Epoch 3117/5000, Batches Processed: 479, Train Loss: 5556.5761, Val Loss: 5451.3938
# Starting epoch 3118/5000
# Epoch 3118, Batch 100/479, Loss: 4631.7407
# Epoch 3118, Batch 200/479, Loss: 5437.8188
# Epoch 3118, Batch 300/479, Loss: 5204.3433
# Epoch 3118, Batch 400/479, Loss: 6223.2515
# Epoch 3118/5000, Batches Processed: 479, Train Loss: 5551.2116, Val Loss: 5452.4518
# Starting epoch 3119/5000
# Epoch 3119, Batch 100/479, Loss: 6124.0151
# Epoch 3119, Batch 200/479, Loss: 5673.2734
# Epoch 3119, Batch 300/479, Loss: 5247.6924
# Epoch 3119, Batch 400/479, Loss: 4556.4482
# Epoch 3119/5000, Batches Processed: 479, Train Loss: 5551.9207, Val Loss: 5440.4474
# Starting epoch 3120/5000
# Epoch 3120, Batch 100/479, Loss: 6522.8545
# Epoch 3120, Batch 200/479, Loss: 5450.6030
# Epoch 3120, Batch 300/479, Loss: 6265.2173
# Epoch 3120, Batch 400/479, Loss: 6482.9907
# Epoch 3120/5000, Batches Processed: 479, Train Loss: 5545.7663, Val Loss: 5441.5257
# Starting epoch 3121/5000
# Epoch 3121, Batch 100/479, Loss: 5197.4585
# Epoch 3121, Batch 200/479, Loss: 6926.6836
# Epoch 3121, Batch 300/479, Loss: 5039.7217
# Epoch 3121, Batch 400/479, Loss: 5206.3145
# Epoch 3121/5000, Batches Processed: 479, Train Loss: 5542.3184, Val Loss: 5435.9972
# Starting epoch 3122/5000
# Epoch 3122, Batch 100/479, Loss: 5222.2915
# Epoch 3122, Batch 200/479, Loss: 6199.1416
# Epoch 3122, Batch 300/479, Loss: 5126.7842
# Epoch 3122, Batch 400/479, Loss: 6046.7271
# Epoch 3122/5000, Batches Processed: 479, Train Loss: 5536.7510, Val Loss: 5430.6667
# Starting epoch 3123/5000
# Epoch 3123, Batch 100/479, Loss: 6376.1167
# Epoch 3123, Batch 200/479, Loss: 6237.0269
# Epoch 3123, Batch 300/479, Loss: 6753.8848
# Epoch 3123, Batch 400/479, Loss: 6112.6323
# Epoch 3123/5000, Batches Processed: 479, Train Loss: 5535.1746, Val Loss: 5435.0126
# Starting epoch 3124/5000
# Epoch 3124, Batch 100/479, Loss: 4464.2300
# Epoch 3124, Batch 200/479, Loss: 6308.4355
# Epoch 3124, Batch 300/479, Loss: 5583.9556
# Epoch 3124, Batch 400/479, Loss: 5695.0513
# Epoch 3124/5000, Batches Processed: 479, Train Loss: 5530.7178, Val Loss: 5427.9137
# Starting epoch 3125/5000
# Epoch 3125, Batch 100/479, Loss: 5278.6392
# Epoch 3125, Batch 200/479, Loss: 5995.1919
# Epoch 3125, Batch 300/479, Loss: 5186.3931
# Epoch 3125, Batch 400/479, Loss: 7921.3687
# Epoch 3125/5000, Batches Processed: 479, Train Loss: 5525.2063, Val Loss: 5423.1237
# Starting epoch 3126/5000
# Epoch 3126, Batch 100/479, Loss: 5747.4751
# Epoch 3126, Batch 200/479, Loss: 5453.1304
# Epoch 3126, Batch 300/479, Loss: 5309.4067
# Epoch 3126, Batch 400/479, Loss: 5621.6655
# Epoch 3126/5000, Batches Processed: 479, Train Loss: 5520.7570, Val Loss: 5419.5092
# Starting epoch 3127/5000
# Epoch 3127, Batch 100/479, Loss: 5829.1919
# Epoch 3127, Batch 200/479, Loss: 4912.9604
# Epoch 3127, Batch 300/479, Loss: 5844.9692
# Epoch 3127, Batch 400/479, Loss: 6031.2715
# Epoch 3127/5000, Batches Processed: 479, Train Loss: 5520.3300, Val Loss: 5414.6300
# Starting epoch 3128/5000
# Epoch 3128, Batch 100/479, Loss: 5828.0464
# Epoch 3128, Batch 200/479, Loss: 5572.9741
# Epoch 3128, Batch 300/479, Loss: 5320.5088
# Epoch 3128, Batch 400/479, Loss: 5800.2305
# Epoch 3128/5000, Batches Processed: 479, Train Loss: 5514.0674, Val Loss: 5412.0016
# Starting epoch 3129/5000
# Epoch 3129, Batch 100/479, Loss: 5958.6997
# Epoch 3129, Batch 200/479, Loss: 6221.3276
# Epoch 3129, Batch 300/479, Loss: 6419.8970
# Epoch 3129, Batch 400/479, Loss: 5476.0923
# Epoch 3129/5000, Batches Processed: 479, Train Loss: 5510.7679, Val Loss: 5410.6315
# Starting epoch 3130/5000
# Epoch 3130, Batch 100/479, Loss: 5722.6270
# Epoch 3130, Batch 200/479, Loss: 5578.8315
# Epoch 3130, Batch 300/479, Loss: 3860.0627
# Epoch 3130, Batch 400/479, Loss: 7064.5918
# Epoch 3130/5000, Batches Processed: 479, Train Loss: 5505.9070, Val Loss: 5409.1096
# Starting epoch 3131/5000
# Epoch 3131, Batch 100/479, Loss: 5664.9141
# Epoch 3131, Batch 200/479, Loss: 5935.9917
# Epoch 3131, Batch 300/479, Loss: 5610.5449
# Epoch 3131, Batch 400/479, Loss: 5898.9614
# Epoch 3131/5000, Batches Processed: 479, Train Loss: 5502.7615, Val Loss: 5404.3501
# Starting epoch 3132/5000
# Epoch 3132, Batch 100/479, Loss: 5330.2075
# Epoch 3132, Batch 200/479, Loss: 5769.6562
# Epoch 3132, Batch 300/479, Loss: 6939.5156
# Epoch 3132, Batch 400/479, Loss: 5829.5771
# Epoch 3132/5000, Batches Processed: 479, Train Loss: 5500.4341, Val Loss: 5399.6604
# Starting epoch 3133/5000
# Epoch 3133, Batch 100/479, Loss: 6063.4277
# Epoch 3133, Batch 200/479, Loss: 6538.9482
# Epoch 3133, Batch 300/479, Loss: 5860.3750
# Epoch 3133, Batch 400/479, Loss: 5140.1177
# Epoch 3133/5000, Batches Processed: 479, Train Loss: 5493.9182, Val Loss: 5393.2138
# Starting epoch 3134/5000
# Epoch 3134, Batch 100/479, Loss: 5475.3140
# Epoch 3134, Batch 200/479, Loss: 4775.2344
# Epoch 3134, Batch 300/479, Loss: 6759.3208
# Epoch 3134, Batch 400/479, Loss: 5562.5752
# Epoch 3134/5000, Batches Processed: 479, Train Loss: 5490.4729, Val Loss: 5390.8232
# Starting epoch 3135/5000
# Epoch 3135, Batch 100/479, Loss: 4760.7349
# Epoch 3135, Batch 200/479, Loss: 6051.1567
# Epoch 3135, Batch 300/479, Loss: 5942.0547
# Epoch 3135, Batch 400/479, Loss: 5080.0000
# Epoch 3135/5000, Batches Processed: 479, Train Loss: 5485.5903, Val Loss: 5392.8786
# Starting epoch 3136/5000
# Epoch 3136, Batch 100/479, Loss: 5776.9009
# Epoch 3136, Batch 200/479, Loss: 5446.0122
# Epoch 3136, Batch 300/479, Loss: 5352.4561
# Epoch 3136, Batch 400/479, Loss: 4209.9829
# Epoch 3136/5000, Batches Processed: 479, Train Loss: 5480.0899, Val Loss: 5386.4232
# Starting epoch 3137/5000
# Epoch 3137, Batch 100/479, Loss: 5334.0415
# Epoch 3137, Batch 200/479, Loss: 6702.3354
# Epoch 3137, Batch 300/479, Loss: 5439.4165
# Epoch 3137, Batch 400/479, Loss: 6163.0933
# Epoch 3137/5000, Batches Processed: 479, Train Loss: 5481.0623, Val Loss: 5384.6396
# Starting epoch 3138/5000
# Epoch 3138, Batch 100/479, Loss: 5744.9468
# Epoch 3138, Batch 200/479, Loss: 6503.5527
# Epoch 3138, Batch 300/479, Loss: 6069.0679
# Epoch 3138, Batch 400/479, Loss: 5128.8359
# Epoch 3138/5000, Batches Processed: 479, Train Loss: 5474.3755, Val Loss: 5382.5656
# Starting epoch 3139/5000
# Epoch 3139, Batch 100/479, Loss: 6406.2793
# Epoch 3139, Batch 200/479, Loss: 5027.5396
# Epoch 3139, Batch 300/479, Loss: 5308.0068
# Epoch 3139, Batch 400/479, Loss: 5697.4858
# Epoch 3139/5000, Batches Processed: 479, Train Loss: 5473.8397, Val Loss: 5377.9874
# Starting epoch 3140/5000
# Epoch 3140, Batch 100/479, Loss: 4762.9004
# Epoch 3140, Batch 200/479, Loss: 5731.7236
# Epoch 3140, Batch 300/479, Loss: 5219.4448
# Epoch 3140, Batch 400/479, Loss: 5286.0400
# Epoch 3140/5000, Batches Processed: 479, Train Loss: 5467.4780, Val Loss: 5369.4475
# Starting epoch 3141/5000
# Epoch 3141, Batch 100/479, Loss: 4690.5327
# Epoch 3141, Batch 200/479, Loss: 4923.8477
# Epoch 3141, Batch 300/479, Loss: 7457.1372
# Epoch 3141, Batch 400/479, Loss: 5044.5986
# Epoch 3141/5000, Batches Processed: 479, Train Loss: 5467.6807, Val Loss: 5373.2606
# Starting epoch 3142/5000
# Epoch 3142, Batch 100/479, Loss: 6259.4014
# Epoch 3142, Batch 200/479, Loss: 5902.5649
# Epoch 3142, Batch 300/479, Loss: 4548.4795
# Epoch 3142, Batch 400/479, Loss: 5820.9443
# Epoch 3142/5000, Batches Processed: 479, Train Loss: 5459.5706, Val Loss: 5369.0716
# Starting epoch 3143/5000
# Epoch 3143, Batch 100/479, Loss: 5612.2080
# Epoch 3143, Batch 200/479, Loss: 4480.5068
# Epoch 3143, Batch 300/479, Loss: 6255.4614
# Epoch 3143, Batch 400/479, Loss: 5515.3530
# Epoch 3143/5000, Batches Processed: 479, Train Loss: 5455.9554, Val Loss: 5359.2765
# Starting epoch 3144/5000
# Epoch 3144, Batch 100/479, Loss: 5139.5664
# Epoch 3144, Batch 200/479, Loss: 5231.5522
# Epoch 3144, Batch 300/479, Loss: 4317.1162
# Epoch 3144, Batch 400/479, Loss: 5518.0356
# Epoch 3144/5000, Batches Processed: 479, Train Loss: 5454.2386, Val Loss: 5361.1075
# Starting epoch 3145/5000
# Epoch 3145, Batch 100/479, Loss: 5256.8047
# Epoch 3145, Batch 200/479, Loss: 5613.1406
# Epoch 3145, Batch 300/479, Loss: 4497.1328
# Epoch 3145, Batch 400/479, Loss: 4970.1079
# Epoch 3145/5000, Batches Processed: 479, Train Loss: 5450.8398, Val Loss: 5357.8484
# Starting epoch 3146/5000
# Epoch 3146, Batch 100/479, Loss: 5366.2832
# Epoch 3146, Batch 200/479, Loss: 5976.8677
# Epoch 3146, Batch 300/479, Loss: 5107.3213
# Epoch 3146, Batch 400/479, Loss: 5484.8203
# Epoch 3146/5000, Batches Processed: 479, Train Loss: 5447.5258, Val Loss: 5354.7632
# Starting epoch 3147/5000
# Epoch 3147, Batch 100/479, Loss: 5284.0459
# Epoch 3147, Batch 200/479, Loss: 4589.9736
# Epoch 3147, Batch 300/479, Loss: 5346.1353
# Epoch 3147, Batch 400/479, Loss: 4302.3765
# Epoch 3147/5000, Batches Processed: 479, Train Loss: 5445.2686, Val Loss: 5354.1041
# Starting epoch 3148/5000
# Epoch 3148, Batch 100/479, Loss: 5005.2778
# Epoch 3148, Batch 200/479, Loss: 6233.4370
# Epoch 3148, Batch 300/479, Loss: 4848.2715
# Epoch 3148, Batch 400/479, Loss: 6364.5752
# Epoch 3148/5000, Batches Processed: 479, Train Loss: 5441.0769, Val Loss: 5346.1067
# Starting epoch 3149/5000
# Epoch 3149, Batch 100/479, Loss: 5429.7876
# Epoch 3149, Batch 200/479, Loss: 6390.8271
# Epoch 3149, Batch 300/479, Loss: 4707.6611
# Epoch 3149, Batch 400/479, Loss: 4323.4541
# Epoch 3149/5000, Batches Processed: 479, Train Loss: 5434.3877, Val Loss: 5348.1458
# Starting epoch 3150/5000
# Epoch 3150, Batch 100/479, Loss: 4877.9756
# Epoch 3150, Batch 200/479, Loss: 5097.9604
# Epoch 3150, Batch 300/479, Loss: 4522.3701
# Epoch 3150, Batch 400/479, Loss: 5860.6387
# Epoch 3150/5000, Batches Processed: 479, Train Loss: 5433.3888, Val Loss: 5347.4934
# Starting epoch 3151/5000
# Epoch 3151, Batch 100/479, Loss: 6253.5864
# Epoch 3151, Batch 200/479, Loss: 5843.0684
# Epoch 3151, Batch 300/479, Loss: 5052.1611
# Epoch 3151, Batch 400/479, Loss: 6268.0210
# Epoch 3151/5000, Batches Processed: 479, Train Loss: 5430.6276, Val Loss: 5339.1322
# Starting epoch 3152/5000
# Epoch 3152, Batch 100/479, Loss: 6334.1880
# Epoch 3152, Batch 200/479, Loss: 5262.6030
# Epoch 3152, Batch 300/479, Loss: 5914.0522
# Epoch 3152, Batch 400/479, Loss: 5756.2563
# Epoch 3152/5000, Batches Processed: 479, Train Loss: 5425.0542, Val Loss: 5334.7092
# Starting epoch 3153/5000
# Epoch 3153, Batch 100/479, Loss: 4810.1240
# Epoch 3153, Batch 200/479, Loss: 4815.2910
# Epoch 3153, Batch 300/479, Loss: 5195.2861
# Epoch 3153, Batch 400/479, Loss: 4086.5095
# Epoch 3153/5000, Batches Processed: 479, Train Loss: 5422.4458, Val Loss: 5339.3227
# Starting epoch 3154/5000
# Epoch 3154, Batch 100/479, Loss: 5469.5137
# Epoch 3154, Batch 200/479, Loss: 6520.8813
# Epoch 3154, Batch 300/479, Loss: 4267.1699
# Epoch 3154, Batch 400/479, Loss: 4626.3940
# Epoch 3154/5000, Batches Processed: 479, Train Loss: 5419.5004, Val Loss: 5333.3256
# Starting epoch 3155/5000
# Epoch 3155, Batch 100/479, Loss: 5727.4839
# Epoch 3155, Batch 200/479, Loss: 5152.8613
# Epoch 3155, Batch 300/479, Loss: 5461.2593
# Epoch 3155, Batch 400/479, Loss: 4957.7769
# Epoch 3155/5000, Batches Processed: 479, Train Loss: 5419.3587, Val Loss: 5329.7972
# Starting epoch 3156/5000
# Epoch 3156, Batch 100/479, Loss: 5287.4126
# Epoch 3156, Batch 200/479, Loss: 5193.1289
# Epoch 3156, Batch 300/479, Loss: 4372.8921
# Epoch 3156, Batch 400/479, Loss: 5867.3262
# Epoch 3156/5000, Batches Processed: 479, Train Loss: 5412.1883, Val Loss: 5328.2680
# Starting epoch 3157/5000
# Epoch 3157, Batch 100/479, Loss: 6417.4766
# Epoch 3157, Batch 200/479, Loss: 4599.5908
# Epoch 3157, Batch 300/479, Loss: 6625.9917
# Epoch 3157, Batch 400/479, Loss: 5530.3188
# Epoch 3157/5000, Batches Processed: 479, Train Loss: 5412.0915, Val Loss: 5320.0763
# Starting epoch 3158/5000
# Epoch 3158, Batch 100/479, Loss: 4616.8896
# Epoch 3158, Batch 200/479, Loss: 5086.6328
# Epoch 3158, Batch 300/479, Loss: 5481.8794
# Epoch 3158, Batch 400/479, Loss: 5694.4287
# Epoch 3158/5000, Batches Processed: 479, Train Loss: 5405.6329, Val Loss: 5320.8368
# Starting epoch 3159/5000
# Epoch 3159, Batch 100/479, Loss: 5356.6865
# Epoch 3159, Batch 200/479, Loss: 5532.8052
# Epoch 3159, Batch 300/479, Loss: 6099.4229
# Epoch 3159, Batch 400/479, Loss: 4414.7681
# Epoch 3159/5000, Batches Processed: 479, Train Loss: 5406.2021, Val Loss: 5315.0538
# Starting epoch 3160/5000
# Epoch 3160, Batch 100/479, Loss: 5689.5444
# Epoch 3160, Batch 200/479, Loss: 4912.3921
# Epoch 3160, Batch 300/479, Loss: 6020.6348
# Epoch 3160, Batch 400/479, Loss: 5596.0479
# Epoch 3160/5000, Batches Processed: 479, Train Loss: 5399.0874, Val Loss: 5314.3744
# Starting epoch 3161/5000
# Epoch 3161, Batch 100/479, Loss: 6153.4966
# Epoch 3161, Batch 200/479, Loss: 7334.4912
# Epoch 3161, Batch 300/479, Loss: 6307.2969
# Epoch 3161, Batch 400/479, Loss: 5247.8623
# Epoch 3161/5000, Batches Processed: 479, Train Loss: 5396.8987, Val Loss: 5313.9752
# Starting epoch 3162/5000
# Epoch 3162, Batch 100/479, Loss: 5160.1348
# Epoch 3162, Batch 200/479, Loss: 6392.5884
# Epoch 3162, Batch 300/479, Loss: 5323.0366
# Epoch 3162, Batch 400/479, Loss: 4933.6987
# Epoch 3162/5000, Batches Processed: 479, Train Loss: 5394.6717, Val Loss: 5304.8816
# Starting epoch 3163/5000
# Epoch 3163, Batch 100/479, Loss: 4958.6143
# Epoch 3163, Batch 200/479, Loss: 5745.0581
# Epoch 3163, Batch 300/479, Loss: 4834.7900
# Epoch 3163, Batch 400/479, Loss: 4778.8052
# Epoch 3163/5000, Batches Processed: 479, Train Loss: 5394.6379, Val Loss: 5305.3726
# Starting epoch 3164/5000
# Epoch 3164, Batch 100/479, Loss: 4805.0298
# Epoch 3164, Batch 200/479, Loss: 5231.7456
# Epoch 3164, Batch 300/479, Loss: 4912.6450
# Epoch 3164, Batch 400/479, Loss: 6098.0938
# ...
# Epoch 4944, Batch 300/479, Loss: 3611.0928
# Epoch 4944, Batch 400/479, Loss: 3847.8833
# Epoch 4944/5000, Batches Processed: 479, Train Loss: 4229.1309, Val Loss: 4358.1370
# Starting epoch 4945/5000
# Epoch 4945, Batch 100/479, Loss: 4051.7822
# Epoch 4945, Batch 200/479, Loss: 4600.7930
# Epoch 4945, Batch 300/479, Loss: 3917.2280
# Epoch 4945, Batch 400/479, Loss: 3973.0320
# Epoch 4945/5000, Batches Processed: 479, Train Loss: 4225.8369, Val Loss: 4354.2525
# Starting epoch 4946/5000
# Epoch 4946, Batch 100/479, Loss: 4152.9893
# Epoch 4946, Batch 200/479, Loss: 3949.1189
# Epoch 4946, Batch 300/479, Loss: 4969.0488
# Epoch 4946, Batch 400/479, Loss: 4481.1602
# Epoch 4946/5000, Batches Processed: 479, Train Loss: 4227.2843, Val Loss: 4357.4027
# Starting epoch 4947/5000
# Epoch 4947, Batch 100/479, Loss: 4706.4736
# Epoch 4947, Batch 200/479, Loss: 3720.4360
# Epoch 4947, Batch 300/479, Loss: 4472.1045
# Epoch 4947, Batch 400/479, Loss: 4522.7451
# Epoch 4947/5000, Batches Processed: 479, Train Loss: 4230.7518, Val Loss: 4354.7406
# Starting epoch 4948/5000
# Epoch 4948, Batch 100/479, Loss: 3763.6792
# Epoch 4948, Batch 200/479, Loss: 4341.8682
# Epoch 4948, Batch 300/479, Loss: 4473.7505
# Epoch 4948, Batch 400/479, Loss: 4962.7397
# Epoch 4948/5000, Batches Processed: 479, Train Loss: 4229.8796, Val Loss: 4357.7080
# Starting epoch 4949/5000
# Epoch 4949, Batch 100/479, Loss: 4814.1812
# Epoch 4949, Batch 200/479, Loss: 3978.7620
# Epoch 4949, Batch 300/479, Loss: 3842.7402
# Epoch 4949, Batch 400/479, Loss: 4604.3442
# Epoch 4949/5000, Batches Processed: 479, Train Loss: 4231.9767, Val Loss: 4358.6290
# Starting epoch 4950/5000
# Epoch 4950, Batch 100/479, Loss: 4240.9727
# Epoch 4950, Batch 200/479, Loss: 4388.1299
# Epoch 4950, Batch 300/479, Loss: 4258.9326
# Epoch 4950, Batch 400/479, Loss: 4803.6538
# Epoch 4950/5000, Batches Processed: 479, Train Loss: 4226.3982, Val Loss: 4354.6435
# Starting epoch 4951/5000
# Epoch 4951, Batch 100/479, Loss: 4590.2964
# Epoch 4951, Batch 200/479, Loss: 4306.2593
# Epoch 4951, Batch 300/479, Loss: 5734.8755
# Epoch 4951, Batch 400/479, Loss: 4982.3696
# Epoch 4951/5000, Batches Processed: 479, Train Loss: 4228.6747, Val Loss: 4355.5866
# Starting epoch 4952/5000
# Epoch 4952, Batch 100/479, Loss: 4661.3130
# Epoch 4952, Batch 200/479, Loss: 4205.2188
# Epoch 4952, Batch 300/479, Loss: 4581.2168
# Epoch 4952, Batch 400/479, Loss: 4226.3677
# Epoch 4952/5000, Batches Processed: 479, Train Loss: 4226.4460, Val Loss: 4363.5744
# Starting epoch 4953/5000
# Epoch 4953, Batch 100/479, Loss: 4027.8652
# Epoch 4953, Batch 200/479, Loss: 4473.7026
# Epoch 4953, Batch 300/479, Loss: 4240.6094
# Epoch 4953, Batch 400/479, Loss: 4880.8916
# Epoch 4953/5000, Batches Processed: 479, Train Loss: 4225.8327, Val Loss: 4356.0138
# Starting epoch 4954/5000
# Epoch 4954, Batch 100/479, Loss: 3857.0427
# Epoch 4954, Batch 200/479, Loss: 4109.2847
# Epoch 4954, Batch 300/479, Loss: 4456.3164
# Epoch 4954, Batch 400/479, Loss: 3680.4824
# Epoch 4954/5000, Batches Processed: 479, Train Loss: 4228.6894, Val Loss: 4355.2049
# Starting epoch 4955/5000
# Epoch 4955, Batch 100/479, Loss: 4734.9111
# Epoch 4955, Batch 200/479, Loss: 4802.3086
# Epoch 4955, Batch 300/479, Loss: 4101.3125
# Epoch 4955, Batch 400/479, Loss: 5108.4800
# Epoch 4955/5000, Batches Processed: 479, Train Loss: 4228.0008, Val Loss: 4351.7336
# Starting epoch 4956/5000
# Epoch 4956, Batch 100/479, Loss: 4217.8896
# Epoch 4956, Batch 200/479, Loss: 4535.0903
# Epoch 4956, Batch 300/479, Loss: 4070.6208
# Epoch 4956, Batch 400/479, Loss: 4725.5391
# Epoch 4956/5000, Batches Processed: 479, Train Loss: 4226.9946, Val Loss: 4357.7248
# Starting epoch 4957/5000
# Epoch 4957, Batch 100/479, Loss: 4201.0479
# Epoch 4957, Batch 200/479, Loss: 3608.1030
# Epoch 4957, Batch 300/479, Loss: 3868.3479
# Epoch 4957, Batch 400/479, Loss: 4572.8760
# Epoch 4957/5000, Batches Processed: 479, Train Loss: 4227.5923, Val Loss: 4354.2834
# Starting epoch 4958/5000
# Epoch 4958, Batch 100/479, Loss: 4435.1924
# Epoch 4958, Batch 200/479, Loss: 5731.4121
# Epoch 4958, Batch 300/479, Loss: 4591.7065
# Epoch 4958, Batch 400/479, Loss: 4357.0596
# Epoch 4958/5000, Batches Processed: 479, Train Loss: 4227.3127, Val Loss: 4360.6633
# Starting epoch 4959/5000
# Epoch 4959, Batch 100/479, Loss: 4559.2412
# Epoch 4959, Batch 200/479, Loss: 4437.3359
# Epoch 4959, Batch 300/479, Loss: 4727.0615
# Epoch 4959, Batch 400/479, Loss: 3435.8235
# Epoch 4959/5000, Batches Processed: 479, Train Loss: 4227.3102, Val Loss: 4352.4517
# Starting epoch 4960/5000
# Epoch 4960, Batch 100/479, Loss: 5213.7876
# Epoch 4960, Batch 200/479, Loss: 4094.9080
# Epoch 4960, Batch 300/479, Loss: 5039.4429
# Epoch 4960, Batch 400/479, Loss: 4647.7681
# Epoch 4960/5000, Batches Processed: 479, Train Loss: 4227.5761, Val Loss: 4351.2116
# Starting epoch 4961/5000
# Epoch 4961, Batch 100/479, Loss: 4103.5054
# Epoch 4961, Batch 200/479, Loss: 4257.5342
# Epoch 4961, Batch 300/479, Loss: 4327.8911
# Epoch 4961, Batch 400/479, Loss: 4380.0210
# Epoch 4961/5000, Batches Processed: 479, Train Loss: 4227.1133, Val Loss: 4353.1729
# Starting epoch 4962/5000
# Epoch 4962, Batch 100/479, Loss: 4942.1372
# Epoch 4962, Batch 200/479, Loss: 4070.6689
# Epoch 4962, Batch 300/479, Loss: 3948.6377
# Epoch 4962, Batch 400/479, Loss: 4447.6377
# Epoch 4962/5000, Batches Processed: 479, Train Loss: 4225.4781, Val Loss: 4355.1433
# Starting epoch 4963/5000
# Epoch 4963, Batch 100/479, Loss: 3579.1633
# Epoch 4963, Batch 200/479, Loss: 3527.3203
# Epoch 4963, Batch 300/479, Loss: 4009.2495
# Epoch 4963, Batch 400/479, Loss: 3805.0447
# Epoch 4963/5000, Batches Processed: 479, Train Loss: 4226.5346, Val Loss: 4349.3465
# Starting epoch 4964/5000
# Epoch 4964, Batch 100/479, Loss: 4090.8093
# Epoch 4964, Batch 200/479, Loss: 4349.8833
# Epoch 4964, Batch 300/479, Loss: 4828.1753
# Epoch 4964, Batch 400/479, Loss: 5382.7749
# Epoch 4964/5000, Batches Processed: 479, Train Loss: 4226.0127, Val Loss: 4348.9802
# Starting epoch 4965/5000
# Epoch 4965, Batch 100/479, Loss: 3445.9360
# Epoch 4965, Batch 200/479, Loss: 3394.9712
# Epoch 4965, Batch 300/479, Loss: 4081.1375
# Epoch 4965, Batch 400/479, Loss: 4105.7529
# Epoch 4965/5000, Batches Processed: 479, Train Loss: 4226.2845, Val Loss: 4351.6439
# Starting epoch 4966/5000
# Epoch 4966, Batch 100/479, Loss: 4761.7524
# Epoch 4966, Batch 200/479, Loss: 4289.5981
# Epoch 4966, Batch 300/479, Loss: 4477.0020
# Epoch 4966, Batch 400/479, Loss: 4049.5918
# Epoch 4966/5000, Batches Processed: 479, Train Loss: 4223.9637, Val Loss: 4354.2364
# Starting epoch 4967/5000
# Epoch 4967, Batch 100/479, Loss: 4123.8784
# Epoch 4967, Batch 200/479, Loss: 4101.9321
# Epoch 4967, Batch 300/479, Loss: 4016.7910
# Epoch 4967, Batch 400/479, Loss: 4580.2642
# Epoch 4967/5000, Batches Processed: 479, Train Loss: 4224.8064, Val Loss: 4355.8287
# Starting epoch 4968/5000
# Epoch 4968, Batch 100/479, Loss: 4801.6187
# Epoch 4968, Batch 200/479, Loss: 4456.1655
# Epoch 4968, Batch 300/479, Loss: 4271.5269
# Epoch 4968, Batch 400/479, Loss: 4358.3828
# Epoch 4968/5000, Batches Processed: 479, Train Loss: 4225.7249, Val Loss: 4358.0418
# Starting epoch 4969/5000
# Epoch 4969, Batch 100/479, Loss: 4207.1616
# Epoch 4969, Batch 200/479, Loss: 4041.2981
# Epoch 4969, Batch 300/479, Loss: 5254.4487
# Epoch 4969, Batch 400/479, Loss: 3897.5635
# Epoch 4969/5000, Batches Processed: 479, Train Loss: 4225.4608, Val Loss: 4353.8474
# Starting epoch 4970/5000
# Epoch 4970, Batch 100/479, Loss: 4092.2664
# Epoch 4970, Batch 200/479, Loss: 4452.7930
# Epoch 4970, Batch 300/479, Loss: 4653.7881
# Epoch 4970, Batch 400/479, Loss: 3989.5354
# Epoch 4970/5000, Batches Processed: 479, Train Loss: 4228.3024, Val Loss: 4351.6075
# Starting epoch 4971/5000
# Epoch 4971, Batch 100/479, Loss: 4175.5786
# Epoch 4971, Batch 200/479, Loss: 4724.1958
# Epoch 4971, Batch 300/479, Loss: 4277.9727
# Epoch 4971, Batch 400/479, Loss: 4168.7129
# Epoch 4971/5000, Batches Processed: 479, Train Loss: 4227.8526, Val Loss: 4344.5488
# Starting epoch 4972/5000
# Epoch 4972, Batch 100/479, Loss: 3944.9102
# Epoch 4972, Batch 200/479, Loss: 4307.5698
# Epoch 4972, Batch 300/479, Loss: 4815.6431
# Epoch 4972, Batch 400/479, Loss: 3992.2695
# Epoch 4972/5000, Batches Processed: 479, Train Loss: 4228.9320, Val Loss: 4354.3258
# Starting epoch 4973/5000
# Epoch 4973, Batch 100/479, Loss: 4553.1831
# Epoch 4973, Batch 200/479, Loss: 4134.6118
# Epoch 4973, Batch 300/479, Loss: 3876.2959
# Epoch 4973, Batch 400/479, Loss: 3621.4246
# Epoch 4973/5000, Batches Processed: 479, Train Loss: 4225.3920, Val Loss: 4355.1515
# Starting epoch 4974/5000
# Epoch 4974, Batch 100/479, Loss: 3809.2834
# Epoch 4974, Batch 200/479, Loss: 4135.9507
# Epoch 4974, Batch 300/479, Loss: 4666.6064
# Epoch 4974, Batch 400/479, Loss: 4503.7109
# Epoch 4974/5000, Batches Processed: 479, Train Loss: 4226.3775, Val Loss: 4348.9827
# Starting epoch 4975/5000
# Epoch 4975, Batch 100/479, Loss: 4456.1118
# Epoch 4975, Batch 200/479, Loss: 3983.0906
# Epoch 4975, Batch 300/479, Loss: 3957.8542
# Epoch 4975, Batch 400/479, Loss: 4604.8477
# Epoch 4975/5000, Batches Processed: 479, Train Loss: 4225.2671, Val Loss: 4352.5662
# Starting epoch 4976/5000
# Epoch 4976, Batch 100/479, Loss: 3960.1626
# Epoch 4976, Batch 200/479, Loss: 4633.7109
# Epoch 4976, Batch 300/479, Loss: 5265.7314
# Epoch 4976, Batch 400/479, Loss: 3825.5203
# Epoch 4976/5000, Batches Processed: 479, Train Loss: 4225.0830, Val Loss: 4353.0537
# Starting epoch 4977/5000
# Epoch 4977, Batch 100/479, Loss: 4320.2202
# Epoch 4977, Batch 200/479, Loss: 3320.3267
# Epoch 4977, Batch 300/479, Loss: 4492.7827
# Epoch 4977, Batch 400/479, Loss: 3999.6284
# Epoch 4977/5000, Batches Processed: 479, Train Loss: 4225.9194, Val Loss: 4350.5960
# Starting epoch 4978/5000
# Epoch 4978, Batch 100/479, Loss: 4135.7529
# Epoch 4978, Batch 200/479, Loss: 4161.3032
# Epoch 4978, Batch 300/479, Loss: 4601.5674
# Epoch 4978, Batch 400/479, Loss: 4346.6831
# Epoch 4978/5000, Batches Processed: 479, Train Loss: 4225.3212, Val Loss: 4352.6926
# Starting epoch 4979/5000
# Epoch 4979, Batch 100/479, Loss: 4869.3818
# Epoch 4979, Batch 200/479, Loss: 4148.5728
# Epoch 4979, Batch 300/479, Loss: 3988.1453
# Epoch 4979, Batch 400/479, Loss: 4653.0898
# Epoch 4979/5000, Batches Processed: 479, Train Loss: 4227.6089, Val Loss: 4351.1399
# Starting epoch 4980/5000
# Epoch 4980, Batch 100/479, Loss: 3574.9653
# Epoch 4980, Batch 200/479, Loss: 4036.9292
# Epoch 4980, Batch 300/479, Loss: 3866.4561
# Epoch 4980, Batch 400/479, Loss: 2957.4670
# Epoch 4980/5000, Batches Processed: 479, Train Loss: 4225.1542, Val Loss: 4352.5805
# Starting epoch 4981/5000
# Epoch 4981, Batch 100/479, Loss: 3617.5444
# Epoch 4981, Batch 200/479, Loss: 3684.1541
# Epoch 4981, Batch 300/479, Loss: 4368.0649
# Epoch 4981, Batch 400/479, Loss: 4650.0747
# Epoch 4981/5000, Batches Processed: 479, Train Loss: 4225.5280, Val Loss: 4355.7014
# Starting epoch 4982/5000
# Epoch 4982, Batch 100/479, Loss: 5063.1543
# Epoch 4982, Batch 200/479, Loss: 4040.6567
# Epoch 4982, Batch 300/479, Loss: 3557.6265
# Epoch 4982, Batch 400/479, Loss: 4694.7881
# Epoch 4982/5000, Batches Processed: 479, Train Loss: 4225.8660, Val Loss: 4352.5636
# Starting epoch 4983/5000
# Epoch 4983, Batch 100/479, Loss: 5856.8916
# Epoch 4983, Batch 200/479, Loss: 5095.7993
# Epoch 4983, Batch 300/479, Loss: 4421.0244
# Epoch 4983, Batch 400/479, Loss: 3885.2305
# Epoch 4983/5000, Batches Processed: 479, Train Loss: 4223.7653, Val Loss: 4349.9003
# Starting epoch 4984/5000
# Epoch 4984, Batch 100/479, Loss: 3588.8220
# Epoch 4984, Batch 200/479, Loss: 3579.3901
# Epoch 4984, Batch 300/479, Loss: 4124.4937
# Epoch 4984, Batch 400/479, Loss: 4328.5547
# Epoch 4984/5000, Batches Processed: 479, Train Loss: 4224.7676, Val Loss: 4354.2708
# Starting epoch 4985/5000
# Epoch 4985, Batch 100/479, Loss: 4433.3926
# Epoch 4985, Batch 200/479, Loss: 3654.7615
# Epoch 4985, Batch 300/479, Loss: 4435.6357
# Epoch 4985, Batch 400/479, Loss: 3540.6499
# Epoch 4985/5000, Batches Processed: 479, Train Loss: 4225.7280, Val Loss: 4356.0858
# Starting epoch 4986/5000
# Epoch 4986, Batch 100/479, Loss: 3848.3835
# Epoch 4986, Batch 200/479, Loss: 4008.3411
# Epoch 4986, Batch 300/479, Loss: 3876.1995
# Epoch 4986, Batch 400/479, Loss: 4432.7637
# Epoch 4986/5000, Batches Processed: 479, Train Loss: 4223.1648, Val Loss: 4351.3415
# Starting epoch 4987/5000
# Epoch 4987, Batch 100/479, Loss: 3708.1304
# Epoch 4987, Batch 200/479, Loss: 4796.7656
# Epoch 4987, Batch 300/479, Loss: 3956.1687
# Epoch 4987, Batch 400/479, Loss: 3230.6270
# Epoch 4987/5000, Batches Processed: 479, Train Loss: 4224.9266, Val Loss: 4353.4504
# Starting epoch 4988/5000
# Epoch 4988, Batch 100/479, Loss: 4133.3027
# Epoch 4988, Batch 200/479, Loss: 3748.4397
# Epoch 4988, Batch 300/479, Loss: 4211.8550
# Epoch 4988, Batch 400/479, Loss: 3833.4941
# Epoch 4988/5000, Batches Processed: 479, Train Loss: 4221.3876, Val Loss: 4344.1055
# Starting epoch 4989/5000
# Epoch 4989, Batch 100/479, Loss: 4865.2344
# Epoch 4989, Batch 200/479, Loss: 3909.9124
# Epoch 4989, Batch 300/479, Loss: 3737.3220
# Epoch 4989, Batch 400/479, Loss: 3822.1746
# Epoch 4989/5000, Batches Processed: 479, Train Loss: 4223.6447, Val Loss: 4358.4028
# Starting epoch 4990/5000
# Epoch 4990, Batch 100/479, Loss: 3450.4160
# Epoch 4990, Batch 200/479, Loss: 4360.4780
# Epoch 4990, Batch 300/479, Loss: 4145.6987
# Epoch 4990, Batch 400/479, Loss: 4538.1152
# Epoch 4990/5000, Batches Processed: 479, Train Loss: 4223.9429, Val Loss: 4353.2023
# Starting epoch 4991/5000
# Epoch 4991, Batch 100/479, Loss: 4326.2314
# Epoch 4991, Batch 200/479, Loss: 3857.8955
# Epoch 4991, Batch 300/479, Loss: 3318.1494
# Epoch 4991, Batch 400/479, Loss: 4221.1333
# Epoch 4991/5000, Batches Processed: 479, Train Loss: 4222.8581, Val Loss: 4347.7296
# Starting epoch 4992/5000
# Epoch 4992, Batch 100/479, Loss: 4257.9385
# Epoch 4992, Batch 200/479, Loss: 4778.8481
# Epoch 4992, Batch 300/479, Loss: 4312.2700
# Epoch 4992, Batch 400/479, Loss: 4547.1177
# Epoch 4992/5000, Batches Processed: 479, Train Loss: 4223.9129, Val Loss: 4348.3598
# Starting epoch 4993/5000
# Epoch 4993, Batch 100/479, Loss: 3781.2751
# Epoch 4993, Batch 200/479, Loss: 4275.2476
# Epoch 4993, Batch 300/479, Loss: 3545.8386
# Epoch 4993, Batch 400/479, Loss: 4763.6152
# Epoch 4993/5000, Batches Processed: 479, Train Loss: 4224.9048, Val Loss: 4350.9593
# Starting epoch 4994/5000
# Epoch 4994, Batch 100/479, Loss: 3993.2700
# Epoch 4994, Batch 200/479, Loss: 4867.0518
# Epoch 4994, Batch 300/479, Loss: 5853.4341
# Epoch 4994, Batch 400/479, Loss: 4189.3818
# Epoch 4994/5000, Batches Processed: 479, Train Loss: 4224.5549, Val Loss: 4352.4330
# Starting epoch 4995/5000
# Epoch 4995, Batch 100/479, Loss: 4005.6165
# Epoch 4995, Batch 200/479, Loss: 4359.8560
# Epoch 4995, Batch 300/479, Loss: 3940.9568
# Epoch 4995, Batch 400/479, Loss: 3916.1226
# Epoch 4995/5000, Batches Processed: 479, Train Loss: 4224.2036, Val Loss: 4347.0339
# Starting epoch 4996/5000
# Epoch 4996, Batch 100/479, Loss: 4431.6885
# Epoch 4996, Batch 200/479, Loss: 3845.9861
# Epoch 4996, Batch 300/479, Loss: 4141.3569
# Epoch 4996, Batch 400/479, Loss: 4084.8899
# Epoch 4996/5000, Batches Processed: 479, Train Loss: 4224.0247, Val Loss: 4357.6241
# Starting epoch 4997/5000
# Epoch 4997, Batch 100/479, Loss: 5063.3726
# Epoch 4997, Batch 200/479, Loss: 4736.6177
# Epoch 4997, Batch 300/479, Loss: 3588.5906
# Epoch 4997, Batch 400/479, Loss: 4122.9272
# Epoch 4997/5000, Batches Processed: 479, Train Loss: 4222.9321, Val Loss: 4348.0974
# Starting epoch 4998/5000
# Epoch 4998, Batch 100/479, Loss: 4160.0542
# Epoch 4998, Batch 200/479, Loss: 4529.0674
# Epoch 4998, Batch 300/479, Loss: 3745.7402
# Epoch 4998, Batch 400/479, Loss: 3372.8193
# Epoch 4998/5000, Batches Processed: 479, Train Loss: 4223.3983, Val Loss: 4354.4603
# Starting epoch 4999/5000
# Epoch 4999, Batch 100/479, Loss: 4340.6392
# Epoch 4999, Batch 200/479, Loss: 4065.5742
# Epoch 4999, Batch 300/479, Loss: 4354.4351
# Epoch 4999, Batch 400/479, Loss: 4154.7690
# Epoch 4999/5000, Batches Processed: 479, Train Loss: 4222.9542, Val Loss: 4351.3944
# Starting epoch 5000/5000
# Epoch 5000, Batch 100/479, Loss: 4234.0112
# Epoch 5000, Batch 200/479, Loss: 4108.4648
# Epoch 5000, Batch 300/479, Loss: 4570.4009
# Epoch 5000, Batch 400/479, Loss: 3763.7312
# Epoch 5000/5000, Batches Processed: 479, Train Loss: 4222.1865, Val Loss: 4349.0641
# Saved final CVAE model to cvae_vehicle_final_epoch5000.pth
# Finished generating samples
